# %%
import os
import re
from pymongo import MongoClient
from dotenv import load_dotenv
from pprint import pprint
from tqdm.notebook import tqdm

# %%
# Load env variables from local/.env
load_dotenv("local/.env")
# Out:
# True

# %%
# Fetch credentials
MONGO_USERNAME = os.getenv("MONGO_NCBI_LOADBALANCER_WRITING_USERNAME")
MONGO_PASSWORD = os.getenv("MONGO_NCBI_LOADBALANCER_WRITING_PW")

# %%
MONGO_USERNAME
# Out:
# 'mam-ncbi'

# %%
MONGO_PASSWORD
# Out:
# 'carve_uninsured_rocking_293'

# %%
# === MongoDB Connection Settings (variable-based) ===
MONGO_HOST = "localhost"   # e.g., "localhost" or "mongo.ncbi.example.org"
MONGO_PORT = 27777               # default MongoDB port

# %%
# Optional authentication options
AUTH_SOURCE = "admin"
AUTH_MECHANISM = "SCRAM-SHA-256"
EXTRA_PARAMS = "directConnection=true"

# %%
# Optional database/collection names as variables
DB_NAME = "ncbi_metadata"
COLLECTION_NAME = "biosamples_env_triad_value_counts_gt_1"

# %%
# Build the URI
mongo_uri = (
    f"mongodb://{MONGO_USERNAME}:{MONGO_PASSWORD}"
    f"@{MONGO_HOST}:{MONGO_PORT}/"
    f"?authSource={AUTH_SOURCE}&authMechanism={AUTH_MECHANISM}&{EXTRA_PARAMS}"
)

# %%
# Connect
client = MongoClient(mongo_uri)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

# %%
strict_curie_pattern = re.compile(
    r"""
    (?P<raw>
        (?P<label>.*?)?                           # optional label
        [\[\(]?\s*                                 # optional open bracket
        \b                                         # word boundary before prefix
        (?P<prefix>[A-Z][A-Z0-9]+)                 # prefix (upper-case)
        [:_]                                       # colon or underscore ONLY (no hyphen/space)
        (?P<local>[A-Za-z0-9]{2,})                 # local ID
        \s*[\]\)]?                                 # optional close bracket
    )
    """,
    re.VERBOSE
)

# %%
def extract_components(text):
    if not isinstance(text, str):
        return []

    components = []
    annotations = text.split('|')

    for ann in annotations:
        matches = list(strict_curie_pattern.finditer(ann))
        if matches:
            for m in matches:
                label = m.group('label')
                if label:
                    label = label.strip().lstrip(',;')
                components.append({
                    'raw': m.group('raw').strip(),
                    'label': label if label else None,
                    'prefix': m.group('prefix').upper().strip(),
                    'local': m.group('local').strip()
                })
        else:
            components.append({
                'raw': ann.strip(),
                'label': ann.strip(),
                'prefix': None,
                'local': None
            })

    return components

# %%
# Fetch one document from the collection
sample_doc = collection.find_one()

# %%
# Pretty-print the result (in Jupyter)
pprint(sample_doc)
# Out:
# {'_id': ObjectId('67e1b8661418ebf728b73a5b'),
#  'count': 1205691,
#  'digits_only': False,
#  'env_triad_value': 'not applicable',
#  'envo_count': 0.0,
#  'equation_like': False,
#  'insdc_missing_match': True,
#  'length': 14}

# %%
docs = list(collection.find({"env_triad_value": {"$exists": True}}))

for doc in tqdm(docs, desc="Parsing and updating"):
    value = doc["env_triad_value"]
    parsed = extract_components(value)

    collection.update_one(
        {"_id": doc["_id"]},
        {
            "$set": {
                "components": parsed,
                "components_count": len(parsed)
            }
        }
    )

# %%
# Remove both fields from all documents
pattern = {
    "$unset": {
        "components": "",
        "components_count": ""
    }
}

# %%
# Remove both fields from all documents
result = collection.update_many({}, pattern)

# %%
# Show how many documents were modified
print(f"Modified {result.modified_count} documents.")
# Out:
# Modified 66177 documents.

# %% [markdown]
# ---

# %%
from oaklib import get_adapter

# %%
envo_adapter_string  = "sqlite:obo:envo"

# %%
envo_adapter = get_adapter(envo_adapter_string)

# %%
all_envo_curies_and_iris = list(envo_adapter.entities())

# %%
all_envo_curies_and_iris
# Out:
# ['<http://geneontology.org/foo/applies-pattern>',
#  '<http://schema.org/image>',
#  '<https://www.wikidata.org/wiki/Q2306597>',
#  '<https://www.wikidata.org/wiki/Q2>',
#  '<https://www.wikidata.org/wiki/Q525>',
#  '<https://www.wikidata.org/wiki/Q715269>',
#  'BFO:0000001',
#  'BFO:0000002',
#  'BFO:0000003',
#  'BFO:0000004',
#  'BFO:0000006',
#  'BFO:0000008',
#  'BFO:0000011',
#  'BFO:0000015',
#  'BFO:0000016',
#  'BFO:0000017',
#  'BFO:0000019',
#  'BFO:0000020',
#  'BFO:0000023',
#  'BFO:0000024',
#  'BFO:0000027',
#  'BFO:0000029',
#  'BFO:0000030',
#  'BFO:0000031',
#  'BFO:0000034',
#  'BFO:0000035',
#  'BFO:0000038',
#  'BFO:0000040',
#  'BFO:0000050',
#  'BFO:0000051',
#  'BFO:0000054',
#  'BFO:0000055',
#  'BFO:0000062',
#  'BFO:0000063',
#  'BFO:0000066',
#  'BFO:0000067',
#  'BFO:0000140',
#  'BFO:0000141',
#  'BFO:0000142',
#  'BFO:0000146',
#  'CHEBI:10545',
#  'CHEBI:131621',
#  'CHEBI:131927',
#  'CHEBI:133331',
#  'CHEBI:13389',
#  'CHEBI:13392',
#  'CHEBI:134024',
#  'CHEBI:134179',
#  'CHEBI:134438',
#  'CHEBI:13643',
#  'CHEBI:137980',
#  'CHEBI:138675',
#  'CHEBI:139120',
#  'CHEBI:139291',
#  'CHEBI:139292',
#  'CHEBI:140503',
#  'CHEBI:15022',
#  'CHEBI:15339',
#  'CHEBI:15368',
#  'CHEBI:15377',
#  'CHEBI:15378',
#  'CHEBI:15379',
#  'CHEBI:15422',
#  'CHEBI:155827',
#  'CHEBI:155903',
#  'CHEBI:155908',
#  'CHEBI:15611',
#  'CHEBI:15734',
#  'CHEBI:15996',
#  'CHEBI:16042',
#  'CHEBI:16134',
#  'CHEBI:16136',
#  'CHEBI:16183',
#  'CHEBI:16189',
#  'CHEBI:16199',
#  'CHEBI:16234',
#  'CHEBI:16236',
#  'CHEBI:16240',
#  'CHEBI:16261',
#  'CHEBI:16301',
#  'CHEBI:16336',
#  'CHEBI:16454',
#  'CHEBI:16474',
#  'CHEBI:16482',
#  'CHEBI:16526',
#  'CHEBI:16646',
#  'CHEBI:16670',
#  'CHEBI:166975',
#  'CHEBI:16701',
#  'CHEBI:16716',
#  'CHEBI:167164',
#  'CHEBI:167559',
#  'CHEBI:16842',
#  'CHEBI:16900',
#  'CHEBI:16908',
#  'CHEBI:16966',
#  'CHEBI:16997',
#  'CHEBI:17029',
#  'CHEBI:17045',
#  'CHEBI:17051',
#  'CHEBI:17087',
#  'CHEBI:17245',
#  'CHEBI:17326',
#  'CHEBI:17347',
#  'CHEBI:17478',
#  'CHEBI:17544',
#  'CHEBI:17548',
#  'CHEBI:17578',
#  'CHEBI:17579',
#  'CHEBI:17632',
#  'CHEBI:17654',
#  'CHEBI:17790',
#  'CHEBI:17792',
#  'CHEBI:17883',
#  'CHEBI:17891',
#  'CHEBI:17972',
#  'CHEBI:17996',
#  'CHEBI:17997',
#  'CHEBI:18059',
#  'CHEBI:18085',
#  'CHEBI:18139',
#  'CHEBI:18140',
#  'CHEBI:18154',
#  'CHEBI:18230',
#  'CHEBI:18246',
#  'CHEBI:18248',
#  'CHEBI:18276',
#  'CHEBI:18291',
#  'CHEBI:18310',
#  'CHEBI:18367',
#  'CHEBI:18407',
#  'CHEBI:18422',
#  'CHEBI:190295',
#  'CHEBI:21638',
#  'CHEBI:21656',
#  'CHEBI:21760',
#  'CHEBI:21766',
#  'CHEBI:22160',
#  'CHEBI:22256',
#  'CHEBI:22313',
#  'CHEBI:22314',
#  'CHEBI:22323',
#  'CHEBI:22331',
#  'CHEBI:22506',
#  'CHEBI:22563',
#  'CHEBI:22629',
#  'CHEBI:22632',
#  'CHEBI:22695',
#  'CHEBI:22712',
#  'CHEBI:22718',
#  'CHEBI:22728',
#  'CHEBI:22918',
#  'CHEBI:22927',
#  'CHEBI:22977',
#  'CHEBI:22984',
#  'CHEBI:22985',
#  'CHEBI:23014',
#  'CHEBI:23016',
#  'CHEBI:23042',
#  'CHEBI:23043',
#  'CHEBI:23044',
#  'CHEBI:23045',
#  'CHEBI:23114',
#  'CHEBI:23116',
#  'CHEBI:23117',
#  'CHEBI:23237',
#  'CHEBI:23367',
#  'CHEBI:23377',
#  'CHEBI:23449',
#  'CHEBI:23824',
#  'CHEBI:23888',
#  'CHEBI:23905',
#  'CHEBI:23906',
#  'CHEBI:23924',
#  'CHEBI:23982',
#  'CHEBI:24061',
#  'CHEBI:24062',
#  'CHEBI:24271',
#  'CHEBI:24373',
#  'CHEBI:24431',
#  'CHEBI:24432',
#  'CHEBI:24433',
#  'CHEBI:24455',
#  'CHEBI:24471',
#  'CHEBI:24473',
#  'CHEBI:24532',
#  'CHEBI:24533',
#  'CHEBI:24586',
#  'CHEBI:24632',
#  'CHEBI:24636',
#  'CHEBI:24651',
#  'CHEBI:24675',
#  'CHEBI:24828',
#  'CHEBI:24833',
#  'CHEBI:24834',
#  'CHEBI:24835',
#  'CHEBI:24836',
#  'CHEBI:24837',
#  'CHEBI:24839',
#  'CHEBI:24840',
#  'CHEBI:24866',
#  'CHEBI:24867',
#  'CHEBI:24870',
#  'CHEBI:24873',
#  'CHEBI:24913',
#  'CHEBI:25016',
#  'CHEBI:25017',
#  'CHEBI:25107',
#  'CHEBI:25108',
#  'CHEBI:25111',
#  'CHEBI:25154',
#  'CHEBI:25212',
#  'CHEBI:25213',
#  'CHEBI:25216',
#  'CHEBI:25248',
#  'CHEBI:25274',
#  'CHEBI:25355',
#  'CHEBI:25362',
#  'CHEBI:25367',
#  'CHEBI:25384',
#  'CHEBI:25388',
#  'CHEBI:25414',
#  'CHEBI:25430',
#  'CHEBI:25435',
#  'CHEBI:25442',
#  'CHEBI:25477',
#  'CHEBI:25501',
#  'CHEBI:25512',
#  'CHEBI:25523',
#  'CHEBI:25524',
#  'CHEBI:25527',
#  'CHEBI:25555',
#  'CHEBI:25567',
#  'CHEBI:25585',
#  'CHEBI:25608',
#  'CHEBI:25693',
#  'CHEBI:25696',
#  'CHEBI:25697',
#  'CHEBI:25698',
#  'CHEBI:25699',
#  'CHEBI:25701',
#  'CHEBI:25703',
#  'CHEBI:2571',
#  'CHEBI:25710',
#  'CHEBI:25741',
#  'CHEBI:25805',
#  'CHEBI:25806',
#  'CHEBI:25812',
#  'CHEBI:25900',
#  'CHEBI:25940',
#  'CHEBI:25944',
#  'CHEBI:26020',
#  'CHEBI:26079',
#  'CHEBI:26082',
#  'CHEBI:26130',
#  'CHEBI:26167',
#  'CHEBI:26178',
#  'CHEBI:26191',
#  'CHEBI:26214',
#  'CHEBI:26216',
#  'CHEBI:26217',
#  'CHEBI:26284',
#  'CHEBI:26288',
#  'CHEBI:26393',
#  'CHEBI:26395',
#  'CHEBI:26398',
#  'CHEBI:26400',
#  'CHEBI:26401',
#  'CHEBI:26421',
#  'CHEBI:26490',
#  'CHEBI:26523',
#  'CHEBI:26561',
#  'CHEBI:26562',
#  'CHEBI:26675',
#  'CHEBI:26677',
#  'CHEBI:26708',
#  'CHEBI:26710',
#  'CHEBI:26712',
#  'CHEBI:26714',
#  'CHEBI:26816',
#  'CHEBI:26820',
#  'CHEBI:26822',
#  'CHEBI:26833',
#  'CHEBI:26835',
#  'CHEBI:26836',
#  'CHEBI:26873',
#  'CHEBI:26878',
#  'CHEBI:26932',
#  'CHEBI:26935',
#  'CHEBI:26986',
#  'CHEBI:27007',
#  'CHEBI:27024',
#  'CHEBI:27026',
#  'CHEBI:27027',
#  'CHEBI:27081',
#  'CHEBI:27153',
#  'CHEBI:27171',
#  'CHEBI:27275',
#  'CHEBI:27295',
#  'CHEBI:27325',
#  'CHEBI:27338',
#  'CHEBI:27363',
#  'CHEBI:27364',
#  'CHEBI:27376',
#  'CHEBI:27547',
#  'CHEBI:27560',
#  'CHEBI:27563',
#  'CHEBI:27573',
#  'CHEBI:27594',
#  'CHEBI:27638',
#  'CHEBI:27780',
#  'CHEBI:27798',
#  'CHEBI:27856',
#  'CHEBI:27888',
#  'CHEBI:27889',
#  'CHEBI:28073',
#  'CHEBI:28112',
#  'CHEBI:28315',
#  'CHEBI:28425',
#  'CHEBI:28659',
#  'CHEBI:28685',
#  'CHEBI:28694',
#  'CHEBI:28793',
#  'CHEBI:28798',
#  'CHEBI:28838',
#  'CHEBI:28868',
#  'CHEBI:28938',
#  'CHEBI:28963',
#  'CHEBI:28966',
#  'CHEBI:28976',
#  'CHEBI:29067',
#  'CHEBI:29075',
#  'CHEBI:29125',
#  'CHEBI:29228',
#  'CHEBI:29238',
#  'CHEBI:29241',
#  'CHEBI:29337',
#  'CHEBI:29347',
#  'CHEBI:29412',
#  'CHEBI:29438',
#  'CHEBI:29919',
#  'CHEBI:30033',
#  'CHEBI:30052',
#  'CHEBI:30145',
#  'CHEBI:30187',
#  'CHEBI:30212',
#  'CHEBI:30216',
#  'CHEBI:30217',
#  'CHEBI:30218',
#  'CHEBI:30356',
#  'CHEBI:30412',
#  'CHEBI:30440',
#  'CHEBI:30496',
#  'CHEBI:30512',
#  'CHEBI:30513',
#  'CHEBI:30514',
#  'CHEBI:30563',
#  'CHEBI:30751',
#  'CHEBI:30762',
#  'CHEBI:30879',
#  'CHEBI:32178',
#  'CHEBI:32234',
#  'CHEBI:32594',
#  'CHEBI:32627',
#  'CHEBI:32628',
#  'CHEBI:32876',
#  'CHEBI:32952',
#  'CHEBI:32955',
#  'CHEBI:32988',
#  'CHEBI:32999',
#  'CHEBI:3311',
#  'CHEBI:33232',
#  'CHEBI:33233',
#  'CHEBI:33238',
#  'CHEBI:33240',
#  'CHEBI:33241',
#  'CHEBI:33242',
#  'CHEBI:33245',
#  'CHEBI:33247',
#  'CHEBI:33248',
#  'CHEBI:33249',
#  'CHEBI:33250',
#  'CHEBI:33251',
#  'CHEBI:33252',
#  'CHEBI:33253',
#  'CHEBI:33256',
#  'CHEBI:33259',
#  'CHEBI:33260',
#  'CHEBI:33261',
#  'CHEBI:33262',
#  'CHEBI:33263',
#  'CHEBI:33265',
#  'CHEBI:33266',
#  'CHEBI:33267',
#  'CHEBI:33273',
#  'CHEBI:33280',
#  'CHEBI:33281',
#  'CHEBI:33284',
#  'CHEBI:33285',
#  'CHEBI:33286',
#  'CHEBI:33287',
#  'CHEBI:33290',
#  'CHEBI:33292',
#  'CHEBI:33296',
#  'CHEBI:33299',
#  'CHEBI:33300',
#  'CHEBI:33302',
#  'CHEBI:33303',
#  'CHEBI:33304',
#  'CHEBI:33306',
#  'CHEBI:33308',
#  'CHEBI:33309',
#  'CHEBI:33315',
#  'CHEBI:33316',
#  'CHEBI:33317',
#  'CHEBI:33318',
#  'CHEBI:33319',
#  'CHEBI:33321',
#  'CHEBI:33324',
#  'CHEBI:33327',
#  'CHEBI:33328',
#  'CHEBI:33331',
#  'CHEBI:33335',
#  'CHEBI:33336',
#  'CHEBI:33340',
#  'CHEBI:33341',
#  'CHEBI:33344',
#  'CHEBI:33345',
#  'CHEBI:33347',
#  'CHEBI:33350',
#  'CHEBI:33352',
#  'CHEBI:33356',
#  'CHEBI:33358',
#  'CHEBI:33362',
#  'CHEBI:33366',
#  'CHEBI:33369',
#  'CHEBI:33372',
#  'CHEBI:33374',
#  'CHEBI:33375',
#  'CHEBI:33377',
#  'CHEBI:33400',
#  'CHEBI:33402',
#  'CHEBI:33405',
#  'CHEBI:33408',
#  'CHEBI:33415',
#  'CHEBI:33424',
#  'CHEBI:33429',
#  'CHEBI:33431',
#  'CHEBI:33432',
#  'CHEBI:33433',
#  'CHEBI:33434',
#  'CHEBI:33447',
#  'CHEBI:33455',
#  'CHEBI:33458',
#  'CHEBI:33459',
#  'CHEBI:33461',
#  'CHEBI:33465',
#  'CHEBI:33482',
#  'CHEBI:33484',
#  'CHEBI:33485',
#  'CHEBI:33497',
#  'CHEBI:33498',
#  'CHEBI:33499',
#  'CHEBI:33521',
#  'CHEBI:33535',
#  'CHEBI:33551',
#  'CHEBI:33552',
#  'CHEBI:33558',
#  'CHEBI:33559',
#  'CHEBI:33560',
#  'CHEBI:33561',
#  'CHEBI:33562',
#  'CHEBI:33575',
#  'CHEBI:33579',
#  'CHEBI:33581',
#  'CHEBI:33582',
#  'CHEBI:33583',
#  'CHEBI:33585',
#  'CHEBI:33595',
#  'CHEBI:33597',
#  'CHEBI:33598',
#  'CHEBI:33608',
#  'CHEBI:33620',
#  'CHEBI:33623',
#  'CHEBI:33628',
#  'CHEBI:33635',
#  'CHEBI:33636',
#  'CHEBI:33637',
#  'CHEBI:33641',
#  'CHEBI:33645',
#  'CHEBI:33646',
#  'CHEBI:33653',
#  'CHEBI:33655',
#  'CHEBI:33658',
#  'CHEBI:33659',
#  'CHEBI:33661',
#  'CHEBI:33662',
#  'CHEBI:33663',
#  'CHEBI:33664',
#  'CHEBI:33666',
#  'CHEBI:33670',
#  'CHEBI:33671',
#  'CHEBI:33672',
#  'CHEBI:33673',
#  'CHEBI:33674',
#  'CHEBI:33675',
#  'CHEBI:33676',
#  'CHEBI:33677',
#  'CHEBI:33679',
#  'CHEBI:33680',
#  'CHEBI:33692',
#  'CHEBI:33693',
#  'CHEBI:33694',
#  'CHEBI:33702',
#  'CHEBI:33703',
#  'CHEBI:33704',
#  'CHEBI:33709',
#  'CHEBI:33719',
#  'CHEBI:33741',
#  'CHEBI:33743',
#  'CHEBI:33744',
#  'CHEBI:33745',
#  'CHEBI:33746',
#  'CHEBI:33747',
#  'CHEBI:33749',
#  'CHEBI:33768',
#  'CHEBI:33822',
#  'CHEBI:33832',
#  'CHEBI:33833',
#  'CHEBI:33836',
#  'CHEBI:33839',
#  'CHEBI:33842',
#  'CHEBI:33847',
#  'CHEBI:33848',
#  'CHEBI:33861',
#  'CHEBI:33893',
#  'CHEBI:33909',
#  'CHEBI:33937',
#  'CHEBI:33958',
#  'CHEBI:33969',
#  'CHEBI:33976',
#  'CHEBI:35106',
#  'CHEBI:35107',
#  'CHEBI:35131',
#  'CHEBI:35156',
#  'CHEBI:35163',
#  'CHEBI:35175',
#  'CHEBI:35186',
#  'CHEBI:35193',
#  'CHEBI:35195',
#  'CHEBI:35196',
#  'CHEBI:35204',
#  'CHEBI:35209',
#  'CHEBI:35217',
#  'CHEBI:35222',
#  'CHEBI:35230',
#  'CHEBI:35274',
#  'CHEBI:35293',
#  'CHEBI:35294',
#  'CHEBI:35295',
#  'CHEBI:35296',
#  'CHEBI:35307',
#  'CHEBI:35341',
#  'CHEBI:35343',
#  'CHEBI:35350',
#  'CHEBI:35352',
#  'CHEBI:35402',
#  'CHEBI:35403',
#  'CHEBI:35404',
#  'CHEBI:35405',
#  'CHEBI:35406',
#  'CHEBI:35426',
#  'CHEBI:35427',
#  'CHEBI:35428',
#  'CHEBI:35441',
#  'CHEBI:35479',
#  'CHEBI:35480',
#  'CHEBI:35552',
#  'CHEBI:35554',
#  'CHEBI:35604',
#  'CHEBI:35605',
#  'CHEBI:35620',
#  'CHEBI:35681',
#  'CHEBI:35701',
#  'CHEBI:35715',
#  'CHEBI:35716',
#  'CHEBI:35757',
#  'CHEBI:35776',
#  'CHEBI:35780',
#  'CHEBI:35789',
#  'CHEBI:35875',
#  'CHEBI:35881',
#  'CHEBI:36059',
#  'CHEBI:36093',
#  'CHEBI:36125',
#  'CHEBI:36244',
#  'CHEBI:36309',
#  'CHEBI:36338',
#  'CHEBI:36339',
#  'CHEBI:36340',
#  'CHEBI:36341',
#  'CHEBI:36342',
#  'CHEBI:36343',
#  'CHEBI:36344',
#  'CHEBI:36347',
#  'CHEBI:36357',
#  'CHEBI:36358',
#  'CHEBI:36359',
#  'CHEBI:36360',
#  'CHEBI:36364',
#  'CHEBI:36388',
#  'CHEBI:36389',
#  'CHEBI:36562',
#  'CHEBI:36586',
#  'CHEBI:36587',
#  'CHEBI:36683',
#  'CHEBI:36785',
#  'CHEBI:36830',
#  'CHEBI:36838',
#  'CHEBI:36892',
#  'CHEBI:36895',
#  'CHEBI:36902',
#  'CHEBI:36908',
#  'CHEBI:36914',
#  'CHEBI:36915',
#  'CHEBI:36916',
#  'CHEBI:36927',
#  'CHEBI:36928',
#  'CHEBI:36961',
#  'CHEBI:36962',
#  'CHEBI:36963',
#  'CHEBI:36976',
#  'CHEBI:36980',
#  'CHEBI:37007',
#  'CHEBI:37015',
#  'CHEBI:37022',
#  'CHEBI:37045',
#  'CHEBI:37076',
#  'CHEBI:37096',
#  'CHEBI:37121',
#  'CHEBI:37133',
#  'CHEBI:37134',
#  'CHEBI:37143',
#  'CHEBI:37163',
#  'CHEBI:37164',
#  'CHEBI:37175',
#  'CHEBI:37176',
#  'CHEBI:37190',
#  'CHEBI:37191',
#  'CHEBI:37193',
#  'CHEBI:37217',
#  'CHEBI:37349',
#  'CHEBI:37376',
#  'CHEBI:37395',
#  'CHEBI:37403',
#  'CHEBI:37404',
#  'CHEBI:37407',
#  'CHEBI:37527',
#  'CHEBI:37577',
#  'CHEBI:37578',
#  'CHEBI:37602',
#  'CHEBI:37622',
#  'CHEBI:37734',
#  'CHEBI:37826',
#  'CHEBI:38077',
#  'CHEBI:38101',
#  'CHEBI:38104',
#  'CHEBI:38166',
#  'CHEBI:38180',
#  'CHEBI:38201',
#  'CHEBI:38206',
#  'CHEBI:38222',
#  'CHEBI:38251',
#  'CHEBI:38252',
#  'CHEBI:38263',
#  'CHEBI:38460',
#  'CHEBI:38496',
#  'CHEBI:38497',
#  'CHEBI:38669',
#  'CHEBI:38702',
#  'CHEBI:38773',
#  'CHEBI:38867',
#  'CHEBI:38869',
#  'CHEBI:38870',
#  'CHEBI:38975',
#  'CHEBI:38976',
#  'CHEBI:39141',
#  'CHEBI:39142',
#  'CHEBI:39143',
#  'CHEBI:39144',
#  'CHEBI:39285',
#  'CHEBI:39478',
#  'CHEBI:39479',
#  'CHEBI:3992',
#  'CHEBI:41609',
#  'CHEBI:43098',
#  'CHEBI:43474',
#  'CHEBI:44882',
#  'CHEBI:45696',
#  'CHEBI:46661',
#  'CHEBI:46662',
#  'CHEBI:46663',
#  'CHEBI:46721',
#  'CHEBI:46787',
#  'CHEBI:46890',
#  'CHEBI:46923',
#  'CHEBI:46926',
#  'CHEBI:47032',
#  'CHEBI:47622',
#  'CHEBI:47788',
#  'CHEBI:47867',
#  'CHEBI:47882',
#  'CHEBI:47885',
#  'CHEBI:47901',
#  'CHEBI:47909',
#  'CHEBI:48041',
#  'CHEBI:48107',
#  'CHEBI:48109',
#  'CHEBI:48123',
#  'CHEBI:48154',
#  'CHEBI:48218',
#  'CHEBI:48219',
#  'CHEBI:48354',
#  'CHEBI:48356',
#  'CHEBI:48359',
#  'CHEBI:48360',
#  'CHEBI:48706',
#  'CHEBI:48730',
#  'CHEBI:49202',
#  'CHEBI:49475',
#  'CHEBI:49637',
#  'CHEBI:49828',
#  'CHEBI:49976',
#  'CHEBI:50047',
#  'CHEBI:50094',
#  'CHEBI:50183',
#  'CHEBI:50312',
#  'CHEBI:50313',
#  'CHEBI:50325',
#  'CHEBI:50335',
#  'CHEBI:50402',
#  'CHEBI:50406',
#  'CHEBI:50584',
#  'CHEBI:50594',
#  'CHEBI:50795',
#  'CHEBI:50796',
#  'CHEBI:50812',
#  'CHEBI:50816',
#  'CHEBI:50860',
#  'CHEBI:50902',
#  'CHEBI:50904',
#  'CHEBI:50906',
#  'CHEBI:50910',
#  'CHEBI:50996',
#  'CHEBI:51082',
#  'CHEBI:51084',
#  'CHEBI:51086',
#  'CHEBI:51129',
#  'CHEBI:51132',
#  'CHEBI:51143',
#  'CHEBI:51447',
#  'CHEBI:51580',
#  'CHEBI:51584',
#  'CHEBI:51585',
#  'CHEBI:51688',
#  'CHEBI:51689',
#  'CHEBI:51718',
#  'CHEBI:51721',
#  'CHEBI:5186',
#  'CHEBI:51958',
#  'CHEBI:52206',
#  'CHEBI:52208',
#  'CHEBI:52209',
#  'CHEBI:52210',
#  'CHEBI:52211',
#  'CHEBI:52214',
#  'CHEBI:52217',
#  'CHEBI:52625',
#  'CHEBI:53000',
#  'CHEBI:53243',
#  'CHEBI:53310',
#  'CHEBI:53387',
#  'CHEBI:53388',
#  'CHEBI:53448',
#  'CHEBI:53550',
#  'CHEBI:5686',
#  'CHEBI:58072',
#  'CHEBI:58416',
#  'CHEBI:58454',
#  'CHEBI:58941',
#  'CHEBI:58950',
#  'CHEBI:58953',
#  'CHEBI:58954',
#  'CHEBI:59163',
#  'CHEBI:59739',
#  'CHEBI:59740',
#  'CHEBI:59999',
#  'CHEBI:60004',
#  'CHEBI:60027',
#  'CHEBI:60034',
#  'CHEBI:60160',
#  'CHEBI:60242',
#  'CHEBI:60272',
#  'CHEBI:60643',
#  'CHEBI:60737',
#  'CHEBI:60798',
#  'CHEBI:60926',
#  'CHEBI:61120',
#  'CHEBI:61292',
#  'CHEBI:61293',
#  'CHEBI:61295',
#  'CHEBI:61296',
#  'CHEBI:61452',
#  'CHEBI:61642',
#  'CHEBI:62488',
#  'CHEBI:62764',
#  'CHEBI:63046',
#  'CHEBI:63062',
#  'CHEBI:63248',
#  'CHEBI:63299',
#  'CHEBI:63367',
#  'CHEBI:63409',
#  'CHEBI:63471',
#  'CHEBI:64047',
#  'CHEBI:64708',
#  'CHEBI:64709',
#  'CHEBI:64712',
#  'CHEBI:64909',
#  'CHEBI:65212',
#  'CHEBI:66933',
#  'CHEBI:72695',
#  'CHEBI:72813',
#  'CHEBI:73113',
#  'CHEBI:73115',
#  'CHEBI:75763',
#  'CHEBI:75767',
#  'CHEBI:75768',
#  'CHEBI:75787',
#  'CHEBI:76413',
#  'CHEBI:76414',
#  'CHEBI:76725',
#  'CHEBI:76741',
#  'CHEBI:76759',
#  'CHEBI:76764',
#  'CHEBI:76807',
#  'CHEBI:76838',
#  'CHEBI:76898',
#  'CHEBI:76932',
#  'CHEBI:76946',
#  'CHEBI:76969',
#  'CHEBI:77746',
#  'CHEBI:77941',
#  'CHEBI:77971',
#  'CHEBI:77974',
#  'CHEBI:78017',
#  'CHEBI:78295',
#  'CHEBI:78298',
#  'CHEBI:78433',
#  'CHEBI:78616',
#  'CHEBI:78840',
#  'CHEBI:79387',
#  'CHEBI:79388',
#  'CHEBI:79389',
#  'CHEBI:82661',
#  'CHEBI:83039',
#  'CHEBI:83056',
#  'CHEBI:83057',
#  'CHEBI:83348',
#  'CHEBI:83628',
#  'CHEBI:83811',
#  'CHEBI:83820',
#  'CHEBI:83821',
#  'CHEBI:83925',
#  'CHEBI:84055',
#  'CHEBI:88184',
#  'CHEBI:91007',
#  'CHEBI:9171',
#  'ENVO:00000000',
#  'ENVO:00000001',
#  'ENVO:00000002',
#  'ENVO:00000003',
#  'ENVO:00000004',
#  'ENVO:00000005',
#  'ENVO:00000006',
#  'ENVO:00000007',
#  'ENVO:00000008',
#  'ENVO:00000009',
#  'ENVO:00000010',
#  'ENVO:00000011',
#  'ENVO:00000012',
#  'ENVO:00000013',
#  'ENVO:00000014',
#  'ENVO:00000015',
#  'ENVO:00000016',
#  'ENVO:00000017',
#  'ENVO:00000019',
#  'ENVO:00000020',
#  'ENVO:00000021',
#  'ENVO:00000022',
#  'ENVO:00000023',
#  'ENVO:00000025',
#  'ENVO:00000026',
#  'ENVO:00000027',
#  'ENVO:00000028',
#  'ENVO:00000029',
#  'ENVO:00000030',
#  'ENVO:00000031',
#  'ENVO:00000032',
#  'ENVO:00000033',
#  'ENVO:00000034',
#  'ENVO:00000035',
#  'ENVO:00000036',
#  'ENVO:00000037',
#  'ENVO:00000038',
#  'ENVO:00000039',
#  'ENVO:00000040',
#  'ENVO:00000041',
#  'ENVO:00000042',
#  'ENVO:00000043',
#  'ENVO:00000044',
#  'ENVO:00000045',
#  'ENVO:00000046',
#  'ENVO:00000048',
#  'ENVO:00000050',
#  'ENVO:00000051',
#  'ENVO:00000052',
#  'ENVO:00000053',
#  'ENVO:00000054',
#  'ENVO:00000055',
#  'ENVO:00000056',
#  'ENVO:00000057',
#  'ENVO:00000058',
#  'ENVO:00000059',
#  'ENVO:00000060',
#  'ENVO:00000061',
#  'ENVO:00000062',
#  'ENVO:00000063',
#  'ENVO:00000064',
#  'ENVO:00000065',
#  'ENVO:00000066',
#  'ENVO:00000067',
#  'ENVO:00000068',
#  'ENVO:00000069',
#  'ENVO:00000070',
#  'ENVO:00000071',
#  'ENVO:00000072',
#  'ENVO:00000073',
#  'ENVO:00000074',
#  'ENVO:00000075',
#  'ENVO:00000076',
#  'ENVO:00000077',
#  'ENVO:00000078',
#  'ENVO:00000079',
#  'ENVO:00000080',
#  'ENVO:00000081',
#  'ENVO:00000082',
#  'ENVO:00000083',
#  'ENVO:00000084',
#  'ENVO:00000085',
#  'ENVO:00000086',
#  'ENVO:00000087',
#  'ENVO:00000088',
#  'ENVO:00000089',
#  'ENVO:00000090',
#  'ENVO:00000091',
#  'ENVO:00000092',
#  'ENVO:00000093',
#  'ENVO:00000094',
#  'ENVO:00000096',
#  'ENVO:00000097',
#  'ENVO:00000098',
#  'ENVO:00000099',
#  'ENVO:00000100',
#  'ENVO:00000101',
#  'ENVO:00000102',
#  'ENVO:00000103',
#  'ENVO:00000104',
#  'ENVO:00000105',
#  'ENVO:00000106',
#  'ENVO:00000107',
#  'ENVO:00000108',
#  'ENVO:00000109',
#  'ENVO:00000110',
#  'ENVO:00000111',
#  'ENVO:00000112',
#  'ENVO:00000114',
#  'ENVO:00000115',
#  'ENVO:00000116',
#  'ENVO:00000117',
#  'ENVO:00000118',
#  'ENVO:00000119',
#  'ENVO:00000120',
#  'ENVO:00000121',
#  'ENVO:00000122',
#  'ENVO:00000123',
#  'ENVO:00000124',
#  'ENVO:00000125',
#  'ENVO:00000126',
#  'ENVO:00000127',
#  'ENVO:00000128',
#  ...]

# %% [markdown]
# ----

# %%
import requests
import requests_cache

# %%
# Create a cache that lasts for 1 hour (3600 seconds)
requests_cache.install_cache('my_cache', expire_after=3600) # 1 hour

# %%
BIOPORTAL_API_KEY = os.getenv("BIOPORTAL_API_KEY")

# %%
print(BIOPORTAL_API_KEY)
# Out:
# e4043787-8e9c-4fc8-a0a0-54fd01b6be9d

# %%
bioportal_ontologies_url = f"https://data.bioontology.org/ontologies?apikey={BIOPORTAL_API_KEY}"

# %%
bioportal_ontologies_resp = requests.get(bioportal_ontologies_url)

# %%
bioportal_ontologies = bioportal_ontologies_resp.json()

# %%
type(bioportal_ontologies)
# Out:
# list

# %%
bioportal_ontologies[0]
# Out:
# {'administeredBy': ['https://data.bioontology.org/users/Hardy+Xie'],
#  'acronym': 'PICO',
#  'name': 'Pathogen-related Informed Consent Ontology',
#  'summaryOnly': False,
#  'flat': None,
#  'ontologyType': 'https://data.bioontology.org/ontology_types/ONTOLOGY',
#  '@id': 'https://data.bioontology.org/ontologies/PICO',
#  '@type': 'http://data.bioontology.org/metadata/Ontology',
#  'links': {'submissions': 'https://data.bioontology.org/ontologies/PICO/submissions',
#   'properties': 'https://data.bioontology.org/ontologies/PICO/properties',
#   'classes': 'https://data.bioontology.org/ontologies/PICO/classes',
#   'single_class': 'https://data.bioontology.org/ontologies/PICO/classes/{class_id}',
#   'roots': 'https://data.bioontology.org/ontologies/PICO/classes/roots',
#   'instances': 'https://data.bioontology.org/ontologies/PICO/instances',
#   'metrics': 'https://data.bioontology.org/ontologies/PICO/metrics',
#   'reviews': 'https://data.bioontology.org/ontologies/PICO/reviews',
#   'notes': 'https://data.bioontology.org/ontologies/PICO/notes',
#   'groups': 'https://data.bioontology.org/ontologies/PICO/groups',
#   'categories': 'https://data.bioontology.org/ontologies/PICO/categories',
#   'latest_submission': 'https://data.bioontology.org/ontologies/PICO/latest_submission',
#   'projects': 'https://data.bioontology.org/ontologies/PICO/projects',
#   'download': 'https://data.bioontology.org/ontologies/PICO/download',
#   'views': 'https://data.bioontology.org/ontologies/PICO/views',
#   'analytics': 'https://data.bioontology.org/ontologies/PICO/analytics',
#   'ui': 'http://bioportal.bioontology.org/ontologies/PICO',
#   '@context': {'submissions': 'http://data.bioontology.org/metadata/OntologySubmission',
#    'properties': 'http://data.bioontology.org/metadata/Property',
#    'classes': 'http://www.w3.org/2002/07/owl#Class',
#    'single_class': 'http://www.w3.org/2002/07/owl#Class',
#    'roots': 'http://www.w3.org/2002/07/owl#Class',
#    'instances': 'http://data.bioontology.org/metadata/Instance',
#    'metrics': 'http://data.bioontology.org/metadata/Metrics',
#    'reviews': 'http://data.bioontology.org/metadata/Review',
#    'notes': 'http://data.bioontology.org/metadata/Note',
#    'groups': 'http://data.bioontology.org/metadata/Group',
#    'categories': 'http://data.bioontology.org/metadata/Category',
#    'latest_submission': 'http://data.bioontology.org/metadata/OntologySubmission',
#    'projects': 'http://data.bioontology.org/metadata/Project',
#    'download': 'http://data.bioontology.org/metadata/Ontology',
#    'views': 'http://data.bioontology.org/metadata/Ontology',
#    'analytics': 'http://data.bioontology.org/metadata/Analytics',
#    'ui': 'http://data.bioontology.org/metadata/Ontology'}},
#  '@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#   'acronym': 'http://omv.ontoware.org/2005/05/ontology#acronym',
#   'name': 'http://omv.ontoware.org/2005/05/ontology#name',
#   'administeredBy': {'@id': 'http://data.bioontology.org/metadata/User',
#    '@type': '@id'},
#   'flat': 'http://data.bioontology.org/metadata/flat',
#   'summaryOnly': 'http://data.bioontology.org/metadata/summaryOnly',
#   'ontologyType': {'@id': 'http://data.bioontology.org/metadata/OntologyType',
#    '@type': '@id'},
#   '@language': 'en'}}
