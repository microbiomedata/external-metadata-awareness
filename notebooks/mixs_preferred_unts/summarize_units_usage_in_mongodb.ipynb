# %%
from pymongo import MongoClient
import pandas as pd

# %%
mongo_url = "mongodb://localhost:27017/"

# %%
database_name = "nmdc"

# %%
collection_name = "flattened_biosample"

# %%
# Connect to local MongoDB
client = MongoClient(mongo_url)

# %%
db = client[database_name]

# %%
collection = db[collection_name]

# %%
# Retrieve all documents in the collection
documents = list(collection.find())

# %%
documents[0]
# Out:
# {'_id': ObjectId('67e46c83379c802141a01463'),
#  'id': 'nmdc:bsm-11-002vgm56',
#  'abs_air_humidity_has_numeric_value': None,
#  'abs_air_humidity_has_raw_value': None,
#  'abs_air_humidity_has_unit': None,
#  'add_date': None,
#  'agrochem_addition': None,
#  'alternative_identifiers': None,
#  'ammonium_has_numeric_value': None,
#  'ammonium_has_unit': None,
#  'ammonium_nitrogen_has_numeric_value': None,
#  'ammonium_nitrogen_has_raw_value': None,
#  'ammonium_nitrogen_has_unit': None,
#  'analysis_type': 'metagenomics',
#  'ances_data_has_raw_value': None,
#  'associated_studies': 'nmdc:sty-11-34xj1150',
#  'avg_temp_has_numeric_value': None,
#  'avg_temp_has_raw_value': None,
#  'avg_temp_has_unit': None,
#  'biosample_categories': 'NEON',
#  'biotic_regm_has_raw_value': None,
#  'calcium_has_numeric_value': None,
#  'calcium_has_raw_value': None,
#  'calcium_has_unit': None,
#  'carb_nitro_ratio_has_numeric_value': 25.4,
#  'carb_nitro_ratio_has_raw_value': None,
#  'chloride_has_numeric_value': None,
#  'chloride_has_unit': None,
#  'chlorophyll_has_numeric_value': None,
#  'chlorophyll_has_unit': None,
#  'collected_from': None,
#  'collection_date_has_raw_value': '2016-07-26T01:30Z',
#  'collection_time': None,
#  'community': None,
#  'conduc_has_numeric_value': None,
#  'conduc_has_unit': None,
#  'cult_root_med_has_raw_value': None,
#  'cur_vegetation_has_raw_value': None,
#  'depth_has_maximum_numeric_value': 0.325,
#  'depth_has_minimum_numeric_value': 0,
#  'depth_has_numeric_value': None,
#  'depth_has_raw_value': None,
#  'depth_has_unit': 'm',
#  'description': None,
#  'diss_inorg_carb_has_numeric_value': None,
#  'diss_inorg_carb_has_unit': None,
#  'diss_inorg_nitro_has_numeric_value': None,
#  'diss_inorg_nitro_has_unit': None,
#  'diss_iron_has_numeric_value': None,
#  'diss_iron_has_unit': None,
#  'diss_org_carb_has_numeric_value': None,
#  'diss_org_carb_has_unit': None,
#  'diss_oxygen_has_numeric_value': None,
#  'diss_oxygen_has_unit': None,
#  'ecosystem': 'Environmental',
#  'ecosystem_category': 'Terrestrial',
#  'ecosystem_subtype': 'Unclassified',
#  'ecosystem_type': 'Soil',
#  'elev': 677.6,
#  'emsl_biosample_identifiers': None,
#  'env_broad_scale_has_raw_value': None,
#  'env_broad_scale_term.id': 'ENVO:00000446',
#  'env_broad_scale_term.name': 'terrestrial biome',
#  'env_local_scale_has_raw_value': None,
#  'env_local_scale_term.id': 'ENVO:01000861',
#  'env_local_scale_term.name': 'area of dwarf scrub',
#  'env_medium_has_raw_value': None,
#  'env_medium_term.id': 'ENVO:00001998',
#  'env_medium_term.name': 'soil',
#  'env_package_has_raw_value': 'soil',
#  'experimental_factor_has_raw_value': None,
#  'experimental_factor_other': None,
#  'experimental_factor_term.id': None,
#  'experimental_factor_term.name': None,
#  'fertilizer_regm': None,
#  'geo_loc_name_has_raw_value': 'USA: Alaska, Healy',
#  'gold_biosample_identifiers': 'gold:Gb0255739',
#  'gravidity_has_raw_value': None,
#  'growth_facil_has_raw_value': None,
#  'growth_facil_term.id': None,
#  'growth_facil_term.name': None,
#  'habitat': None,
#  'host_age_has_numeric_value': None,
#  'host_age_has_raw_value': None,
#  'host_age_has_unit': None,
#  'host_body_habitat_has_raw_value': None,
#  'host_body_site_has_raw_value': None,
#  'host_body_site_term.id': None,
#  'host_body_site_term.name': None,
#  'host_common_name_has_raw_value': None,
#  'host_diet': None,
#  'host_dry_mass_has_numeric_value': None,
#  'host_dry_mass_has_raw_value': None,
#  'host_dry_mass_has_unit': None,
#  'host_genotype_has_raw_value': None,
#  'host_height_has_numeric_value': None,
#  'host_height_has_raw_value': None,
#  'host_height_has_unit': None,
#  'host_life_stage_has_raw_value': None,
#  'host_name': None,
#  'host_sex': None,
#  'host_taxid_has_raw_value': None,
#  'host_taxid_term.id': None,
#  'host_taxid_term.name': None,
#  'humidity_has_numeric_value': None,
#  'humidity_has_raw_value': None,
#  'humidity_has_unit': None,
#  'igsn_biosample_identifiers': None,
#  'img_identifiers': None,
#  'insdc_biosample_identifiers': None,
#  'lat_lon_has_raw_value': None,
#  'lat_lon_latitude': 63.875088,
#  'lat_lon_longitude': -149.210438,
#  'lbc_thirty_has_numeric_value': None,
#  'lbc_thirty_has_raw_value': None,
#  'lbc_thirty_has_unit': None,
#  'lbceq_has_numeric_value': None,
#  'lbceq_has_raw_value': None,
#  'lbceq_has_unit': None,
#  'location': None,
#  'magnesium_has_numeric_value': None,
#  'magnesium_has_raw_value': None,
#  'magnesium_has_unit': None,
#  'manganese_has_numeric_value': None,
#  'manganese_has_raw_value': None,
#  'manganese_has_unit': None,
#  'micro_biomass_meth': None,
#  'misc_param': None,
#  'mod_date': None,
#  'name': 'HEAL_048-O-6.5-19.5-20160725',
#  'ncbi_taxonomy_name': None,
#  'nitrate_has_raw_value': None,
#  'nitrate_has_unit': None,
#  'nitrate_nitrogen_has_numeric_value': None,
#  'nitrate_nitrogen_has_raw_value': None,
#  'nitrate_nitrogen_has_unit': None,
#  'nitrite_nitrogen_has_numeric_value': None,
#  'nitrite_nitrogen_has_raw_value': None,
#  'nitrite_nitrogen_has_unit': None,
#  'nitro_has_numeric_value': 1.02,
#  'nitro_has_unit': 'percent',
#  'org_carb_has_numeric_value': 25.94,
#  'org_carb_has_unit': 'percent',
#  'other_treatment': None,
#  'perturbation': None,
#  'ph': 6.04,
#  'photon_flux_has_numeric_value': None,
#  'photon_flux_has_raw_value': None,
#  'photon_flux_has_unit': None,
#  'plant_struc_has_raw_value': None,
#  'plant_struc_term.id': None,
#  'plant_struc_term.name': None,
#  'potassium_has_numeric_value': None,
#  'potassium_has_raw_value': None,
#  'potassium_has_unit': None,
#  'salinity_has_raw_value': None,
#  'samp_collec_device': 'corer',
#  'samp_collec_method': None,
#  'samp_mat_process_has_raw_value': None,
#  'samp_name': None,
#  'samp_size_has_numeric_value': None,
#  'samp_size_has_raw_value': None,
#  'samp_size_has_unit': None,
#  'samp_store_loc_has_raw_value': None,
#  'samp_store_temp_has_numeric_value': None,
#  'samp_store_temp_has_raw_value': None,
#  'samp_store_temp_has_unit': None,
#  'samp_taxon_id_has_raw_value': None,
#  'samp_taxon_id_term.id': None,
#  'samp_taxon_id_term.name': None,
#  'sample_collection_site': None,
#  'sample_link': None,
#  'sieving_has_raw_value': None,
#  'sodium_has_numeric_value': None,
#  'sodium_has_unit': None,
#  'soil_horizon': 'O horizon',
#  'soil_texture_meth': None,
#  'soil_type_has_raw_value': None,
#  'soil_type_meth_has_raw_value': None,
#  'solar_irradiance_has_numeric_value': None,
#  'solar_irradiance_has_raw_value': None,
#  'solar_irradiance_has_unit': None,
#  'soluble_react_phosp_has_numeric_value': None,
#  'soluble_react_phosp_has_unit': None,
#  'source_mat_id_has_raw_value': None,
#  'specific_ecosystem': None,
#  'store_cond_has_raw_value': None,
#  'subsurface_depth_has_numeric_value': None,
#  'subsurface_depth_has_raw_value': None,
#  'subsurface_depth_has_unit': None,
#  'sulfate_has_numeric_value': None,
#  'sulfate_has_unit': None,
#  'temp_has_numeric_value': 6.6,
#  'temp_has_raw_value': None,
#  'temp_has_unit': 'Celsius',
#  'tot_carb_has_numeric_value': None,
#  'tot_carb_has_raw_value': None,
#  'tot_carb_has_unit': None,
#  'tot_nitro_content_has_numeric_value': None,
#  'tot_nitro_content_has_raw_value': None,
#  'tot_nitro_content_has_unit': None,
#  'tot_nitro_has_numeric_value': None,
#  'tot_nitro_has_raw_value': None,
#  'tot_nitro_has_unit': None,
#  'tot_org_carb_has_numeric_value': None,
#  'tot_org_carb_has_raw_value': None,
#  'tot_org_carb_has_unit': None,
#  'tot_phosp_has_numeric_value': None,
#  'tot_phosp_has_raw_value': None,
#  'tot_phosp_has_unit': None,
#  'water_content': '2.667 g of water/g of dry soil',
#  'watering_regm': None,
#  'wind_direction_has_raw_value': None,
#  'wind_speed_has_numeric_value': None,
#  'wind_speed_has_raw_value': None,
#  'wind_speed_has_unit': None,
#  'zinc_has_numeric_value': None,
#  'zinc_has_raw_value': None,
#  'zinc_has_unit': None}

# %%
df = pd.DataFrame(documents)

# %%
all_col_names = list(df.columns)

# %%
unit_col_names = [ i for i in all_col_names if i.endswith("_has_unit") ]

# %%
desired_col_names = ['id'] + unit_col_names

# %%
df = df[desired_col_names]

# %%
df
# Out:
#                          id abs_air_humidity_has_unit ammonium_has_unit  \
# 0      nmdc:bsm-11-002vgm56                      None              None
# 1      nmdc:bsm-11-006pnx90                       kPa              None
# 2      nmdc:bsm-11-00dkyf35                      None              None
# 3      nmdc:bsm-11-00f5nh68                      None              None
# 4      nmdc:bsm-11-00hrxp98                      None              None
# ...                     ...                       ...               ...
# 13001  nmdc:bsm-13-zms1jq91                      None              None
# 13002  nmdc:bsm-13-zq681s85                      None              None
# 13003  nmdc:bsm-13-zr9dcy94                      None              None
# 13004  nmdc:bsm-13-zvz59s14                      None              None
# 13005  nmdc:bsm-13-zxqyyz58                      None              None
#
#       ammonium_nitrogen_has_unit avg_temp_has_unit calcium_has_unit  \
# 0                           None              None             None
# 1                           None               Cel             None
# 2                           mg/L              None             None
# 3                           None              None             None
# 4                           None              None             None
# ...                          ...               ...              ...
# 13001                       None              None             None
# 13002                       None              None             None
# 13003                       None              None             None
# 13004                       None              None             None
# 13005                       None              None             None
#
#       chloride_has_unit chlorophyll_has_unit conduc_has_unit depth_has_unit  \
# 0                  None                 None            None              m
# 1                  None                 None            None           None
# 2                  None                 None            None              m
# 3                  None                 None            None           None
# 4                  None                 None            None              m
# ...                 ...                  ...             ...            ...
# 13001              None                 None            None              m
# 13002              None                 None            None           None
# 13003              None                 None            None              m
# 13004              None                 None            None              m
# 13005              None                 None            None              m
#
#        ... subsurface_depth_has_unit sulfate_has_unit temp_has_unit  \
# 0      ...                      None             None       Celsius
# 1      ...                      None             None          None
# 2      ...                      None             None       Celsius
# 3      ...                      None             None          None
# 4      ...                      None             None       Celsius
# ...    ...                       ...              ...           ...
# 13001  ...                      None             None          None
# 13002  ...                      None             None          None
# 13003  ...                      None             None          None
# 13004  ...                      None             None          None
# 13005  ...                      None             None          None
#
#       tot_carb_has_unit tot_nitro_content_has_unit tot_nitro_has_unit  \
# 0                  None                       None               None
# 1                     %                          %               None
# 2                  None                       mg/L               None
# 3                  None                       None               None
# 4                  None                       None               None
# ...                 ...                        ...                ...
# 13001              None                       None               None
# 13002              None                       None               None
# 13003              None                       None               None
# 13004              None                       None               None
# 13005              None                       None               None
#
#       tot_org_carb_has_unit tot_phosp_has_unit wind_speed_has_unit  \
# 0                      None               None                None
# 1                      None               None                 m/s
# 2                      None               None                None
# 3                      None               None                None
# 4                      None               None                None
# ...                     ...                ...                 ...
# 13001                  None               None                None
# 13002                  None               None                None
# 13003                  None               None                None
# 13004                  None               None                None
# 13005                  None               None                None
#
#       zinc_has_unit
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 13001          None
# 13002          None
# 13003          None
# 13004          None
# 13005          None
#
# [13006 rows x 45 columns]

# %%
# Melt the DataFrame using 'id' as the identifier
melted_df = pd.melt(df, id_vars=["id"], var_name="source_column", value_name="value")

# %%
# Remove rows where 'value' is NA, null, etc.
melted_df = melted_df.dropna(subset=["value"])

# %%
melted_df
# Out:
#                           id              source_column  value
# 1       nmdc:bsm-11-006pnx90  abs_air_humidity_has_unit    kPa
# 39      nmdc:bsm-11-0435yq18  abs_air_humidity_has_unit    kPa
# 70      nmdc:bsm-11-06mvg980  abs_air_humidity_has_unit    kPa
# 92      nmdc:bsm-11-07nqms41  abs_air_humidity_has_unit    kPa
# 94      nmdc:bsm-11-07qp3e36  abs_air_humidity_has_unit    kPa
# ...                      ...                        ...    ...
# 570790  nmdc:bsm-11-ynkz2756              zinc_has_unit  mg/kg
# 570820  nmdc:bsm-11-yqjjes90              zinc_has_unit  mg/kg
# 570822  nmdc:bsm-11-yqrv3r15              zinc_has_unit  mg/kg
# 570956  nmdc:bsm-11-z423gx54              zinc_has_unit  mg/kg
# 571042  nmdc:bsm-11-zaph9002              zinc_has_unit  mg/kg
#
# [25275 rows x 3 columns]

# %%
# Group by 'source_column' and count occurrences of each value in 'value'
value_counts = melted_df.groupby('source_column')['value'].value_counts()

# %%
# Optional: Reset index to convert the result into a DataFrame with columns: source_column, value, and counts
value_counts_df = value_counts.reset_index(name='counts')

# %%
value_counts_df
# Out:
#                    source_column      value  counts
# 0      abs_air_humidity_has_unit        kPa     192
# 1              ammonium_has_unit       mg/L      45
# 2     ammonium_nitrogen_has_unit       mg/L    1239
# 3     ammonium_nitrogen_has_unit      mg/kg     103
# 4              avg_temp_has_unit        Cel     192
# 5               calcium_has_unit      mg/kg     103
# 6               calcium_has_unit       mg/L       6
# 7              chloride_has_unit       mg/L       6
# 8           chlorophyll_has_unit       μg/L      47
# 9                conduc_has_unit      uS/cm     180
# 10                depth_has_unit          m    5974
# 11                depth_has_unit     meters     391
# 12      diss_inorg_carb_has_unit       mg/L      25
# 13     diss_inorg_nitro_has_unit       mg/L      45
# 14            diss_iron_has_unit       mg/L       6
# 15        diss_org_carb_has_unit       mg/L      25
# 16          diss_oxygen_has_unit       mg/L     435
# 17             host_age_has_unit       days     138
# 18             host_age_has_unit      years      28
# 19        host_dry_mass_has_unit          g     192
# 20          host_height_has_unit         cm     192
# 21             humidity_has_unit          %     192
# 22           lbc_thirty_has_unit        ppm     103
# 23                lbceq_has_unit        ppm     103
# 24            magnesium_has_unit      mg/kg     103
# 25            magnesium_has_unit       mg/L       6
# 26            manganese_has_unit      mg/kg     103
# 27            manganese_has_unit       mg/L       6
# 28              nitrate_has_unit  detection      18
# 29     nitrate_nitrogen_has_unit      mg/kg     103
# 30     nitrite_nitrogen_has_unit      mg/kg     103
# 31                nitro_has_unit    percent     919
# 32             org_carb_has_unit    percent    1407
# 33          photon_flux_has_unit  u[E]/m2/s     192
# 34            potassium_has_unit      mg/kg     103
# 35            potassium_has_unit       mg/L       6
# 36            samp_size_has_unit         mL     629
# 37            samp_size_has_unit          g      36
# 38      samp_store_temp_has_unit    Celsius    3823
# 39      samp_store_temp_has_unit        Cel     192
# 40      samp_store_temp_has_unit    Celcius     152
# 41      samp_store_temp_has_unit          C      42
# 42               sodium_has_unit       mg/L       6
# 43     solar_irradiance_has_unit       W/m2     192
# 44  soluble_react_phosp_has_unit       mg/L      45
# 45     subsurface_depth_has_unit      meter       1
# 46              sulfate_has_unit       mg/L       6
# 47                 temp_has_unit    Celsius    4352
# 48                 temp_has_unit          C     368
# 49                 temp_has_unit        Cel     180
# 50             tot_carb_has_unit          %     192
# 51    tot_nitro_content_has_unit       mg/L    1240
# 52    tot_nitro_content_has_unit          %     192
# 53            tot_nitro_has_unit    Percent     103
# 54         tot_org_carb_has_unit       mg/L      26
# 55            tot_phosp_has_unit        ppm     127
# 56            tot_phosp_has_unit       mg/L      45
# 57           wind_speed_has_unit        m/s     192
# 58                 zinc_has_unit      mg/kg     103

# %%
value_counts_df.to_csv("nmdc_mongo_biosample_unit_counts.tsv", sep="\t", index=False)
