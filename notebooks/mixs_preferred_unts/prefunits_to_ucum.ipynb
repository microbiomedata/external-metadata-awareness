# %%
import pandas as pd
import re

# %% [markdown]
# create a mixs_schema file with external_metadata_awareness/class_slot_flattening.py

# %%
mixs_schema_file = "../../unorganized/mixs-schema.tsv"

# %%
exploded_prefunits_to_ucum = "mixs-exploded-prefunit-counts-ucum.tsv"

# %%
def improved_split_units(val):
    val = val.strip()

    # Look for parenthetical alternatives: "number of cells per gram (or ml or cm^2)"
    match = re.match(r'^(.*?\bper\b)\s*([^\s()]+)\s*\((?:or\s+)?(.+?)\)$', val)
    if match:
        prefix = match.group(1).strip()  # "number of cells per"
        first = match.group(2).strip()   # "gram"
        others = re.split(r'\s*or\s*', match.group(3).strip())
        return [f"{prefix} {unit}".strip() for unit in [first] + others]

    # Fallback to regular split
    return re.split(r'\s*(?:,|;|\bor\b)\s*', val)

# %%
mixs_schema_frame = pd.read_csv(mixs_schema_file, sep="\t", low_memory=False)

# %%
mixs_schema_frame = mixs_schema_frame[~mixs_schema_frame['class_uri'].str.contains('_', na=False)]

# %%
preferred_unit_df = mixs_schema_frame[
    mixs_schema_frame['annotation_Preferred_unit'].notna() &
    (mixs_schema_frame['annotation_Preferred_unit'].str.strip() != '')
][['class', 'slot', 'annotation_Preferred_unit']]

# %%
preferred_unit_df
# Out:
#              class               slot  \
# 2      Agriculture  agrochem_addition
# 6      Agriculture      annual_precpt
# 7      Agriculture        annual_temp
# 17     Agriculture         crop_yield
# 22     Agriculture              depth
# ...            ...                ...
# 33738        Water    tot_inorg_nitro
# 33739        Water          tot_nitro
# 33740        Water      tot_part_carb
# 33741        Water          tot_phosp
# 33743        Water      water_current
#
#                                annotation_Preferred_unit
# 2              gram, mole per liter, milligram per liter
# 6                                             millimeter
# 7                                         degree Celsius
# 17                             kilogram per metre square
# 22                                                 meter
# ...                                                  ...
# 33738                                microgram per liter
# 33739  microgram per liter, micromole per liter, mill...
# 33740           microgram per liter, micromole per liter
# 33741  micromole per liter, milligram per liter, part...
# 33743                      cubic meter per second, knots
#
# [677 rows x 3 columns]

# %%
unit_strings_with_counts = (
    preferred_unit_df['annotation_Preferred_unit']
    .value_counts()
    .reset_index()
)

# %%
unit_strings_with_counts
# Out:
#                              annotation_Preferred_unit  count
# 0                                       degree Celsius     88
# 1                                                meter     72
# 2    micromole per liter, milligram per liter, part...     35
# 3       milliliter, gram, milligram, square centimeter     33
# 4               milligram per liter, parts per million     32
# ..                                                 ...    ...
# 104  microEinstein per square meter per second, mic...      1
# 105     milligram chlorophyll a per cubic meter, volts      1
# 106                                                lux      1
# 107         number of photons per second per unit area      1
# 108  milligram per cubic meter per day, gram per sq...      1
#
# [109 rows x 2 columns]

# %%
# Apply the improved splitter to get exploded units
unit_strings_with_counts['exploded_prefunit'] = unit_strings_with_counts['annotation_Preferred_unit'].apply(improved_split_units)

# %%
# Explode into one row per individual unit
exploded_df = unit_strings_with_counts.explode('exploded_prefunit').reset_index(drop=True)

# %%
# Rename count in the unit-level counts so it doesn't clash
exploded_df = exploded_df.rename(
    columns={
        'count': 'prefunit_count',
    },
)

# %%
exploded_df
# Out:
#                              annotation_Preferred_unit  prefunit_count  \
# 0                                       degree Celsius              88
# 1                                                meter              72
# 2    micromole per liter, milligram per liter, part...              35
# 3    micromole per liter, milligram per liter, part...              35
# 4    micromole per liter, milligram per liter, part...              35
# ..                                                 ...             ...
# 198     milligram chlorophyll a per cubic meter, volts               1
# 199                                                lux               1
# 200         number of photons per second per unit area               1
# 201  milligram per cubic meter per day, gram per sq...               1
# 202  milligram per cubic meter per day, gram per sq...               1
#
#                               exploded_prefunit
# 0                                degree Celsius
# 1                                         meter
# 2                           micromole per liter
# 3                           milligram per liter
# 4                             parts per million
# ..                                          ...
# 198                                       volts
# 199                                         lux
# 200  number of photons per second per unit area
# 201           milligram per cubic meter per day
# 202               gram per square meter per day
#
# [203 rows x 3 columns]

# %%
exploded_unit_counts = (
    exploded_df['exploded_prefunit']
    .value_counts()
    .reset_index()
)

# %%
exploded_unit_counts
# Out:
#                                   exploded_prefunit  count
# 0                               milligram per liter     15
# 1                                 parts per million     11
# 2                                              gram     10
# 3                               micromole per liter      8
# 4                                    mole per liter      7
# ..                                              ...    ...
# 106  microEinstein per square centimeter per second      1
# 107         milligram chlorophyll a per cubic meter      1
# 108                                           volts      1
# 109      number of photons per second per unit area      1
# 110                   gram per square meter per day      1
#
# [111 rows x 2 columns]

# %%
# Rename count in the unit-level counts so it doesn't clash
exploded_unit_counts = exploded_unit_counts.rename(
    columns={
        'count': 'exploded_count',
    },
)

# %%
exploded_df.columns
# Out:
# Index(['annotation_Preferred_unit', 'prefunit_count', 'exploded_prefunit'], dtype='object')

# %%
exploded_unit_counts.columns
# Out:
# Index(['exploded_prefunit', 'exploded_count'], dtype='object')

# %%
# Merge onto exploded_df
exploded_df = exploded_df.merge(
    exploded_unit_counts,
    on='exploded_prefunit',
    how='left'
)

# %%
exploded_df
# Out:
#                              annotation_Preferred_unit  prefunit_count  \
# 0                                       degree Celsius              88
# 1                                                meter              72
# 2    micromole per liter, milligram per liter, part...              35
# 3    micromole per liter, milligram per liter, part...              35
# 4    micromole per liter, milligram per liter, part...              35
# ..                                                 ...             ...
# 198     milligram chlorophyll a per cubic meter, volts               1
# 199                                                lux               1
# 200         number of photons per second per unit area               1
# 201  milligram per cubic meter per day, gram per sq...               1
# 202  milligram per cubic meter per day, gram per sq...               1
#
#                               exploded_prefunit  exploded_count
# 0                                degree Celsius               2
# 1                                         meter               3
# 2                           micromole per liter               8
# 3                           milligram per liter              15
# 4                             parts per million              11
# ..                                          ...             ...
# 198                                       volts               1
# 199                                         lux               3
# 200  number of photons per second per unit area               1
# 201           milligram per cubic meter per day               3
# 202               gram per square meter per day               1
#
# [203 rows x 4 columns]

# %%
# Final merge: attach class and slot to each exploded unit row
detailed_exploded_df = preferred_unit_df.merge(
    exploded_df,
    on='annotation_Preferred_unit',
    how='left'
)

# %%
detailed_exploded_df
# Out:
#             class               slot  \
# 0     Agriculture  agrochem_addition
# 1     Agriculture  agrochem_addition
# 2     Agriculture  agrochem_addition
# 3     Agriculture      annual_precpt
# 4     Agriculture        annual_temp
# ...           ...                ...
# 1204        Water          tot_phosp
# 1205        Water          tot_phosp
# 1206        Water          tot_phosp
# 1207        Water      water_current
# 1208        Water      water_current
#
#                               annotation_Preferred_unit  prefunit_count  \
# 0             gram, mole per liter, milligram per liter              13
# 1             gram, mole per liter, milligram per liter              13
# 2             gram, mole per liter, milligram per liter              13
# 3                                            millimeter               6
# 4                                        degree Celsius              88
# ...                                                 ...             ...
# 1204  micromole per liter, milligram per liter, part...              35
# 1205  micromole per liter, milligram per liter, part...              35
# 1206  micromole per liter, milligram per liter, part...              35
# 1207                      cubic meter per second, knots               2
# 1208                      cubic meter per second, knots               2
#
#            exploded_prefunit  exploded_count
# 0                       gram              10
# 1             mole per liter               7
# 2        milligram per liter              15
# 3                 millimeter               2
# 4             degree Celsius               2
# ...                      ...             ...
# 1204     micromole per liter               8
# 1205     milligram per liter              15
# 1206       parts per million              11
# 1207  cubic meter per second               1
# 1208                   knots               1
#
# [1209 rows x 6 columns]

# %%
detailed_exploded_df['annotation_times_explosion_count'] = detailed_exploded_df['prefunit_count'] * \
                                                           detailed_exploded_df['exploded_count']

# %%
detailed_exploded_df.to_csv("mixs-prefunit-explosion.tsv", index=False, sep="\t")

# %%
summary_df = (
    detailed_exploded_df
    .groupby('exploded_prefunit', as_index=False)['annotation_times_explosion_count']
    .max()
)

# %%
summary_df
# Out:
#         exploded_prefunit  annotation_times_explosion_count
# 0                angstrom                                 1
# 1              atmosphere                                12
# 2        beats per minute                                 5
# 3    cP at degree Celsius                                 2
# 4      cardinal direction                                 2
# ..                    ...                               ...
# 106                   ton                                 8
# 107                 volts                                 1
# 108                 weeks                                 1
# 109                  year                                22
# 110                 years                                 1
#
# [111 rows x 2 columns]

# %%
summary_df.to_csv("mixs-exploded-prefunit-counts.tsv", index=False, sep="\t")

# %%
exploded_prefunits_to_ucum_frame = pd.read_csv(exploded_prefunits_to_ucum, sep="\t", low_memory=False)

# %%
# Drop 'annotation_times_explosion_count' before merging
ucum_mapping_cleaned = exploded_prefunits_to_ucum_frame.drop(columns=['annotation_times_explosion_count'], errors='ignore')

# Merge on exploded_prefunit
merged_df = detailed_exploded_df.merge(
    ucum_mapping_cleaned,
    on='exploded_prefunit',
    how='left'
)

# %%
merged_df
# Out:
#             class               slot  \
# 0     Agriculture  agrochem_addition
# 1     Agriculture  agrochem_addition
# 2     Agriculture  agrochem_addition
# 3     Agriculture      annual_precpt
# 4     Agriculture        annual_temp
# ...           ...                ...
# 1204        Water          tot_phosp
# 1205        Water          tot_phosp
# 1206        Water          tot_phosp
# 1207        Water      water_current
# 1208        Water      water_current
#
#                               annotation_Preferred_unit  prefunit_count  \
# 0             gram, mole per liter, milligram per liter              13
# 1             gram, mole per liter, milligram per liter              13
# 2             gram, mole per liter, milligram per liter              13
# 3                                            millimeter               6
# 4                                        degree Celsius              88
# ...                                                 ...             ...
# 1204  micromole per liter, milligram per liter, part...              35
# 1205  micromole per liter, milligram per liter, part...              35
# 1206  micromole per liter, milligram per liter, part...              35
# 1207                      cubic meter per second, knots               2
# 1208                      cubic meter per second, knots               2
#
#            exploded_prefunit  exploded_count  \
# 0                       gram              10
# 1             mole per liter               7
# 2        milligram per liter              15
# 3                 millimeter               2
# 4             degree Celsius               2
# ...                      ...             ...
# 1204     micromole per liter               8
# 1205     milligram per liter              15
# 1206       parts per million              11
# 1207  cubic meter per second               1
# 1208                   knots               1
#
#       annotation_times_explosion_count               ucum notes  \
# 0                                  130                  g   NaN
# 1                                   91              mol/h   NaN
# 2                                  195               mg/L   NaN
# 3                                   12                 mm   NaN
# 4                                  176                Cel   NaN
# ...                                ...                ...   ...
# 1204                               280             umol/L   NaN
# 1205                               525               mg/L   NaN
# 1206                               385              [ppm]   NaN
# 1207                                 2               m3/s   NaN
# 1208                                 2  {nautical_mile}/h   NaN
#
#                                slots             example
# 0                                NaN                 NaN
# 1                                NaN                 NaN
# 2                                NaN                 NaN
# 3                                NaN                 NaN
# 4                                NaN                 NaN
# ...                              ...                 ...
# 1204                             NaN                 NaN
# 1205                             NaN                 NaN
# 1206                             NaN                 NaN
# 1207                             NaN                 NaN
# 1208  water_current|atmospheric_data  wind speed;9 knots
#
# [1209 rows x 11 columns]

# %%
merged_df.to_csv("mixs-prefunit-slots-to-ucum.tsv", index=False, sep="\t")
