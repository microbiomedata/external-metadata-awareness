# %%
import csv
import pprint
import xml.etree.ElementTree as ET
from collections import Counter

import requests
import yaml

# %%
# TSV inputs
obo_ontologies_tsv = "obo_ontologies.tsv"
bioportal_ontologies_tsv = "bioportal_ontology_class_counts.tsv"

# %%
# Fetch XML from the web
s3_url = "https://s3.amazonaws.com/bbop-sqlite"

registry_url = "https://raw.githubusercontent.com/INCATools/semantic-sql/refs/heads/main/src/semsql/builder/registry/ontologies.yaml"

ols_ontologies_endpoint_url = "https://www.ebi.ac.uk/ols4/api/ontologies?lang=en"

# Namespace needed to access elements correctly
namespace = {'ns': 'http://s3.amazonaws.com/doc/2006-03-01/'}

tsv_output = "bbop-sem-sql-catalog-filtered.tsv"

# %%
def read_tsv_to_dicts(filepath):
    with open(filepath, mode='r', newline='', encoding='utf-8') as file:
        reader = csv.DictReader(file, delimiter='\t')  # Use '\t' as the delimiter for TSV
        data = [row for row in reader]  # Convert each row into a dictionary
    return data

# %%
obo_ontologies = read_tsv_to_dicts(obo_ontologies_tsv)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 obo_ontologies = read_tsv_to_dicts(obo_ontologies_tsv)
#
# Cell In[4], line 2, in read_tsv_to_dicts(filepath)
#       1 def read_tsv_to_dicts(filepath):
# ----> 2     with open(filepath, mode='r', newline='', encoding='utf-8') as file:
#       3         reader = csv.DictReader(file, delimiter='\t')  # Use '\t' as the delimiter for TSV
#       4         data = [row for row in reader]  # Convert each row into a dictionary
#
# File ~/gitrepos/external-metadata-awareness/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'obo_ontologies.tsv'

# %%
bioportal_ontologies = read_tsv_to_dicts(bioportal_ontologies_tsv)

# %%
obo_ontologies = {i["id"]: i for i in obo_ontologies}

# %%
bioportal_ontologies = {i["acronym"].lower(): i for i in bioportal_ontologies}

# %%
bioportal_ontologies
# Out:
# {'aba-amb': {'acronym': 'ABA-AMB',
#   'name': 'Allen Brain Atlas (ABA) Adult Mouse Brain Ontology',
#   'class_count': '913'},
#  'abd': {'acronym': 'ABD',
#   'name': 'Anthology of Biosurveillance Diseases',
#   'class_count': '1445'},
#  'aceso': {'acronym': 'ACESO',
#   'name': 'Adverse Childhood Experiences Ontology',
#   'class_count': '296'},
#  'acgt-mo': {'acronym': 'ACGT-MO',
#   'name': 'Cancer Research and Management ACGT Master Ontology',
#   'class_count': '1770'},
#  'acvd_ontology': {'acronym': 'ACVD_ONTOLOGY',
#   'name': 'Atherosclerotic Cerebrovascular Disease Ontology',
#   'class_count': '1719'},
#  'ad-drop': {'acronym': 'AD-DROP',
#   'name': 'Alzheimer Disease Relevance Ontology by Process',
#   'class_count': '25'},
#  'adalab': {'acronym': 'ADALAB', 'name': 'AdaLab ontology', 'class_count': ''},
#  'adalab-meta': {'acronym': 'ADALAB-META',
#   'name': 'AdaLab-meta ontology',
#   'class_count': ''},
#  'adar': {'acronym': 'ADAR',
#   'name': 'Autism DSM-ADI-R ontology',
#   'class_count': '791'},
#  'adcad': {'acronym': 'ADCAD',
#   'name': 'Arctic Data Center Academic Disciplines Ontology',
#   'class_count': '67'},
#  'adher_intcare_en': {'acronym': 'ADHER_INTCARE_EN',
#   'name': 'Adherence and Integrated Care',
#   'class_count': '264'},
#  'adher_intcare_sp': {'acronym': 'ADHER_INTCARE_SP',
#   'name': 'Adherence and Integrated Care in Spanish',
#   'class_count': ''},
#  'admf': {'acronym': 'ADMF',
#   'name': 'alzhaimer dessiese main factors',
#   'class_count': ''},
#  'admin': {'acronym': 'ADMIN',
#   'name': 'Nurse Administrator',
#   'class_count': ''},
#  'admo': {'acronym': 'ADMO',
#   'name': 'Alzheimer Disease Map Ontology',
#   'class_count': '10943'},
#  'ado': {'acronym': 'ADO',
#   'name': "Alzheimer's Disease Ontology",
#   'class_count': ''},
#  'adw': {'acronym': 'ADW',
#   'name': 'Animal Natural History and Life History Ontology',
#   'class_count': '364'},
#  'aeo': {'acronym': 'AEO',
#   'name': 'Anatomical Entity Ontology',
#   'class_count': '250'},
#  'aero': {'acronym': 'AERO',
#   'name': 'Adverse Event Reporting Ontology',
#   'class_count': '497'},
#  'afo': {'acronym': 'AFO',
#   'name': 'Allotrope Merged Ontology Suite',
#   'class_count': '3367'},
#  'afpo': {'acronym': 'AFPO',
#   'name': 'African Population Ontology',
#   'class_count': '473'},
#  'agro': {'acronym': 'AGRO',
#   'name': 'AGRonomy Ontology',
#   'class_count': '4163'},
#  'agrocymac': {'acronym': 'AGROCYMAC',
#   'name': 'Control y Monitoreo de afecciones en los cultivos',
#   'class_count': ''},
#  'agromop': {'acronym': 'AGROMOP',
#   'name': 'Control de Cacao',
#   'class_count': ''},
#  'ahol': {'acronym': 'AHOL',
#   'name': 'Animal Health Ontology for Livestock',
#   'class_count': '339'},
#  'ahso': {'acronym': 'AHSO',
#   'name': 'Animal Health Surveillance Ontology',
#   'class_count': '38'},
#  'ai': {'acronym': 'AI',
#   'name': 'Artificial Intelligence',
#   'class_count': '444'},
#  'ai-rheum': {'acronym': 'AI-RHEUM',
#   'name': 'Artificial Intelligence Rheumatology Consultant System Ontology',
#   'class_count': '808'},
#  'aio': {'acronym': 'AIO',
#   'name': 'Artificial Intelligence Ontology',
#   'class_count': '443'},
#  'aism': {'acronym': 'AISM',
#   'name': 'Ontology for the Anatomy of the Insect SkeletoMuscular system',
#   'class_count': '7443'},
#  'allergidoc': {'acronym': 'ALLERGIDOC',
#   'name': 'Allergy Ontology',
#   'class_count': '106'},
#  'allergydetector': {'acronym': 'ALLERGYDETECTOR',
#   'name': 'Allergy Detector II',
#   'class_count': '12'},
#  'altproton': {'acronym': 'ALTPROTON',
#   'name': 'An Ontology for integration and interoperability of multi-aspect data of Protein food production chains',
#   'class_count': '300'},
#  'amino-acid': {'acronym': 'AMINO-ACID',
#   'name': 'Amino Acid Ontology',
#   'class_count': '46'},
#  'amphx': {'acronym': 'AMPHX',
#   'name': 'The Amphioxus Development and Anatomy Ontology',
#   'class_count': '403'},
#  'ao': {'acronym': 'AO', 'name': 'Asthma Ontology', 'class_count': '289'},
#  'apacomputer': {'acronym': 'APACOMPUTER',
#   'name': 'Computer Cluster',
#   'class_count': '114'},
#  'apadisorders': {'acronym': 'APADISORDERS',
#   'name': 'Disorders cluster',
#   'class_count': '822'},
#  'apaeducluster': {'acronym': 'APAEDUCLUSTER',
#   'name': 'Educational Cluster',
#   'class_count': '509'},
#  'apaneurocluster': {'acronym': 'APANEUROCLUSTER',
#   'name': 'APA Neuro Cluster',
#   'class_count': '501'},
#  'apaocuemploy': {'acronym': 'APAOCUEMPLOY',
#   'name': 'APA Occupational and Employment cluster',
#   'class_count': '448'},
#  'apaonto': {'acronym': 'APAONTO',
#   'name': 'Psychology Ontology',
#   'class_count': '6037'},
#  'apastatistical': {'acronym': 'APASTATISTICAL',
#   'name': 'APA Statistical Cluster',
#   'class_count': '140'},
#  'apatandt': {'acronym': 'APATANDT',
#   'name': 'APA Tests and Testing cluster',
#   'class_count': '208'},
#  'apatreatment': {'acronym': 'APATREATMENT',
#   'name': 'APA Treatment Cluster',
#   'class_count': '480'},
#  'apo': {'acronym': 'APO',
#   'name': 'Ascomycete Phenotype Ontology',
#   'class_count': '619'},
#  'apollo-sv': {'acronym': 'APOLLO-SV',
#   'name': 'Apollo Structured Vocabulary',
#   'class_count': '1717'},
#  'apro': {'acronym': 'APRO',
#   'name': 'Ancient Poet Resource Ontology',
#   'class_count': ''},
#  'arcrc': {'acronym': 'ARCRC',
#   'name': 'Arctic Report Card',
#   'class_count': '95'},
#  'aro': {'acronym': 'ARO',
#   'name': 'Antibiotic Resistance Ontology',
#   'class_count': '8526'},
#  'asdf': {'acronym': 'ASDF', 'name': 'testiiii1', 'class_count': ''},
#  'asdpto': {'acronym': 'ASDPTO',
#   'name': 'Autism Spectrum Disorder Phenotype Ontology',
#   'class_count': '284'},
#  'aspect': {'acronym': 'ASPECT',
#   'name': 'ASPECT: wind energy vAriableS, ParametErs and ConsTants',
#   'class_count': '2'},
#  'assaynode': {'acronym': 'ASSAYNODE',
#   'name': 'Assaynode',
#   'class_count': '48'},
#  'atc': {'acronym': 'ATC',
#   'name': 'Anatomical Therapeutic Chemical Classification',
#   'class_count': '6934'},
#  'ato': {'acronym': 'ATO',
#   'name': 'Amphibian Taxonomy Ontology',
#   'class_count': '6135'},
#  'atol': {'acronym': 'ATOL',
#   'name': 'Animal Trait Ontology for Livestock',
#   'class_count': '2352'},
#  'atom': {'acronym': 'ATOM',
#   'name': 'Atlas Ontology Model',
#   'class_count': '93'},
#  'aura': {'acronym': 'AURA', 'name': 'KB_Bio_101', 'class_count': '27396'},
#  'bao': {'acronym': 'BAO', 'name': 'BioAssay Ontology', 'class_count': '7781'},
#  'bao-gpcr': {'acronym': 'BAO-GPCR',
#   'name': 'G Protein-Coupled Receptor BioAssays Ontology',
#   'class_count': '904'},
#  'bcgo': {'acronym': 'BCGO',
#   'name': 'Breast Cancer Grading Ontology',
#   'class_count': '133'},
#  'bci-o': {'acronym': 'BCI-O',
#   'name': 'Brain-Computer Interaction (BCI) Ontology',
#   'class_count': '182'},
#  'bclion': {'acronym': 'BCLION',
#   'name': 'Breast Cancer Lifestyle Ontology',
#   'class_count': '30'},
#  'bcmo': {'acronym': 'BCMO',
#   'name': 'Breast Cancer-Microbiome Ontology ',
#   'class_count': ''},
#  'bco': {'acronym': 'BCO',
#   'name': 'Biological Collections Ontology',
#   'class_count': '254'},
#  'bcon': {'acronym': 'BCON',
#   'name': 'Breast Cancer Ontology',
#   'class_count': '66'},
#  'bcs7': {'acronym': 'BCS7',
#   'name': 'Breast Cancer Staging - 7th Edition',
#   'class_count': '22'},
#  'bcs8': {'acronym': 'BCS8',
#   'name': 'Breast Cancer Staging - 8th Edition',
#   'class_count': '31'},
#  'bcsr-onto': {'acronym': 'BCSR-ONTO',
#   'name': 'Breast cancer screening recommendation ontology',
#   'class_count': '34'},
#  'bcteo': {'acronym': 'BCTEO',
#   'name': 'Bone and Cartilage Tissue Engineering Ontology',
#   'class_count': '253'},
#  'bctt': {'acronym': 'BCTT',
#   'name': 'Behaviour Change Technique Taxonomy',
#   'class_count': '110'},
#  'bdo': {'acronym': 'BDO',
#   'name': 'Bone Dysplasia Ontology',
#   'class_count': '3668'},
#  'be': {'acronym': 'BE', 'name': 'Bioentities', 'class_count': '442'},
#  'bero': {'acronym': 'BERO',
#   'name': 'Biological and Environmental Research Ontology',
#   'class_count': '392307'},
#  'bflc': {'acronym': 'BFLC',
#   'name': 'LC BIBFRAME 2.0 Vocabulary Extension',
#   'class_count': ''},
#  'bfo': {'acronym': 'BFO',
#   'name': 'Basic Formal Ontology',
#   'class_count': '35'},
#  'bhn': {'acronym': 'BHN',
#   'name': 'Biologie Hors Nomenclature',
#   'class_count': '2534'},
#  'bho': {'acronym': 'BHO',
#   'name': 'Bleeding History Phenotype Ontology',
#   'class_count': '544'},
#  'bibframe': {'acronym': 'BIBFRAME',
#   'name': 'BIBFRAME 2.0',
#   'class_count': ''},
#  'bibliotek-o': {'acronym': 'BIBLIOTEK-O',
#   'name': 'The Biblioteko Ontology',
#   'class_count': '278'},
#  'bifo': {'acronym': 'BIFO', 'name': 'Biofilm Ontology', 'class_count': '78'},
#  'bim': {'acronym': 'BIM',
#   'name': 'Biomedical Image Ontology',
#   'class_count': ''},
#  'bin': {'acronym': 'BIN',
#   'name': 'Body in Numbers project terminology',
#   'class_count': ''},
#  'biodivthes': {'acronym': 'BIODIVTHES',
#   'name': 'Biodiversity Thesaurus',
#   'class_count': '4'},
#  'biolink': {'acronym': 'BIOLINK',
#   'name': 'Biolink Model',
#   'class_count': '505'},
#  'biomo': {'acronym': 'BIOMO',
#   'name': 'Biological Observation Matrix Ontology',
#   'class_count': '1596'},
#  'biomodels': {'acronym': 'BIOMODELS',
#   'name': 'BioModels Ontology',
#   'class_count': '187520'},
#  'bipom': {'acronym': 'BIPOM',
#   'name': 'Biological interlocked Process Ontology for metabolism',
#   'class_count': '142'},
#  'bipon': {'acronym': 'BIPON',
#   'name': 'Bacterial interlocked Process ONtology',
#   'class_count': '1746'},
#  'birnlex': {'acronym': 'BIRNLEX',
#   'name': 'Biomedical Informatics Research Network Project Lexicon',
#   'class_count': '3580'},
#  'birthonto': {'acronym': 'BIRTHONTO',
#   'name': 'BirthOnto: Birth Data Analysis',
#   'class_count': '87'},
#  'bko': {'acronym': 'BKO', 'name': 'Bricks ontology', 'class_count': '669'},
#  'bllm': {'acronym': 'BLLM',
#   'name': 'Large Language Model Ontology',
#   'class_count': ''},
#  'bmont': {'acronym': 'BMONT',
#   'name': 'The Biomarker Ontology',
#   'class_count': '542'},
#  'bms-lm': {'acronym': 'BMS-LM',
#   'name': 'BioMedical Study Lifecycle Management',
#   'class_count': '154'},
#  'bmt': {'acronym': 'BMT', 'name': 'Biomedical Topics', 'class_count': '253'},
#  'bno': {'acronym': 'BNO',
#   'name': 'Bionutrition Ontology',
#   'class_count': '100'},
#  'bof': {'acronym': 'BOF',
#   'name': 'Biodiversity Ontology',
#   'class_count': '189'},
#  'boshi': {'acronym': 'BOSHI', 'name': 'boshra', 'class_count': ''},
#  'bp': {'acronym': 'BP',
#   'name': 'BioPAX Ontology of Biological Pathways',
#   'class_count': '69'},
#  'bp-metadata': {'acronym': 'BP-METADATA',
#   'name': 'BioPortal Metadata Ontology',
#   'class_count': '102'},
#  'bpforms': {'acronym': 'BPFORMS',
#   'name': 'Ontology of chemically concrete, composable DNA, RNA, and protein residue and crosslinks',
#   'class_count': ''},
#  'bpt': {'acronym': 'BPT',
#   'name': 'Biological Pathway Taxonomy',
#   'class_count': '3875'},
#  'brain-cof': {'acronym': 'BRAIN-COF',
#   'name': 'Computational Ontology Framework for Brain Profiles',
#   'class_count': '125'},
#  'brazi': {'acronym': 'BRAZI',
#   'name': 'Estados, Municipios, Bairros e Regiões do Brasil',
#   'class_count': ''},
#  'brct': {'acronym': 'BRCT',
#   'name': 'Brain Region & Cell Type terminology',
#   'class_count': '1654'},
#  'bridg': {'acronym': 'BRIDG',
#   'name': 'Biomedical Research Integrated Domain Group Model',
#   'class_count': '325'},
#  'bro': {'acronym': 'BRO',
#   'name': 'Biomedical Resource Ontology',
#   'class_count': '488'},
#  'brso': {'acronym': 'BRSO',
#   'name': 'Biological Resource Schema Ontology',
#   'class_count': '15'},
#  'bsao': {'acronym': 'BSAO',
#   'name': 'Botryllus schlosseri anatomy and development ontology',
#   'class_count': '104'},
#  'bspo': {'acronym': 'BSPO', 'name': 'Spatial Ontology', 'class_count': '170'},
#  'bt': {'acronym': 'BT', 'name': 'BioTop Ontology', 'class_count': '390'},
#  'bt-ontology': {'acronym': 'BT-ONTOLOGY',
#   'name': 'BrainTeaser Ontology (BTO)',
#   'class_count': '180'},
#  'bto': {'acronym': 'BTO',
#   'name': 'BRENDA Tissue and Enzyme Source Ontology',
#   'class_count': '6569'},
#  'bto-bfo': {'acronym': 'BTO-BFO',
#   'name': 'Brinell Test Ontology-BFO',
#   'class_count': '182'},
#  'bto-emmo': {'acronym': 'BTO-EMMO',
#   'name': 'Brinell Test Ontology-EMMO',
#   'class_count': '2227'},
#  'bto-provo': {'acronym': 'BTO-PROVO',
#   'name': 'Brinell Test Ontology-PROVO',
#   'class_count': '253'},
#  'bto_ontology': {'acronym': 'BTO_ONTOLOGY',
#   'name': 'Brain Tumour Ontology',
#   'class_count': '28'},
#  'c19m': {'acronym': 'C19M', 'name': 'COVID-19', 'class_count': ''},
#  'cabro': {'acronym': 'CABRO',
#   'name': 'Computer Assisted Brain Injury Rehabilitation Ontology',
#   'class_count': '59'},
#  'canco': {'acronym': 'CANCO',
#   'name': 'Cancer Chemoprevention Ontology',
#   'class_count': '127'},
#  'canont': {'acronym': 'CANONT',
#   'name': 'Upper-Level Cancer Ontology ',
#   'class_count': '56'},
#  'cao': {'acronym': 'CAO',
#   'name': 'Clusters of Orthologous Groups (COG) Analysis Ontology',
#   'class_count': '205'},
#  'carelex': {'acronym': 'CARELEX',
#   'name': 'Content Archive Resource Exchange Lexicon',
#   'class_count': '339'},
#  'caro': {'acronym': 'CARO',
#   'name': 'Common Anatomy Reference Ontology',
#   'class_count': '721'},
#  'carolio': {'acronym': 'CAROLIO',
#   'name': "Caroli's Disease and Syndrome Ontology",
#   'class_count': '87'},
#  'carre': {'acronym': 'CARRE',
#   'name': 'CARRE Risk Factor ontology',
#   'class_count': '175'},
#  'case-base-onto': {'acronym': 'CASE-BASE-ONTO',
#   'name': 'Case-base ontology for gastric dystemperament in Persian medicine',
#   'class_count': ''},
#  'cbo': {'acronym': 'CBO',
#   'name': 'Cell Behavior Ontology',
#   'class_count': '246'},
#  'ccf': {'acronym': 'CCF',
#   'name': 'Human Reference Atlas Common Coordinate Framework Ontology',
#   'class_count': '41'},
#  'cco': {'acronym': 'CCO',
#   'name': 'Cell Cycle Ontology',
#   'class_count': '264891'},
#  'ccon': {'acronym': 'CCON',
#   'name': 'Cerrado concepts and plant community dynamics',
#   'class_count': '86'},
#  'ccont': {'acronym': 'CCONT',
#   'name': 'Cell Culture Ontology',
#   'class_count': ''},
#  'cctoo': {'acronym': 'CCTOO',
#   'name': 'Cancer Care: Treatment Outcome Ontology',
#   'class_count': '1133'},
#  'cdao': {'acronym': 'CDAO',
#   'name': 'Comparative Data Analysis Ontology',
#   'class_count': '165'},
#  'cdmonto': {'acronym': 'CDMONTO',
#   'name': 'Common Diabetes Medications Ontology',
#   'class_count': '303'},
#  'cdno': {'acronym': 'CDNO',
#   'name': 'Compositional Dietary Nutrition Ontology',
#   'class_count': ''},
#  'cdo': {'acronym': 'CDO',
#   'name': 'Chinese Diabetes Mellitus Ontology',
#   'class_count': ''},
#  'cdoh': {'acronym': 'CDOH',
#   'name': 'Commercial determinant of Health Ontology',
#   'class_count': '357'},
#  'cdpeo': {'acronym': 'CDPEO',
#   'name': 'Chronic Disease Patient Education Ontology',
#   'class_count': '40'},
#  'cedarpc': {'acronym': 'CEDARPC',
#   'name': 'CEDAR Provisional Classes',
#   'class_count': ''},
#  'cedarvs': {'acronym': 'CEDARVS',
#   'name': 'CEDAR Value Sets',
#   'class_count': '34'},
#  'ceph': {'acronym': 'CEPH',
#   'name': 'Cephalopod Ontology',
#   'class_count': '1569'},
#  'chd': {'acronym': 'CHD',
#   'name': 'Congenital Heart Defects Ontology',
#   'class_count': '511'},
#  'chear': {'acronym': 'CHEAR',
#   'name': "Children's Health Exposure Analysis Resource",
#   'class_count': '14864'},
#  'chebi': {'acronym': 'CHEBI',
#   'name': 'Chemical Entities of Biological Interest Ontology',
#   'class_count': '220816'},
#  'chembio': {'acronym': 'CHEMBIO',
#   'name': 'Systems Chemical Biology and Chemogenomics Ontology ',
#   'class_count': '104'},
#  'cheminf': {'acronym': 'CHEMINF',
#   'name': 'Chemical Information Ontology',
#   'class_count': '849'},
#  'chemrof': {'acronym': 'CHEMROF', 'name': 'CHEMROF', 'class_count': '237'},
#  'chiro': {'acronym': 'CHIRO',
#   'name': 'CHEBI Integrated Role Ontology',
#   'class_count': '13286'},
#  'chmo': {'acronym': 'CHMO',
#   'name': 'Chemical Methods Ontology',
#   'class_count': '3100'},
#  'cho': {'acronym': 'CHO', 'name': 'ChemoOnto', 'class_count': '14'},
#  'chr': {'acronym': 'CHR', 'name': 'Monochrom', 'class_count': '2650'},
#  'chro': {'acronym': 'CHRO',
#   'name': 'Chromatin Regulator Ontology',
#   'class_count': '1204'},
#  'cido': {'acronym': 'CIDO',
#   'name': 'Coronavirus Infectious Disease Ontology',
#   'class_count': '31924'},
#  'cidoc-crm': {'acronym': 'CIDOC-CRM',
#   'name': 'CIDOC Conceptual Reference Model',
#   'class_count': '85'},
#  'ciinteado': {'acronym': 'CIINTEADO',
#   'name': 'Ciona intestinalis Anatomy and Development Ontology',
#   'class_count': '880'},
#  'cio': {'acronym': 'CIO',
#   'name': 'Confidence Information Ontology',
#   'class_count': '44'},
#  'cisaviado': {'acronym': 'CISAVIADO',
#   'name': 'Ciona savignyi Anatomy and Development Ontology ',
#   'class_count': '880'},
#  'ckdo': {'acronym': 'CKDO',
#   'name': 'Chronic Kidney Disease Ontology',
#   'class_count': '280'},
#  'cl': {'acronym': 'CL', 'name': 'Cell Ontology', 'class_count': '16667'},
#  'clao': {'acronym': 'CLAO',
#   'name': 'Collembola Anatomy Ontology',
#   'class_count': '1516'},
#  'clo': {'acronym': 'CLO',
#   'name': 'Cell Line Ontology',
#   'class_count': '43327'},
#  'clyh': {'acronym': 'CLYH',
#   'name': 'Clytia hemisphaerica Development and Anatomy Ontology',
#   'class_count': '265'},
#  'cmdo': {'acronym': 'CMDO',
#   'name': 'Clinical MetaData Ontology',
#   'class_count': '188'},
#  'cmecs': {'acronym': 'CMECS',
#   'name': 'Coastal and Marine Ecological Classification Standard Catalog',
#   'class_count': '1690'},
#  'cmo': {'acronym': 'CMO',
#   'name': 'Clinical Measurement Ontology',
#   'class_count': '4047'},
#  'cmpo': {'acronym': 'CMPO',
#   'name': 'Cellular microscopy phenotype ontology',
#   'class_count': '813'},
#  'cmr-qa': {'acronym': 'CMR-QA',
#   'name': 'Cardiovascular Magnetic Resonance Quality Assessment Ontology',
#   'class_count': '110'},
#  'cn': {'acronym': 'CN', 'name': 'computer network', 'class_count': '537'},
#  'cno': {'acronym': 'CNO',
#   'name': 'Computational Neuroscience Ontology',
#   'class_count': '386'},
#  'co': {'acronym': 'CO', 'name': 'Crop Ontology', 'class_count': ''},
#  'co-wheat': {'acronym': 'CO-WHEAT',
#   'name': 'Wheat Trait Ontology ',
#   'class_count': '176'},
#  'cob': {'acronym': 'COB',
#   'name': 'Core Ontology for Biology and Biomedicine',
#   'class_count': '68'},
#  'codo': {'acronym': 'CODO',
#   'name': 'CODO: an Ontology for collection and analysis of COviD-19 data',
#   'class_count': '385'},
#  'cogat': {'acronym': 'COGAT',
#   'name': 'Cognitive Atlas Ontology',
#   'class_count': '4053'},
#  'cogpo': {'acronym': 'COGPO',
#   'name': 'Cognitive Paradigm Ontology',
#   'class_count': '199'},
#  'cohsi2study': {'acronym': 'COHSI2STUDY',
#   'name': 'cohsi2study',
#   'class_count': '2'},
#  'cohsi2termsweekx': {'acronym': 'COHSI2TERMSWEEKX',
#   'name': 'cohsi2termsweekx',
#   'class_count': '2'},
#  'coid': {'acronym': 'COID',
#   'name': 'Combined Ontology for Inflammatory Diseases',
#   'class_count': '1185'},
#  'cokpme': {'acronym': 'COKPME',
#   'name': 'COKPME - COVID19 Ontology for analyzing the Karnataka Private Medical Establishments Data  ',
#   'class_count': '25'},
#  'colao': {'acronym': 'COLAO',
#   'name': 'Coleoptera Anatomy Ontology',
#   'class_count': '894'},
#  'comet': {'acronym': 'COMET',
#   'name': 'LinkML Common Metadata Elements and Terms',
#   'class_count': '207'},
#  'como': {'acronym': 'COMO',
#   'name': 'Context and Measurement Ontology',
#   'class_count': '445'},
#  'comodi': {'acronym': 'COMODI', 'name': 'COMODI', 'class_count': '65'},
#  'condor': {'acronym': 'CONDOR',
#   'name': 'Liver Cancer Ontology Diagnosis Treatment',
#   'class_count': '55'},
#  'contsonto': {'acronym': 'CONTSONTO',
#   'name': 'Continuity of care',
#   'class_count': '171'},
#  'copdo': {'acronym': 'COPDO', 'name': 'COPD Ontology', 'class_count': '108'},
#  'costart': {'acronym': 'COSTART',
#   'name': 'Coding Symbols for a Thesaurus of Adverse Reaction Terms',
#   'class_count': '1707'},
#  'covid-19': {'acronym': 'COVID-19',
#   'name': 'COVID-19 Ontology',
#   'class_count': '2270'},
#  'covid-19-ont-pm': {'acronym': 'COVID-19-ONT-PM',
#   'name': 'COVID-19OntologyInPatternMedicine',
#   'class_count': '299'},
#  'covid19': {'acronym': 'COVID19',
#   'name': 'COVID-19 Surveillance Ontology',
#   'class_count': '32'},
#  'covid19-ibo': {'acronym': 'COVID19-IBO',
#   'name': 'Covid19 Impact on Banking Ontology',
#   'class_count': '159'},
#  'covidcrfrapid': {'acronym': 'COVIDCRFRAPID',
#   'name': 'WHO COVID-19 Rapid Version CRF semantic data model',
#   'class_count': '396'},
#  'cpro': {'acronym': 'CPRO',
#   'name': 'Computer-Based Patient Record Ontology',
#   'class_count': '128'},
#  'cpt': {'acronym': 'CPT',
#   'name': 'CPT - Current Procedural Terminology',
#   'class_count': '14403'},
#  'cptac': {'acronym': 'CPTAC',
#   'name': 'CPTAC Proteomics Pipeline Infrastructure Ontology',
#   'class_count': '19'},
#  'creno': {'acronym': 'CRENO',
#   'name': 'Culture, Race, Ethnicity and Nationality Ontology',
#   'class_count': '1107'},
#  'crisp': {'acronym': 'CRISP',
#   'name': 'Computer Retrieval of Information on Scientific Projects Thesaurus',
#   'class_count': '9039'},
#  'cro': {'acronym': 'CRO',
#   'name': 'Contributor Role Ontology',
#   'class_count': '124'},
#  'cryoem': {'acronym': 'CRYOEM',
#   'name': 'Cryo Electron Microscopy',
#   'class_count': '111'},
#  'cs': {'acronym': 'CS',
#   'name': 'Coping Strategies for Adverse Drug Events Ontology',
#   'class_count': ''},
#  'cseo': {'acronym': 'CSEO',
#   'name': 'Cigarette Smoke Exposure Ontology',
#   'class_count': '20085'},
#  'cso': {'acronym': 'CSO',
#   'name': 'Clinical Study Ontology',
#   'class_count': '37'},
#  'csso': {'acronym': 'CSSO',
#   'name': 'Clinical Signs and Symptoms Ontology',
#   'class_count': '303'},
#  'cst': {'acronym': 'CST', 'name': 'Cancer Staging Terms', 'class_count': ''},
#  'cstd': {'acronym': 'CSTD',
#   'name': 'Clinical smell and taste disorders',
#   'class_count': '98'},
#  'ctcae': {'acronym': 'CTCAE',
#   'name': 'Common Terminology Criteria for Adverse Events',
#   'class_count': '4049'},
#  'cteno': {'acronym': 'CTENO',
#   'name': 'Ctenophore Ontology',
#   'class_count': '668'},
#  'ctgo': {'acronym': 'CTGO',
#   'name': 'Clinical Trials Gov Ontology',
#   'class_count': '121'},
#  'cto': {'acronym': 'CTO',
#   'name': 'Clinical Trials Ontology',
#   'class_count': '273'},
#  'cto-ndd': {'acronym': 'CTO-NDD',
#   'name': 'Clinical Trials Ontology - Neurodegenerative Diseases',
#   'class_count': '377'},
#  'ctont': {'acronym': 'CTONT',
#   'name': 'Epoch Clinical Trial Ontology',
#   'class_count': '43'},
#  'ctu_beready_gem': {'acronym': 'CTU_BEREADY_GEM',
#   'name': 'CTU Bern BEReady Gemeinden',
#   'class_count': '3'},
#  'ctx': {'acronym': 'CTX',
#   'name': 'Cerebrotendinous Xanthomatosis Ontology',
#   'class_count': '479'},
#  'cu-vo': {'acronym': 'CU-VO', 'name': 'Venom Ontology', 'class_count': '11'},
#  'cvao': {'acronym': 'CVAO', 'name': 'STO', 'class_count': '1712'},
#  'cvdo': {'acronym': 'CVDO',
#   'name': 'Cardiovascular Disease Ontology',
#   'class_count': '720'},
#  'cwd': {'acronym': 'CWD',
#   'name': 'Consumer Wearable Device',
#   'class_count': '46'},
#  'cyto': {'acronym': 'CYTO', 'name': 'CYTOKINE', 'class_count': '317'},
#  'd3o': {'acronym': 'D3O',
#   'name': 'DSMZ Digital Diversity Ontology',
#   'class_count': '294'},
#  'datacite': {'acronym': 'DATACITE',
#   'name': 'SPAR DataCite Ontology',
#   'class_count': '21'},
#  'datacite-vocab': {'acronym': 'DATACITE-VOCAB',
#   'name': 'DATACITE V4.4',
#   'class_count': '2'},
#  'dc': {'acronym': 'DC', 'name': 'Dublin Core', 'class_count': '11'},
#  'dcat': {'acronym': 'DCAT',
#   'name': 'Data Catalog Vocabulary',
#   'class_count': ''},
#  'dcat-fdc': {'acronym': 'DCAT-FDC',
#   'name': 'Data Catalog Vocabulary (DCAT)',
#   'class_count': '73'},
#  'dcat3': {'acronym': 'DCAT3', 'name': 'DCAT3', 'class_count': '75'},
#  'dccdfv': {'acronym': 'DCCDFV',
#   'name': 'Dublin Core Collection Description Frequency Vocabulary',
#   'class_count': '1'},
#  'dcm': {'acronym': 'DCM',
#   'name': 'DICOM Controlled Terminology',
#   'class_count': '4866'},
#  'dcmitype': {'acronym': 'DCMITYPE',
#   'name': 'DCMI Type Vocabulary',
#   'class_count': '18'},
#  'dco': {'acronym': 'DCO',
#   'name': 'Dispedia Core Ontology',
#   'class_count': '49'},
#  'dct': {'acronym': 'DCT', 'name': 'DC Terms', 'class_count': '25'},
#  'dcterms': {'acronym': 'DCTERMS',
#   'name': 'DCMI Metadata Terms: properties in /terms/ namespace',
#   'class_count': '25'},
#  'ddanat': {'acronym': 'DDANAT',
#   'name': 'Dictyostelium Discoideum Anatomy Ontology',
#   'class_count': '135'},
#  'ddi': {'acronym': 'DDI',
#   'name': 'Ontology for Drug Discovery Investigations',
#   'class_count': '156'},
#  'ddiem': {'acronym': 'DDIEM',
#   'name': 'Drug Database for Inborn Errors of Metabolism (DDIEM) Ontology',
#   'class_count': '208'},
#  'ddpheno': {'acronym': 'DDPHENO',
#   'name': 'Dictyostelium Discoideum Phenotype Ontology',
#   'class_count': '1373'},
#  'ddss': {'acronym': 'DDSS',
#   'name': 'Health_ontology',
#   'class_count': '712018'},
#  'deb': {'acronym': 'DEB',
#   'name': 'Devices, Experimental scaffolds and Biomaterials Ontology',
#   'class_count': '601'},
#  'decide': {'acronym': 'DECIDE',
#   'name': 'DECIDE ONTOLOGY',
#   'class_count': '19'},
#  'dermlex': {'acronym': 'DERMLEX',
#   'name': 'Dermatology Lexicon',
#   'class_count': '6106'},
#  'dermo': {'acronym': 'DERMO',
#   'name': 'Human Dermatological Disease Ontology',
#   'class_count': '3521'},
#  'dfo': {'acronym': 'DFO',
#   'name': 'Databank Family Ontology',
#   'class_count': '12'},
#  'dhmo': {'acronym': 'DHMO',
#   'name': 'RADx Data Hub Metadata Ontology',
#   'class_count': '145'},
#  'diab': {'acronym': 'DIAB',
#   'name': 'BioMedBridges Diabetes Ontology',
#   'class_count': '375'},
#  'diagont': {'acronym': 'DIAGONT',
#   'name': 'Diagnostic Ontology',
#   'class_count': '96'},
#  'dideo': {'acronym': 'DIDEO',
#   'name': 'Drug Interaction and Evidence Ontology',
#   'class_count': '617'},
#  'dikb': {'acronym': 'DIKB',
#   'name': 'Drug Interaction Knowledge Base Ontology',
#   'class_count': '161'},
#  'dilon': {'acronym': 'DILON',
#   'name': 'Dietary lifestyle ontology',
#   'class_count': '262'},
#  'dinto': {'acronym': 'DINTO',
#   'name': 'The Drug-Drug Interactions Ontology',
#   'class_count': '28178'},
#  'disdriv': {'acronym': 'DISDRIV',
#   'name': 'Disease Drivers Ontology',
#   'class_count': '18'},
#  'dloro': {'acronym': 'DLORO',
#   'name': 'Dependency Layered Ontology for Radiation Oncology',
#   'class_count': '295'},
#  'dmdsont': {'acronym': 'DMDSONT',
#   'name': 'Diabetes Mellitus Diagnosis and Support Ontology ',
#   'class_count': '8'},
#  'dmto': {'acronym': 'DMTO',
#   'name': 'Diabetes Mellitus Treatment Ontology',
#   'class_count': ''},
#  'doccc': {'acronym': 'DOCCC',
#   'name': 'Diagnosis Ontology of Clinical Care Classification',
#   'class_count': '204'},
#  'doid': {'acronym': 'DOID',
#   'name': 'Human Disease Ontology',
#   'class_count': '18897'},
#  'doremus-keys': {'acronym': 'DOREMUS-KEYS',
#   'name': 'Doremus List of Keys',
#   'class_count': '3'},
#  'doves': {'acronym': 'DOVES',
#   'name': 'Digital medicine Outcomes Value Set (DOVeS) Ontology',
#   'class_count': '27531'},
#  'dpco': {'acronym': 'DPCO',
#   'name': 'Diabetes Pharmacology Ontology',
#   'class_count': ''},
#  'dpo': {'acronym': 'DPO',
#   'name': 'Drosophila Phenotype Ontology',
#   'class_count': '1382'},
#  'dranpto': {'acronym': 'DRANPTO',
#   'name': 'Dementia-Related Agitation Non-Pharmacological Treatment Ontology',
#   'class_count': '569'},
#  'dreamdnpto': {'acronym': 'DREAMDNPTO',
#   'name': 'Dementia-Related Emotional And Mood Disturbance Non-Pharmacological Treatment Ontology',
#   'class_count': '1258'},
#  'drmo': {'acronym': 'DRMO',
#   'name': 'Dental Restorative Material Ontology',
#   'class_count': ''},
#  'dron': {'acronym': 'DRON',
#   'name': 'The Drug Ontology',
#   'class_count': '747494'},
#  'drpsnpto': {'acronym': 'DRPSNPTO',
#   'name': 'Dementia-Related Psychotic Symptoms Non-Pharmacological Treatment Ontology',
#   'class_count': '610'},
#  'dseo': {'acronym': 'DSEO',
#   'name': 'Data Science Education Ontology',
#   'class_count': '131'},
#  'dsip': {'acronym': 'DSIP', 'name': 'Pharmacy mock data', 'class_count': ''},
#  'dsip1v': {'acronym': 'DSIP1V',
#   'name': 'DSIP1_vocabulary',
#   'class_count': '2'},
#  'dsip2324_demo': {'acronym': 'DSIP2324_DEMO',
#   'name': 'DSIP2324_Demonstration',
#   'class_count': '2'},
#  'dsip7': {'acronym': 'DSIP7', 'name': 'DSIP_FieldLab_7', 'class_count': '2'},
#  'dsip8': {'acronym': 'DSIP8', 'name': 'DSIP8REFUGEE', 'class_count': '2'},
#  'dsipf7': {'acronym': 'DSIPF7',
#   'name': 'DSIP FiledLab7 ',
#   'class_count': '2'},
#  'dsipfl7': {'acronym': 'DSIPFL7',
#   'name': 'DSIP_Fieldlab_7',
#   'class_count': '2'},
#  'dsip_fl_7': {'acronym': 'DSIP_FL_7',
#   'name': 'DSIP_FL_7',
#   'class_count': '2'},
#  'dto': {'acronym': 'DTO',
#   'name': 'Drug Target Ontology',
#   'class_count': '10075'},
#  'duo': {'acronym': 'DUO',
#   'name': 'The Data Use Ontology',
#   'class_count': '307'},
#  'e-ppo': {'acronym': 'E-PPO',
#   'name': 'Enhanced Personal Profile Ontology',
#   'class_count': '54'},
#  'ebp': {'acronym': 'EBP', 'name': 'EmpowerBP', 'class_count': '50'},
#  'ecao': {'acronym': 'ECAO',
#   'name': 'The Echinoderm Anatomy and Development Ontology',
#   'class_count': '7160'},
#  'ecdo': {'acronym': 'ECDO',
#   'name': 'Elderly Care Dementia Ontology',
#   'class_count': '2'},
#  'ecg': {'acronym': 'ECG',
#   'name': 'Electrocardiography Ontology',
#   'class_count': '1124'},
#  'ecm4m-md-vocabs': {'acronym': 'ECM4M-MD-VOCABS',
#   'name': 'EarthCube M4M Metadata Vocabulary',
#   'class_count': '2'},
#  'eco': {'acronym': 'ECO',
#   'name': 'Evidence and Conclusion Ontology',
#   'class_count': '2284'},
#  'ecocore': {'acronym': 'ECOCORE',
#   'name': 'An ontology of core ecological entities',
#   'class_count': '5586'},
#  'ecosim': {'acronym': 'ECOSIM',
#   'name': 'ecosim ontology',
#   'class_count': '1684'},
#  'ecp': {'acronym': 'ECP',
#   'name': 'Electronic Care Plan',
#   'class_count': '32'},
#  'ecso': {'acronym': 'ECSO',
#   'name': 'The Ecosystem Ontology',
#   'class_count': '2094'},
#  'ecto': {'acronym': 'ECTO',
#   'name': 'Environmental conditions, treatments and exposures ontology',
#   'class_count': ''},
#  'edam': {'acronym': 'EDAM',
#   'name': 'EDAM - The data analysis and management ontology',
#   'class_count': '3511'},
#  'edam-bioimaging': {'acronym': 'EDAM-BIOIMAGING',
#   'name': 'EDAM Bioimaging Ontology',
#   'class_count': '341'},
#  'edda': {'acronym': 'EDDA',
#   'name': 'EDDA Study Designs Taxonomy',
#   'class_count': '502'},
#  'edda_pt': {'acronym': 'EDDA_PT',
#   'name': 'EDDA Publication Types Taxonomy',
#   'class_count': '93'},
#  'edem-connectonto': {'acronym': 'EDEM-CONNECTONTO',
#   'name': 'eDEM-Connect: Ontology of Dementia-related Agitation and Relationship between Informal Caregivers and Persons with Dementia',
#   'class_count': '241'},
#  'efo': {'acronym': 'EFO',
#   'name': 'Experimental Factor Ontology',
#   'class_count': '63496'},
#  'ego': {'acronym': 'EGO',
#   'name': 'Epigenome Ontology',
#   'class_count': '2952'},
#  'ehda': {'acronym': 'EHDA',
#   'name': 'Human Developmental Anatomy Ontology, timed version',
#   'class_count': '8340'},
#  'ehdaa': {'acronym': 'EHDAA',
#   'name': 'Human Developmental Anatomy Ontology, abstract version 1',
#   'class_count': '2314'},
#  'ehdaa2': {'acronym': 'EHDAA2',
#   'name': 'Human Developmental Anatomy Ontology, abstract version 2',
#   'class_count': '2743'},
#  'eld': {'acronym': 'ELD',
#   'name': 'EthiopianListOfDiseases',
#   'class_count': '2'},
#  'electrica': {'acronym': 'ELECTRICA',
#   'name': 'Ontology for ELEctronic tool for Clinicians, Trainers and Researchers In Child Abuse',
#   'class_count': '1741'},
#  'elig': {'acronym': 'ELIG',
#   'name': 'Eligibility Feature Hierarchy',
#   'class_count': '29'},
#  'elter_cl': {'acronym': 'ELTER_CL',
#   'name': 'eLTER Controlled Lists',
#   'class_count': '23'},
#  'emap': {'acronym': 'EMAP',
#   'name': 'Mouse Gross Anatomy and Development Ontology',
#   'class_count': '19444'},
#  'emapa': {'acronym': 'EMAPA',
#   'name': 'Mouse gross anatomy and development, timed',
#   'class_count': '8768'},
#  'emif-ad': {'acronym': 'EMIF-AD',
#   'name': 'EMIF-AD ontology',
#   'class_count': '700'},
#  'emo': {'acronym': 'EMO',
#   'name': 'Enzyme Mechanism Ontology',
#   'class_count': ''},
#  'endoh': {'acronym': 'ENDOH',
#   'name': 'Environmental Determinants of Health',
#   'class_count': '102'},
#  'enm': {'acronym': 'ENM', 'name': 'eNanoMapper', 'class_count': '25795'},
#  'entity': {'acronym': 'ENTITY',
#   'name': 'ISO-15926-2_2003_entityMembership',
#   'class_count': '203'},
#  'envo': {'acronym': 'ENVO',
#   'name': 'Environment Ontology',
#   'class_count': '7030'},
#  'envs_variables': {'acronym': 'ENVS_VARIABLES',
#   'name': 'ENVS variables',
#   'class_count': '2'},
#  'envthes': {'acronym': 'ENVTHES',
#   'name': 'Thesaurus for long-term ecological research, monitoring, experiments',
#   'class_count': '6'},
#  'eo': {'acronym': 'EO', 'name': 'Ethnicity Ontoloy', 'class_count': ''},
#  'eo1': {'acronym': 'EO1', 'name': 'Example Ontology', 'class_count': '2'},
#  'eol': {'acronym': 'EOL',
#   'name': 'Environment Ontology for Livestock',
#   'class_count': '648'},
#  'ep': {'acronym': 'EP',
#   'name': 'Cardiac Electrophysiology Ontology',
#   'class_count': '232'},
#  'epie': {'acronym': 'EPIE',
#   'name': 'Epigenetic Entity',
#   'class_count': '392'},
#  'epilont': {'acronym': 'EPILONT',
#   'name': 'Epilepsy Ontology',
#   'class_count': '138'},
#  'epio': {'acronym': 'EPIO',
#   'name': 'EpilepsyOntology',
#   'class_count': '1916'},
#  'epip': {'acronym': 'EPIP',
#   'name': 'Epigenetic Process',
#   'class_count': '263'},
#  'episem': {'acronym': 'EPISEM',
#   'name': 'Epilepsy Semiology',
#   'class_count': '1594'},
#  'epo': {'acronym': 'EPO',
#   'name': 'Early Pregnancy Ontology',
#   'class_count': ''},
#  'epso': {'acronym': 'EPSO',
#   'name': 'Epilepsy and Seizure Ontology',
#   'class_count': '2160'},
#  'ero': {'acronym': 'ERO',
#   'name': 'Eagle-I Research Resource Ontology',
#   'class_count': '4061'},
#  'esfo': {'acronym': 'ESFO',
#   'name': 'Enzyme Structure Function Ontology',
#   'class_count': '22'},
#  'eso_c': {'acronym': 'ESO_C',
#   'name': 'Epilepsy Semiology Ontology',
#   'class_count': '179'},
#  'esso': {'acronym': 'ESSO',
#   'name': 'Epilepsy Syndrome Seizure Ontology',
#   'class_count': '2705'},
#  'etanc': {'acronym': 'ETANC', 'name': 'ETHIOPIANC', 'class_count': '2'},
#  'ethanc': {'acronym': 'ETHANC', 'name': 'ETHANC', 'class_count': '2'},
#  'ethopd': {'acronym': 'ETHOPD', 'name': 'Ethiopian OPD', 'class_count': '2'},
#  'eupath': {'acronym': 'EUPATH',
#   'name': 'VEuPathDB Ontology',
#   'class_count': '5110'},
#  'evi': {'acronym': 'EVI',
#   'name': 'Evidence Graph Ontology',
#   'class_count': '31'},
#  'evs': {'acronym': 'EVS', 'name': 'Exposure Value Set', 'class_count': '2'},
#  'exact': {'acronym': 'EXACT',
#   'name': 'An ontology for experimental actions',
#   'class_count': '162'},
#  'exmo': {'acronym': 'EXMO',
#   'name': 'Exercise Medicine Ontology',
#   'class_count': ''},
#  'exo': {'acronym': 'EXO', 'name': 'Exposure Ontology', 'class_count': '152'},
#  'exon': {'acronym': 'EXON',
#   'name': 'Experimental Ontology',
#   'class_count': '5'},
#  'extract': {'acronym': 'EXTRACT',
#   'name': 'EXTeRnAl Conditions Taxonomy (EXTRACT)',
#   'class_count': '2'},
#  'faldo': {'acronym': 'FALDO',
#   'name': 'Feature Annotation Location Description Ontology ',
#   'class_count': '19'},
#  'fall': {'acronym': 'FALL',
#   'name': 'MyOntoServiceFull_FallDetection',
#   'class_count': '51'},
#  'falls': {'acronym': 'FALLS',
#   'name': 'falls prevention ',
#   'class_count': '30'},
#  'fao': {'acronym': 'FAO',
#   'name': 'Fungal Gross Anatomy Ontology',
#   'class_count': '120'},
#  'farmaci': {'acronym': 'FARMACI', 'name': 'FARMACI AIFA', 'class_count': ''},
#  'fast-chrono': {'acronym': 'FAST-CHRONO',
#   'name': 'FAST (Faceted Access of Subject Terminology) Chronological Facet',
#   'class_count': '3'},
#  'fast-event': {'acronym': 'FAST-EVENT',
#   'name': 'FAST (Faceted Application of Subject Terminology) Event',
#   'class_count': '4'},
#  'fast-event-skos': {'acronym': 'FAST-EVENT-SKOS',
#   'name': 'FAST (Faceted Application of Subject Terminology) Event Facet',
#   'class_count': '4'},
#  'fast-formgenre': {'acronym': 'FAST-FORMGENRE',
#   'name': 'FAST (Faceted Application of Subject Terminology) FormGenre facet',
#   'class_count': '3'},
#  'fast-genreform': {'acronym': 'FAST-GENREFORM',
#   'name': 'FAST (Faceted Access of Subject Terminology) GenreForm',
#   'class_count': '4'},
#  'fast-title': {'acronym': 'FAST-TITLE',
#   'name': 'FAST (Faceted Application of Subject Terminology) Title Facet',
#   'class_count': '3'},
#  'fasto': {'acronym': 'FASTO',
#   'name': 'HL7 FHIR and SSN ontology based Type 1 Diabetes Mellitus Ontology',
#   'class_count': ''},
#  'fb-bt': {'acronym': 'FB-BT',
#   'name': 'Drosophila Gross Anatomy Ontology',
#   'class_count': '28344'},
#  'fb-cv': {'acronym': 'FB-CV',
#   'name': 'FlyBase Controlled Vocabulary',
#   'class_count': '2332'},
#  'fb-dv': {'acronym': 'FB-DV',
#   'name': 'Drosophila Development Ontology',
#   'class_count': '222'},
#  'fb-sp': {'acronym': 'FB-SP', 'name': 'Fly Taxonomy', 'class_count': '6600'},
#  'fbbi': {'acronym': 'FBbi',
#   'name': 'Biological Imaging Methods Ontology',
#   'class_count': '649'},
#  'fcc1': {'acronym': 'FCC1',
#   'name': 'Fernald Community Cohort N',
#   'class_count': '9'},
#  'fdc-gdmt': {'acronym': 'FDC-GDMT',
#   'name': 'Ontology for Generic Dataset Metadata Template',
#   'class_count': '2'},
#  'fdsajfahsjk': {'acronym': 'FDSAJFAHSJK',
#   'name': 'OWL_XML_Tool5',
#   'class_count': '3'},
#  'fdt-o': {'acronym': 'FDT-O',
#   'name': 'FAIR Data Train Ontology',
#   'class_count': '47'},
#  'fenics': {'acronym': 'FENICS',
#   'name': 'Functional Electrophysiology Nomenclature for Ion Channels',
#   'class_count': '153'},
#  'fg': {'acronym': 'FG', 'name': 'FAIR Genomes', 'class_count': '9'},
#  'fgnhns': {'acronym': 'FGNHNS',
#   'name': 'FoodGroupNHNS',
#   'class_count': '6087'},
#  'fhho': {'acronym': 'FHHO',
#   'name': 'Family Health History Ontology',
#   'class_count': '238'},
#  'fideo': {'acronym': 'FIDEO',
#   'name': 'Food Interactions with Drugs Evidence Ontology',
#   'class_count': '3543'},
#  'fire': {'acronym': 'FIRE', 'name': 'Fire Ontology', 'class_count': '53'},
#  'fish-ast': {'acronym': 'FISH-AST',
#   'name': 'FISH Archaeological Sciences Thesaurus',
#   'class_count': '2'},
#  'fisho': {'acronym': 'FISHO', 'name': 'Fish Ontology', 'class_count': '386'},
#  'fitbit': {'acronym': 'FITBIT',
#   'name': 'Fitbit Vocabulary',
#   'class_count': ''},
#  'fit_bit': {'acronym': 'FIT_BIT',
#   'name': 'Fitbit Vocabularies ',
#   'class_count': '2'},
#  'fix': {'acronym': 'FIX',
#   'name': 'Physico-Chemical Methods and Properties',
#   'class_count': '1163'},
#  'fldlb3': {'acronym': 'FLDLB3',
#   'name': 'FIELDLAB3_2023_2',
#   'class_count': '2'},
#  'flopo': {'acronym': 'FLOPO',
#   'name': 'Flora Phenotype Ontology',
#   'class_count': '26873'},
#  'flu': {'acronym': 'FLU', 'name': 'Influenza Ontology', 'class_count': '585'},
#  'flyglycodb': {'acronym': 'FLYGLYCODB',
#   'name': 'FlyGlycoDB',
#   'class_count': '114'},
#  'fma': {'acronym': 'FMA',
#   'name': 'Foundational Model of Anatomy',
#   'class_count': '104721'},
#  'fmpm': {'acronym': 'FMPM',
#   'name': 'Food Matrix for Predictive Microbiology',
#   'class_count': '162'},
#  'fns-h': {'acronym': 'FNS-H', 'name': 'FNS-Harmony', 'class_count': '31464'},
#  'fo': {'acronym': 'FO', 'name': 'Fern Ontology', 'class_count': ''},
#  'foaf': {'acronym': 'FOAF',
#   'name': 'Friend of a Friend Vocabulary',
#   'class_count': '22'},
#  'fobi': {'acronym': 'FOBI',
#   'name': 'FOBI (Food-Biomarker Ontology)',
#   'class_count': '1334'},
#  'foodon': {'acronym': 'FOODON',
#   'name': 'The FoodOn Food Ontology',
#   'class_count': '39435'},
#  'four-m_vocabs': {'acronym': 'FOUR-M_VOCABS',
#   'name': 'AGE-FRIENDLY 4M VOCABULARY',
#   'class_count': ''},
#  'fovt': {'acronym': 'FOVT',
#   'name': 'FuTRES Ontology of Vertebrate Traits',
#   'class_count': '11322'},
#  'fplx': {'acronym': 'FPLX', 'name': 'FamPlex', 'class_count': ''},
#  'frmo': {'acronym': 'FRMO',
#   'name': 'Fall Risk Management Ontology ',
#   'class_count': '890'},
#  'ftc': {'acronym': 'FTC',
#   'name': 'Functional Therapeutic Chemical Classification System',
#   'class_count': '61426'},
#  'fypo': {'acronym': 'FYPO',
#   'name': 'Fission Yeast Phenotype Ontology',
#   'class_count': '16770'},
#  'g-prov': {'acronym': 'G-PROV',
#   'name': 'Guideline Provenance',
#   'class_count': '138'},
#  'g4-dsip': {'acronym': 'G4-DSIP',
#   'name': 'Group 4-Data Science in Practice',
#   'class_count': '2'},
#  'galen': {'acronym': 'GALEN',
#   'name': 'Galen Ontology',
#   'class_count': '23141'},
#  'gallont': {'acronym': 'GALLONT',
#   'name': 'Plant Gall Ontology',
#   'class_count': '395'},
#  'gamuts': {'acronym': 'GAMUTS',
#   'name': 'Radiology Gamuts Ontology',
#   'class_count': '16876'},
#  'gaz': {'acronym': 'GAZ', 'name': 'Gazetteer', 'class_count': '668838'},
#  'gb': {'acronym': 'GB', 'name': 'GlycanBind', 'class_count': '13'},
#  'gbm': {'acronym': 'GBM', 'name': 'Glioblastoma', 'class_count': ''},
#  'gbol': {'acronym': 'GBOL', 'name': 'GBOL', 'class_count': '337'},
#  'gcbo': {'acronym': 'GCBO',
#   'name': 'Global Code Book Ontology',
#   'class_count': '3395'},
#  'gco': {'acronym': 'GCO',
#   'name': 'Genome Component Ontology',
#   'class_count': '5'},
#  'gdco': {'acronym': 'GDCO',
#   'name': 'Data Collection Ontology',
#   'class_count': '73'},
#  'gdmt': {'acronym': 'GDMT',
#   'name': 'Generic Dataset Metadata Template Vocabulary',
#   'class_count': ''},
#  'gdoa': {'acronym': 'GDOA',
#   'name': 'Graphic Descriptor Ontology Anatomy Extension',
#   'class_count': '188'},
#  'gecco': {'acronym': 'GECCO',
#   'name': 'COVID-19 Common Datamodel',
#   'class_count': ''},
#  'gecko': {'acronym': 'GECKO',
#   'name': 'Genomics Cohorts Knowledge Ontology',
#   'class_count': '154'},
#  'genai': {'acronym': 'GENAI',
#   'name': 'Generative AI Ontology',
#   'class_count': '55'},
#  'gender': {'acronym': 'GENDER',
#   'name': 'Gender Identity',
#   'class_count': '2'},
#  'gene-cds': {'acronym': 'GENE-CDS',
#   'name': 'Genomic Clinical Decision Support Ontology',
#   'class_count': '2265'},
#  'genepio': {'acronym': 'GENEPIO',
#   'name': 'Genomic Epidemiology Application Ontology ',
#   'class_count': '7208'},
#  'genevieve': {'acronym': 'GENEVIEVE', 'name': 'Charlotte', 'class_count': ''},
#  'geno': {'acronym': 'GENO',
#   'name': 'Genotype Ontology',
#   'class_count': '425'},
#  'geo': {'acronym': 'GEO',
#   'name': 'Geographical Entity Ontology',
#   'class_count': '328'},
#  'geosparql': {'acronym': 'GEOSPARQL',
#   'name': 'GeoSPARQL',
#   'class_count': '61'},
#  'geospecies': {'acronym': 'GEOSPECIES',
#   'name': 'GeoSpecies Ontology',
#   'class_count': '86'},
#  'gexo': {'acronym': 'GEXO',
#   'name': 'Gene Expression Ontology',
#   'class_count': '166254'},
#  'gff-m4m': {'acronym': 'GFF-M4M', 'name': 'GO FAIR M4M', 'class_count': '10'},
#  'gffo': {'acronym': 'GFFO',
#   'name': 'Genetic Feature Format Ontology',
#   'class_count': '1'},
#  'gfo': {'acronym': 'GFO',
#   'name': 'General Formal Ontology',
#   'class_count': '45'},
#  'gfo-bio': {'acronym': 'GFO-BIO',
#   'name': 'General Formal Ontology for Biology',
#   'class_count': '168'},
#  'gfvo': {'acronym': 'GFVO',
#   'name': 'Genomic Feature and Variation Ontology',
#   'class_count': '102'},
#  'glyco': {'acronym': 'GLYCO',
#   'name': 'Glycomics Ontology',
#   'class_count': ''},
#  'glycocoo': {'acronym': 'GLYCOCOO',
#   'name': 'GlycoConjugate Ontology',
#   'class_count': '51'},
#  'glycordf': {'acronym': 'GLYCORDF', 'name': 'GlycoRDF', 'class_count': '137'},
#  'gml': {'acronym': 'GML',
#   'name': 'Ontology for Geography Markup Language (GML3.0)',
#   'class_count': '175'},
#  'gmm': {'acronym': 'GMM', 'name': 'GoMapMan', 'class_count': '1896'},
#  'gmo': {'acronym': 'GMO',
#   'name': 'Growth Medium Ontology',
#   'class_count': '1559'},
#  'gno': {'acronym': 'GNO',
#   'name': 'Glycan Naming Ontology',
#   'class_count': '194565'},
#  'go': {'acronym': 'GO', 'name': 'Gene Ontology', 'class_count': '51641'},
#  'go-ext': {'acronym': 'GO-EXT',
#   'name': 'Gene Ontology Extension',
#   'class_count': '35873'},
#  'go-plus': {'acronym': 'GO-PLUS', 'name': 'go-plus', 'class_count': '84145'},
#  'goldterms': {'acronym': 'GOLDTERMS',
#   'name': 'GOLD Ecosystem Classification',
#   'class_count': '1825'},
#  'gpml': {'acronym': 'GPML',
#   'name': 'Graphical Pathway Markup Language',
#   'class_count': '19'},
#  'gro': {'acronym': 'GRO',
#   'name': 'Gene Regulation Ontology',
#   'class_count': '507'},
#  'gro-cpd': {'acronym': 'GRO-CPD',
#   'name': 'Cereal Plant Development Ontology',
#   'class_count': '238'},
#  'gro-cpga': {'acronym': 'GRO-CPGA',
#   'name': 'Cereal Plant Gross Anatomy Ontology',
#   'class_count': '1548'},
#  'gsso': {'acronym': 'GSSO',
#   'name': 'Gender, Sex, and Sexual Orientation Ontology',
#   'class_count': '13192'},
#  'gvo': {'acronym': 'GVO',
#   'name': 'Genome Variation Ontology',
#   'class_count': '77'},
#  'haauraado': {'acronym': 'HAAURAADO',
#   'name': 'Halocynthia aurantium Anatomy and Development Ontology',
#   'class_count': '856'},
#  'hamidehsgh': {'acronym': 'HAMIDEHSGH',
#   'name': 'Inherited Retinal Dystrophy',
#   'class_count': '407'},
#  'hancestro': {'acronym': 'HANCESTRO',
#   'name': 'Human Ancestry Ontology',
#   'class_count': '1259'},
#  'hao': {'acronym': 'HAO',
#   'name': 'Hymenoptera Anatomy Ontology',
#   'class_count': '2597'},
#  'haroreado': {'acronym': 'HAROREADO',
#   'name': 'Halocynthia roretzi Anatomy and Development Ontology',
#   'class_count': '856'},
#  'hasco': {'acronym': 'HASCO',
#   'name': 'Human-Aware Science Ontology',
#   'class_count': '2490'},
#  'hc': {'acronym': 'HC',
#   'name': 'Habronattus Courtship Ontology',
#   'class_count': ''},
#  'hcdr': {'acronym': 'HCDR',
#   'name': 'Homelessness and Clinical Data Recording',
#   'class_count': '119'},
#  'hcodonont': {'acronym': 'HCODONONT',
#   'name': 'HGeneCodonOntology',
#   'class_count': '98'},
#  'hcpcs': {'acronym': 'HCPCS',
#   'name': 'Healthcare Common Procedure Coding System',
#   'class_count': '7778'},
#  'hdmponto': {'acronym': 'HDMPONTO',
#   'name': 'HierarchicalDMProcessOnto',
#   'class_count': '377'},
#  'hecon': {'acronym': 'HECON',
#   'name': 'HECON: Health Condition Evolution Ontology',
#   'class_count': '16'},
#  'hed': {'acronym': 'HED',
#   'name': 'Hierarchical Event Descriptors',
#   'class_count': '1358'},
#  'heio': {'acronym': 'HEIO',
#   'name': 'Regional Healthcare System Interoperability and Information Exchange Measurement Ontology',
#   'class_count': '125'},
#  'helifit': {'acronym': 'HELIFIT',
#   'name': 'HeLiFit-Ontology',
#   'class_count': '511'},
#  'henecon': {'acronym': 'HENECON',
#   'name': 'Head and Neck Cancer Ontology',
#   'class_count': '1841'},
#  'henegeo': {'acronym': 'HENEGEO',
#   'name': 'Head and Neck Cancer - Clinical and Gene Ontology',
#   'class_count': '29996'},
#  'hero': {'acronym': 'HERO',
#   'name': 'Healthcare Monitoring and Emergency Response Ontology',
#   'class_count': '1205'},
#  'hfo': {'acronym': 'HFO',
#   'name': 'Heart Failure Ontology',
#   'class_count': '1652'},
#  'hgnc': {'acronym': 'HGNC',
#   'name': 'HUGO Gene Nomenclature',
#   'class_count': '32918'},
#  'hgnc-nr': {'acronym': 'HGNC-NR',
#   'name': 'HGNC New Releases Ontology',
#   'class_count': '49026'},
#  'hhear': {'acronym': 'HHEAR',
#   'name': 'Human Health Exposure Analysis Resource',
#   'class_count': ''},
#  'hhearp': {'acronym': 'HHEARP',
#   'name': 'HHEAR Properties',
#   'class_count': '2489'},
#  'hhearvs': {'acronym': 'HHEARVS',
#   'name': 'HHEAR Value Sets',
#   'class_count': '3'},
#  'hino': {'acronym': 'HINO',
#   'name': 'Human Interaction Network Ontology',
#   'class_count': '37630'},
#  'hio': {'acronym': 'HIO',
#   'name': 'Hearing Impairment Ontology',
#   'class_count': '496'},
#  'hiv': {'acronym': 'HIV', 'name': 'HIV ontology', 'class_count': ''},
#  'hivcrs': {'acronym': 'HIVCRS',
#   'name': 'HIVCompoundRels',
#   'class_count': '8'},
#  'hivhpv': {'acronym': 'HIVHPV', 'name': 'HIVHPV', 'class_count': ''},
#  'hivhpvfgs': {'acronym': 'HIVHPVFGS',
#   'name': 'HIV, HPV, FGS vocabulary',
#   'class_count': '2'},
#  'hivhpvschistosom': {'acronym': 'HIVHPVSCHISTOSOM',
#   'name': 'HIVHPVSchistosomiasis',
#   'class_count': '2'},
#  'hivhpvstom': {'acronym': 'HIVHPVSTOM',
#   'name': 'HIVHPVStom',
#   'class_count': ''},
#  'hivmt': {'acronym': 'HIVMT', 'name': 'HIVMutation', 'class_count': '161'},
#  'hivo004': {'acronym': 'HIVO004',
#   'name': 'HIVOntologymain.owl',
#   'class_count': ''},
#  'hl7': {'acronym': 'HL7',
#   'name': 'Health Level Seven Reference Implementation Model, Version 3',
#   'class_count': '9095'},
#  'hmado': {'acronym': 'HMADO',
#   'name': 'Human Microbiome Associated Disease Ontology ',
#   'class_count': ''},
#  'hmis033b': {'acronym': 'HMIS033B', 'name': 'HMIS 033', 'class_count': '0'},
#  'hmislab0115': {'acronym': 'HMISLAB0115',
#   'name': 'HMIS LAB 011 5',
#   'class_count': '2'},
#  'hns': {'acronym': 'HNS', 'name': 'HNS_Ontolgoy', 'class_count': ''},
# ...
#   'class_count': '178'},
#  'ontopneumo': {'acronym': 'ONTOPNEUMO',
#   'name': 'Ontology of Pneumology',
#   'class_count': '1153'},
#  'ontopsychia': {'acronym': 'ONTOPSYCHIA',
#   'name': 'OntoPsychia, social module',
#   'class_count': '1719'},
#  'ontoreplicov': {'acronym': 'ONTOREPLICOV',
#   'name': 'OntoRepliCov',
#   'class_count': '85'},
#  'ontosim': {'acronym': 'ONTOSIM',
#   'name': 'The Ontology of Information System on Mortality',
#   'class_count': '11'},
#  'ontosinasc': {'acronym': 'ONTOSINASC',
#   'name': 'Ontology of Information System on Live Births',
#   'class_count': '8'},
#  'ontotox': {'acronym': 'ONTOTOX',
#   'name': 'Chemotherapy Toxicities Ontology',
#   'class_count': '16'},
#  'ontotoxnuc': {'acronym': 'ONTOTOXNUC',
#   'name': 'Ontology of Nuclear Toxicity',
#   'class_count': '650'},
#  'ontriscal': {'acronym': 'ONTRISCAL',
#   'name': 'Ontology of Risk Stratification in Mental Health',
#   'class_count': '332'},
#  'ooevv': {'acronym': 'OOEVV',
#   'name': 'Ontology of Experimental Variables and Values',
#   'class_count': '68'},
#  'oostt': {'acronym': 'OOSTT',
#   'name': 'Ontology of Organizational Structures of Trauma centers and Trauma systems',
#   'class_count': '823'},
#  'opb': {'acronym': 'OPB',
#   'name': 'Ontology of Physics for Biology',
#   'class_count': '858'},
#  'opd-nambobi': {'acronym': 'OPD-NAMBOBI',
#   'name': 'SELECTED OTHER PRIORITY DISEASES UNDER IDSR (INTEGRATED DISEASE SURVEILLANCE AND RESPONSES)',
#   'class_count': '0'},
#  'opde': {'acronym': 'OPDE', 'name': 'OPD-Ethiopia', 'class_count': '2'},
#  'opdre': {'acronym': 'OPDRE',
#   'name': 'OPD Regitry Ethiopia',
#   'class_count': '0'},
#  'opdront': {'acronym': 'OPDRONT',
#   'name': 'OPD Register Ontology',
#   'class_count': '2'},
#  'opdt': {'acronym': 'OPDT', 'name': 'opd_test', 'class_count': '2'},
#  'opdzimbabwe': {'acronym': 'OPDZIMBABWE',
#   'name': 'OPDZimbabwe',
#   'class_count': '2'},
#  'ope': {'acronym': 'OPE',
#   'name': 'Ontology of Physical Exercises',
#   'class_count': '634'},
#  'opl': {'acronym': 'OPL',
#   'name': 'Ontology for Parasite LifeCycle',
#   'class_count': '561'},
#  'opmi': {'acronym': 'OPMI',
#   'name': 'Ontology of Precision Medicine and Investigation',
#   'class_count': '3153'},
#  'optimal': {'acronym': 'OPTIMAL',
#   'name': 'OPTImAL: An ontology for patient adherence modeling in physical activity domain',
#   'class_count': '142'},
#  'option-ontology': {'acronym': 'OPTION-ONTOLOGY',
#   'name': 'Optimization Algorithm Benchmarking Ontology',
#   'class_count': '347'},
#  'orcs': {'acronym': 'ORCS',
#   'name': 'Ontology for Representing CDM Semantics',
#   'class_count': '861'},
#  'ordo': {'acronym': 'ORDO',
#   'name': 'Orphanet Rare Disease Ontology',
#   'class_count': '15579'},
#  'orex-sam': {'acronym': 'OREX-SAM',
#   'name': 'OSIRIS-REx sample type',
#   'class_count': '5'},
#  'orex-wg': {'acronym': 'OREX-WG',
#   'name': 'OSIRIS-REx sample analysis workgroups',
#   'class_count': '5'},
#  'ornaseq': {'acronym': 'ORNASEQ',
#   'name': 'Ontology of RNA Sequencing',
#   'class_count': '164'},
#  'orth': {'acronym': 'ORTH',
#   'name': 'Orthology Ontology',
#   'class_count': '34'},
#  'oto': {'acronym': 'OTO',
#   'name': ' Obesity Tracking Ontology',
#   'class_count': ''},
#  'ovae': {'acronym': 'OVAE',
#   'name': 'Ontology of Vaccine Adverse Events',
#   'class_count': '1555'},
#  'ontovip': {'acronym': 'OntoVIP',
#   'name': 'Medical image simulation',
#   'class_count': ''},
#  'paco': {'acronym': 'PACO',
#   'name': 'Physical Activity Ontology',
#   'class_count': '224'},
#  'pae': {'acronym': 'PAE', 'name': 'Plant Anatomy', 'class_count': '1548'},
#  'paino': {'acronym': 'PAINO', 'name': 'Pain Ontology', 'class_count': ''},
#  'panda': {'acronym': 'PANDA',
#   'name': 'Probabilistic Knowledge Assembly Ontology',
#   'class_count': '75'},
#  'panet': {'acronym': 'PANET',
#   'name': 'PaN Experimental technique',
#   'class_count': '379'},
#  'partumdo': {'acronym': 'PARTUMDO',
#   'name': 'postpartum depression ontology',
#   'class_count': '734'},
#  'pataxo': {'acronym': 'PATAXO',
#   'name': 'Technical Taxonomies for Patents',
#   'class_count': '0'},
#  'patct': {'acronym': 'PATCT',
#   'name': 'Placental Cell Type',
#   'class_count': '153'},
#  'patel': {'acronym': 'PATEL', 'name': 'Archana Patel', 'class_count': '123'},
#  'patgv': {'acronym': 'PATGV',
#   'name': 'Placental Genetic Variance',
#   'class_count': '73'},
#  'pathlex': {'acronym': 'PATHLEX',
#   'name': 'Anatomic Pathology Lexicon',
#   'class_count': '1786'},
#  'patit': {'acronym': 'PATIT',
#   'name': 'Placental Investigative Technique',
#   'class_count': '139'},
#  'patmhc': {'acronym': 'PATMHC',
#   'name': 'Placental Maternal Health Conditions',
#   'class_count': '228'},
#  'pato': {'acronym': 'PATO',
#   'name': 'Phenotypic Quality Ontology',
#   'class_count': '8688'},
#  'pav': {'acronym': 'PAV',
#   'name': 'PAV Provenance, Authoring and Versioning',
#   'class_count': '2'},
#  'paymentmode': {'acronym': 'PAYMENTMODE',
#   'name': 'Payment Mode',
#   'class_count': '2'},
#  'payor': {'acronym': 'PAYOR', 'name': 'Payor', 'class_count': '2'},
#  'pbo': {'acronym': 'PBO',
#   'name': 'Plant Breeding Ontology',
#   'class_count': '2272'},
#  'pbpko': {'acronym': 'PBPKO',
#   'name': 'Physiologically Based Pharmacokinetic ontology',
#   'class_count': ''},
#  'pcalion': {'acronym': 'PCALION',
#   'name': 'Prostate Cancer Lifestyle Ontology',
#   'class_count': ''},
#  'pcao': {'acronym': 'PCAO',
#   'name': 'Prostate Cancer Ontology',
#   'class_count': '633'},
#  'pcl': {'acronym': 'PCL',
#   'name': 'Provisional Cell Ontology',
#   'class_count': '197879'},
#  'pcmo': {'acronym': 'PCMO',
#   'name': 'Pediatric Consultation and Monitoring Ontology ',
#   'class_count': '20'},
#  'pco': {'acronym': 'PCO',
#   'name': 'Population and Community Ontology',
#   'class_count': '221'},
#  'pdo': {'acronym': 'PDO',
#   'name': 'Pathogenic Disease Ontology',
#   'class_count': ''},
#  'pdon': {'acronym': 'PDON',
#   'name': "Parkinson's Disease Ontology",
#   'class_count': '632'},
#  'pdo_cas': {'acronym': 'PDO_CAS',
#   'name': 'Plant Diversity Ontology',
#   'class_count': '380'},
#  'pdq': {'acronym': 'PDQ', 'name': 'Physician Data Query', 'class_count': ''},
#  'pdro': {'acronym': 'PDRO',
#   'name': 'The Prescription of Drugs Ontology',
#   'class_count': '703043'},
#  'pdumdv': {'acronym': 'PDUMDV',
#   'name': 'Platynereis Developmental Stages',
#   'class_count': '21'},
#  'pe': {'acronym': 'PE',
#   'name': 'Pulmonary Embolism Ontology',
#   'class_count': '97'},
#  'pe-o': {'acronym': 'PE-O',
#   'name': 'Pre-eclampsia Ontology',
#   'class_count': '1251'},
#  'peao': {'acronym': 'PEAO',
#   'name': 'Plant Experimental Assay Ontology',
#   'class_count': '2298'},
#  'peco': {'acronym': 'PECO',
#   'name': 'Plant Experimental Conditions Ontology',
#   'class_count': '3135'},
#  'pedterm': {'acronym': 'PEDTERM',
#   'name': 'Pediatric Terminology',
#   'class_count': '1771'},
#  'peo': {'acronym': 'PEO',
#   'name': 'Parasite Experiment Ontology',
#   'class_count': '143'},
#  'peo_ontology': {'acronym': 'PEO_ONTOLOGY',
#   'name': 'Prompt Engineering Ontology',
#   'class_count': '124'},
#  'pesont': {'acronym': 'PESONT',
#   'name': 'Preposition_enabled Spatial Ontology',
#   'class_count': '160'},
#  'pghd-bp': {'acronym': 'PGHD-BP',
#   'name': 'PGHD Auxillary - BP',
#   'class_count': '2'},
#  'pghd_connect': {'acronym': 'PGHD_CONNECT',
#   'name': 'PGHD_CONNECT',
#   'class_count': ''},
#  'pgxo': {'acronym': 'PGXO', 'name': 'PGxO', 'class_count': '15'},
#  'phage': {'acronym': 'PHAGE',
#   'name': 'Phylogenetics Ontology',
#   'class_count': '51495'},
#  'phare': {'acronym': 'PHARE',
#   'name': 'Pharmacogenomic Relationships Ontology',
#   'class_count': '229'},
#  'pharmgkb': {'acronym': 'PHARMGKB',
#   'name': 'PharmGKB Ontology',
#   'class_count': ''},
#  'phenomeblast': {'acronym': 'PHENOMEBLAST',
#   'name': 'PhenomeBLAST Ontology',
#   'class_count': ''},
#  'phenx': {'acronym': 'PHENX',
#   'name': 'PhenX Phenotypic Terms',
#   'class_count': '533'},
#  'phfumiado': {'acronym': 'PHFUMIADO',
#   'name': 'Phallusia fumigata Anatomy and Development Ontology',
#   'class_count': '880'},
#  'phipo': {'acronym': 'PHIPO',
#   'name': 'Pathogen Host Interaction Phenotype Ontology',
#   'class_count': '3978'},
#  'phmammado': {'acronym': 'PHMAMMADO',
#   'name': 'Phallusia mammillata Anatomy and Development Ontology',
#   'class_count': '880'},
#  'phy': {'acronym': 'PHY', 'name': 'physiotherapy', 'class_count': '5'},
#  'phylont': {'acronym': 'PHYLONT',
#   'name': 'Phylogenetic Ontology',
#   'class_count': '148'},
#  'piero': {'acronym': 'PIERO',
#   'name': 'Enzyme Reaction Ontology for annotating Partial Information of chemical transformation',
#   'class_count': '36'},
#  'pino': {'acronym': 'PINO',
#   'name': 'Pregnancy Information Needs Ontology',
#   'class_count': '267'},
#  'plana': {'acronym': 'PLANA',
#   'name': 'Planarian Anatomy and Developmental Stage Ontolgoy',
#   'class_count': '876'},
#  'planp': {'acronym': 'PLANP',
#   'name': 'Planarian Phenotype Ontology',
#   'class_count': '3562'},
#  'plantso': {'acronym': 'PLANTSO',
#   'name': 'Plant Stress Ontology',
#   'class_count': '3933'},
#  'plio': {'acronym': 'PLIO',
#   'name': 'Protein-ligand interaction ontology',
#   'class_count': '376'},
#  'plosthes': {'acronym': 'PLOSTHES',
#   'name': 'PLOS Thesaurus',
#   'class_count': '4'},
#  'pma': {'acronym': 'PMA',
#   'name': 'Portfolio Management Application',
#   'class_count': '2084'},
#  'pmapp-pmo': {'acronym': 'PMAPP-PMO',
#   'name': 'PMO Precision Medicine Ontology',
#   'class_count': '76155'},
#  'pmd': {'acronym': 'PMD',
#   'name': 'Persian Medicine Diseases Ontology',
#   'class_count': '529'},
#  'pmdo': {'acronym': 'PMDO',
#   'name': 'Parkinson and Movement Disorder Ontology',
#   'class_count': '629'},
#  'pmo': {'acronym': 'PMO',
#   'name': 'Performed Music Ontology',
#   'class_count': '45'},
#  'pmo-speed': {'acronym': 'PMO-SPEED',
#   'name': 'PMO Playing Speed Vocabulary',
#   'class_count': '2'},
#  'pmr': {'acronym': 'PMR',
#   'name': 'Physical Medicine and Rehabilitation',
#   'class_count': '1597'},
#  'pnado': {'acronym': 'PNADO',
#   'name': 'Pneumonia Diagnosis Ontology',
#   'class_count': ''},
#  'po': {'acronym': 'PO', 'name': 'Plant Ontology', 'class_count': '2026'},
#  'poem': {'acronym': 'POEM',
#   'name': 'Psychometric Ontology of Experiences and Measures',
#   'class_count': '1636'},
#  'poro': {'acronym': 'PORO',
#   'name': 'Porifera Ontology',
#   'class_count': '896'},
#  'pp': {'acronym': 'PP',
#   'name': 'Pipeline Patterns Ontology',
#   'class_count': '15'},
#  'pplc': {'acronym': 'PPLC',
#   'name': 'Placental Pathology Lesion Classification',
#   'class_count': ''},
#  'ppo': {'acronym': 'PPO',
#   'name': 'Plant Phenology Ontology',
#   'class_count': '543'},
#  'pr': {'acronym': 'PR', 'name': 'Protein Ontology', 'class_count': '360877'},
#  'pregonto': {'acronym': 'PREGONTO',
#   'name': 'Pregnancy Ontology',
#   'class_count': '39'},
#  'premedonto': {'acronym': 'PREMEDONTO',
#   'name': 'Precision Medicine Ontology',
#   'class_count': '543'},
#  'preo': {'acronym': 'PREO',
#   'name': 'Presence Ontology',
#   'class_count': '276'},
#  'procchemical': {'acronym': 'PROCCHEMICAL',
#   'name': 'Chemical Process',
#   'class_count': '53'},
#  'proco': {'acronym': 'PROCO',
#   'name': 'Process Chemistry Ontology',
#   'class_count': '922'},
#  'proj': {'acronym': 'PROJ', 'name': 'Project ontology', 'class_count': '46'},
#  'propreo': {'acronym': 'PROPREO',
#   'name': 'Proteomics Data and Process Provenance Ontology',
#   'class_count': '401'},
#  'provo': {'acronym': 'PROVO',
#   'name': 'Provenance Ontology',
#   'class_count': '31'},
#  'psdo': {'acronym': 'PSDO',
#   'name': 'Performance Summary Display Ontology',
#   'class_count': '1123'},
#  'psds': {'acronym': 'PSDS',
#   'name': 'Plant Structure Development Stage',
#   'class_count': '345'},
#  'psimod': {'acronym': 'PSIMOD',
#   'name': 'Protein Modification Ontology',
#   'class_count': '2098'},
#  'pso': {'acronym': 'PSO',
#   'name': 'PatientSafetyOntology',
#   'class_count': '567'},
#  'pso_2': {'acronym': 'PSO_2',
#   'name': 'PatientSafetyOntologyRevisted',
#   'class_count': '291'},
#  'pto': {'acronym': 'PTO',
#   'name': 'Plant Trait Ontology',
#   'class_count': '1691'},
#  'ptrans': {'acronym': 'PTRANS',
#   'name': 'Pathogen Transmission Ontology',
#   'class_count': '35'},
#  'pts': {'acronym': 'PTS',
#   'name': 'Pathway Terminology System',
#   'class_count': '6623'},
#  'pu': {'acronym': 'PU', 'name': 'PUPR Dataset', 'class_count': ''},
#  'pvonto': {'acronym': 'PVONTO',
#   'name': 'Pharmacovigilance Ontology',
#   'class_count': '33'},
#  'pw': {'acronym': 'PW', 'name': 'Pathway Ontology', 'class_count': '2700'},
#  'qudt': {'acronym': 'QUDT',
#   'name': 'Quantities, Units, Dimensions, and Types Ontology',
#   'class_count': '133'},
#  'qudt2': {'acronym': 'QUDT2',
#   'name': 'Quantities, Units, Dimensions and Types (QUDT) Schema - Version 2.0',
#   'class_count': '114'},
#  'qudt2-1': {'acronym': 'QUDT2-1',
#   'name': 'Quantities, Units, Dimensions and Types (QUDT Version 2.1)',
#   'class_count': ''},
#  'radlex': {'acronym': 'RADLEX',
#   'name': 'Radiology Lexicon',
#   'class_count': '46840'},
#  'radmo': {'acronym': 'RADMO',
#   'name': 'RADx Metadata Ontology',
#   'class_count': ''},
#  'radxtt-mvreasons': {'acronym': 'RADXTT-MVREASONS',
#   'name': 'RADx Tiger Team Missing Value Reasons',
#   'class_count': '2'},
#  'rao': {'acronym': 'RAO',
#   'name': 'Rheumatoid Arthritis ontology',
#   'class_count': '280'},
#  'rb': {'acronym': 'RB', 'name': 'RegenBase ontology', 'class_count': '442'},
#  'rbo': {'acronym': 'RBO',
#   'name': 'Radiation Biology Ontology',
#   'class_count': '8799'},
#  'rcd': {'acronym': 'RCD',
#   'name': 'Read Codes, Clinical Terms Version 3 (CTV3) ',
#   'class_count': ''},
#  'rctont': {'acronym': 'RCTONT',
#   'name': 'Randomized Controlled Trials Ontology',
#   'class_count': '195'},
#  'rctv2': {'acronym': 'RCTV2',
#   'name': 'Read Clinical Terminology Version 2',
#   'class_count': '88854'},
#  'rda-content': {'acronym': 'RDA-CONTENT',
#   'name': 'RDA Content type',
#   'class_count': '2'},
#  'rda-issuance': {'acronym': 'RDA-ISSUANCE',
#   'name': 'RDA Mode of Issuance',
#   'class_count': '2'},
#  'rdfs': {'acronym': 'RDFS',
#   'name': 'The RDF Schema vocabulary',
#   'class_count': '7'},
#  'rdl': {'acronym': 'RDL', 'name': 'RDL', 'class_count': '203'},
#  'rdo': {'acronym': 'RDO',
#   'name': 'Reusable Biodiversity Ontology',
#   'class_count': '362'},
#  'regn_bro': {'acronym': 'REGN_BRO', 'name': 'REGN_BRO', 'class_count': '486'},
#  'regn_go': {'acronym': 'REGN_GO', 'name': 'REGN_GO', 'class_count': '51063'},
#  'repo': {'acronym': 'REPO',
#   'name': 'Reproductive Trait and Phenotype Ontology',
#   'class_count': '96'},
#  'repos': {'acronym': 'REPOS', 'name': 'repository', 'class_count': '5'},
#  'reproduce-me': {'acronym': 'REPRODUCE-ME',
#   'name': 'REPRODUCE-ME',
#   'class_count': '347'},
#  'reto': {'acronym': 'RETO',
#   'name': 'Regulation of Transcription Ontology',
#   'class_count': '147738'},
#  'rex': {'acronym': 'REX',
#   'name': 'Physico-Chemical Process',
#   'class_count': '552'},
#  'rexo': {'acronym': 'REXO',
#   'name': 'Regulation of Gene Expression Ontolology',
#   'class_count': '158239'},
#  'rgd': {'acronym': 'RGD', 'name': 'RRB Group D', 'class_count': ''},
#  'rh-mesh': {'acronym': 'RH-MESH',
#   'name': 'Robert Hoehndorf Version of MeSH',
#   'class_count': '305349'},
#  'rnao': {'acronym': 'RNAO', 'name': 'RNA Ontology', 'class_count': '692'},
#  'rnprio': {'acronym': 'RNPRIO',
#   'name': 'Research Network and Patient Registry Inventory Ontology',
#   'class_count': '79'},
#  'rnrmu': {'acronym': 'RNRMU', 'name': 'RNRMU', 'class_count': '2310'},
#  'ro': {'acronym': 'RO', 'name': 'Radiomics Ontology', 'class_count': '458'},
#  'rocknrolltest': {'acronym': 'ROCKNROLLTEST',
#   'name': 'ROCK-N-ROLL-TEST',
#   'class_count': ''},
#  'roleo': {'acronym': 'ROLEO', 'name': 'Role Ontology', 'class_count': '2125'},
#  'roo': {'acronym': 'ROO',
#   'name': 'Radiation Oncology Ontology',
#   'class_count': '1307'},
#  'ros': {'acronym': 'ROS',
#   'name': 'Radiation Oncology Structures Ontology',
#   'class_count': '416'},
#  'rpo': {'acronym': 'RPO',
#   'name': 'Resource of Asian Primary Immunodeficiency Diseases (RAPID) Phenotype Ontology',
#   'class_count': '1545'},
#  'rs': {'acronym': 'RS', 'name': 'Rat Strain Ontology', 'class_count': '5363'},
#  'rsa': {'acronym': 'RSA',
#   'name': 'Reference Sequence Annotation',
#   'class_count': '10'},
#  ...}

# %%
# Fetch and parse the semsql registry YAML
response = requests.get(registry_url)
response.raise_for_status()  # Raise an error for bad status codes
registry_dict = yaml.safe_load(response.text)

# %%
pprint.pprint(registry_dict)
# Out:
# {'description': 'Registry overlap for Semantic-SQL designed to supplement OBO '
#                 'vocabularies',
#  'id': 'semantic-sql-registry',
#  'license': 'CC0',
#  'ontologies': {'aio': {'url': 'https://raw.githubusercontent.com/berkeleybop/artificial-intelligence-ontology/main/aio.owl'},
#                 'bao': {'has_imports': True,
#                         'url': 'http://www.bioassayontology.org/bao/bao_complete.owl'},
#                 'bcio': {'prefixmap': {'BCIO': 'http://humanbehaviourchange.org/ontology/BCIO_',
#                                        'BCIOR': 'http://humanbehaviourchange.org/ontology/BCIOR_'},
#                          'url': 'http://humanbehaviourchange.org/ontology/bcio.owl'},
#                 'bero': {'url': 'https://github.com/berkeleybop/bero/releases/download/2022-05-26/bero.owl'},
#                 'bfo2020': {'url': 'http://purl.obolibrary.org/obo/bfo/2020/bfo.owl'},
#                 'bfo2020_core': {'url': 'http://purl.obolibrary.org/obo/bfo/2020/bfo-core.owl'},
#                 'bfo2020_notime': {'url': 'http://purl.obolibrary.org/obo/bfo/2020/notime/bfo.owl'},
#                 'bfo2020_time': {'url': 'https://raw.githubusercontent.com/BFO-ontology/BFO-2020/master/src/owl/profiles/temporal%20extensions/temporalized%20relations/owl/bfo-temporalized-relations.owl'},
#                 'biolink': {'format': 'turtle',
#                             'jsonld_context': 'https://biolink.github.io/biolink-model/context.jsonld',
#                             'url': 'https://w3id.org/biolink/biolink-model.owl.ttl'},
#                 'biopax': {'url': 'http://www.biopax.org/release/biopax-level3.owl'},
#                 'biopragmatics-reactome': {'prefixmap': {'reactome.obo': 'http://purl.obolibrary.org/obo/reactome_'},
#                                            'url': 'https://w3id.org/biopragmatics/resources/reactome/reactome.obo'},
#                 'biovoices': {'build_command': 'robot relax -i $< merge -o $@',
#                               'prefixmap': {'ontorion': 'http://ontorion.com/namespace#'},
#                               'url': 'https://zenodo.org/record/5589773/files/ontology.owl?download=1'},
#                 'cco': {'build_command': 'robot merge -i $< relax -o $@',
#                         'prefixmap': {'CCO': 'http://www.ontologyrepository.com/CommonCoreOntologies/'},
#                         'url': 'http://www.ontologyrepository.com/CommonCoreOntologies/Mid/AllCoreOntology'},
#                 'cellosaurus': {'format': 'obo',
#                                 'prefixmap': {'cellosaurus': 'http://purl.obolibrary.org/obo/Cellosaurus#CVCL_'},
#                                 'url': 'https://raw.githubusercontent.com/calipho-sib/cellosaurus/master/cellosaurus.obo'},
#                 'chebiplus': {'build_command': 'robot merge -i $< -I '
#                                                'http://purl.obolibrary.org/obo/chiro.owl '
#                                                'relax -o $@',
#                               'url': 'http://purl.obolibrary.org/obo/chebi.owl'},
#                 'chemessence': {'prefixmap': {'chemrof': 'https://w3id.org/chemrof/'},
#                                 'url': 'https://github.com/cmungall/chemessence/releases/latest/download/chemessence.owl'},
#                 'chemont': {'build_command': 'robot convert -i $< -o $@',
#                             'prefixmap': {'CHEMONTID': 'http://purl.obolibrary.org/obo/CHEMONTID_'},
#                             'url': 'http://classyfire.wishartlab.com/system/downloads/1_0/chemont/ChemOnt_2_1.obo.zip',
#                             'zip_extract_file': 'ChemOnt_2_1.obo'},
#                 'chiro': {'build_command': 'robot relax -i $< merge -o $@',
#                           'url': 'http://purl.obolibrary.org/obo/chiro.owl'},
#                 'chr': {'prefixmap': {'chr': 'http://purl.obolibrary.org/obo/CHR_'},
#                         'url': 'https://raw.githubusercontent.com/monarch-initiative/monochrom/master/chr.owl'},
#                 'co_324': {'prefixmap': {'co_324': 'https://cropontology.org/rdf/CO_324:'},
#                            'url': 'https://cropontology.org/ontology/CO_324/rdf'},
#                 'comet': {'build_command': 'robot relax -i $< merge -o $@',
#                           'prefixmap': {'comet': 'https://w3id.org/linkml-common/'},
#                           'url': 'https://raw.githubusercontent.com/linkml/linkml-common/main/project/owl/linkml_common.owl.ttl'},
#                 'complexportal': {'compression': 'gzip',
#                                   'prefixmap': {'complexportal': 'http://purl.obolibrary.org/obo/complexportal_'},
#                                   'url': 'https://github.com/biopragmatics/obo-db-ingest/raw/main/export/complexportal/2022-02-03/complexportal.owl.gz'},
#                 'comploinc': {'build_command': 'robot relax -i $< merge -o $@',
#                               'prefixmap': {'loinc': 'https://loinc.org/'},
#                               'url': 'https://github.com/loinc/comp-loinc/releases/download/v2022-11-05/merged_reasoned_loinc.owl'},
#                 'cosmo': {'has_imports': True,
#                           'url': 'https://micra.com/COSMO/COSMO.owl'},
#                 'cpont': {'url': 'https://w3id.org/cpont/cpont.owl'},
#                 'credit': {'prefixmap': {'credit': 'https://credit.niso.org/contributor-roles/'},
#                            'url': 'https://raw.githubusercontent.com/biopragmatics/obo-db-ingest/main/export/credit/credit.owl'},
#                 'cso': {'prefixmap': {'cso': 'https://cso.kmi.open.ac.uk/topics/',
#                                       'cyc': 'http://sw.cyc.com/concept',
#                                       'freebase': 'http://rdf.freebase.com/ns/',
#                                       'yago': 'http://yago-knowledge.org/resource/'},
#                         'url': 'https://cso.kmi.open.ac.uk/download/version-3.3/CSO.3.3.owl.zip',
#                         'zip_extract_file': 'CSO.3.3.owl'},
#                 'dbpendiaont': {'prefixmap': {'dbpedia': 'http://dbpedia.org/',
#                                               'dbpediaont': 'http://dbpedia.org/ontology/'},
#                                 'url': 'https://databus.dbpedia.org/ontologies/dbpedia.org/ontology--DEV/2023.01.03-072003/ontology--DEV_type=parsed.owl'},
#                 'dhba': {'prefixmap': {'DHBA': 'https://purl.brain-bican.org/ontology/dhbao/DHBA_'},
#                          'url': 'https://github.com/brain-bican/developing_human_brain_atlas_ontology/raw/main/dhbao-base.owl'},
#                 'dmba': {'prefixmap': {'DMBA': 'https://purl.brain-bican.org/ontology/dmbao/DMBA_'},
#                          'url': 'https://github.com/brain-bican/developing_mouse_brain_atlas_ontology/raw/main/dmbao-base.owl'},
#                 'drugbank': {'compression': 'gzip',
#                              'prefixmap': {'drugbank': 'http://purl.obolibrary.org/obo/drugbank_'},
#                              'url': 'https://github.com/biopragmatics/obo-db-ingest/raw/main/export/drugbank/5.1.9/drugbank.owl.gz'},
#                 'drugcentral': {'compression': 'gzip',
#                                 'prefixmap': {'drugbank': 'http://purl.obolibrary.org/obo/drugcentral_'},
#                                 'url': 'https://github.com/biopragmatics/obo-db-ingest/raw/main/export/drugcentral.owl.gz'},
#                 'drugmechdb': {'prefixmap': {'MESH': 'http://id.nlm.nih.gov/mesh/'}},
#                 'dtype': {'prefixmap': {'dtype': 'http://www.linkedmodel.org/schema/dtype#',
#                                         'voag': 'http://voag.linkedmodel.org/voag#'},
#                           'url': 'http://www.linkedmodel.org/schema/dtype'},
#                 'eccode': {'compression': 'gzip',
#                            'prefixmap': {'EC': 'https://bioregistry.io/eccode:',
#                                          'UniProtKB': 'https://bioregistry.io/uniprot:'},
#                            'url': 'https://w3id.org/biopragmatics/resources/eccode/eccode.owl.gz'},
#                 'ecosim': {'prefixmap': {'ECOSIM': 'http://purl.obolibrary.org/obo/ECOSIM_',
#                                          'ECOSIMCONCEPT': 'http://purl.obolibrary.org/obo/ECOSIMCONCEPT_'},
#                            'url': 'https://data.bioontology.org/ontologies/ECOSIM/submissions/1/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb'},
#                 'ecso': {'prefixmap': {'ECSO': 'http://purl.dataone.org/odo/ECSO_'},
#                          'url': "'https://data.bioontology.org/ontologies/ECSO/submissions/64/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb'"},
#                 'edam': {'url': 'http://edamontology.org/EDAM.owl'},
#                 'efo': {'has_imports': True,
#                         'url': 'http://www.ebi.ac.uk/efo/efo.owl'},
#                 'enanomapper': {'has_imports': True,
#                                 'prefixmap': {'evs.ncit': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#',
#                                               'old.fix': 'http://purl.org/obo/owl/FIX#'},
#                                 'url': 'http://enanomapper.github.io/ontologies/enanomapper.owl'},
#                 'enigma_context': {'build_command': 'robot merge -i $<  -o $@',
#                                    'url': 'https://raw.githubusercontent.com/jmchandonia/CORAL/main/example/enigma/ontologies/context_measurement_ontology.obo'},
#                 'envthes': {'build_command': 'robot query -i $< --update '
#                                              'sparql/skos-to-owl.ru -o $@',
#                             'prefixmap': {'envthes': 'http://vocabs.lter-europe.net/EnvThes/',
#                                           'iadopt': 'https://w3id.org/iadopt/ont/',
#                                           'lternet.tema': 'https://vocab.lternet.edu/vocab/vocab/?tema=',
#                                           'omv': 'http://omv.ontoware.org/2005/05/'},
#                             'url': 'https://vocabs.lter-europe.net/rest/v1/envthes/data?format=text/turtle'},
#                 'fhkb': {'prefixmap': {'fhkb': 'http://owl.cs.manchester.ac.uk/tutorials/fhkb#'}},
#                 'fibo': {'build_command': 'robot merge -i $<  -o $@',
#                          'prefixmap': {'cmnsav': 'https://www.omg.org/spec/Commons/AnnotationVocabulary/',
#                                        'fibo': 'https://spec.edmcouncil.org/fibo/ontology/'},
#                          'url': 'https://spec.edmcouncil.org/fibo/ontology/AboutFIBOProd/'},
#                 'fma': {'prefixmap': {'FMA': 'http://purl.org/sig/ont/fma/fma'},
#                         'url': 'http://sig.biostr.washington.edu/share/downloads/fma/release/latest/fma.owl'},
#                 'foodon': {'build_command': 'robot merge -i $< relax reduce -c '
#                                             'true -o $@',
#                            'url': 'http://purl.obolibrary.org/obo/foodon.owl'},
#                 'gard': {'prefixmap': {'GARD': 'http://purl.obolibrary.org/obo/GARD_'},
#                          'url': 'https://github.com/monarch-initiative/mondo-ingest/releases/latest/download/gard.owl'},
#                 'go': {'url': 'http://purl.obolibrary.org/obo/go/extensions/go-plus.owl'},
#                 'go-amigo': {'url': 'http://purl.obolibrary.org/obo/go/extensions/go-amigo.owl'},
#                 'go-lego': {'url': 'http://purl.obolibrary.org/obo/go/extensions/go-lego.owl'},
#                 'goldterms': {'build_command': 'robot relax -i $< reason -o $@',
#                               'prefixmap': {'GOLDTERMS': 'https://w3id.org/gold.path/',
#                                             'GOLDVOCAB': 'https://w3id.org/gold.vocab/'},
#                               'url': 'https://raw.githubusercontent.com/cmungall/gold-ontology/main/gold.owl'},
#                 'gtdb': {'prefixmap': {'gtdb': 'https://gtdb.ecogenomic.org/tree?r='},
#                          'url': 'https://w3id.org/biopragmatics/resources/gtdb/gtdb.owl'},
#                 'hba': {'prefixmap': {'HBA': 'https://purl.brain-bican.org/ontology/hbao/HBA_'},
#                         'url': 'https://github.com/brain-bican/human_brain_atlas_ontology/raw/main/hbao-base.owl'},
#                 'hcao': {'url': 'https://raw.githubusercontent.com/HumanCellAtlas/ontology/master/hcao.owl'},
#                 'hgnc': {'compression': 'gzip',
#                          'prefixmap': {'hgnc': 'http://purl.obolibrary.org/obo/hgnc_'},
#                          'url': 'https://github.com/biopragmatics/obo-db-ingest/raw/main/export/hgnc/2022-06-01/hgnc.owl.gz'},
#                 'hgnc.genegroup': {'compression': 'gzip',
#                                    'prefixmap': {'hgnc.genegroup': 'http://purl.obolibrary.org/obo/hgnc.genegroup_'},
#                                    'url': 'https://github.com/biopragmatics/obo-db-ingest/raw/main/export/hgnc.genegroup/hgnc.genegroup.owl.gz'},
#                 'hpinternational': {'url': 'http://purl.obolibrary.org/obo/hp/hp-international.owl'},
#                 'icd10cm': {'prefixmap': {'ICD10CM': 'http://purl.bioontology.org/ontology/ICD10CM/'},
#                             'url': 'https://github.com/monarch-initiative/mondo-ingest/releases/latest/download/icd10cm.owl'},
#                 'icd10who': {'prefixmap': {'icd10who': 'https://icd.who.int/browse10/2019/en#/'},
#                              'url': 'https://github.com/monarch-initiative/mondo-ingest/releases/latest/download/icd10who.owl'},
#                 'interpro': {'build_command': "perl -npe 's@ go:@ GO:@g;s@ "
#                                               'ro:@ RO:@g;s@ interpro:@ '
#                                               "InterPro:@g' $< > $@.tmp && "
#                                               'robot convert -i $@.tmp -o $@',
#                              'format': 'obo',
#                              'prefixmap': {'InterPro': 'http://purl.obolibrary.org/obo/InterPro_'},
#                              'url': 'https://w3id.org/biopragmatics/resources/interpro/interpro.obo'},
#                 'iof': {'build_command': 'robot relax -i $< merge -o $@',
#                         'prefixmap': {'IOFcore': 'https://spec.industrialontologies.org/ontology/'},
#                         'url': 'https://spec.industrialontologies.org/ontology/AboutIOFProd/'},
#                 'ito': {'prefixmap': {'ito': 'https://identifiers.org/ito:'},
#                         'url': 'https://github.com/OpenBioLink/ITO/raw/master/ITO.owl.zip',
#                         'zip_extract_file': 'ITO.owl'},
#                 'kegg.genome': {'prefixmap': {'pathbank': 'http://purl.obolibrary.org/obo/kegg.genome_'},
#                                 'url': 'https://w3id.org/biopragmatics/resources/kegg.genome/kegg.genome.obo'},
#                 'kgcl': {'build_command': 'robot merge -i $< reason  -o $@',
#                          'prefixmap': {'kgcl': 'https://w3id.org/kgcl/'},
#                          'url': 'https://w3id.org/kgcl/kgcl.owl.ttl'},
#                 'kin': {'build_command': 'robot reason -i $< -o $@',
#                         'prefixmap': {'KIN': 'http://purl.org/ga4gh/kin.owl#KIN_'},
#                         'url': 'http://purl.org/ga4gh/kin.owl'},
#                 'lov': {'compression': 'gzip',
#                         'format': 'n3',
#                         'url': 'https://lov.linkeddata.es/lov.n3.gz'},
#                 'maxo': {'build_command': 'robot relax -i $< merge reason -r '
#                                           'structural -o $@',
#                          'url': 'http://purl.obolibrary.org/obo/maxo.owl'},
#                 'mba': {'prefixmap': {'MBA': 'https://purl.brain-bican.org/ontology/mbao/MBA_'},
#                         'url': 'https://github.com/brain-bican/mouse_brain_atlas_ontology/raw/main/mbao-base.owl'},
#                 'mixs': {'build_command': 'robot merge -i $< reason  -o $@',
#                          'prefixmap': {'mixs': 'https://w3id.org/mixs/'},
#                          'url': 'https://raw.githubusercontent.com/GenomicsStandardsConsortium/mixs/main/project/owl/mixs.owl.ttl'},
#                 'mlo': {'has_imports': True,
#                         'prefixmap': {'mlo': 'http://www.a2rd.net.br/mlo#'},
#                         'url': 'https://raw.githubusercontent.com/berkeleybop/artificial-intelligence-ontology/v2023-09-11/external/ml-ontology-202010021305.owl'},
#                 'modl': {'prefixmap': {'modl': 'https://archive.org/services/purl/purl/modular_ontology_design_library#'},
#                          'url': 'https://raw.githubusercontent.com/Data-Semantics-Laboratory/modular-ontology-design-library/master/MODL.owl'},
#                 'molgenie': {'build_command': 'robot convert -i $< -o $@',
#                              'url': 'https://github.com/MolGenie/ontology/blob/main/mol_classes_ext_2024-11-20.obo'},
#                 'mondo-ingest': {'prefixmap': {'CHR': 'http://purl.obolibrary.org/obo/CHR_',
#                                                'OMIM': 'https://omim.org/entry/',
#                                                'OMIMPS': 'https://www.omim.org/phenotypicSeries/PS'},
#                                  'url': 'https://github.com/monarch-initiative/mondo-ingest/releases/latest/download/mondo-ingest.owl'},
#                 'msio': {'prefixmap': {'MSIO': 'http://purl.obolibrary.org/obo/MSIO_',
#                                        'nmrCV': 'http://nmrML.org/nmrCV#NMR:'},
#                          'url': 'https://raw.githubusercontent.com/MSI-Metabolomics-Standards-Initiative/MSIO/master/releases/latest_release/MSIO-merged-reasoned.owl'},
#                 'nando': {'prefixmap': {'NANDO': 'http://nanbyodata.jp/ontology/NANDO_'},
#                           'url': "'https://data.bioontology.org/ontologies/NANDO/submissions/15/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb'"},
#                 'ncit': {'build_command': 'robot relax -i $< merge -o $@',
#                          'url': 'http://purl.obolibrary.org/obo/ncit.owl'},
#                 'neo': {'url': 'http://purl.obolibrary.org/obo/go/noctua/neo.owl'},
#                 'nmdc_schema': {'build_command': 'robot merge -i $<  -o $@',
#                                 'prefixmap': {'linkml': 'https://w3id.org/linkml/',
#                                               'mixs': 'https://w3id.org/mixs/',
#                                               'nmdc': 'https://w3id.org/nmdc/'},
#                                 'url': 'https://raw.githubusercontent.com/microbiomedata/nmdc-schema/main/project/owl/nmdc.owl.ttl'},
#                 'obiws': {'prefixmap': {'OBIws': 'http://purl.obolibrary.org/obo/OBIws_'},
#                           'url': 'https://data.bioontology.org/ontologies/OBIWS/submissions/2/download?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb'},
#                 'oboe-core': {'prefixmap': {'oboe-core': 'http://ecoinformatics.org/oboe/oboe.1.0/oboe-core.owl#'},
#                               'url': 'http://ecoinformatics.org/oboe/oboe.1.0/oboe-core.owl'},
#                 'oboe-standards': {'prefixmap': {'oboe-standards': 'http://ecoinformatics.org/oboe/oboe.1.0/oboe-standards.owl#'},
#                                    'url': 'http://ecoinformatics.org/oboe/oboe.1.0/oboe-standards.owl'},
#                 'occo': {'prefixmap': {'OccO': 'http://purl.obolibrary.org/obo/OccO_'},
#                          'url': 'https://raw.githubusercontent.com/Occupation-Ontology/OccO/main/src/ontology/occo-merged.owl'},
#                 'oeo': {'prefixmap': {'OEO': 'http://openenergy-platform.org/ontology/oeo/OEO_',
#                                       'OEOX': 'http://openenergy-platform.org/ontology/oeo/OEOX_'},
#                         'url': 'https://openenergyplatform.org/ontology/oeo/releases/oeo-full.owl'},
#                 'ogco': {'prefixmap': {'OGCO': 'http://purl.obolibrary.org/obo/OGCO_'},
#                          'url': 'https://raw.githubusercontent.com/cmungall/chemessence/refs/heads/main/src/ontology/components/ogco.owl'},
#                 'omim': {'prefixmap': {'OMIM': 'https://omim.org/entry/',
#                                        'OMIMPS': 'https://www.omim.org/phenotypicSeries/PS'},
#                          'url': 'https://github.com/monarch-initiative/mondo-ingest/releases/latest/download/omim.owl'},
#                 'omop': {'prefixmap': {'omop': 'https://athena.ohdsi.org/search-terms/terms/'}},
#                 'ontie': {'prefixmap': {'ONTIE': 'https://ontology.iedb.org/ontology/ONTIE_'},
#                           'url': 'https://ontology.iedb.org/file/ontie.owl'},
#                 'ontobiotope': {'prefixmap': {'OBT': 'http://purl.obolibrary.org/obo/OBT_'},
#                                 'url': "'https://data.agroportal.lirmm.fr/ontologies/ONTOBIOTOPE/download?apikey=1de0a270-29c5-4dda-b043-7c3580628cd5&download_format=rdf'"},
#                 'orcid': {'prefixmap': {'orcid': 'https://orcid.org/'},
#                           'url': 'https://w3id.org/orcidio/orcidio.owl'},
#                 'ordo': {'url': 'https://github.com/monarch-initiative/mondo-ingest/releases/latest/download/ordo.owl'},
#                 'pathbank': {'compression': 'gzip',
#                              'prefixmap': {'pathbank': 'http://purl.obolibrary.org/obo/pathbank_'},
#                              'url': 'https://w3id.org/biopragmatics/resources/pathbank/pathbank.obo.gz'},
#                 'pba': {'prefixmap': {'PBA': 'https://purl.brain-bican.org/ontology/pbao/PBA_'},
#                         'url': 'https://github.com/brain-bican/primate_brain_atlas_ontology/raw/main/pbao-base.owl'},
#                 'pcl': {'prefixmap': {'ENSEMBL': 'http://identifiers.org/ensembl/',
#                                       'PCL': 'http://purl.obolibrary.org/obo/PCL_'},
#                         'url': 'http://purl.obolibrary.org/obo/pcl.owl'},
#                 'pfam': {'prefixmap': {'PFAM': 'https://www.ebi.ac.uk/interpro/entry/pfam/',
#                                        'PFAM.CLAN': 'https://www.ebi.ac.uk/interpro/set/pfam/'},
#                          'url': 'https://w3id.org/biopragmatics/resources/pfam/pfam.owl'},
#                 'phenio': {'compression': 'gzip',
#                            'description': 'Monarch Phenomics Integrated '
#                                           'Ontology',
#                            'prefixmap': {'biolink': 'https://w3id.org/biolink/vocab/'},
#                            'relation_graph_settings': {'properties': ['BFO:0000050',
#                                                                       'BFO:0000051',
#                                                                       'UPHENO:0000001',
#                                                                       'UPHENO:0000003',
#                                                                       'RO:0002202']},
#                            'url': 'https://github.com/monarch-initiative/phenio/releases/latest/download/phenio.owl.gz'},
#                 'phenio_test': {'description': 'Monarch Phenomics Integrated '
#                                                'Ontology (Test)',
#                                 'prefixmap': {'biolink': 'https://w3id.org/biolink/vocab/'},
#                                 'relation_graph_settings': {'properties': ['BFO:0000050',
#                                                                            'BFO:0000051',
#                                                                            'UPHENO:0000001',
#                                                                            'UPHENO:0000003',
#                                                                            'RO:0002202']},
#                                 'url': 'https://github.com/monarch-initiative/phenio/releases/latest/download/phenio-test.owl'},
#                 'ppeo': {'prefixmap': {'PPEO': 'http://purl.org/ppeo/PPEO.owl#'},
#                          'url': 'http://purl.org/ppeo/PPEO.owl'},
#                 'pride': {'build_command': 'robot relax -i $< merge -o $@',
#                           'prefixmap': {'PRIDE': 'http://purl.obolibrary.org/obo/PRIDE_'},
#                           'url': 'https://raw.githubusercontent.com/PRIDE-Archive/pride-ontology/master/pride_cv.obo'},
#                 'prov': {'prefixmap': {'prov': 'http://www.w3.org/ns/prov#'},
#                          'url': 'http://www.w3.org/ns/prov.owl'},
#                 'quantitykind': {'build_command': 'robot merge -i $<  -o $@',
#                                  'prefixmap': {'quantitykind': 'http://qudt.org/vocab/quantitykind/'},
#                                  'url': 'http://qudt.org/vocab/quantitykind'},
#                 'qudtunit': {'build_command': 'robot merge -i $<  -o $@',
#                              'prefixmap': {'qudtschema': 'http://qudt.org/schema/qudt/',
#                                            'qudtunit': 'http://qudt.org/vocab/unit/',
#                                            'si-quantity': 'https://si-digital-framework.org/SI/quantities/'},
#                              'url': 'http://qudt.org/vocab/unit'},
#                 'reacto': {'url': 'http://purl.obolibrary.org/obo/go/extensions/reacto.owl'},
#                 'reactome-hs': {'prefixmap': {'reactome.biopax': 'http://www.reactome.org/biopax/77/48887#'},
#                                 'url': 'https://reactome.org/download/current/biopax.zip',
#                                 'zip_extract_file': 'Homo_sapiens.owl'},
#                 'reactome-mm': {'post_processing_steps': ['sqlite3 {db} < '
#                                                           'views/reactome.sql'],
#                                 'url': 'https://reactome.org/download/current/biopax.zip',
#                                 'zip_extract_file': 'Mus_musculus.owl'},
#                 'rhea': {'build_command': 'perl -npe '
#                                           "'s@https://www.ebi.ac.uk/.*ec=@https://bioregistry.io/eccode:@g' "
#                                           '$< > $@.tmp && robot convert -i '
#                                           '$@.tmp -o $@',
#                          'compression': 'gzip',
#                          'prefixmap': {'RHEA': 'https://www.rhea-db.org/rhea/'},
#                          'url': 'https://w3id.org/biopragmatics/resources/rhea/rhea.owl.gz'},
#                 'ror': {'compression': 'gzip',
#                         'prefixmap': {'ror': 'https://ror.org/'},
#                         'url': 'https://w3id.org/biopragmatics/resources/ror/ror.owl.gz'},
#                 'rxnorm': {'prefixmap': {'RXNORM': 'http://purl.bioontology.org/ontology/RXNORM/'}},
#                 'schema-dot-org': {'url': 'https://schema.org/version/latest/schemaorg-current-https.rdf'},
#                 'sdgio': {'prefixmap': {'SDGIO': 'http://purl.unep.org/sdg/SDGIO_'},
#                           'url': 'https://raw.githubusercontent.com/SDG-InterfaceOntology/sdgio/master/sdgio.owl'},
#                 'sgd': {'format': 'obo',
#                         'prefixmap': {'SGD': 'https://www.yeastgenome.org/locus/'},
#                         'url': 'https://w3id.org/biopragmatics/resources/sgd/sgd.obo'},
#                 'sio': {'prefixmap': {'SIO': 'http://semanticscience.org/resource/SIO_'},
#                         'url': 'http://semanticscience.org/ontology/sio.owl'},
#                 'sweetAll': {'has_imports': True,
#                              'named_prefixmaps': ['sweet', 'prefixcc'],
#                              'url': 'http://sweetontology.net/sweetAll'},
#                 'swisslipid': {'compression': 'gzip',
#                                'format': 'obo',
#                                'prefixmap': {'swisslipid': 'http://purl.obolibrary.org/obo/swisslipid_'},
#                                'url': 'https://github.com/biopragmatics/obo-db-ingest/raw/main/export/swisslipid/2023-02-03/swisslipid.obo.gz'},
#                 'swo': {'build_command': 'robot merge -i $<  -o $@',
#                         'prefixmap': {'OntoDM': 'http://www.ontodm.com/OntoDM-core/OntoDM_',
#                                       'OntoDM.kdd': 'http://kt.ijs.si/panovp/OntoDM#OntoDM-KDD',
#                                       'SWO': 'http://www.ebi.ac.uk/swo/SWO_',
#                                       'SWO.algorithm': 'http://www.ebi.ac.uk/swo/algorithm/SWO_',
#                                       'SWO.data': 'http://www.ebi.ac.uk/swo/data/SWO_',
#                                       'SWO.interface': 'http://www.ebi.ac.uk/swo/interface/SWO_',
#                                       'SWO.license': 'http://www.ebi.ac.uk/swo/license/SWO_',
#                                       'SWO.maturity': 'http://www.ebi.ac.uk/swo/maturity/SWO_',
#                                       'SWO.objective': 'http://www.ebi.ac.uk/swo/objective/SWO_',
#                                       'SWO.organization': 'http://www.ebi.ac.uk/swo/organization/SWO_',
#                                       'SWO.version': 'http://www.ebi.ac.uk/swo/version/SWO_'},
#                         'url': 'http://purl.obolibrary.org/obo/swo.owl'},
#                 'taxslim': {'build_command': 'robot convert -i $< -o $@',
#                             'url': 'http://purl.obolibrary.org/obo/ncbitaxon/subsets/taxslim.obo'},
#                 'uberoncm': {'url': 'https://github.com/obophenotype/uberon/releases/latest/download/composite-metazoan.owl'},
#                 'uniprot': {'compression': 'gzip',
#                             'prefixmap': {'UniProtKB': 'https://bioregistry.io/uniprot:'},
#                             'url': 'https://w3id.org/biopragmatics/resources/uniprot/uniprot.owl.gz'},
#                 'uniprot.ptm': {'prefixmap': {'RESID': 'https://proteininformationresource.org/cgi-bin/resid?id=',
#                                               'UNIMOD': 'http://www.unimod.org/modifications_view.php?editid1=',
#                                               'uniprot.ptm': 'https://biopragmatics.github.io/providers/uniprot.ptm/'},
#                                 'url': 'https://w3id.org/biopragmatics/resources/uniprot.ptm/uniprot.ptm.owl'},
#                 'upa': {'prefixmap': {'UPa': 'http://purl.obolibrary.org/obo/UPa_'},
#                         'url': 'http://purl.obolibrary.org/obo/upa.owl'},
#                 'vaem': {'prefixmap': {'vaem': 'http://www.linkedmodel.org/schema/vaem#'},
#                          'url': 'http://www.linkedmodel.org/schema/vaem'},
#                 'vccf': {'prefixmap': {'VCCF': 'http://purl.obolibrary.org/obo/VCCF_'},
#                          'url': 'https://raw.githubusercontent.com/obophenotype/vccf-ontology/main/vccf.owl'},
#                 'wifire': {'prefixmap': {'webprotege': 'http://webprotege.stanford.edu/'},
#                            'url': 'https://raw.githubusercontent.com/WIFIRE-Lab/WIFIRE-commons-ontology/master/WIFIRE-commons-ontology-V1.owl'},
#                 'wikipathways': {'prefixmap': {'complexportal': 'http://purl.obolibrary.org/obo/wikipathways_'},
#                                  'url': 'https://w3id.org/biopragmatics/resources/wikipathways/wikipathways.owl'},
#                 'xsmo': {'prefixmap': {'XSMO': 'http://purl.obolibrary.org/obo/XSMO_'},
#                          'url': 'https://download.xenbase.org/xenbase/Ontologies/XSMO/XSMO_1.1/XSMO_1.1.owl'}}}

# %%
x = list(registry_dict['ontologies'].keys())
x.sort()
x
# Out:
# ['aio',
#  'bao',
#  'bcio',
#  'bero',
#  'bfo2020',
#  'bfo2020_core',
#  'bfo2020_notime',
#  'bfo2020_time',
#  'biolink',
#  'biopax',
#  'biopragmatics-reactome',
#  'biovoices',
#  'cco',
#  'cellosaurus',
#  'chebiplus',
#  'chemessence',
#  'chemont',
#  'chiro',
#  'chr',
#  'co_324',
#  'comet',
#  'complexportal',
#  'comploinc',
#  'cosmo',
#  'cpont',
#  'credit',
#  'cso',
#  'dbpendiaont',
#  'dhba',
#  'dmba',
#  'drugbank',
#  'drugcentral',
#  'drugmechdb',
#  'dtype',
#  'eccode',
#  'ecosim',
#  'ecso',
#  'edam',
#  'efo',
#  'enanomapper',
#  'enigma_context',
#  'envthes',
#  'fhkb',
#  'fibo',
#  'fma',
#  'foodon',
#  'gard',
#  'go',
#  'go-amigo',
#  'go-lego',
#  'goldterms',
#  'gtdb',
#  'hba',
#  'hcao',
#  'hgnc',
#  'hgnc.genegroup',
#  'hpinternational',
#  'icd10cm',
#  'icd10who',
#  'interpro',
#  'iof',
#  'ito',
#  'kegg.genome',
#  'kgcl',
#  'kin',
#  'lov',
#  'maxo',
#  'mba',
#  'mixs',
#  'mlo',
#  'modl',
#  'molgenie',
#  'mondo-ingest',
#  'msio',
#  'nando',
#  'ncit',
#  'neo',
#  'nmdc_schema',
#  'obiws',
#  'oboe-core',
#  'oboe-standards',
#  'occo',
#  'oeo',
#  'ogco',
#  'omim',
#  'omop',
#  'ontie',
#  'ontobiotope',
#  'orcid',
#  'ordo',
#  'pathbank',
#  'pba',
#  'pcl',
#  'pfam',
#  'phenio',
#  'phenio_test',
#  'ppeo',
#  'pride',
#  'prov',
#  'quantitykind',
#  'qudtunit',
#  'reacto',
#  'reactome-hs',
#  'reactome-mm',
#  'rhea',
#  'ror',
#  'rxnorm',
#  'schema-dot-org',
#  'sdgio',
#  'sgd',
#  'sio',
#  'sweetAll',
#  'swisslipid',
#  'swo',
#  'taxslim',
#  'uberoncm',
#  'uniprot',
#  'uniprot.ptm',
#  'upa',
#  'vaem',
#  'vccf',
#  'wifire',
#  'wikipathways',
#  'xsmo']

# %%
# Fetch the BBOP SQLite S3 XML catalog
response = requests.get(s3_url)
response.raise_for_status()  # Raise an error if the request failed

# %%
# Parse the XML
root = ET.fromstring(response.content)

# %%
bioportal_ontologies
# Out:
# {'aba-amb': {'acronym': 'ABA-AMB',
#   'name': 'Allen Brain Atlas (ABA) Adult Mouse Brain Ontology',
#   'class_count': '913'},
#  'abd': {'acronym': 'ABD',
#   'name': 'Anthology of Biosurveillance Diseases',
#   'class_count': '1445'},
#  'aceso': {'acronym': 'ACESO',
#   'name': 'Adverse Childhood Experiences Ontology',
#   'class_count': '296'},
#  'acgt-mo': {'acronym': 'ACGT-MO',
#   'name': 'Cancer Research and Management ACGT Master Ontology',
#   'class_count': '1770'},
#  'acvd_ontology': {'acronym': 'ACVD_ONTOLOGY',
#   'name': 'Atherosclerotic Cerebrovascular Disease Ontology',
#   'class_count': '1719'},
#  'ad-drop': {'acronym': 'AD-DROP',
#   'name': 'Alzheimer Disease Relevance Ontology by Process',
#   'class_count': '25'},
#  'adalab': {'acronym': 'ADALAB', 'name': 'AdaLab ontology', 'class_count': ''},
#  'adalab-meta': {'acronym': 'ADALAB-META',
#   'name': 'AdaLab-meta ontology',
#   'class_count': ''},
#  'adar': {'acronym': 'ADAR',
#   'name': 'Autism DSM-ADI-R ontology',
#   'class_count': '791'},
#  'adcad': {'acronym': 'ADCAD',
#   'name': 'Arctic Data Center Academic Disciplines Ontology',
#   'class_count': '67'},
#  'adher_intcare_en': {'acronym': 'ADHER_INTCARE_EN',
#   'name': 'Adherence and Integrated Care',
#   'class_count': '264'},
#  'adher_intcare_sp': {'acronym': 'ADHER_INTCARE_SP',
#   'name': 'Adherence and Integrated Care in Spanish',
#   'class_count': ''},
#  'admf': {'acronym': 'ADMF',
#   'name': 'alzhaimer dessiese main factors',
#   'class_count': ''},
#  'admin': {'acronym': 'ADMIN',
#   'name': 'Nurse Administrator',
#   'class_count': ''},
#  'admo': {'acronym': 'ADMO',
#   'name': 'Alzheimer Disease Map Ontology',
#   'class_count': '10943'},
#  'ado': {'acronym': 'ADO',
#   'name': "Alzheimer's Disease Ontology",
#   'class_count': ''},
#  'adw': {'acronym': 'ADW',
#   'name': 'Animal Natural History and Life History Ontology',
#   'class_count': '364'},
#  'aeo': {'acronym': 'AEO',
#   'name': 'Anatomical Entity Ontology',
#   'class_count': '250'},
#  'aero': {'acronym': 'AERO',
#   'name': 'Adverse Event Reporting Ontology',
#   'class_count': '497'},
#  'afo': {'acronym': 'AFO',
#   'name': 'Allotrope Merged Ontology Suite',
#   'class_count': '3367'},
#  'afpo': {'acronym': 'AFPO',
#   'name': 'African Population Ontology',
#   'class_count': '473'},
#  'agro': {'acronym': 'AGRO',
#   'name': 'AGRonomy Ontology',
#   'class_count': '4163'},
#  'agrocymac': {'acronym': 'AGROCYMAC',
#   'name': 'Control y Monitoreo de afecciones en los cultivos',
#   'class_count': ''},
#  'agromop': {'acronym': 'AGROMOP',
#   'name': 'Control de Cacao',
#   'class_count': ''},
#  'ahol': {'acronym': 'AHOL',
#   'name': 'Animal Health Ontology for Livestock',
#   'class_count': '339'},
#  'ahso': {'acronym': 'AHSO',
#   'name': 'Animal Health Surveillance Ontology',
#   'class_count': '38'},
#  'ai': {'acronym': 'AI',
#   'name': 'Artificial Intelligence',
#   'class_count': '444'},
#  'ai-rheum': {'acronym': 'AI-RHEUM',
#   'name': 'Artificial Intelligence Rheumatology Consultant System Ontology',
#   'class_count': '808'},
#  'aio': {'acronym': 'AIO',
#   'name': 'Artificial Intelligence Ontology',
#   'class_count': '443'},
#  'aism': {'acronym': 'AISM',
#   'name': 'Ontology for the Anatomy of the Insect SkeletoMuscular system',
#   'class_count': '7443'},
#  'allergidoc': {'acronym': 'ALLERGIDOC',
#   'name': 'Allergy Ontology',
#   'class_count': '106'},
#  'allergydetector': {'acronym': 'ALLERGYDETECTOR',
#   'name': 'Allergy Detector II',
#   'class_count': '12'},
#  'altproton': {'acronym': 'ALTPROTON',
#   'name': 'An Ontology for integration and interoperability of multi-aspect data of Protein food production chains',
#   'class_count': '300'},
#  'amino-acid': {'acronym': 'AMINO-ACID',
#   'name': 'Amino Acid Ontology',
#   'class_count': '46'},
#  'amphx': {'acronym': 'AMPHX',
#   'name': 'The Amphioxus Development and Anatomy Ontology',
#   'class_count': '403'},
#  'ao': {'acronym': 'AO', 'name': 'Asthma Ontology', 'class_count': '289'},
#  'apacomputer': {'acronym': 'APACOMPUTER',
#   'name': 'Computer Cluster',
#   'class_count': '114'},
#  'apadisorders': {'acronym': 'APADISORDERS',
#   'name': 'Disorders cluster',
#   'class_count': '822'},
#  'apaeducluster': {'acronym': 'APAEDUCLUSTER',
#   'name': 'Educational Cluster',
#   'class_count': '509'},
#  'apaneurocluster': {'acronym': 'APANEUROCLUSTER',
#   'name': 'APA Neuro Cluster',
#   'class_count': '501'},
#  'apaocuemploy': {'acronym': 'APAOCUEMPLOY',
#   'name': 'APA Occupational and Employment cluster',
#   'class_count': '448'},
#  'apaonto': {'acronym': 'APAONTO',
#   'name': 'Psychology Ontology',
#   'class_count': '6037'},
#  'apastatistical': {'acronym': 'APASTATISTICAL',
#   'name': 'APA Statistical Cluster',
#   'class_count': '140'},
#  'apatandt': {'acronym': 'APATANDT',
#   'name': 'APA Tests and Testing cluster',
#   'class_count': '208'},
#  'apatreatment': {'acronym': 'APATREATMENT',
#   'name': 'APA Treatment Cluster',
#   'class_count': '480'},
#  'apo': {'acronym': 'APO',
#   'name': 'Ascomycete Phenotype Ontology',
#   'class_count': '619'},
#  'apollo-sv': {'acronym': 'APOLLO-SV',
#   'name': 'Apollo Structured Vocabulary',
#   'class_count': '1717'},
#  'apro': {'acronym': 'APRO',
#   'name': 'Ancient Poet Resource Ontology',
#   'class_count': ''},
#  'arcrc': {'acronym': 'ARCRC',
#   'name': 'Arctic Report Card',
#   'class_count': '95'},
#  'aro': {'acronym': 'ARO',
#   'name': 'Antibiotic Resistance Ontology',
#   'class_count': '8526'},
#  'asdf': {'acronym': 'ASDF', 'name': 'testiiii1', 'class_count': ''},
#  'asdpto': {'acronym': 'ASDPTO',
#   'name': 'Autism Spectrum Disorder Phenotype Ontology',
#   'class_count': '284'},
#  'aspect': {'acronym': 'ASPECT',
#   'name': 'ASPECT: wind energy vAriableS, ParametErs and ConsTants',
#   'class_count': '2'},
#  'assaynode': {'acronym': 'ASSAYNODE',
#   'name': 'Assaynode',
#   'class_count': '48'},
#  'atc': {'acronym': 'ATC',
#   'name': 'Anatomical Therapeutic Chemical Classification',
#   'class_count': '6934'},
#  'ato': {'acronym': 'ATO',
#   'name': 'Amphibian Taxonomy Ontology',
#   'class_count': '6135'},
#  'atol': {'acronym': 'ATOL',
#   'name': 'Animal Trait Ontology for Livestock',
#   'class_count': '2352'},
#  'atom': {'acronym': 'ATOM',
#   'name': 'Atlas Ontology Model',
#   'class_count': '93'},
#  'aura': {'acronym': 'AURA', 'name': 'KB_Bio_101', 'class_count': '27396'},
#  'bao': {'acronym': 'BAO', 'name': 'BioAssay Ontology', 'class_count': '7781'},
#  'bao-gpcr': {'acronym': 'BAO-GPCR',
#   'name': 'G Protein-Coupled Receptor BioAssays Ontology',
#   'class_count': '904'},
#  'bcgo': {'acronym': 'BCGO',
#   'name': 'Breast Cancer Grading Ontology',
#   'class_count': '133'},
#  'bci-o': {'acronym': 'BCI-O',
#   'name': 'Brain-Computer Interaction (BCI) Ontology',
#   'class_count': '182'},
#  'bclion': {'acronym': 'BCLION',
#   'name': 'Breast Cancer Lifestyle Ontology',
#   'class_count': '30'},
#  'bcmo': {'acronym': 'BCMO',
#   'name': 'Breast Cancer-Microbiome Ontology ',
#   'class_count': ''},
#  'bco': {'acronym': 'BCO',
#   'name': 'Biological Collections Ontology',
#   'class_count': '254'},
#  'bcon': {'acronym': 'BCON',
#   'name': 'Breast Cancer Ontology',
#   'class_count': '66'},
#  'bcs7': {'acronym': 'BCS7',
#   'name': 'Breast Cancer Staging - 7th Edition',
#   'class_count': '22'},
#  'bcs8': {'acronym': 'BCS8',
#   'name': 'Breast Cancer Staging - 8th Edition',
#   'class_count': '31'},
#  'bcsr-onto': {'acronym': 'BCSR-ONTO',
#   'name': 'Breast cancer screening recommendation ontology',
#   'class_count': '34'},
#  'bcteo': {'acronym': 'BCTEO',
#   'name': 'Bone and Cartilage Tissue Engineering Ontology',
#   'class_count': '253'},
#  'bctt': {'acronym': 'BCTT',
#   'name': 'Behaviour Change Technique Taxonomy',
#   'class_count': '110'},
#  'bdo': {'acronym': 'BDO',
#   'name': 'Bone Dysplasia Ontology',
#   'class_count': '3668'},
#  'be': {'acronym': 'BE', 'name': 'Bioentities', 'class_count': '442'},
#  'bero': {'acronym': 'BERO',
#   'name': 'Biological and Environmental Research Ontology',
#   'class_count': '392307'},
#  'bflc': {'acronym': 'BFLC',
#   'name': 'LC BIBFRAME 2.0 Vocabulary Extension',
#   'class_count': ''},
#  'bfo': {'acronym': 'BFO',
#   'name': 'Basic Formal Ontology',
#   'class_count': '35'},
#  'bhn': {'acronym': 'BHN',
#   'name': 'Biologie Hors Nomenclature',
#   'class_count': '2534'},
#  'bho': {'acronym': 'BHO',
#   'name': 'Bleeding History Phenotype Ontology',
#   'class_count': '544'},
#  'bibframe': {'acronym': 'BIBFRAME',
#   'name': 'BIBFRAME 2.0',
#   'class_count': ''},
#  'bibliotek-o': {'acronym': 'BIBLIOTEK-O',
#   'name': 'The Biblioteko Ontology',
#   'class_count': '278'},
#  'bifo': {'acronym': 'BIFO', 'name': 'Biofilm Ontology', 'class_count': '78'},
#  'bim': {'acronym': 'BIM',
#   'name': 'Biomedical Image Ontology',
#   'class_count': ''},
#  'bin': {'acronym': 'BIN',
#   'name': 'Body in Numbers project terminology',
#   'class_count': ''},
#  'biodivthes': {'acronym': 'BIODIVTHES',
#   'name': 'Biodiversity Thesaurus',
#   'class_count': '4'},
#  'biolink': {'acronym': 'BIOLINK',
#   'name': 'Biolink Model',
#   'class_count': '505'},
#  'biomo': {'acronym': 'BIOMO',
#   'name': 'Biological Observation Matrix Ontology',
#   'class_count': '1596'},
#  'biomodels': {'acronym': 'BIOMODELS',
#   'name': 'BioModels Ontology',
#   'class_count': '187520'},
#  'bipom': {'acronym': 'BIPOM',
#   'name': 'Biological interlocked Process Ontology for metabolism',
#   'class_count': '142'},
#  'bipon': {'acronym': 'BIPON',
#   'name': 'Bacterial interlocked Process ONtology',
#   'class_count': '1746'},
#  'birnlex': {'acronym': 'BIRNLEX',
#   'name': 'Biomedical Informatics Research Network Project Lexicon',
#   'class_count': '3580'},
#  'birthonto': {'acronym': 'BIRTHONTO',
#   'name': 'BirthOnto: Birth Data Analysis',
#   'class_count': '87'},
#  'bko': {'acronym': 'BKO', 'name': 'Bricks ontology', 'class_count': '669'},
#  'bllm': {'acronym': 'BLLM',
#   'name': 'Large Language Model Ontology',
#   'class_count': ''},
#  'bmont': {'acronym': 'BMONT',
#   'name': 'The Biomarker Ontology',
#   'class_count': '542'},
#  'bms-lm': {'acronym': 'BMS-LM',
#   'name': 'BioMedical Study Lifecycle Management',
#   'class_count': '154'},
#  'bmt': {'acronym': 'BMT', 'name': 'Biomedical Topics', 'class_count': '253'},
#  'bno': {'acronym': 'BNO',
#   'name': 'Bionutrition Ontology',
#   'class_count': '100'},
#  'bof': {'acronym': 'BOF',
#   'name': 'Biodiversity Ontology',
#   'class_count': '189'},
#  'boshi': {'acronym': 'BOSHI', 'name': 'boshra', 'class_count': ''},
#  'bp': {'acronym': 'BP',
#   'name': 'BioPAX Ontology of Biological Pathways',
#   'class_count': '69'},
#  'bp-metadata': {'acronym': 'BP-METADATA',
#   'name': 'BioPortal Metadata Ontology',
#   'class_count': '102'},
#  'bpforms': {'acronym': 'BPFORMS',
#   'name': 'Ontology of chemically concrete, composable DNA, RNA, and protein residue and crosslinks',
#   'class_count': ''},
#  'bpt': {'acronym': 'BPT',
#   'name': 'Biological Pathway Taxonomy',
#   'class_count': '3875'},
#  'brain-cof': {'acronym': 'BRAIN-COF',
#   'name': 'Computational Ontology Framework for Brain Profiles',
#   'class_count': '125'},
#  'brazi': {'acronym': 'BRAZI',
#   'name': 'Estados, Municipios, Bairros e Regiões do Brasil',
#   'class_count': ''},
#  'brct': {'acronym': 'BRCT',
#   'name': 'Brain Region & Cell Type terminology',
#   'class_count': '1654'},
#  'bridg': {'acronym': 'BRIDG',
#   'name': 'Biomedical Research Integrated Domain Group Model',
#   'class_count': '325'},
#  'bro': {'acronym': 'BRO',
#   'name': 'Biomedical Resource Ontology',
#   'class_count': '488'},
#  'brso': {'acronym': 'BRSO',
#   'name': 'Biological Resource Schema Ontology',
#   'class_count': '15'},
#  'bsao': {'acronym': 'BSAO',
#   'name': 'Botryllus schlosseri anatomy and development ontology',
#   'class_count': '104'},
#  'bspo': {'acronym': 'BSPO', 'name': 'Spatial Ontology', 'class_count': '170'},
#  'bt': {'acronym': 'BT', 'name': 'BioTop Ontology', 'class_count': '390'},
#  'bt-ontology': {'acronym': 'BT-ONTOLOGY',
#   'name': 'BrainTeaser Ontology (BTO)',
#   'class_count': '180'},
#  'bto': {'acronym': 'BTO',
#   'name': 'BRENDA Tissue and Enzyme Source Ontology',
#   'class_count': '6569'},
#  'bto-bfo': {'acronym': 'BTO-BFO',
#   'name': 'Brinell Test Ontology-BFO',
#   'class_count': '182'},
#  'bto-emmo': {'acronym': 'BTO-EMMO',
#   'name': 'Brinell Test Ontology-EMMO',
#   'class_count': '2227'},
#  'bto-provo': {'acronym': 'BTO-PROVO',
#   'name': 'Brinell Test Ontology-PROVO',
#   'class_count': '253'},
#  'bto_ontology': {'acronym': 'BTO_ONTOLOGY',
#   'name': 'Brain Tumour Ontology',
#   'class_count': '28'},
#  'c19m': {'acronym': 'C19M', 'name': 'COVID-19', 'class_count': ''},
#  'cabro': {'acronym': 'CABRO',
#   'name': 'Computer Assisted Brain Injury Rehabilitation Ontology',
#   'class_count': '59'},
#  'canco': {'acronym': 'CANCO',
#   'name': 'Cancer Chemoprevention Ontology',
#   'class_count': '127'},
#  'canont': {'acronym': 'CANONT',
#   'name': 'Upper-Level Cancer Ontology ',
#   'class_count': '56'},
#  'cao': {'acronym': 'CAO',
#   'name': 'Clusters of Orthologous Groups (COG) Analysis Ontology',
#   'class_count': '205'},
#  'carelex': {'acronym': 'CARELEX',
#   'name': 'Content Archive Resource Exchange Lexicon',
#   'class_count': '339'},
#  'caro': {'acronym': 'CARO',
#   'name': 'Common Anatomy Reference Ontology',
#   'class_count': '721'},
#  'carolio': {'acronym': 'CAROLIO',
#   'name': "Caroli's Disease and Syndrome Ontology",
#   'class_count': '87'},
#  'carre': {'acronym': 'CARRE',
#   'name': 'CARRE Risk Factor ontology',
#   'class_count': '175'},
#  'case-base-onto': {'acronym': 'CASE-BASE-ONTO',
#   'name': 'Case-base ontology for gastric dystemperament in Persian medicine',
#   'class_count': ''},
#  'cbo': {'acronym': 'CBO',
#   'name': 'Cell Behavior Ontology',
#   'class_count': '246'},
#  'ccf': {'acronym': 'CCF',
#   'name': 'Human Reference Atlas Common Coordinate Framework Ontology',
#   'class_count': '41'},
#  'cco': {'acronym': 'CCO',
#   'name': 'Cell Cycle Ontology',
#   'class_count': '264891'},
#  'ccon': {'acronym': 'CCON',
#   'name': 'Cerrado concepts and plant community dynamics',
#   'class_count': '86'},
#  'ccont': {'acronym': 'CCONT',
#   'name': 'Cell Culture Ontology',
#   'class_count': ''},
#  'cctoo': {'acronym': 'CCTOO',
#   'name': 'Cancer Care: Treatment Outcome Ontology',
#   'class_count': '1133'},
#  'cdao': {'acronym': 'CDAO',
#   'name': 'Comparative Data Analysis Ontology',
#   'class_count': '165'},
#  'cdmonto': {'acronym': 'CDMONTO',
#   'name': 'Common Diabetes Medications Ontology',
#   'class_count': '303'},
#  'cdno': {'acronym': 'CDNO',
#   'name': 'Compositional Dietary Nutrition Ontology',
#   'class_count': ''},
#  'cdo': {'acronym': 'CDO',
#   'name': 'Chinese Diabetes Mellitus Ontology',
#   'class_count': ''},
#  'cdoh': {'acronym': 'CDOH',
#   'name': 'Commercial determinant of Health Ontology',
#   'class_count': '357'},
#  'cdpeo': {'acronym': 'CDPEO',
#   'name': 'Chronic Disease Patient Education Ontology',
#   'class_count': '40'},
#  'cedarpc': {'acronym': 'CEDARPC',
#   'name': 'CEDAR Provisional Classes',
#   'class_count': ''},
#  'cedarvs': {'acronym': 'CEDARVS',
#   'name': 'CEDAR Value Sets',
#   'class_count': '34'},
#  'ceph': {'acronym': 'CEPH',
#   'name': 'Cephalopod Ontology',
#   'class_count': '1569'},
#  'chd': {'acronym': 'CHD',
#   'name': 'Congenital Heart Defects Ontology',
#   'class_count': '511'},
#  'chear': {'acronym': 'CHEAR',
#   'name': "Children's Health Exposure Analysis Resource",
#   'class_count': '14864'},
#  'chebi': {'acronym': 'CHEBI',
#   'name': 'Chemical Entities of Biological Interest Ontology',
#   'class_count': '220816'},
#  'chembio': {'acronym': 'CHEMBIO',
#   'name': 'Systems Chemical Biology and Chemogenomics Ontology ',
#   'class_count': '104'},
#  'cheminf': {'acronym': 'CHEMINF',
#   'name': 'Chemical Information Ontology',
#   'class_count': '849'},
#  'chemrof': {'acronym': 'CHEMROF', 'name': 'CHEMROF', 'class_count': '237'},
#  'chiro': {'acronym': 'CHIRO',
#   'name': 'CHEBI Integrated Role Ontology',
#   'class_count': '13286'},
#  'chmo': {'acronym': 'CHMO',
#   'name': 'Chemical Methods Ontology',
#   'class_count': '3100'},
#  'cho': {'acronym': 'CHO', 'name': 'ChemoOnto', 'class_count': '14'},
#  'chr': {'acronym': 'CHR', 'name': 'Monochrom', 'class_count': '2650'},
#  'chro': {'acronym': 'CHRO',
#   'name': 'Chromatin Regulator Ontology',
#   'class_count': '1204'},
#  'cido': {'acronym': 'CIDO',
#   'name': 'Coronavirus Infectious Disease Ontology',
#   'class_count': '31924'},
#  'cidoc-crm': {'acronym': 'CIDOC-CRM',
#   'name': 'CIDOC Conceptual Reference Model',
#   'class_count': '85'},
#  'ciinteado': {'acronym': 'CIINTEADO',
#   'name': 'Ciona intestinalis Anatomy and Development Ontology',
#   'class_count': '880'},
#  'cio': {'acronym': 'CIO',
#   'name': 'Confidence Information Ontology',
#   'class_count': '44'},
#  'cisaviado': {'acronym': 'CISAVIADO',
#   'name': 'Ciona savignyi Anatomy and Development Ontology ',
#   'class_count': '880'},
#  'ckdo': {'acronym': 'CKDO',
#   'name': 'Chronic Kidney Disease Ontology',
#   'class_count': '280'},
#  'cl': {'acronym': 'CL', 'name': 'Cell Ontology', 'class_count': '16667'},
#  'clao': {'acronym': 'CLAO',
#   'name': 'Collembola Anatomy Ontology',
#   'class_count': '1516'},
#  'clo': {'acronym': 'CLO',
#   'name': 'Cell Line Ontology',
#   'class_count': '43327'},
#  'clyh': {'acronym': 'CLYH',
#   'name': 'Clytia hemisphaerica Development and Anatomy Ontology',
#   'class_count': '265'},
#  'cmdo': {'acronym': 'CMDO',
#   'name': 'Clinical MetaData Ontology',
#   'class_count': '188'},
#  'cmecs': {'acronym': 'CMECS',
#   'name': 'Coastal and Marine Ecological Classification Standard Catalog',
#   'class_count': '1690'},
#  'cmo': {'acronym': 'CMO',
#   'name': 'Clinical Measurement Ontology',
#   'class_count': '4047'},
#  'cmpo': {'acronym': 'CMPO',
#   'name': 'Cellular microscopy phenotype ontology',
#   'class_count': '813'},
#  'cmr-qa': {'acronym': 'CMR-QA',
#   'name': 'Cardiovascular Magnetic Resonance Quality Assessment Ontology',
#   'class_count': '110'},
#  'cn': {'acronym': 'CN', 'name': 'computer network', 'class_count': '537'},
#  'cno': {'acronym': 'CNO',
#   'name': 'Computational Neuroscience Ontology',
#   'class_count': '386'},
#  'co': {'acronym': 'CO', 'name': 'Crop Ontology', 'class_count': ''},
#  'co-wheat': {'acronym': 'CO-WHEAT',
#   'name': 'Wheat Trait Ontology ',
#   'class_count': '176'},
#  'cob': {'acronym': 'COB',
#   'name': 'Core Ontology for Biology and Biomedicine',
#   'class_count': '68'},
#  'codo': {'acronym': 'CODO',
#   'name': 'CODO: an Ontology for collection and analysis of COviD-19 data',
#   'class_count': '385'},
#  'cogat': {'acronym': 'COGAT',
#   'name': 'Cognitive Atlas Ontology',
#   'class_count': '4053'},
#  'cogpo': {'acronym': 'COGPO',
#   'name': 'Cognitive Paradigm Ontology',
#   'class_count': '199'},
#  'cohsi2study': {'acronym': 'COHSI2STUDY',
#   'name': 'cohsi2study',
#   'class_count': '2'},
#  'cohsi2termsweekx': {'acronym': 'COHSI2TERMSWEEKX',
#   'name': 'cohsi2termsweekx',
#   'class_count': '2'},
#  'coid': {'acronym': 'COID',
#   'name': 'Combined Ontology for Inflammatory Diseases',
#   'class_count': '1185'},
#  'cokpme': {'acronym': 'COKPME',
#   'name': 'COKPME - COVID19 Ontology for analyzing the Karnataka Private Medical Establishments Data  ',
#   'class_count': '25'},
#  'colao': {'acronym': 'COLAO',
#   'name': 'Coleoptera Anatomy Ontology',
#   'class_count': '894'},
#  'comet': {'acronym': 'COMET',
#   'name': 'LinkML Common Metadata Elements and Terms',
#   'class_count': '207'},
#  'como': {'acronym': 'COMO',
#   'name': 'Context and Measurement Ontology',
#   'class_count': '445'},
#  'comodi': {'acronym': 'COMODI', 'name': 'COMODI', 'class_count': '65'},
#  'condor': {'acronym': 'CONDOR',
#   'name': 'Liver Cancer Ontology Diagnosis Treatment',
#   'class_count': '55'},
#  'contsonto': {'acronym': 'CONTSONTO',
#   'name': 'Continuity of care',
#   'class_count': '171'},
#  'copdo': {'acronym': 'COPDO', 'name': 'COPD Ontology', 'class_count': '108'},
#  'costart': {'acronym': 'COSTART',
#   'name': 'Coding Symbols for a Thesaurus of Adverse Reaction Terms',
#   'class_count': '1707'},
#  'covid-19': {'acronym': 'COVID-19',
#   'name': 'COVID-19 Ontology',
#   'class_count': '2270'},
#  'covid-19-ont-pm': {'acronym': 'COVID-19-ONT-PM',
#   'name': 'COVID-19OntologyInPatternMedicine',
#   'class_count': '299'},
#  'covid19': {'acronym': 'COVID19',
#   'name': 'COVID-19 Surveillance Ontology',
#   'class_count': '32'},
#  'covid19-ibo': {'acronym': 'COVID19-IBO',
#   'name': 'Covid19 Impact on Banking Ontology',
#   'class_count': '159'},
#  'covidcrfrapid': {'acronym': 'COVIDCRFRAPID',
#   'name': 'WHO COVID-19 Rapid Version CRF semantic data model',
#   'class_count': '396'},
#  'cpro': {'acronym': 'CPRO',
#   'name': 'Computer-Based Patient Record Ontology',
#   'class_count': '128'},
#  'cpt': {'acronym': 'CPT',
#   'name': 'CPT - Current Procedural Terminology',
#   'class_count': '14403'},
#  'cptac': {'acronym': 'CPTAC',
#   'name': 'CPTAC Proteomics Pipeline Infrastructure Ontology',
#   'class_count': '19'},
#  'creno': {'acronym': 'CRENO',
#   'name': 'Culture, Race, Ethnicity and Nationality Ontology',
#   'class_count': '1107'},
#  'crisp': {'acronym': 'CRISP',
#   'name': 'Computer Retrieval of Information on Scientific Projects Thesaurus',
#   'class_count': '9039'},
#  'cro': {'acronym': 'CRO',
#   'name': 'Contributor Role Ontology',
#   'class_count': '124'},
#  'cryoem': {'acronym': 'CRYOEM',
#   'name': 'Cryo Electron Microscopy',
#   'class_count': '111'},
#  'cs': {'acronym': 'CS',
#   'name': 'Coping Strategies for Adverse Drug Events Ontology',
#   'class_count': ''},
#  'cseo': {'acronym': 'CSEO',
#   'name': 'Cigarette Smoke Exposure Ontology',
#   'class_count': '20085'},
#  'cso': {'acronym': 'CSO',
#   'name': 'Clinical Study Ontology',
#   'class_count': '37'},
#  'csso': {'acronym': 'CSSO',
#   'name': 'Clinical Signs and Symptoms Ontology',
#   'class_count': '303'},
#  'cst': {'acronym': 'CST', 'name': 'Cancer Staging Terms', 'class_count': ''},
#  'cstd': {'acronym': 'CSTD',
#   'name': 'Clinical smell and taste disorders',
#   'class_count': '98'},
#  'ctcae': {'acronym': 'CTCAE',
#   'name': 'Common Terminology Criteria for Adverse Events',
#   'class_count': '4049'},
#  'cteno': {'acronym': 'CTENO',
#   'name': 'Ctenophore Ontology',
#   'class_count': '668'},
#  'ctgo': {'acronym': 'CTGO',
#   'name': 'Clinical Trials Gov Ontology',
#   'class_count': '121'},
#  'cto': {'acronym': 'CTO',
#   'name': 'Clinical Trials Ontology',
#   'class_count': '273'},
#  'cto-ndd': {'acronym': 'CTO-NDD',
#   'name': 'Clinical Trials Ontology - Neurodegenerative Diseases',
#   'class_count': '377'},
#  'ctont': {'acronym': 'CTONT',
#   'name': 'Epoch Clinical Trial Ontology',
#   'class_count': '43'},
#  'ctu_beready_gem': {'acronym': 'CTU_BEREADY_GEM',
#   'name': 'CTU Bern BEReady Gemeinden',
#   'class_count': '3'},
#  'ctx': {'acronym': 'CTX',
#   'name': 'Cerebrotendinous Xanthomatosis Ontology',
#   'class_count': '479'},
#  'cu-vo': {'acronym': 'CU-VO', 'name': 'Venom Ontology', 'class_count': '11'},
#  'cvao': {'acronym': 'CVAO', 'name': 'STO', 'class_count': '1712'},
#  'cvdo': {'acronym': 'CVDO',
#   'name': 'Cardiovascular Disease Ontology',
#   'class_count': '720'},
#  'cwd': {'acronym': 'CWD',
#   'name': 'Consumer Wearable Device',
#   'class_count': '46'},
#  'cyto': {'acronym': 'CYTO', 'name': 'CYTOKINE', 'class_count': '317'},
#  'd3o': {'acronym': 'D3O',
#   'name': 'DSMZ Digital Diversity Ontology',
#   'class_count': '294'},
#  'datacite': {'acronym': 'DATACITE',
#   'name': 'SPAR DataCite Ontology',
#   'class_count': '21'},
#  'datacite-vocab': {'acronym': 'DATACITE-VOCAB',
#   'name': 'DATACITE V4.4',
#   'class_count': '2'},
#  'dc': {'acronym': 'DC', 'name': 'Dublin Core', 'class_count': '11'},
#  'dcat': {'acronym': 'DCAT',
#   'name': 'Data Catalog Vocabulary',
#   'class_count': ''},
#  'dcat-fdc': {'acronym': 'DCAT-FDC',
#   'name': 'Data Catalog Vocabulary (DCAT)',
#   'class_count': '73'},
#  'dcat3': {'acronym': 'DCAT3', 'name': 'DCAT3', 'class_count': '75'},
#  'dccdfv': {'acronym': 'DCCDFV',
#   'name': 'Dublin Core Collection Description Frequency Vocabulary',
#   'class_count': '1'},
#  'dcm': {'acronym': 'DCM',
#   'name': 'DICOM Controlled Terminology',
#   'class_count': '4866'},
#  'dcmitype': {'acronym': 'DCMITYPE',
#   'name': 'DCMI Type Vocabulary',
#   'class_count': '18'},
#  'dco': {'acronym': 'DCO',
#   'name': 'Dispedia Core Ontology',
#   'class_count': '49'},
#  'dct': {'acronym': 'DCT', 'name': 'DC Terms', 'class_count': '25'},
#  'dcterms': {'acronym': 'DCTERMS',
#   'name': 'DCMI Metadata Terms: properties in /terms/ namespace',
#   'class_count': '25'},
#  'ddanat': {'acronym': 'DDANAT',
#   'name': 'Dictyostelium Discoideum Anatomy Ontology',
#   'class_count': '135'},
#  'ddi': {'acronym': 'DDI',
#   'name': 'Ontology for Drug Discovery Investigations',
#   'class_count': '156'},
#  'ddiem': {'acronym': 'DDIEM',
#   'name': 'Drug Database for Inborn Errors of Metabolism (DDIEM) Ontology',
#   'class_count': '208'},
#  'ddpheno': {'acronym': 'DDPHENO',
#   'name': 'Dictyostelium Discoideum Phenotype Ontology',
#   'class_count': '1373'},
#  'ddss': {'acronym': 'DDSS',
#   'name': 'Health_ontology',
#   'class_count': '712018'},
#  'deb': {'acronym': 'DEB',
#   'name': 'Devices, Experimental scaffolds and Biomaterials Ontology',
#   'class_count': '601'},
#  'decide': {'acronym': 'DECIDE',
#   'name': 'DECIDE ONTOLOGY',
#   'class_count': '19'},
#  'dermlex': {'acronym': 'DERMLEX',
#   'name': 'Dermatology Lexicon',
#   'class_count': '6106'},
#  'dermo': {'acronym': 'DERMO',
#   'name': 'Human Dermatological Disease Ontology',
#   'class_count': '3521'},
#  'dfo': {'acronym': 'DFO',
#   'name': 'Databank Family Ontology',
#   'class_count': '12'},
#  'dhmo': {'acronym': 'DHMO',
#   'name': 'RADx Data Hub Metadata Ontology',
#   'class_count': '145'},
#  'diab': {'acronym': 'DIAB',
#   'name': 'BioMedBridges Diabetes Ontology',
#   'class_count': '375'},
#  'diagont': {'acronym': 'DIAGONT',
#   'name': 'Diagnostic Ontology',
#   'class_count': '96'},
#  'dideo': {'acronym': 'DIDEO',
#   'name': 'Drug Interaction and Evidence Ontology',
#   'class_count': '617'},
#  'dikb': {'acronym': 'DIKB',
#   'name': 'Drug Interaction Knowledge Base Ontology',
#   'class_count': '161'},
#  'dilon': {'acronym': 'DILON',
#   'name': 'Dietary lifestyle ontology',
#   'class_count': '262'},
#  'dinto': {'acronym': 'DINTO',
#   'name': 'The Drug-Drug Interactions Ontology',
#   'class_count': '28178'},
#  'disdriv': {'acronym': 'DISDRIV',
#   'name': 'Disease Drivers Ontology',
#   'class_count': '18'},
#  'dloro': {'acronym': 'DLORO',
#   'name': 'Dependency Layered Ontology for Radiation Oncology',
#   'class_count': '295'},
#  'dmdsont': {'acronym': 'DMDSONT',
#   'name': 'Diabetes Mellitus Diagnosis and Support Ontology ',
#   'class_count': '8'},
#  'dmto': {'acronym': 'DMTO',
#   'name': 'Diabetes Mellitus Treatment Ontology',
#   'class_count': ''},
#  'doccc': {'acronym': 'DOCCC',
#   'name': 'Diagnosis Ontology of Clinical Care Classification',
#   'class_count': '204'},
#  'doid': {'acronym': 'DOID',
#   'name': 'Human Disease Ontology',
#   'class_count': '18897'},
#  'doremus-keys': {'acronym': 'DOREMUS-KEYS',
#   'name': 'Doremus List of Keys',
#   'class_count': '3'},
#  'doves': {'acronym': 'DOVES',
#   'name': 'Digital medicine Outcomes Value Set (DOVeS) Ontology',
#   'class_count': '27531'},
#  'dpco': {'acronym': 'DPCO',
#   'name': 'Diabetes Pharmacology Ontology',
#   'class_count': ''},
#  'dpo': {'acronym': 'DPO',
#   'name': 'Drosophila Phenotype Ontology',
#   'class_count': '1382'},
#  'dranpto': {'acronym': 'DRANPTO',
#   'name': 'Dementia-Related Agitation Non-Pharmacological Treatment Ontology',
#   'class_count': '569'},
#  'dreamdnpto': {'acronym': 'DREAMDNPTO',
#   'name': 'Dementia-Related Emotional And Mood Disturbance Non-Pharmacological Treatment Ontology',
#   'class_count': '1258'},
#  'drmo': {'acronym': 'DRMO',
#   'name': 'Dental Restorative Material Ontology',
#   'class_count': ''},
#  'dron': {'acronym': 'DRON',
#   'name': 'The Drug Ontology',
#   'class_count': '747494'},
#  'drpsnpto': {'acronym': 'DRPSNPTO',
#   'name': 'Dementia-Related Psychotic Symptoms Non-Pharmacological Treatment Ontology',
#   'class_count': '610'},
#  'dseo': {'acronym': 'DSEO',
#   'name': 'Data Science Education Ontology',
#   'class_count': '131'},
#  'dsip': {'acronym': 'DSIP', 'name': 'Pharmacy mock data', 'class_count': ''},
#  'dsip1v': {'acronym': 'DSIP1V',
#   'name': 'DSIP1_vocabulary',
#   'class_count': '2'},
#  'dsip2324_demo': {'acronym': 'DSIP2324_DEMO',
#   'name': 'DSIP2324_Demonstration',
#   'class_count': '2'},
#  'dsip7': {'acronym': 'DSIP7', 'name': 'DSIP_FieldLab_7', 'class_count': '2'},
#  'dsip8': {'acronym': 'DSIP8', 'name': 'DSIP8REFUGEE', 'class_count': '2'},
#  'dsipf7': {'acronym': 'DSIPF7',
#   'name': 'DSIP FiledLab7 ',
#   'class_count': '2'},
#  'dsipfl7': {'acronym': 'DSIPFL7',
#   'name': 'DSIP_Fieldlab_7',
#   'class_count': '2'},
#  'dsip_fl_7': {'acronym': 'DSIP_FL_7',
#   'name': 'DSIP_FL_7',
#   'class_count': '2'},
#  'dto': {'acronym': 'DTO',
#   'name': 'Drug Target Ontology',
#   'class_count': '10075'},
#  'duo': {'acronym': 'DUO',
#   'name': 'The Data Use Ontology',
#   'class_count': '307'},
#  'e-ppo': {'acronym': 'E-PPO',
#   'name': 'Enhanced Personal Profile Ontology',
#   'class_count': '54'},
#  'ebp': {'acronym': 'EBP', 'name': 'EmpowerBP', 'class_count': '50'},
#  'ecao': {'acronym': 'ECAO',
#   'name': 'The Echinoderm Anatomy and Development Ontology',
#   'class_count': '7160'},
#  'ecdo': {'acronym': 'ECDO',
#   'name': 'Elderly Care Dementia Ontology',
#   'class_count': '2'},
#  'ecg': {'acronym': 'ECG',
#   'name': 'Electrocardiography Ontology',
#   'class_count': '1124'},
#  'ecm4m-md-vocabs': {'acronym': 'ECM4M-MD-VOCABS',
#   'name': 'EarthCube M4M Metadata Vocabulary',
#   'class_count': '2'},
#  'eco': {'acronym': 'ECO',
#   'name': 'Evidence and Conclusion Ontology',
#   'class_count': '2284'},
#  'ecocore': {'acronym': 'ECOCORE',
#   'name': 'An ontology of core ecological entities',
#   'class_count': '5586'},
#  'ecosim': {'acronym': 'ECOSIM',
#   'name': 'ecosim ontology',
#   'class_count': '1684'},
#  'ecp': {'acronym': 'ECP',
#   'name': 'Electronic Care Plan',
#   'class_count': '32'},
#  'ecso': {'acronym': 'ECSO',
#   'name': 'The Ecosystem Ontology',
#   'class_count': '2094'},
#  'ecto': {'acronym': 'ECTO',
#   'name': 'Environmental conditions, treatments and exposures ontology',
#   'class_count': ''},
#  'edam': {'acronym': 'EDAM',
#   'name': 'EDAM - The data analysis and management ontology',
#   'class_count': '3511'},
#  'edam-bioimaging': {'acronym': 'EDAM-BIOIMAGING',
#   'name': 'EDAM Bioimaging Ontology',
#   'class_count': '341'},
#  'edda': {'acronym': 'EDDA',
#   'name': 'EDDA Study Designs Taxonomy',
#   'class_count': '502'},
#  'edda_pt': {'acronym': 'EDDA_PT',
#   'name': 'EDDA Publication Types Taxonomy',
#   'class_count': '93'},
#  'edem-connectonto': {'acronym': 'EDEM-CONNECTONTO',
#   'name': 'eDEM-Connect: Ontology of Dementia-related Agitation and Relationship between Informal Caregivers and Persons with Dementia',
#   'class_count': '241'},
#  'efo': {'acronym': 'EFO',
#   'name': 'Experimental Factor Ontology',
#   'class_count': '63496'},
#  'ego': {'acronym': 'EGO',
#   'name': 'Epigenome Ontology',
#   'class_count': '2952'},
#  'ehda': {'acronym': 'EHDA',
#   'name': 'Human Developmental Anatomy Ontology, timed version',
#   'class_count': '8340'},
#  'ehdaa': {'acronym': 'EHDAA',
#   'name': 'Human Developmental Anatomy Ontology, abstract version 1',
#   'class_count': '2314'},
#  'ehdaa2': {'acronym': 'EHDAA2',
#   'name': 'Human Developmental Anatomy Ontology, abstract version 2',
#   'class_count': '2743'},
#  'eld': {'acronym': 'ELD',
#   'name': 'EthiopianListOfDiseases',
#   'class_count': '2'},
#  'electrica': {'acronym': 'ELECTRICA',
#   'name': 'Ontology for ELEctronic tool for Clinicians, Trainers and Researchers In Child Abuse',
#   'class_count': '1741'},
#  'elig': {'acronym': 'ELIG',
#   'name': 'Eligibility Feature Hierarchy',
#   'class_count': '29'},
#  'elter_cl': {'acronym': 'ELTER_CL',
#   'name': 'eLTER Controlled Lists',
#   'class_count': '23'},
#  'emap': {'acronym': 'EMAP',
#   'name': 'Mouse Gross Anatomy and Development Ontology',
#   'class_count': '19444'},
#  'emapa': {'acronym': 'EMAPA',
#   'name': 'Mouse gross anatomy and development, timed',
#   'class_count': '8768'},
#  'emif-ad': {'acronym': 'EMIF-AD',
#   'name': 'EMIF-AD ontology',
#   'class_count': '700'},
#  'emo': {'acronym': 'EMO',
#   'name': 'Enzyme Mechanism Ontology',
#   'class_count': ''},
#  'endoh': {'acronym': 'ENDOH',
#   'name': 'Environmental Determinants of Health',
#   'class_count': '102'},
#  'enm': {'acronym': 'ENM', 'name': 'eNanoMapper', 'class_count': '25795'},
#  'entity': {'acronym': 'ENTITY',
#   'name': 'ISO-15926-2_2003_entityMembership',
#   'class_count': '203'},
#  'envo': {'acronym': 'ENVO',
#   'name': 'Environment Ontology',
#   'class_count': '7030'},
#  'envs_variables': {'acronym': 'ENVS_VARIABLES',
#   'name': 'ENVS variables',
#   'class_count': '2'},
#  'envthes': {'acronym': 'ENVTHES',
#   'name': 'Thesaurus for long-term ecological research, monitoring, experiments',
#   'class_count': '6'},
#  'eo': {'acronym': 'EO', 'name': 'Ethnicity Ontoloy', 'class_count': ''},
#  'eo1': {'acronym': 'EO1', 'name': 'Example Ontology', 'class_count': '2'},
#  'eol': {'acronym': 'EOL',
#   'name': 'Environment Ontology for Livestock',
#   'class_count': '648'},
#  'ep': {'acronym': 'EP',
#   'name': 'Cardiac Electrophysiology Ontology',
#   'class_count': '232'},
#  'epie': {'acronym': 'EPIE',
#   'name': 'Epigenetic Entity',
#   'class_count': '392'},
#  'epilont': {'acronym': 'EPILONT',
#   'name': 'Epilepsy Ontology',
#   'class_count': '138'},
#  'epio': {'acronym': 'EPIO',
#   'name': 'EpilepsyOntology',
#   'class_count': '1916'},
#  'epip': {'acronym': 'EPIP',
#   'name': 'Epigenetic Process',
#   'class_count': '263'},
#  'episem': {'acronym': 'EPISEM',
#   'name': 'Epilepsy Semiology',
#   'class_count': '1594'},
#  'epo': {'acronym': 'EPO',
#   'name': 'Early Pregnancy Ontology',
#   'class_count': ''},
#  'epso': {'acronym': 'EPSO',
#   'name': 'Epilepsy and Seizure Ontology',
#   'class_count': '2160'},
#  'ero': {'acronym': 'ERO',
#   'name': 'Eagle-I Research Resource Ontology',
#   'class_count': '4061'},
#  'esfo': {'acronym': 'ESFO',
#   'name': 'Enzyme Structure Function Ontology',
#   'class_count': '22'},
#  'eso_c': {'acronym': 'ESO_C',
#   'name': 'Epilepsy Semiology Ontology',
#   'class_count': '179'},
#  'esso': {'acronym': 'ESSO',
#   'name': 'Epilepsy Syndrome Seizure Ontology',
#   'class_count': '2705'},
#  'etanc': {'acronym': 'ETANC', 'name': 'ETHIOPIANC', 'class_count': '2'},
#  'ethanc': {'acronym': 'ETHANC', 'name': 'ETHANC', 'class_count': '2'},
#  'ethopd': {'acronym': 'ETHOPD', 'name': 'Ethiopian OPD', 'class_count': '2'},
#  'eupath': {'acronym': 'EUPATH',
#   'name': 'VEuPathDB Ontology',
#   'class_count': '5110'},
#  'evi': {'acronym': 'EVI',
#   'name': 'Evidence Graph Ontology',
#   'class_count': '31'},
#  'evs': {'acronym': 'EVS', 'name': 'Exposure Value Set', 'class_count': '2'},
#  'exact': {'acronym': 'EXACT',
#   'name': 'An ontology for experimental actions',
#   'class_count': '162'},
#  'exmo': {'acronym': 'EXMO',
#   'name': 'Exercise Medicine Ontology',
#   'class_count': ''},
#  'exo': {'acronym': 'EXO', 'name': 'Exposure Ontology', 'class_count': '152'},
#  'exon': {'acronym': 'EXON',
#   'name': 'Experimental Ontology',
#   'class_count': '5'},
#  'extract': {'acronym': 'EXTRACT',
#   'name': 'EXTeRnAl Conditions Taxonomy (EXTRACT)',
#   'class_count': '2'},
#  'faldo': {'acronym': 'FALDO',
#   'name': 'Feature Annotation Location Description Ontology ',
#   'class_count': '19'},
#  'fall': {'acronym': 'FALL',
#   'name': 'MyOntoServiceFull_FallDetection',
#   'class_count': '51'},
#  'falls': {'acronym': 'FALLS',
#   'name': 'falls prevention ',
#   'class_count': '30'},
#  'fao': {'acronym': 'FAO',
#   'name': 'Fungal Gross Anatomy Ontology',
#   'class_count': '120'},
#  'farmaci': {'acronym': 'FARMACI', 'name': 'FARMACI AIFA', 'class_count': ''},
#  'fast-chrono': {'acronym': 'FAST-CHRONO',
#   'name': 'FAST (Faceted Access of Subject Terminology) Chronological Facet',
#   'class_count': '3'},
#  'fast-event': {'acronym': 'FAST-EVENT',
#   'name': 'FAST (Faceted Application of Subject Terminology) Event',
#   'class_count': '4'},
#  'fast-event-skos': {'acronym': 'FAST-EVENT-SKOS',
#   'name': 'FAST (Faceted Application of Subject Terminology) Event Facet',
#   'class_count': '4'},
#  'fast-formgenre': {'acronym': 'FAST-FORMGENRE',
#   'name': 'FAST (Faceted Application of Subject Terminology) FormGenre facet',
#   'class_count': '3'},
#  'fast-genreform': {'acronym': 'FAST-GENREFORM',
#   'name': 'FAST (Faceted Access of Subject Terminology) GenreForm',
#   'class_count': '4'},
#  'fast-title': {'acronym': 'FAST-TITLE',
#   'name': 'FAST (Faceted Application of Subject Terminology) Title Facet',
#   'class_count': '3'},
#  'fasto': {'acronym': 'FASTO',
#   'name': 'HL7 FHIR and SSN ontology based Type 1 Diabetes Mellitus Ontology',
#   'class_count': ''},
#  'fb-bt': {'acronym': 'FB-BT',
#   'name': 'Drosophila Gross Anatomy Ontology',
#   'class_count': '28344'},
#  'fb-cv': {'acronym': 'FB-CV',
#   'name': 'FlyBase Controlled Vocabulary',
#   'class_count': '2332'},
#  'fb-dv': {'acronym': 'FB-DV',
#   'name': 'Drosophila Development Ontology',
#   'class_count': '222'},
#  'fb-sp': {'acronym': 'FB-SP', 'name': 'Fly Taxonomy', 'class_count': '6600'},
#  'fbbi': {'acronym': 'FBbi',
#   'name': 'Biological Imaging Methods Ontology',
#   'class_count': '649'},
#  'fcc1': {'acronym': 'FCC1',
#   'name': 'Fernald Community Cohort N',
#   'class_count': '9'},
#  'fdc-gdmt': {'acronym': 'FDC-GDMT',
#   'name': 'Ontology for Generic Dataset Metadata Template',
#   'class_count': '2'},
#  'fdsajfahsjk': {'acronym': 'FDSAJFAHSJK',
#   'name': 'OWL_XML_Tool5',
#   'class_count': '3'},
#  'fdt-o': {'acronym': 'FDT-O',
#   'name': 'FAIR Data Train Ontology',
#   'class_count': '47'},
#  'fenics': {'acronym': 'FENICS',
#   'name': 'Functional Electrophysiology Nomenclature for Ion Channels',
#   'class_count': '153'},
#  'fg': {'acronym': 'FG', 'name': 'FAIR Genomes', 'class_count': '9'},
#  'fgnhns': {'acronym': 'FGNHNS',
#   'name': 'FoodGroupNHNS',
#   'class_count': '6087'},
#  'fhho': {'acronym': 'FHHO',
#   'name': 'Family Health History Ontology',
#   'class_count': '238'},
#  'fideo': {'acronym': 'FIDEO',
#   'name': 'Food Interactions with Drugs Evidence Ontology',
#   'class_count': '3543'},
#  'fire': {'acronym': 'FIRE', 'name': 'Fire Ontology', 'class_count': '53'},
#  'fish-ast': {'acronym': 'FISH-AST',
#   'name': 'FISH Archaeological Sciences Thesaurus',
#   'class_count': '2'},
#  'fisho': {'acronym': 'FISHO', 'name': 'Fish Ontology', 'class_count': '386'},
#  'fitbit': {'acronym': 'FITBIT',
#   'name': 'Fitbit Vocabulary',
#   'class_count': ''},
#  'fit_bit': {'acronym': 'FIT_BIT',
#   'name': 'Fitbit Vocabularies ',
#   'class_count': '2'},
#  'fix': {'acronym': 'FIX',
#   'name': 'Physico-Chemical Methods and Properties',
#   'class_count': '1163'},
#  'fldlb3': {'acronym': 'FLDLB3',
#   'name': 'FIELDLAB3_2023_2',
#   'class_count': '2'},
#  'flopo': {'acronym': 'FLOPO',
#   'name': 'Flora Phenotype Ontology',
#   'class_count': '26873'},
#  'flu': {'acronym': 'FLU', 'name': 'Influenza Ontology', 'class_count': '585'},
#  'flyglycodb': {'acronym': 'FLYGLYCODB',
#   'name': 'FlyGlycoDB',
#   'class_count': '114'},
#  'fma': {'acronym': 'FMA',
#   'name': 'Foundational Model of Anatomy',
#   'class_count': '104721'},
#  'fmpm': {'acronym': 'FMPM',
#   'name': 'Food Matrix for Predictive Microbiology',
#   'class_count': '162'},
#  'fns-h': {'acronym': 'FNS-H', 'name': 'FNS-Harmony', 'class_count': '31464'},
#  'fo': {'acronym': 'FO', 'name': 'Fern Ontology', 'class_count': ''},
#  'foaf': {'acronym': 'FOAF',
#   'name': 'Friend of a Friend Vocabulary',
#   'class_count': '22'},
#  'fobi': {'acronym': 'FOBI',
#   'name': 'FOBI (Food-Biomarker Ontology)',
#   'class_count': '1334'},
#  'foodon': {'acronym': 'FOODON',
#   'name': 'The FoodOn Food Ontology',
#   'class_count': '39435'},
#  'four-m_vocabs': {'acronym': 'FOUR-M_VOCABS',
#   'name': 'AGE-FRIENDLY 4M VOCABULARY',
#   'class_count': ''},
#  'fovt': {'acronym': 'FOVT',
#   'name': 'FuTRES Ontology of Vertebrate Traits',
#   'class_count': '11322'},
#  'fplx': {'acronym': 'FPLX', 'name': 'FamPlex', 'class_count': ''},
#  'frmo': {'acronym': 'FRMO',
#   'name': 'Fall Risk Management Ontology ',
#   'class_count': '890'},
#  'ftc': {'acronym': 'FTC',
#   'name': 'Functional Therapeutic Chemical Classification System',
#   'class_count': '61426'},
#  'fypo': {'acronym': 'FYPO',
#   'name': 'Fission Yeast Phenotype Ontology',
#   'class_count': '16770'},
#  'g-prov': {'acronym': 'G-PROV',
#   'name': 'Guideline Provenance',
#   'class_count': '138'},
#  'g4-dsip': {'acronym': 'G4-DSIP',
#   'name': 'Group 4-Data Science in Practice',
#   'class_count': '2'},
#  'galen': {'acronym': 'GALEN',
#   'name': 'Galen Ontology',
#   'class_count': '23141'},
#  'gallont': {'acronym': 'GALLONT',
#   'name': 'Plant Gall Ontology',
#   'class_count': '395'},
#  'gamuts': {'acronym': 'GAMUTS',
#   'name': 'Radiology Gamuts Ontology',
#   'class_count': '16876'},
#  'gaz': {'acronym': 'GAZ', 'name': 'Gazetteer', 'class_count': '668838'},
#  'gb': {'acronym': 'GB', 'name': 'GlycanBind', 'class_count': '13'},
#  'gbm': {'acronym': 'GBM', 'name': 'Glioblastoma', 'class_count': ''},
#  'gbol': {'acronym': 'GBOL', 'name': 'GBOL', 'class_count': '337'},
#  'gcbo': {'acronym': 'GCBO',
#   'name': 'Global Code Book Ontology',
#   'class_count': '3395'},
#  'gco': {'acronym': 'GCO',
#   'name': 'Genome Component Ontology',
#   'class_count': '5'},
#  'gdco': {'acronym': 'GDCO',
#   'name': 'Data Collection Ontology',
#   'class_count': '73'},
#  'gdmt': {'acronym': 'GDMT',
#   'name': 'Generic Dataset Metadata Template Vocabulary',
#   'class_count': ''},
#  'gdoa': {'acronym': 'GDOA',
#   'name': 'Graphic Descriptor Ontology Anatomy Extension',
#   'class_count': '188'},
#  'gecco': {'acronym': 'GECCO',
#   'name': 'COVID-19 Common Datamodel',
#   'class_count': ''},
#  'gecko': {'acronym': 'GECKO',
#   'name': 'Genomics Cohorts Knowledge Ontology',
#   'class_count': '154'},
#  'genai': {'acronym': 'GENAI',
#   'name': 'Generative AI Ontology',
#   'class_count': '55'},
#  'gender': {'acronym': 'GENDER',
#   'name': 'Gender Identity',
#   'class_count': '2'},
#  'gene-cds': {'acronym': 'GENE-CDS',
#   'name': 'Genomic Clinical Decision Support Ontology',
#   'class_count': '2265'},
#  'genepio': {'acronym': 'GENEPIO',
#   'name': 'Genomic Epidemiology Application Ontology ',
#   'class_count': '7208'},
#  'genevieve': {'acronym': 'GENEVIEVE', 'name': 'Charlotte', 'class_count': ''},
#  'geno': {'acronym': 'GENO',
#   'name': 'Genotype Ontology',
#   'class_count': '425'},
#  'geo': {'acronym': 'GEO',
#   'name': 'Geographical Entity Ontology',
#   'class_count': '328'},
#  'geosparql': {'acronym': 'GEOSPARQL',
#   'name': 'GeoSPARQL',
#   'class_count': '61'},
#  'geospecies': {'acronym': 'GEOSPECIES',
#   'name': 'GeoSpecies Ontology',
#   'class_count': '86'},
#  'gexo': {'acronym': 'GEXO',
#   'name': 'Gene Expression Ontology',
#   'class_count': '166254'},
#  'gff-m4m': {'acronym': 'GFF-M4M', 'name': 'GO FAIR M4M', 'class_count': '10'},
#  'gffo': {'acronym': 'GFFO',
#   'name': 'Genetic Feature Format Ontology',
#   'class_count': '1'},
#  'gfo': {'acronym': 'GFO',
#   'name': 'General Formal Ontology',
#   'class_count': '45'},
#  'gfo-bio': {'acronym': 'GFO-BIO',
#   'name': 'General Formal Ontology for Biology',
#   'class_count': '168'},
#  'gfvo': {'acronym': 'GFVO',
#   'name': 'Genomic Feature and Variation Ontology',
#   'class_count': '102'},
#  'glyco': {'acronym': 'GLYCO',
#   'name': 'Glycomics Ontology',
#   'class_count': ''},
#  'glycocoo': {'acronym': 'GLYCOCOO',
#   'name': 'GlycoConjugate Ontology',
#   'class_count': '51'},
#  'glycordf': {'acronym': 'GLYCORDF', 'name': 'GlycoRDF', 'class_count': '137'},
#  'gml': {'acronym': 'GML',
#   'name': 'Ontology for Geography Markup Language (GML3.0)',
#   'class_count': '175'},
#  'gmm': {'acronym': 'GMM', 'name': 'GoMapMan', 'class_count': '1896'},
#  'gmo': {'acronym': 'GMO',
#   'name': 'Growth Medium Ontology',
#   'class_count': '1559'},
#  'gno': {'acronym': 'GNO',
#   'name': 'Glycan Naming Ontology',
#   'class_count': '194565'},
#  'go': {'acronym': 'GO', 'name': 'Gene Ontology', 'class_count': '51641'},
#  'go-ext': {'acronym': 'GO-EXT',
#   'name': 'Gene Ontology Extension',
#   'class_count': '35873'},
#  'go-plus': {'acronym': 'GO-PLUS', 'name': 'go-plus', 'class_count': '84145'},
#  'goldterms': {'acronym': 'GOLDTERMS',
#   'name': 'GOLD Ecosystem Classification',
#   'class_count': '1825'},
#  'gpml': {'acronym': 'GPML',
#   'name': 'Graphical Pathway Markup Language',
#   'class_count': '19'},
#  'gro': {'acronym': 'GRO',
#   'name': 'Gene Regulation Ontology',
#   'class_count': '507'},
#  'gro-cpd': {'acronym': 'GRO-CPD',
#   'name': 'Cereal Plant Development Ontology',
#   'class_count': '238'},
#  'gro-cpga': {'acronym': 'GRO-CPGA',
#   'name': 'Cereal Plant Gross Anatomy Ontology',
#   'class_count': '1548'},
#  'gsso': {'acronym': 'GSSO',
#   'name': 'Gender, Sex, and Sexual Orientation Ontology',
#   'class_count': '13192'},
#  'gvo': {'acronym': 'GVO',
#   'name': 'Genome Variation Ontology',
#   'class_count': '77'},
#  'haauraado': {'acronym': 'HAAURAADO',
#   'name': 'Halocynthia aurantium Anatomy and Development Ontology',
#   'class_count': '856'},
#  'hamidehsgh': {'acronym': 'HAMIDEHSGH',
#   'name': 'Inherited Retinal Dystrophy',
#   'class_count': '407'},
#  'hancestro': {'acronym': 'HANCESTRO',
#   'name': 'Human Ancestry Ontology',
#   'class_count': '1259'},
#  'hao': {'acronym': 'HAO',
#   'name': 'Hymenoptera Anatomy Ontology',
#   'class_count': '2597'},
#  'haroreado': {'acronym': 'HAROREADO',
#   'name': 'Halocynthia roretzi Anatomy and Development Ontology',
#   'class_count': '856'},
#  'hasco': {'acronym': 'HASCO',
#   'name': 'Human-Aware Science Ontology',
#   'class_count': '2490'},
#  'hc': {'acronym': 'HC',
#   'name': 'Habronattus Courtship Ontology',
#   'class_count': ''},
#  'hcdr': {'acronym': 'HCDR',
#   'name': 'Homelessness and Clinical Data Recording',
#   'class_count': '119'},
#  'hcodonont': {'acronym': 'HCODONONT',
#   'name': 'HGeneCodonOntology',
#   'class_count': '98'},
#  'hcpcs': {'acronym': 'HCPCS',
#   'name': 'Healthcare Common Procedure Coding System',
#   'class_count': '7778'},
#  'hdmponto': {'acronym': 'HDMPONTO',
#   'name': 'HierarchicalDMProcessOnto',
#   'class_count': '377'},
#  'hecon': {'acronym': 'HECON',
#   'name': 'HECON: Health Condition Evolution Ontology',
#   'class_count': '16'},
#  'hed': {'acronym': 'HED',
#   'name': 'Hierarchical Event Descriptors',
#   'class_count': '1358'},
#  'heio': {'acronym': 'HEIO',
#   'name': 'Regional Healthcare System Interoperability and Information Exchange Measurement Ontology',
#   'class_count': '125'},
#  'helifit': {'acronym': 'HELIFIT',
#   'name': 'HeLiFit-Ontology',
#   'class_count': '511'},
#  'henecon': {'acronym': 'HENECON',
#   'name': 'Head and Neck Cancer Ontology',
#   'class_count': '1841'},
#  'henegeo': {'acronym': 'HENEGEO',
#   'name': 'Head and Neck Cancer - Clinical and Gene Ontology',
#   'class_count': '29996'},
#  'hero': {'acronym': 'HERO',
#   'name': 'Healthcare Monitoring and Emergency Response Ontology',
#   'class_count': '1205'},
#  'hfo': {'acronym': 'HFO',
#   'name': 'Heart Failure Ontology',
#   'class_count': '1652'},
#  'hgnc': {'acronym': 'HGNC',
#   'name': 'HUGO Gene Nomenclature',
#   'class_count': '32918'},
#  'hgnc-nr': {'acronym': 'HGNC-NR',
#   'name': 'HGNC New Releases Ontology',
#   'class_count': '49026'},
#  'hhear': {'acronym': 'HHEAR',
#   'name': 'Human Health Exposure Analysis Resource',
#   'class_count': ''},
#  'hhearp': {'acronym': 'HHEARP',
#   'name': 'HHEAR Properties',
#   'class_count': '2489'},
#  'hhearvs': {'acronym': 'HHEARVS',
#   'name': 'HHEAR Value Sets',
#   'class_count': '3'},
#  'hino': {'acronym': 'HINO',
#   'name': 'Human Interaction Network Ontology',
#   'class_count': '37630'},
#  'hio': {'acronym': 'HIO',
#   'name': 'Hearing Impairment Ontology',
#   'class_count': '496'},
#  'hiv': {'acronym': 'HIV', 'name': 'HIV ontology', 'class_count': ''},
#  'hivcrs': {'acronym': 'HIVCRS',
#   'name': 'HIVCompoundRels',
#   'class_count': '8'},
#  'hivhpv': {'acronym': 'HIVHPV', 'name': 'HIVHPV', 'class_count': ''},
#  'hivhpvfgs': {'acronym': 'HIVHPVFGS',
#   'name': 'HIV, HPV, FGS vocabulary',
#   'class_count': '2'},
#  'hivhpvschistosom': {'acronym': 'HIVHPVSCHISTOSOM',
#   'name': 'HIVHPVSchistosomiasis',
#   'class_count': '2'},
#  'hivhpvstom': {'acronym': 'HIVHPVSTOM',
#   'name': 'HIVHPVStom',
#   'class_count': ''},
#  'hivmt': {'acronym': 'HIVMT', 'name': 'HIVMutation', 'class_count': '161'},
#  'hivo004': {'acronym': 'HIVO004',
#   'name': 'HIVOntologymain.owl',
#   'class_count': ''},
#  'hl7': {'acronym': 'HL7',
#   'name': 'Health Level Seven Reference Implementation Model, Version 3',
#   'class_count': '9095'},
#  'hmado': {'acronym': 'HMADO',
#   'name': 'Human Microbiome Associated Disease Ontology ',
#   'class_count': ''},
#  'hmis033b': {'acronym': 'HMIS033B', 'name': 'HMIS 033', 'class_count': '0'},
#  'hmislab0115': {'acronym': 'HMISLAB0115',
#   'name': 'HMIS LAB 011 5',
#   'class_count': '2'},
#  'hns': {'acronym': 'HNS', 'name': 'HNS_Ontolgoy', 'class_count': ''},
# ...
#   'class_count': '178'},
#  'ontopneumo': {'acronym': 'ONTOPNEUMO',
#   'name': 'Ontology of Pneumology',
#   'class_count': '1153'},
#  'ontopsychia': {'acronym': 'ONTOPSYCHIA',
#   'name': 'OntoPsychia, social module',
#   'class_count': '1719'},
#  'ontoreplicov': {'acronym': 'ONTOREPLICOV',
#   'name': 'OntoRepliCov',
#   'class_count': '85'},
#  'ontosim': {'acronym': 'ONTOSIM',
#   'name': 'The Ontology of Information System on Mortality',
#   'class_count': '11'},
#  'ontosinasc': {'acronym': 'ONTOSINASC',
#   'name': 'Ontology of Information System on Live Births',
#   'class_count': '8'},
#  'ontotox': {'acronym': 'ONTOTOX',
#   'name': 'Chemotherapy Toxicities Ontology',
#   'class_count': '16'},
#  'ontotoxnuc': {'acronym': 'ONTOTOXNUC',
#   'name': 'Ontology of Nuclear Toxicity',
#   'class_count': '650'},
#  'ontriscal': {'acronym': 'ONTRISCAL',
#   'name': 'Ontology of Risk Stratification in Mental Health',
#   'class_count': '332'},
#  'ooevv': {'acronym': 'OOEVV',
#   'name': 'Ontology of Experimental Variables and Values',
#   'class_count': '68'},
#  'oostt': {'acronym': 'OOSTT',
#   'name': 'Ontology of Organizational Structures of Trauma centers and Trauma systems',
#   'class_count': '823'},
#  'opb': {'acronym': 'OPB',
#   'name': 'Ontology of Physics for Biology',
#   'class_count': '858'},
#  'opd-nambobi': {'acronym': 'OPD-NAMBOBI',
#   'name': 'SELECTED OTHER PRIORITY DISEASES UNDER IDSR (INTEGRATED DISEASE SURVEILLANCE AND RESPONSES)',
#   'class_count': '0'},
#  'opde': {'acronym': 'OPDE', 'name': 'OPD-Ethiopia', 'class_count': '2'},
#  'opdre': {'acronym': 'OPDRE',
#   'name': 'OPD Regitry Ethiopia',
#   'class_count': '0'},
#  'opdront': {'acronym': 'OPDRONT',
#   'name': 'OPD Register Ontology',
#   'class_count': '2'},
#  'opdt': {'acronym': 'OPDT', 'name': 'opd_test', 'class_count': '2'},
#  'opdzimbabwe': {'acronym': 'OPDZIMBABWE',
#   'name': 'OPDZimbabwe',
#   'class_count': '2'},
#  'ope': {'acronym': 'OPE',
#   'name': 'Ontology of Physical Exercises',
#   'class_count': '634'},
#  'opl': {'acronym': 'OPL',
#   'name': 'Ontology for Parasite LifeCycle',
#   'class_count': '561'},
#  'opmi': {'acronym': 'OPMI',
#   'name': 'Ontology of Precision Medicine and Investigation',
#   'class_count': '3153'},
#  'optimal': {'acronym': 'OPTIMAL',
#   'name': 'OPTImAL: An ontology for patient adherence modeling in physical activity domain',
#   'class_count': '142'},
#  'option-ontology': {'acronym': 'OPTION-ONTOLOGY',
#   'name': 'Optimization Algorithm Benchmarking Ontology',
#   'class_count': '347'},
#  'orcs': {'acronym': 'ORCS',
#   'name': 'Ontology for Representing CDM Semantics',
#   'class_count': '861'},
#  'ordo': {'acronym': 'ORDO',
#   'name': 'Orphanet Rare Disease Ontology',
#   'class_count': '15579'},
#  'orex-sam': {'acronym': 'OREX-SAM',
#   'name': 'OSIRIS-REx sample type',
#   'class_count': '5'},
#  'orex-wg': {'acronym': 'OREX-WG',
#   'name': 'OSIRIS-REx sample analysis workgroups',
#   'class_count': '5'},
#  'ornaseq': {'acronym': 'ORNASEQ',
#   'name': 'Ontology of RNA Sequencing',
#   'class_count': '164'},
#  'orth': {'acronym': 'ORTH',
#   'name': 'Orthology Ontology',
#   'class_count': '34'},
#  'oto': {'acronym': 'OTO',
#   'name': ' Obesity Tracking Ontology',
#   'class_count': ''},
#  'ovae': {'acronym': 'OVAE',
#   'name': 'Ontology of Vaccine Adverse Events',
#   'class_count': '1555'},
#  'ontovip': {'acronym': 'OntoVIP',
#   'name': 'Medical image simulation',
#   'class_count': ''},
#  'paco': {'acronym': 'PACO',
#   'name': 'Physical Activity Ontology',
#   'class_count': '224'},
#  'pae': {'acronym': 'PAE', 'name': 'Plant Anatomy', 'class_count': '1548'},
#  'paino': {'acronym': 'PAINO', 'name': 'Pain Ontology', 'class_count': ''},
#  'panda': {'acronym': 'PANDA',
#   'name': 'Probabilistic Knowledge Assembly Ontology',
#   'class_count': '75'},
#  'panet': {'acronym': 'PANET',
#   'name': 'PaN Experimental technique',
#   'class_count': '379'},
#  'partumdo': {'acronym': 'PARTUMDO',
#   'name': 'postpartum depression ontology',
#   'class_count': '734'},
#  'pataxo': {'acronym': 'PATAXO',
#   'name': 'Technical Taxonomies for Patents',
#   'class_count': '0'},
#  'patct': {'acronym': 'PATCT',
#   'name': 'Placental Cell Type',
#   'class_count': '153'},
#  'patel': {'acronym': 'PATEL', 'name': 'Archana Patel', 'class_count': '123'},
#  'patgv': {'acronym': 'PATGV',
#   'name': 'Placental Genetic Variance',
#   'class_count': '73'},
#  'pathlex': {'acronym': 'PATHLEX',
#   'name': 'Anatomic Pathology Lexicon',
#   'class_count': '1786'},
#  'patit': {'acronym': 'PATIT',
#   'name': 'Placental Investigative Technique',
#   'class_count': '139'},
#  'patmhc': {'acronym': 'PATMHC',
#   'name': 'Placental Maternal Health Conditions',
#   'class_count': '228'},
#  'pato': {'acronym': 'PATO',
#   'name': 'Phenotypic Quality Ontology',
#   'class_count': '8688'},
#  'pav': {'acronym': 'PAV',
#   'name': 'PAV Provenance, Authoring and Versioning',
#   'class_count': '2'},
#  'paymentmode': {'acronym': 'PAYMENTMODE',
#   'name': 'Payment Mode',
#   'class_count': '2'},
#  'payor': {'acronym': 'PAYOR', 'name': 'Payor', 'class_count': '2'},
#  'pbo': {'acronym': 'PBO',
#   'name': 'Plant Breeding Ontology',
#   'class_count': '2272'},
#  'pbpko': {'acronym': 'PBPKO',
#   'name': 'Physiologically Based Pharmacokinetic ontology',
#   'class_count': ''},
#  'pcalion': {'acronym': 'PCALION',
#   'name': 'Prostate Cancer Lifestyle Ontology',
#   'class_count': ''},
#  'pcao': {'acronym': 'PCAO',
#   'name': 'Prostate Cancer Ontology',
#   'class_count': '633'},
#  'pcl': {'acronym': 'PCL',
#   'name': 'Provisional Cell Ontology',
#   'class_count': '197879'},
#  'pcmo': {'acronym': 'PCMO',
#   'name': 'Pediatric Consultation and Monitoring Ontology ',
#   'class_count': '20'},
#  'pco': {'acronym': 'PCO',
#   'name': 'Population and Community Ontology',
#   'class_count': '221'},
#  'pdo': {'acronym': 'PDO',
#   'name': 'Pathogenic Disease Ontology',
#   'class_count': ''},
#  'pdon': {'acronym': 'PDON',
#   'name': "Parkinson's Disease Ontology",
#   'class_count': '632'},
#  'pdo_cas': {'acronym': 'PDO_CAS',
#   'name': 'Plant Diversity Ontology',
#   'class_count': '380'},
#  'pdq': {'acronym': 'PDQ', 'name': 'Physician Data Query', 'class_count': ''},
#  'pdro': {'acronym': 'PDRO',
#   'name': 'The Prescription of Drugs Ontology',
#   'class_count': '703043'},
#  'pdumdv': {'acronym': 'PDUMDV',
#   'name': 'Platynereis Developmental Stages',
#   'class_count': '21'},
#  'pe': {'acronym': 'PE',
#   'name': 'Pulmonary Embolism Ontology',
#   'class_count': '97'},
#  'pe-o': {'acronym': 'PE-O',
#   'name': 'Pre-eclampsia Ontology',
#   'class_count': '1251'},
#  'peao': {'acronym': 'PEAO',
#   'name': 'Plant Experimental Assay Ontology',
#   'class_count': '2298'},
#  'peco': {'acronym': 'PECO',
#   'name': 'Plant Experimental Conditions Ontology',
#   'class_count': '3135'},
#  'pedterm': {'acronym': 'PEDTERM',
#   'name': 'Pediatric Terminology',
#   'class_count': '1771'},
#  'peo': {'acronym': 'PEO',
#   'name': 'Parasite Experiment Ontology',
#   'class_count': '143'},
#  'peo_ontology': {'acronym': 'PEO_ONTOLOGY',
#   'name': 'Prompt Engineering Ontology',
#   'class_count': '124'},
#  'pesont': {'acronym': 'PESONT',
#   'name': 'Preposition_enabled Spatial Ontology',
#   'class_count': '160'},
#  'pghd-bp': {'acronym': 'PGHD-BP',
#   'name': 'PGHD Auxillary - BP',
#   'class_count': '2'},
#  'pghd_connect': {'acronym': 'PGHD_CONNECT',
#   'name': 'PGHD_CONNECT',
#   'class_count': ''},
#  'pgxo': {'acronym': 'PGXO', 'name': 'PGxO', 'class_count': '15'},
#  'phage': {'acronym': 'PHAGE',
#   'name': 'Phylogenetics Ontology',
#   'class_count': '51495'},
#  'phare': {'acronym': 'PHARE',
#   'name': 'Pharmacogenomic Relationships Ontology',
#   'class_count': '229'},
#  'pharmgkb': {'acronym': 'PHARMGKB',
#   'name': 'PharmGKB Ontology',
#   'class_count': ''},
#  'phenomeblast': {'acronym': 'PHENOMEBLAST',
#   'name': 'PhenomeBLAST Ontology',
#   'class_count': ''},
#  'phenx': {'acronym': 'PHENX',
#   'name': 'PhenX Phenotypic Terms',
#   'class_count': '533'},
#  'phfumiado': {'acronym': 'PHFUMIADO',
#   'name': 'Phallusia fumigata Anatomy and Development Ontology',
#   'class_count': '880'},
#  'phipo': {'acronym': 'PHIPO',
#   'name': 'Pathogen Host Interaction Phenotype Ontology',
#   'class_count': '3978'},
#  'phmammado': {'acronym': 'PHMAMMADO',
#   'name': 'Phallusia mammillata Anatomy and Development Ontology',
#   'class_count': '880'},
#  'phy': {'acronym': 'PHY', 'name': 'physiotherapy', 'class_count': '5'},
#  'phylont': {'acronym': 'PHYLONT',
#   'name': 'Phylogenetic Ontology',
#   'class_count': '148'},
#  'piero': {'acronym': 'PIERO',
#   'name': 'Enzyme Reaction Ontology for annotating Partial Information of chemical transformation',
#   'class_count': '36'},
#  'pino': {'acronym': 'PINO',
#   'name': 'Pregnancy Information Needs Ontology',
#   'class_count': '267'},
#  'plana': {'acronym': 'PLANA',
#   'name': 'Planarian Anatomy and Developmental Stage Ontolgoy',
#   'class_count': '876'},
#  'planp': {'acronym': 'PLANP',
#   'name': 'Planarian Phenotype Ontology',
#   'class_count': '3562'},
#  'plantso': {'acronym': 'PLANTSO',
#   'name': 'Plant Stress Ontology',
#   'class_count': '3933'},
#  'plio': {'acronym': 'PLIO',
#   'name': 'Protein-ligand interaction ontology',
#   'class_count': '376'},
#  'plosthes': {'acronym': 'PLOSTHES',
#   'name': 'PLOS Thesaurus',
#   'class_count': '4'},
#  'pma': {'acronym': 'PMA',
#   'name': 'Portfolio Management Application',
#   'class_count': '2084'},
#  'pmapp-pmo': {'acronym': 'PMAPP-PMO',
#   'name': 'PMO Precision Medicine Ontology',
#   'class_count': '76155'},
#  'pmd': {'acronym': 'PMD',
#   'name': 'Persian Medicine Diseases Ontology',
#   'class_count': '529'},
#  'pmdo': {'acronym': 'PMDO',
#   'name': 'Parkinson and Movement Disorder Ontology',
#   'class_count': '629'},
#  'pmo': {'acronym': 'PMO',
#   'name': 'Performed Music Ontology',
#   'class_count': '45'},
#  'pmo-speed': {'acronym': 'PMO-SPEED',
#   'name': 'PMO Playing Speed Vocabulary',
#   'class_count': '2'},
#  'pmr': {'acronym': 'PMR',
#   'name': 'Physical Medicine and Rehabilitation',
#   'class_count': '1597'},
#  'pnado': {'acronym': 'PNADO',
#   'name': 'Pneumonia Diagnosis Ontology',
#   'class_count': ''},
#  'po': {'acronym': 'PO', 'name': 'Plant Ontology', 'class_count': '2026'},
#  'poem': {'acronym': 'POEM',
#   'name': 'Psychometric Ontology of Experiences and Measures',
#   'class_count': '1636'},
#  'poro': {'acronym': 'PORO',
#   'name': 'Porifera Ontology',
#   'class_count': '896'},
#  'pp': {'acronym': 'PP',
#   'name': 'Pipeline Patterns Ontology',
#   'class_count': '15'},
#  'pplc': {'acronym': 'PPLC',
#   'name': 'Placental Pathology Lesion Classification',
#   'class_count': ''},
#  'ppo': {'acronym': 'PPO',
#   'name': 'Plant Phenology Ontology',
#   'class_count': '543'},
#  'pr': {'acronym': 'PR', 'name': 'Protein Ontology', 'class_count': '360877'},
#  'pregonto': {'acronym': 'PREGONTO',
#   'name': 'Pregnancy Ontology',
#   'class_count': '39'},
#  'premedonto': {'acronym': 'PREMEDONTO',
#   'name': 'Precision Medicine Ontology',
#   'class_count': '543'},
#  'preo': {'acronym': 'PREO',
#   'name': 'Presence Ontology',
#   'class_count': '276'},
#  'procchemical': {'acronym': 'PROCCHEMICAL',
#   'name': 'Chemical Process',
#   'class_count': '53'},
#  'proco': {'acronym': 'PROCO',
#   'name': 'Process Chemistry Ontology',
#   'class_count': '922'},
#  'proj': {'acronym': 'PROJ', 'name': 'Project ontology', 'class_count': '46'},
#  'propreo': {'acronym': 'PROPREO',
#   'name': 'Proteomics Data and Process Provenance Ontology',
#   'class_count': '401'},
#  'provo': {'acronym': 'PROVO',
#   'name': 'Provenance Ontology',
#   'class_count': '31'},
#  'psdo': {'acronym': 'PSDO',
#   'name': 'Performance Summary Display Ontology',
#   'class_count': '1123'},
#  'psds': {'acronym': 'PSDS',
#   'name': 'Plant Structure Development Stage',
#   'class_count': '345'},
#  'psimod': {'acronym': 'PSIMOD',
#   'name': 'Protein Modification Ontology',
#   'class_count': '2098'},
#  'pso': {'acronym': 'PSO',
#   'name': 'PatientSafetyOntology',
#   'class_count': '567'},
#  'pso_2': {'acronym': 'PSO_2',
#   'name': 'PatientSafetyOntologyRevisted',
#   'class_count': '291'},
#  'pto': {'acronym': 'PTO',
#   'name': 'Plant Trait Ontology',
#   'class_count': '1691'},
#  'ptrans': {'acronym': 'PTRANS',
#   'name': 'Pathogen Transmission Ontology',
#   'class_count': '35'},
#  'pts': {'acronym': 'PTS',
#   'name': 'Pathway Terminology System',
#   'class_count': '6623'},
#  'pu': {'acronym': 'PU', 'name': 'PUPR Dataset', 'class_count': ''},
#  'pvonto': {'acronym': 'PVONTO',
#   'name': 'Pharmacovigilance Ontology',
#   'class_count': '33'},
#  'pw': {'acronym': 'PW', 'name': 'Pathway Ontology', 'class_count': '2700'},
#  'qudt': {'acronym': 'QUDT',
#   'name': 'Quantities, Units, Dimensions, and Types Ontology',
#   'class_count': '133'},
#  'qudt2': {'acronym': 'QUDT2',
#   'name': 'Quantities, Units, Dimensions and Types (QUDT) Schema - Version 2.0',
#   'class_count': '114'},
#  'qudt2-1': {'acronym': 'QUDT2-1',
#   'name': 'Quantities, Units, Dimensions and Types (QUDT Version 2.1)',
#   'class_count': ''},
#  'radlex': {'acronym': 'RADLEX',
#   'name': 'Radiology Lexicon',
#   'class_count': '46840'},
#  'radmo': {'acronym': 'RADMO',
#   'name': 'RADx Metadata Ontology',
#   'class_count': ''},
#  'radxtt-mvreasons': {'acronym': 'RADXTT-MVREASONS',
#   'name': 'RADx Tiger Team Missing Value Reasons',
#   'class_count': '2'},
#  'rao': {'acronym': 'RAO',
#   'name': 'Rheumatoid Arthritis ontology',
#   'class_count': '280'},
#  'rb': {'acronym': 'RB', 'name': 'RegenBase ontology', 'class_count': '442'},
#  'rbo': {'acronym': 'RBO',
#   'name': 'Radiation Biology Ontology',
#   'class_count': '8799'},
#  'rcd': {'acronym': 'RCD',
#   'name': 'Read Codes, Clinical Terms Version 3 (CTV3) ',
#   'class_count': ''},
#  'rctont': {'acronym': 'RCTONT',
#   'name': 'Randomized Controlled Trials Ontology',
#   'class_count': '195'},
#  'rctv2': {'acronym': 'RCTV2',
#   'name': 'Read Clinical Terminology Version 2',
#   'class_count': '88854'},
#  'rda-content': {'acronym': 'RDA-CONTENT',
#   'name': 'RDA Content type',
#   'class_count': '2'},
#  'rda-issuance': {'acronym': 'RDA-ISSUANCE',
#   'name': 'RDA Mode of Issuance',
#   'class_count': '2'},
#  'rdfs': {'acronym': 'RDFS',
#   'name': 'The RDF Schema vocabulary',
#   'class_count': '7'},
#  'rdl': {'acronym': 'RDL', 'name': 'RDL', 'class_count': '203'},
#  'rdo': {'acronym': 'RDO',
#   'name': 'Reusable Biodiversity Ontology',
#   'class_count': '362'},
#  'regn_bro': {'acronym': 'REGN_BRO', 'name': 'REGN_BRO', 'class_count': '486'},
#  'regn_go': {'acronym': 'REGN_GO', 'name': 'REGN_GO', 'class_count': '51063'},
#  'repo': {'acronym': 'REPO',
#   'name': 'Reproductive Trait and Phenotype Ontology',
#   'class_count': '96'},
#  'repos': {'acronym': 'REPOS', 'name': 'repository', 'class_count': '5'},
#  'reproduce-me': {'acronym': 'REPRODUCE-ME',
#   'name': 'REPRODUCE-ME',
#   'class_count': '347'},
#  'reto': {'acronym': 'RETO',
#   'name': 'Regulation of Transcription Ontology',
#   'class_count': '147738'},
#  'rex': {'acronym': 'REX',
#   'name': 'Physico-Chemical Process',
#   'class_count': '552'},
#  'rexo': {'acronym': 'REXO',
#   'name': 'Regulation of Gene Expression Ontolology',
#   'class_count': '158239'},
#  'rgd': {'acronym': 'RGD', 'name': 'RRB Group D', 'class_count': ''},
#  'rh-mesh': {'acronym': 'RH-MESH',
#   'name': 'Robert Hoehndorf Version of MeSH',
#   'class_count': '305349'},
#  'rnao': {'acronym': 'RNAO', 'name': 'RNA Ontology', 'class_count': '692'},
#  'rnprio': {'acronym': 'RNPRIO',
#   'name': 'Research Network and Patient Registry Inventory Ontology',
#   'class_count': '79'},
#  'rnrmu': {'acronym': 'RNRMU', 'name': 'RNRMU', 'class_count': '2310'},
#  'ro': {'acronym': 'RO', 'name': 'Radiomics Ontology', 'class_count': '458'},
#  'rocknrolltest': {'acronym': 'ROCKNROLLTEST',
#   'name': 'ROCK-N-ROLL-TEST',
#   'class_count': ''},
#  'roleo': {'acronym': 'ROLEO', 'name': 'Role Ontology', 'class_count': '2125'},
#  'roo': {'acronym': 'ROO',
#   'name': 'Radiation Oncology Ontology',
#   'class_count': '1307'},
#  'ros': {'acronym': 'ROS',
#   'name': 'Radiation Oncology Structures Ontology',
#   'class_count': '416'},
#  'rpo': {'acronym': 'RPO',
#   'name': 'Resource of Asian Primary Immunodeficiency Diseases (RAPID) Phenotype Ontology',
#   'class_count': '1545'},
#  'rs': {'acronym': 'RS', 'name': 'Rat Strain Ontology', 'class_count': '5363'},
#  'rsa': {'acronym': 'RSA',
#   'name': 'Reference Sequence Annotation',
#   'class_count': '10'},
#  ...}

# %%
# Extract Contents elements into a list of dictionaries
contents = []
extension_counter = Counter()
base_names = set()
db_gz_basenames = set()


for content in root.findall('ns:Contents', namespace):
    key = content.find('ns:Key', namespace).text
    size = int(content.find('ns:Size', namespace).text)

    # Skip entries with directory paths
    if '/' in key:
        print(f"Skipping directory entry: {key}")
        continue

    # Skip empty files
    if size == 0:
        print(f"Skipping empty entry: {key}")
        continue

    # Custom basename and extension logic
    if '-' in key:
        split_index = key.find('-')
        basename = key[:split_index]
        extension = key[split_index + 1:]
    elif '.' in key:
        split_index = key.find('.')
        basename = key[:split_index]
        extension = key[split_index + 1:]
    else:
        basename = key
        extension = ''

    base_names.add(basename)
    if extension == 'db.gz':
        db_gz_basenames.add(basename)

    # Count the extension
    extension_counter[extension] += 1

    entry = {
        'Key': key,
        'basename': basename,
        'extension': extension,
        'LastModified': content.find('ns:LastModified', namespace).text,
        # 'ETag': content.find('ns:ETag', namespace).text.replace('"', ''),
        'Size': size,
        # 'StorageClass': content.find('ns:StorageClass', namespace).text,
        'obo_foundry_title': obo_ontologies.get(basename, {}).get('title', None),
        'bioportal_name': bioportal_ontologies.get(basename, {}).get('name', None),
        'registry_url': registry_dict['ontologies'].get(basename, {}).get('url', None),
    }
    contents.append(entry)
# Out:
# Skipping empty entry: biopragmatics-reactome.db.gz.tmp
# Skipping empty entry: ceph.db
# Skipping empty entry: cmo.db
# Skipping empty entry: dictybase.db.gz.tmp
# Skipping empty entry: drugcentral.db.gz.tmp
# Skipping empty entry: drugmechdb.db.gz.tmp
# Skipping empty entry: ecosim.db.gz.tmp
# Skipping empty entry: epio-relation-graph.tsv.owl.tmp
# Skipping empty entry: epio.db
# Skipping empty entry: go-lego.db.gz.tmp
# Skipping empty entry: gsso
# Skipping empty entry: gsso.db
# Skipping empty entry: gssox.db
# Skipping empty entry: kegg.genome.db.gz.tmp
# Skipping empty entry: lov.db.gz.tmp
# Skipping empty entry: micro.db
# Skipping empty entry: molgenie.db.gz.tmp
# Skipping empty entry: omop.db.gz.tmp
# Skipping empty entry: pathbank.db.gz.tmp
# Skipping directory entry: releases/2022-05-31/README.md
# Skipping directory entry: releases/2022-05-31/aeo.db
# Skipping directory entry: releases/2022-05-31/agro-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/agro.db
# Skipping directory entry: releases/2022-05-31/agro.owl
# Skipping directory entry: releases/2022-05-31/aism-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/aism.db
# Skipping directory entry: releases/2022-05-31/aism.owl
# Skipping directory entry: releases/2022-05-31/amphx-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/amphx.db
# Skipping directory entry: releases/2022-05-31/amphx.owl
# Skipping directory entry: releases/2022-05-31/apo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/apo.db
# Skipping directory entry: releases/2022-05-31/apo.owl
# Skipping directory entry: releases/2022-05-31/apollo_sv-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/apollo_sv.db
# Skipping directory entry: releases/2022-05-31/apollo_sv.owl
# Skipping directory entry: releases/2022-05-31/aro-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/aro.db
# Skipping directory entry: releases/2022-05-31/aro.owl
# Skipping directory entry: releases/2022-05-31/bad-ontology.db
# Skipping directory entry: releases/2022-05-31/bad-ontology.db.old
# Skipping directory entry: releases/2022-05-31/bco-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/bco.db
# Skipping directory entry: releases/2022-05-31/bco.owl
# Skipping directory entry: releases/2022-05-31/bero-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/bero.db
# Skipping directory entry: releases/2022-05-31/bero.owl
# Skipping directory entry: releases/2022-05-31/bfo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/bfo.db
# Skipping directory entry: releases/2022-05-31/bfo.owl
# Skipping directory entry: releases/2022-05-31/bspo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/bspo.db
# Skipping directory entry: releases/2022-05-31/bspo.owl
# Skipping directory entry: releases/2022-05-31/bto-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/bto.db
# Skipping directory entry: releases/2022-05-31/bto.owl
# Skipping directory entry: releases/2022-05-31/caro-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/caro.db
# Skipping directory entry: releases/2022-05-31/caro.db.old
# Skipping directory entry: releases/2022-05-31/caro.owl
# Skipping directory entry: releases/2022-05-31/cdao-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cdao.db
# Skipping directory entry: releases/2022-05-31/cdao.owl
# Skipping directory entry: releases/2022-05-31/cdno-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cdno.db
# Skipping directory entry: releases/2022-05-31/cdno.owl
# Skipping directory entry: releases/2022-05-31/chebi-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/chebi.db
# Skipping directory entry: releases/2022-05-31/chebi.db.old
# Skipping directory entry: releases/2022-05-31/chebi.owl
# Skipping directory entry: releases/2022-05-31/cheminf-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cheminf.db
# Skipping directory entry: releases/2022-05-31/cheminf.owl
# Skipping directory entry: releases/2022-05-31/chiro-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/chiro.db
# Skipping directory entry: releases/2022-05-31/chiro.owl
# Skipping directory entry: releases/2022-05-31/chmo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/chmo.db
# Skipping directory entry: releases/2022-05-31/chmo.owl
# Skipping directory entry: releases/2022-05-31/cido-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cido.db
# Skipping directory entry: releases/2022-05-31/cido.owl
# Skipping directory entry: releases/2022-05-31/cio-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cio.db
# Skipping directory entry: releases/2022-05-31/cio.owl
# Skipping directory entry: releases/2022-05-31/cl-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cl.db
# Skipping directory entry: releases/2022-05-31/cl.owl
# Skipping directory entry: releases/2022-05-31/clao-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/clao.db
# Skipping directory entry: releases/2022-05-31/clao.owl
# Skipping directory entry: releases/2022-05-31/clo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/clo.db
# Skipping directory entry: releases/2022-05-31/clo.owl
# Skipping directory entry: releases/2022-05-31/clyh-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/clyh.db
# Skipping directory entry: releases/2022-05-31/clyh.owl
# Skipping directory entry: releases/2022-05-31/cmo-relation-graph.tsv
# Skipping directory entry: releases/2022-05-31/cmo.db
# Skipping directory entry: releases/2022-05-31/cmo.db.tmp
# Skipping directory entry: releases/2022-05-31/cmo.owl
# Skipping directory entry: releases/2022-05-31/cob-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cob.db
# Skipping directory entry: releases/2022-05-31/cob.db.old
# Skipping directory entry: releases/2022-05-31/cob.owl
# Skipping directory entry: releases/2022-05-31/colao-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/colao.db
# Skipping directory entry: releases/2022-05-31/colao.owl
# Skipping directory entry: releases/2022-05-31/cro-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cro.db
# Skipping directory entry: releases/2022-05-31/cro.owl
# Skipping directory entry: releases/2022-05-31/cteno-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cteno.db
# Skipping directory entry: releases/2022-05-31/cteno.owl
# Skipping directory entry: releases/2022-05-31/cto-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cto.db
# Skipping directory entry: releases/2022-05-31/cto.owl
# Skipping directory entry: releases/2022-05-31/cvdo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/cvdo.db
# Skipping directory entry: releases/2022-05-31/cvdo.owl
# Skipping directory entry: releases/2022-05-31/ddanat-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/ddanat.db
# Skipping directory entry: releases/2022-05-31/ddanat.owl
# Skipping directory entry: releases/2022-05-31/ddpheno-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/ddpheno.db
# Skipping directory entry: releases/2022-05-31/ddpheno.owl
# Skipping directory entry: releases/2022-05-31/dideo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/dideo.db
# Skipping directory entry: releases/2022-05-31/dideo.owl
# Skipping directory entry: releases/2022-05-31/disdriv-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/disdriv.db
# Skipping directory entry: releases/2022-05-31/disdriv.owl
# Skipping directory entry: releases/2022-05-31/doid-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/doid.db
# Skipping directory entry: releases/2022-05-31/doid.owl
# Skipping directory entry: releases/2022-05-31/dpo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/dpo.db
# Skipping directory entry: releases/2022-05-31/dpo.owl
# Skipping directory entry: releases/2022-05-31/dron-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/dron.db
# Skipping directory entry: releases/2022-05-31/dron.owl
# Skipping directory entry: releases/2022-05-31/duo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/duo.db
# Skipping directory entry: releases/2022-05-31/duo.owl
# Skipping directory entry: releases/2022-05-31/ecao-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/ecao.db
# Skipping directory entry: releases/2022-05-31/ecao.owl
# Skipping directory entry: releases/2022-05-31/eco-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/eco.db
# Skipping directory entry: releases/2022-05-31/eco.owl
# Skipping directory entry: releases/2022-05-31/ecocore-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/ecocore.db
# Skipping directory entry: releases/2022-05-31/ecocore.owl
# Skipping directory entry: releases/2022-05-31/ecto-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/ecto.db
# Skipping directory entry: releases/2022-05-31/ecto.owl
# Skipping directory entry: releases/2022-05-31/emapa-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/emapa.db
# Skipping directory entry: releases/2022-05-31/emapa.owl
# Skipping directory entry: releases/2022-05-31/envo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/envo.db
# Skipping directory entry: releases/2022-05-31/envo.owl
# Skipping directory entry: releases/2022-05-31/epio-relation-graph.tsv.owl.tmp
# Skipping directory entry: releases/2022-05-31/epio-relation-graph.tsv.ttl.tmp
# Skipping directory entry: releases/2022-05-31/epio.db
# Skipping directory entry: releases/2022-05-31/epio.owl
# Skipping directory entry: releases/2022-05-31/eupath-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/eupath.db
# Skipping directory entry: releases/2022-05-31/eupath.owl
# Skipping directory entry: releases/2022-05-31/exo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/exo.db
# Skipping directory entry: releases/2022-05-31/exo.owl
# Skipping directory entry: releases/2022-05-31/fao-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/fao.db
# Skipping directory entry: releases/2022-05-31/fao.owl
# Skipping directory entry: releases/2022-05-31/fbbi-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/fbbi.db
# Skipping directory entry: releases/2022-05-31/fbbi.owl
# Skipping directory entry: releases/2022-05-31/fbbt-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/fbbt.db
# Skipping directory entry: releases/2022-05-31/fbbt.owl
# Skipping directory entry: releases/2022-05-31/fbcv-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/fbcv.db
# Skipping directory entry: releases/2022-05-31/fbcv.owl
# Skipping directory entry: releases/2022-05-31/fbdv-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/fbdv.db
# Skipping directory entry: releases/2022-05-31/fbdv.owl
# Skipping directory entry: releases/2022-05-31/fideo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/fideo.db
# Skipping directory entry: releases/2022-05-31/fideo.owl
# Skipping directory entry: releases/2022-05-31/flopo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/flopo.db
# Skipping directory entry: releases/2022-05-31/flopo.owl
# Skipping directory entry: releases/2022-05-31/fma.db
# Skipping directory entry: releases/2022-05-31/fobi-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/fobi.db
# Skipping directory entry: releases/2022-05-31/fobi.owl
# Skipping directory entry: releases/2022-05-31/foodon-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/foodon.db
# Skipping directory entry: releases/2022-05-31/foodon.owl
# Skipping directory entry: releases/2022-05-31/fovt-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/fovt.db
# Skipping directory entry: releases/2022-05-31/fovt.owl
# Skipping directory entry: releases/2022-05-31/fypo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/fypo.db
# Skipping directory entry: releases/2022-05-31/fypo.db.old
# Skipping directory entry: releases/2022-05-31/fypo.owl
# Skipping directory entry: releases/2022-05-31/gaz.db
# Skipping directory entry: releases/2022-05-31/gecko-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/gecko.db
# Skipping directory entry: releases/2022-05-31/gecko.owl
# Skipping directory entry: releases/2022-05-31/geno-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/geno.db
# Skipping directory entry: releases/2022-05-31/geno.owl
# Skipping directory entry: releases/2022-05-31/geo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/geo.db
# Skipping directory entry: releases/2022-05-31/geo.owl
# Skipping directory entry: releases/2022-05-31/gno-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/gno.db
# Skipping directory entry: releases/2022-05-31/gno.owl
# Skipping directory entry: releases/2022-05-31/go-nucleus-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/go-nucleus.db
# Skipping directory entry: releases/2022-05-31/go-nucleus.db.old
# Skipping directory entry: releases/2022-05-31/go-nucleus.owl
# Skipping directory entry: releases/2022-05-31/go-plus.db
# Skipping directory entry: releases/2022-05-31/go-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/go.db
# Skipping directory entry: releases/2022-05-31/go.owl
# Skipping directory entry: releases/2022-05-31/goa_uniprot_all.db
# Skipping directory entry: releases/2022-05-31/gsso-relation-graph.tsv
# Skipping directory entry: releases/2022-05-31/gsso.db
# Skipping directory entry: releases/2022-05-31/gsso.db.tmp
# Skipping directory entry: releases/2022-05-31/gsso.owl
# Skipping directory entry: releases/2022-05-31/gssox.db
# Skipping directory entry: releases/2022-05-31/hancestro-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/hancestro.db
# Skipping directory entry: releases/2022-05-31/hancestro.owl
# Skipping directory entry: releases/2022-05-31/hao-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/hao.db
# Skipping directory entry: releases/2022-05-31/hao.owl
# Skipping directory entry: releases/2022-05-31/hom-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/hom.db
# Skipping directory entry: releases/2022-05-31/hom.owl
# Skipping directory entry: releases/2022-05-31/hp-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/hp.db
# Skipping directory entry: releases/2022-05-31/hp.owl
# Skipping directory entry: releases/2022-05-31/hsapdv-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/hsapdv.db
# Skipping directory entry: releases/2022-05-31/hsapdv.owl
# Skipping directory entry: releases/2022-05-31/hso-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/hso.db
# Skipping directory entry: releases/2022-05-31/hso.owl
# Skipping directory entry: releases/2022-05-31/htn-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/htn.db
# Skipping directory entry: releases/2022-05-31/htn.owl
# Skipping directory entry: releases/2022-05-31/iao-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/iao.db
# Skipping directory entry: releases/2022-05-31/iao.owl
# Skipping directory entry: releases/2022-05-31/iceo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/iceo.db
# Skipping directory entry: releases/2022-05-31/iceo.owl
# Skipping directory entry: releases/2022-05-31/ico-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/ico.db
# Skipping directory entry: releases/2022-05-31/ico.owl
# Skipping directory entry: releases/2022-05-31/ido-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/ido.db
# Skipping directory entry: releases/2022-05-31/ido.owl
# Skipping directory entry: releases/2022-05-31/ino-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/ino.db
# Skipping directory entry: releases/2022-05-31/ino.owl
# Skipping directory entry: releases/2022-05-31/kisao-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/kisao.db
# Skipping directory entry: releases/2022-05-31/kisao.owl
# Skipping directory entry: releases/2022-05-31/labo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/labo.db
# Skipping directory entry: releases/2022-05-31/labo.owl
# Skipping directory entry: releases/2022-05-31/lepao-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/lepao.db
# Skipping directory entry: releases/2022-05-31/lepao.owl
# Skipping directory entry: releases/2022-05-31/ma-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/ma.db
# Skipping directory entry: releases/2022-05-31/ma.owl
# Skipping directory entry: releases/2022-05-31/mamo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/mamo.db
# Skipping directory entry: releases/2022-05-31/mamo.owl
# Skipping directory entry: releases/2022-05-31/matcher-test.db.old
# Skipping directory entry: releases/2022-05-31/maxo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/maxo.db
# Skipping directory entry: releases/2022-05-31/maxo.owl
# Skipping directory entry: releases/2022-05-31/mco-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/mco.db
# Skipping directory entry: releases/2022-05-31/mco.owl
# Skipping directory entry: releases/2022-05-31/mf-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/mf.db
# Skipping directory entry: releases/2022-05-31/mf.owl
# Skipping directory entry: releases/2022-05-31/mfmo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/mfmo.db
# Skipping directory entry: releases/2022-05-31/mfmo.owl
# Skipping directory entry: releases/2022-05-31/mfoem-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/mfoem.db
# Skipping directory entry: releases/2022-05-31/mfoem.owl
# Skipping directory entry: releases/2022-05-31/mfomd-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/mfomd.db
# Skipping directory entry: releases/2022-05-31/mfomd.owl
# Skipping directory entry: releases/2022-05-31/mi-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/mi.db
# Skipping directory entry: releases/2022-05-31/mi.owl
# Skipping directory entry: releases/2022-05-31/miapa-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/miapa.db
# Skipping directory entry: releases/2022-05-31/miapa.owl
# Skipping directory entry: releases/2022-05-31/micro-relation-graph.tsv
# Skipping directory entry: releases/2022-05-31/micro.db
# Skipping directory entry: releases/2022-05-31/micro.db.tmp
# Skipping directory entry: releases/2022-05-31/micro.owl
# Skipping directory entry: releases/2022-05-31/mmo-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/mmo.db
# Skipping directory entry: releases/2022-05-31/mmo.owl
# Skipping directory entry: releases/2022-05-31/mmusdv-relation-graph.tsv.gz
# Skipping directory entry: releases/2022-05-31/mmusdv.db
# Skipping directory entry: releases/2022-05-31/mmusdv.owl

# %%
non_db_gz_basenames = list(base_names - db_gz_basenames)
non_db_gz_basenames.sort()

# %%
non_db_gz_basenames
# Out:
# ['README',
#  'aeo',
#  'allotrope',
#  'bad',
#  'biopragmatics',
#  'cme',
#  'envo.db',
#  'foo',
#  'goa_uniprot_all',
#  'inst',
#  'kegg',
#  'matcher',
#  'obo',
#  'obo_prefixes',
#  'oboe',
#  'omiabis',
#  'reactome']

# %%
extension_counter
# Out:
# Counter({'db.gz': 237,
#          'owl': 150,
#          'relation-graph.tsv.gz': 147,
#          'db': 112,
#          'relation-graph.tsv': 3,
#          'db.tmp': 3,
#          'md': 1,
#          'ontology.db': 1,
#          'ontology.db.old': 1,
#          'reactome.db.gz': 1,
#          'db.old': 1,
#          'owl.old': 1,
#          'journal': 1,
#          'relation-graph.tsv.ttl.tmp': 1,
#          'amigo.db.gz': 1,
#          'lego.db.gz': 1,
#          'nucleus-relation-graph.tsv.gz': 1,
#          'nucleus.db': 1,
#          'nucleus.db.old': 1,
#          'nucleus.owl': 1,
#          'plus.db': 1,
#          'genegroup.db.gz': 1,
#          'db.gz.old': 1,
#          'genome.db.gz': 1,
#          'test.db.old': 1,
#          'ingest.db.gz': 1,
#          'ontologies.db': 1,
#          'core.db.gz': 1,
#          'standards.db.gz': 1,
#          'min.owl': 1,
#          'db.db': 1,
#          'Homo-sapiens.db.gz': 1,
#          'hs.db.gz': 1,
#          'mm.db.gz': 1})

# %%
# Write the data to a TSV file
with open(tsv_output, 'w', newline='') as tsvfile:
    writer = csv.DictWriter(tsvfile, fieldnames=contents[0].keys(), delimiter='\t')
    writer.writeheader()
    writer.writerows(contents)

print(f"Fetched and saved {len(contents)} entries to {tsv_output}")
# Out:
# Fetched and saved 680 entries to bbop-sem-sql-catalog-filtered.tsv
