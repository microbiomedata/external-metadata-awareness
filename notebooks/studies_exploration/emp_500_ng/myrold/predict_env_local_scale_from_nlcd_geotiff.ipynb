# %%
import pandas as pd
import rasterio
from rasterio.warp import transform
import pprint

from oaklib import get_adapter

# %%
# Path to your input files
tsv_file = 'myrold_attributes.tsv'
nlcd_geotiff = 'Annual_NLCD_LndCov_2023_CU_C1V0.tif'
output_file = 'myrold_attributes_with_land_cover.tsv'

# %%
envo_adapter_string = 'sqlite:obo:envo'

# %%
lat_col = 'latitude'
lon_col = 'longitude'

# %%
# Function to get land cover value from NLCD
def get_land_cover(lat, lon, dataset):
    try:
        # Transform coordinates to the GeoTIFF's CRS
        dst_crs = dataset.crs  # CRS of the GeoTIFF
        lon_transformed, lat_transformed = transform('EPSG:4326', dst_crs, [lon], [lat])

        # Query the pixel value at the transformed coordinate
        coords = [(lon_transformed[0], lat_transformed[0])]
        for val in dataset.sample(coords):
            return int(val[0])
    except Exception as e:
        print(f"Error processing point ({lat}, {lon}): {e}")
        return None

# %%
envo_adapter = get_adapter(envo_adapter_string)

# %%
# Get  CURIEs from the ontology
envo_curies = envo_adapter.entities(filter_obsoletes=True)

# %%
# Collect metadata for each class
nlcd_to_envo = {}

for envo_curie in envo_curies:
    term_label = envo_adapter.label(envo_curie)
    term_metadata = envo_adapter.entity_metadata_map(envo_curie)
    db_xrefs = term_metadata.get('oio:hasDbXref', []) if term_metadata else []

    for xref in db_xrefs:
        if xref.startswith("NLCD:"):
            nlcd_numeric = xref.split(":")[1]
            nlcd_to_envo[nlcd_numeric] = {
                "envo_curie": envo_curie,
                "envo_label": term_label,
            }

# %%
# pprint.pprint(nlcd_to_envo)
# Out:
# {'11': {'envo_curie': 'ENVO:01000666', 'envo_label': 'area of open water'},
#  '12': {'envo_curie': 'ENVO:01000746',
#         'envo_label': 'area of perennial ice or snow'},
#  '21': {'envo_curie': 'ENVO:01000883',
#         'envo_label': 'area of developed open space'},
#  '22': {'envo_curie': 'ENVO:01000884',
#         'envo_label': 'area of developed space with low usage intensity'},
#  '23': {'envo_curie': 'ENVO:01000885',
#         'envo_label': 'area of developed space with medium usage intensity'},
#  '24': {'envo_curie': 'ENVO:01000886',
#         'envo_label': 'area of developed space with high usage intensity'},
#  '31': {'envo_curie': 'ENVO:01000752', 'envo_label': 'area of barren land'},
#  '41': {'envo_curie': 'ENVO:01000816',
#         'envo_label': 'area of deciduous forest'},
#  '42': {'envo_curie': 'ENVO:01000843',
#         'envo_label': 'area of evergreen forest'},
#  '43': {'envo_curie': 'ENVO:01000855', 'envo_label': 'area of mixed forest'},
#  '51': {'envo_curie': 'ENVO:01000861', 'envo_label': 'area of dwarf scrub'},
#  '52': {'envo_curie': 'ENVO:01000869', 'envo_label': 'area of scrub'},
#  '71': {'envo_curie': 'ENVO:01000888',
#         'envo_label': 'area of gramanoid or herbaceous vegetation'},
#  '72': {'envo_curie': 'ENVO:01000887',
#         'envo_label': 'area of sedge- and forb-dominated herbaceous '
#                       'vegetation'},
#  '73': {'envo_curie': 'ENVO:01000889',
#         'envo_label': 'area of lichen-dominated vegetation'},
#  '74': {'envo_curie': 'ENVO:01000890',
#         'envo_label': 'area of moss-dominated vegetation'},
#  '81': {'envo_curie': 'ENVO:01000891',
#         'envo_label': 'area of pastureland or hayfields'},
#  '82': {'envo_curie': 'ENVO:01000892', 'envo_label': 'area of cropland'},
#  '90': {'envo_curie': 'ENVO:01000893', 'envo_label': 'area of woody wetland'},
#  '95': {'envo_curie': 'ENVO:01000894',
#         'envo_label': 'area of emergent herbaceous wetland'}}

# %%
# Load the TSV file
df = pd.read_csv(tsv_file, sep='\t')

# %%
df.columns = [col.lower().strip() for col in df.columns]

# %%
# Open the NLCD GeoTIFF file
with rasterio.open(nlcd_geotiff) as src:
    # Infer land cover for each row using dynamic column names
    df['land_cover'] = df.apply(
        lambda row: get_land_cover(row[lat_col], row[lon_col], src), axis=1
    )

# %%
# Map ENVO curies and labels from the dictionary
df['envo_curie'] = df['land_cover'].map(lambda x: nlcd_to_envo.get(str(x), {}).get('envo_curie'))
df['envo_label'] = df['land_cover'].map(lambda x: nlcd_to_envo.get(str(x), {}).get('envo_label'))

# %%
df
# Out:
#        accession ena first public ena last update ena-checklist  \
# 0   SAMEA7724195       2020-12-17      2020-12-16     ERC000011
# 1   SAMEA7724196       2020-12-17      2020-12-16     ERC000011
# 2   SAMEA7724197       2020-12-17      2020-12-16     ERC000011
# 3   SAMEA7724198       2020-12-17      2020-12-16     ERC000011
# 4   SAMEA7724199       2020-12-17      2020-12-16     ERC000011
# 5   SAMEA7724200       2020-12-17      2020-12-16     ERC000011
# 6   SAMEA7724201       2020-12-17      2020-12-16     ERC000011
# 7   SAMEA7724202       2020-12-17      2020-12-16     ERC000011
# 8   SAMEA7724203       2020-12-17      2020-12-16     ERC000011
# 9   SAMEA7724204       2020-12-17      2020-12-16     ERC000011
# 10  SAMEA7724205       2020-12-17      2020-12-16     ERC000011
# 11  SAMEA7724206       2020-12-17      2020-12-16     ERC000011
# 12  SAMEA7724207              NaN             NaN     ERC000011
# 13  SAMEA7724208       2020-12-17      2020-12-16     ERC000011
# 14  SAMEA7724209       2020-12-17      2020-12-16     ERC000011
# 15  SAMEA7724210       2020-12-17      2020-12-16     ERC000011
# 16  SAMEA7724211       2020-12-17      2020-12-16     ERC000011
# 17  SAMEA7724212       2020-12-17      2020-12-16     ERC000011
# 18  SAMEA7724213       2020-12-17      2020-12-16     ERC000011
# 19  SAMEA7724214       2020-12-17      2020-12-16     ERC000011
# 20  SAMEA7724215       2020-12-17      2020-12-16     ERC000011
# 21  SAMEA7724216       2020-12-17      2020-12-16     ERC000011
# 22  SAMEA7724217       2020-12-17      2020-12-16     ERC000011
# 23  SAMEA7724218       2020-12-17      2020-12-16     ERC000011
# 24  SAMEA7724219       2020-12-17      2020-12-16     ERC000011
# 25  SAMEA7724220       2020-12-17      2020-12-16     ERC000011
# 26  SAMEA7724221       2020-12-17      2020-12-16     ERC000011
# 27  SAMEA7724222       2020-12-17      2020-12-16     ERC000011
# 28  SAMEA7724223       2020-12-17      2020-12-16     ERC000011
# 29  SAMEA7724224       2020-12-17      2020-12-16     ERC000011
# 30  SAMEA7724225       2020-12-17      2020-12-16     ERC000011
# 31  SAMEA7724226       2020-12-17      2020-12-16     ERC000011
# 5                     6   NaN       1.522300             gravimetric
# 6                     7   NaN       0.569200             gravimetric
# 7                     8   NaN       0.735300             gravimetric
# 8                     9   NaN       0.671700             gravimetric
# 9                    10   NaN       0.604800             gravimetric
# 10                   11   NaN       0.614400             gravimetric
# 11                   12   NaN       0.531000             gravimetric
# 12                    1   1.0      26.264583             gravemetric
# 13                    2   1.0      40.874067             gravemetric
# 14                    3   1.0      32.946498             gravemetric
# 15                    4   1.0      41.852463             gravemetric
# 16                    5   1.0      25.577451             gravemetric
# 17                    6   1.0      64.035223             gravemetric
# 18                    7   1.0     342.240088             gravemetric
# 19                    8   1.0      14.951271             gravemetric
# 20                    9   1.0      13.412901             gravemetric
# 21                   10   1.0      11.087530             gravemetric
# 22                   11   1.0      71.792586             gravemetric
# 23                   12   1.0       5.965090             gravemetric
# 24                   13   1.0      10.443592             gravemetric
# 25                   14   1.0      10.560141             gravemetric
# 26                   15   1.0      79.611287             gravemetric
# 27                   16   1.0       9.582366             gravemetric
# 28                   17   1.0      21.121079             gravemetric
# 29                   18   1.0      16.225847             gravemetric
# 30                   19   1.0      65.257748             gravemetric
# 31                   20   1.0      14.342692             gravemetric
# 32                   21   1.0      17.577972             gravemetric
# 33                   22   1.0      21.570250             gravemetric
#
#    land_cover     envo_curie                                  envo_label
# 0          43  ENVO:01000855                        area of mixed forest
# 1          43  ENVO:01000855                        area of mixed forest
# 2          43  ENVO:01000855                        area of mixed forest
# 3          43  ENVO:01000855                        area of mixed forest
# 4          43  ENVO:01000855                        area of mixed forest
# 5          43  ENVO:01000855                        area of mixed forest
# 6          42  ENVO:01000843                    area of evergreen forest
# 7          42  ENVO:01000843                    area of evergreen forest
# 8          42  ENVO:01000843                    area of evergreen forest
# 9          42  ENVO:01000843                    area of evergreen forest
# 10         42  ENVO:01000843                    area of evergreen forest
# 11         42  ENVO:01000843                    area of evergreen forest
# 12         81  ENVO:01000891            area of pastureland or hayfields
# 13         81  ENVO:01000891            area of pastureland or hayfields
# 14         81  ENVO:01000891            area of pastureland or hayfields
# 15         81  ENVO:01000891            area of pastureland or hayfields
# 16         71  ENVO:01000888  area of gramanoid or herbaceous vegetation
# 17         42  ENVO:01000843                    area of evergreen forest
# 18         95  ENVO:01000894         area of emergent herbaceous wetland
# 19         71  ENVO:01000888  area of gramanoid or herbaceous vegetation
# 20         82  ENVO:01000892                            area of cropland
# 21         82  ENVO:01000892                            area of cropland
# 22         81  ENVO:01000891            area of pastureland or hayfields
# 23         82  ENVO:01000892                            area of cropland
# 24         52  ENVO:01000869                               area of scrub
# 25         52  ENVO:01000869                               area of scrub
# 26         95  ENVO:01000894         area of emergent herbaceous wetland
# 27         52  ENVO:01000869                               area of scrub
# 28         42  ENVO:01000843                    area of evergreen forest
# 29         31  ENVO:01000752                         area of barren land
# 30         42  ENVO:01000843                    area of evergreen forest
# 31         82  ENVO:01000892                            area of cropland
# 32         42  ENVO:01000843                    area of evergreen forest
# 33         52  ENVO:01000869                               area of scrub
#
# [34 rows x 54 columns]

# %%
df.to_csv(output_file, sep="\t", index=False)
