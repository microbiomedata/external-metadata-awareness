# %%
import pandas as pd
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pprint

# %%
# Read the TSV files into pandas DataFrames
df_citations = pd.read_csv("doi_metadata.tsv", sep="\t")
df_metadata = pd.read_csv("pdf_metadata.tsv", sep="\t")

# %%
# Combine title and author information into a single field for both datasets
df_citations['title_author'] = df_citations['Title'] + ' ' + df_citations['Authors']
df_metadata['title_author'] = df_metadata['Title'] + ' ' + df_metadata['Author']

# %%
# Preprocess the combined field
def preprocess_text(text):
    if pd.isnull(text):  # Handle NaN values
        return ''
    text = text.translate(str.maketrans('', '', string.punctuation))  # Remove punctuation
    text = text.lower()  # Convert to lowercase
    return text.split()  # Tokenize

# %%
df_citations['title_author_tokens'] = df_citations['title_author'].apply(preprocess_text)
df_metadata['title_author_tokens'] = df_metadata['title_author'].apply(preprocess_text)

# %%
df_citations
# Out:
#                                 DOI                 Updated DOI  \
# 0         10.1128/mSystems.00045-18                         NaN
# 1         10.1101/2022.12.12.520098  10.3389/fsoil.2023.1120425
# 2        10.1038/s41564-022-01266-x                         NaN
# 3           10.1111/1462-2920.16314                         NaN
# 4                 10.1111/mec.16891                         NaN
# 5       10.1021/acs.estlett.0c00748                         NaN
# 6         10.1128/msystems.00768-19                         NaN
# 7      10.1371/journal.pone.0228165                         NaN
# 8    10.1016/j.geoderma.2021.115674                         NaN
# 9              10.1029/2022JG006889                         NaN
# 10                 10.1002/ppp.2200                         NaN
# 11       10.1038/s41467-023-36515-y                         NaN
# 12                10.1002/lno.11306                         NaN
# 13       10.1038/s41597-024-03069-7                         NaN
# 14       10.1038/s41564-020-00861-0                         NaN
# 15             10.1128/MRA.01361-19                         NaN
# 16             10.1128/mra.01080-23                         NaN
# 17        10.1038/s41597-019-0132-4                         NaN
# 18       10.1038/s41597-024-04013-5                         NaN
# 19       10.1186/s40168-020-00889-8                         NaN
# 20              10.1093/nar/gkab990                         NaN
# 21           10.1126/sciadv.adg7888                         NaN
# 22     10.1371/journal.pone.0228165                         NaN
# 23    10.3390/microorganisms9020357                         NaN
# 24  10.3897/tdwgproceedings.1.20637                         NaN
# 25        10.5194/acp-23-15783-2023                         NaN
#
#                                                 Title  \
# 0   Exploration of the Biosynthetic Potential of t...
# 1   One thousand soils for molecular understanding...
# 2   Standardized multi-omics of Earth’s microbiome...
# 3   Environmental predictors of electroactive bact...
# 4   Diversity, distribution, and expression of ops...
# 5   Long-Term Warming Decreases Redox Capacity of ...
# 6   Complementary Metagenomic Approaches Improve R...
# 7   Distinct temporal diversity profiles for nitro...
# 8   Soil pore network response to freeze-thaw cycl...
# 9   The Impact of Freeze‐Thaw History on Soil Carb...
# 10  Topography and canopy cover influence soil org...
# 11  Seasonal activities of the phyllosphere microb...
# 12  Time‐series metatranscriptomes reveal conserve...
# 13  An integrated metagenomic, metabolomic and tra...
# 14  Genomic and functional analyses of fungal and ...
# 15  Metatranscriptomic Sequencing of a Cyanobacter...
# 16  Metatranscriptomes of two biological soil crus...
# 17  Microbial metagenomes and metatranscriptomes d...
# 18  Microbial Metagenomes Across a Complete Phytop...
# 19  Influence of the polar light cycle on seasonal...
# 20  The National Microbiome Data Collaborative Dat...
# 21  Reproducible growth of<i>Brachypodium</i>in Ec...
# 22  Distinct temporal diversity profiles for nitro...
# 23  Soil Bacterial Diversity Is Positively Correla...
# 24  Using MIxS: An Implementation Report from Two ...
# 25  Active thermokarst regions contain rich  sourc...
#
#                                             Journal  Year        Year Type  \
# 0                                          mSystems  2018  published-print
# 1                         Frontiers in Soil Science  2023        published
# 2                               Nature Microbiology  2022        published
# 3                        Environmental Microbiology  2023  published-print
# 4                                 Molecular Ecology  2023  published-print
# 5    Environmental Science &amp; Technology Letters  2021  published-print
# 6                                          mSystems  2020  published-print
# 7                                          PLOS ONE  2020        published
# 8                                          Geoderma  2022  published-print
# 9   Journal of Geophysical Research: Biogeosciences  2022  published-print
# 10             Permafrost and Periglacial Processes  2023  published-print
# 11                            Nature Communications  2023        published
# 12                       Limnology and Oceanography  2020  published-print
# 13                                  Scientific Data  2024        published
# 14                              Nature Microbiology  2021        published
# 15              Microbiology Resource Announcements  2020  published-print
# 16              Microbiology Resource Announcements  2024  published-print
# 17                                  Scientific Data  2019        published
# 18                                  Scientific Data  2024        published
# 19                                       Microbiome  2020  published-print
# 20                           Nucleic Acids Research  2022        published
# 21                                 Science Advances  2024  published-print
# 22                                         PLOS ONE  2020        published
# 23                                   Microorganisms  2021        published
# 24                              Proceedings of TDWG  2017        published
# 25                Atmospheric Chemistry and Physics  2023        published
#
#                                             Publisher  \
# 0                   American Society for Microbiology
# 1                                  Frontiers Media SA
# 2             Springer Science and Business Media LLC
# 3                                               Wiley
# 4                                               Wiley
# 5                     American Chemical Society (ACS)
# 6                   American Society for Microbiology
# 7                    Public Library of Science (PLoS)
# 8                                         Elsevier BV
# 9                    American Geophysical Union (AGU)
# 10                                              Wiley
# 11            Springer Science and Business Media LLC
# 12                                              Wiley
# 13            Springer Science and Business Media LLC
# 14            Springer Science and Business Media LLC
# 15                  American Society for Microbiology
# 16                  American Society for Microbiology
# 17            Springer Science and Business Media LLC
# 18            Springer Science and Business Media LLC
# 19            Springer Science and Business Media LLC
# 20                      Oxford University Press (OUP)
# 21  American Association for the Advancement of Sc...
# 22                   Public Library of Science (PLoS)
# 23                                            MDPI AG
# 24                                 Pensoft Publishers
# 25                                    Copernicus GmbH
#
#                                               Authors  Volume Issue  \
# 0   Patricia M. Blair; Miriam L. Land; Marek J. Pi...     3.0     5
# 1   Maggie M. Bowman; Alexis E. Heath; Tamas Varga...     3.0   NaN
# 2   Justin P. Shaffer; Louis-Félix Nothias; Luke R...     7.0    12
# 3   Charles N. Olmsted; Roger Ort; Patricia Q. Tra...    25.0     3
# 4   Shaomei He; Alexandra M. Linz; Sarah L. R. Ste...    32.0    11
# 5   Rachelle E. LaCroix; Nicolas Walpen; Michael S...     8.0     1
# 6   L. V. Alteio; F. Schulz; R. Seshadri; N. Vargh...     5.0     2
# 7   William C. Nelson; Emily B. Graham; Alex R. Cr...    15.0     1
# 8   Erin C. Rooney; Vanessa L. Bailey; Kaizad F. P...   411.0   NaN
# 9   Erin C. Rooney; Vanessa L. Bailey; Kaizad F. P...   127.0     5
# 10  Erin C. Rooney; Vanessa L. Bailey; Kaizad F. P...    34.0     3
# 11  Adina Howe; Nejc Stopnisek; Shane K. Dooley; F...    14.0     1
# 12  Alexandra M. Linz; Frank O. Aylward; Stefan Be...    65.0    S1
# 13  Christopher Schadt; Stanton Martin; Alyssa Car...    11.0     1
# 14  Xuefeng Peng; St. Elmo Wilken; Thomas S. Lanki...     6.0     4
# 15  Terrence H. Bell; Ryan V. Trexler; Xin Peng; M...     9.0     1
# 16  Thuy M. Nguyen; Nuttapon Pombubpa; Marcel Hunt...    13.0     2
# 17  Brent Nowinski; Christa B. Smith; Courtney M. ...     6.0     1
# 18  Brook L. Nunn; Emma Timmins-Schiffman; Miranda...    11.0     1
# 19  Pratibha Panwar; Michelle A. Allen; Timothy J....     8.0     1
# 20                                                NaN     NaN   NaN
# 21  Vlastimil Novak; Peter F. Andeer; Benjamin P. ...    10.0     1
# 22  William C. Nelson; Emily B. Graham; Alex R. Cr...    15.0     1
# 23  Akane Chiba; Yoshitaka Uchida; Susanne Kublik;...     9.0     2
# 24  Joel Sachs; Luke Thompson; Nazir El-Kayssi; Sa...     1.0   NaN
# 25  Kevin R. Barry; Thomas C. J. Hill; Marina Niet...    23.0    24
#
#           Pages                                          DOI URL  \
# 0           NaN        https://doi.org/10.1128/msystems.00045-18
# 1           NaN       https://doi.org/10.3389/fsoil.2023.1120425
# 2     2128-2150       https://doi.org/10.1038/s41564-022-01266-x
# 3       705-720          https://doi.org/10.1111/1462-2920.16314
# 4     2798-2817                https://doi.org/10.1111/mec.16891
# 5         92-97      https://doi.org/10.1021/acs.estlett.0c00748
# 6           NaN        https://doi.org/10.1128/msystems.00768-19
# 7      e0228165     https://doi.org/10.1371/journal.pone.0228165
# 8        115674   https://doi.org/10.1016/j.geoderma.2021.115674
# 9           NaN             https://doi.org/10.1029/2022jg006889
# 10      331-358                 https://doi.org/10.1002/ppp.2200
# 11          NaN       https://doi.org/10.1038/s41467-023-36515-y
# 12          NaN                https://doi.org/10.1002/lno.11306
# 13          NaN       https://doi.org/10.1038/s41597-024-03069-7
# 14      499-511       https://doi.org/10.1038/s41564-020-00861-0
# 15          NaN             https://doi.org/10.1128/mra.01361-19
# 16          NaN             https://doi.org/10.1128/mra.01080-23
# 17          NaN        https://doi.org/10.1038/s41597-019-0132-4
# 18          NaN       https://doi.org/10.1038/s41597-024-04013-5
# 19          NaN       https://doi.org/10.1186/s40168-020-00889-8
# 20          NaN              https://doi.org/10.1093/nar/gkab990
# 21          NaN           https://doi.org/10.1126/sciadv.adg7888
# 22     e0228165     https://doi.org/10.1371/journal.pone.0228165
# 23          357    https://doi.org/10.3390/microorganisms9020357
# 24       e20637  https://doi.org/10.3897/tdwgproceedings.1.20637
# 25  15783-15793        https://doi.org/10.5194/acp-23-15783-2023
#
#                                          title_author  \
# 0   Exploration of the Biosynthetic Potential of t...
# 1   One thousand soils for molecular understanding...
# 2   Standardized multi-omics of Earth’s microbiome...
# 3   Environmental predictors of electroactive bact...
# 4   Diversity, distribution, and expression of ops...
# 5   Long-Term Warming Decreases Redox Capacity of ...
# 6   Complementary Metagenomic Approaches Improve R...
# 7   Distinct temporal diversity profiles for nitro...
# 8   Soil pore network response to freeze-thaw cycl...
# 9   The Impact of Freeze‐Thaw History on Soil Carb...
# 10  Topography and canopy cover influence soil org...
# 11  Seasonal activities of the phyllosphere microb...
# 12  Time‐series metatranscriptomes reveal conserve...
# 13  An integrated metagenomic, metabolomic and tra...
# 14  Genomic and functional analyses of fungal and ...
# 15  Metatranscriptomic Sequencing of a Cyanobacter...
# 16  Metatranscriptomes of two biological soil crus...
# 17  Microbial metagenomes and metatranscriptomes d...
# 18  Microbial Metagenomes Across a Complete Phytop...
# 19  Influence of the polar light cycle on seasonal...
# 20                                                NaN
# 21  Reproducible growth of<i>Brachypodium</i>in Ec...
# 22  Distinct temporal diversity profiles for nitro...
# 23  Soil Bacterial Diversity Is Positively Correla...
# 24  Using MIxS: An Implementation Report from Two ...
# 25  Active thermokarst regions contain rich  sourc...
#
#                                   title_author_tokens
# 0   [exploration, of, the, biosynthetic, potential...
# 1   [one, thousand, soils, for, molecular, underst...
# 2   [standardized, multiomics, of, earth’s, microb...
# 3   [environmental, predictors, of, electroactive,...
# 4   [diversity, distribution, and, expression, of,...
# 5   [longterm, warming, decreases, redox, capacity...
# 6   [complementary, metagenomic, approaches, impro...
# 7   [distinct, temporal, diversity, profiles, for,...
# 8   [soil, pore, network, response, to, freezethaw...
# 9   [the, impact, of, freeze‐thaw, history, on, so...
# 10  [topography, and, canopy, cover, influence, so...
# 11  [seasonal, activities, of, the, phyllosphere, ...
# 12  [time‐series, metatranscriptomes, reveal, cons...
# 13  [an, integrated, metagenomic, metabolomic, and...
# 14  [genomic, and, functional, analyses, of, funga...
# 15  [metatranscriptomic, sequencing, of, a, cyanob...
# 16  [metatranscriptomes, of, two, biological, soil...
# 17  [microbial, metagenomes, and, metatranscriptom...
# 18  [microbial, metagenomes, across, a, complete, ...
# 19  [influence, of, the, polar, light, cycle, on, ...
# 20
# 21  [reproducible, growth, ofibrachypodiumiin, eco...
# 22  [distinct, temporal, diversity, profiles, for,...
# 23  [soil, bacterial, diversity, is, positively, c...
# 24  [using, mixs, an, implementation, report, from...
# 25  [active, thermokarst, regions, contain, rich, ...

# %%
df_metadata
# Out:
#                                              Filename  \
# 0                               acp-23-15783-2023.pdf
# 1   bell-et-al-2020-metatranscriptomic-sequencing-...
# 2   Soil_Bacterial_Diversity_Is_Positively_Correla...
# 3                              BISS_article_20637.pdf
# 4                              s40168-020-00889-8.pdf
# 5                                  sciadv.adg7888.pdf
# 6                              s41597-024-04013-5.pdf
# 7                              s41564-020-00861-0.pdf
# 8                          41564_2019_Article_449.pdf
# 9                                         gkab990.pdf
# 10  blair-et-al-2018-exploration-of-the-biosynthet...
# 11                              s41597-019-0132-4.pdf
# 12  Limnology   Oceanography - 2019 - Linz - Time‐...
# 13                                           file.pdf
# 14                     microorganisms-09-00357-v2.pdf
# 15  Environmental Microbiology - 2022 - Olmsted - ...
# 16                  1-s2.0-S0016706121007540-main.pdf
# 17  Molecular Ecology - 2023 - He - Diversity  dis...
# 18  JGR Biogeosciences - 2022 - Rooney - The Impac...
# 19                             s41564-022-01266-x.pdf
# 20                             s41467-023-36515-y.pdf
# 21  nguyen-et-al-2024-metatranscriptomes-of-two-bi...
# 22                       2022.12.12.520098v2.full.pdf
# 23                             s41597-024-03069-7.pdf
# 24  alteio-et-al-2020-complementary-metagenomic-ap...
# 25  New Phytologist - 2018 - Sasse - Multilab EcoF...
#
#                                DOI    Year    Volume          Pages  \
# 0                              NaN     NaN       NaN            NaN
# 1             10.1128/mra.01361-19  2020.0       9.0             10
# 2                              NaN     NaN       NaN            NaN
# 3                              NaN     NaN       NaN            NaN
# 4       10.1186/s40168-020-00889-8     NaN       NaN            NaN
# 5                              NaN  2024.0      10.0       eadg7888
# 6       10.1038/s41597-024-04013-5     NaN       NaN            NaN
# 7       10.1038/s41564-020-00861-0     NaN       NaN            NaN
# 8        10.1038/s41564-019-0449-y     NaN       NaN            NaN
# 9                              NaN     NaN       NaN            NaN
# 10       10.1128/msystems.00045-18  2018.0       3.0             10
# 11       10.1038/s41597-019-0132-4     NaN       NaN            NaN
# 12                             NaN  2020.0      65.0      S101-S112
# 13                             NaN     NaN       NaN            NaN
# 14                             NaN     NaN       NaN            NaN
# 15                             NaN  2023.0      25.0        705-720
# 16  10.1016/j.geoderma.2021.115674  2021.0  115674.0            NaN
# 17                             NaN  2023.0      32.0      2798-2817
# 18                             NaN  2022.0     127.0  e2022JG006889
# 19      10.1038/s41564-022-01266-x     NaN       NaN            NaN
# 20      10.1038/s41467-023-36515-y     NaN       NaN            NaN
# 21                             NaN  2024.0      13.0      e01080-23
# 22                             NaN     NaN       NaN            NaN
# 23      10.1038/s41597-024-03069-7     NaN       NaN            NaN
# 24       10.1128/msystems.00768-19  2020.0       5.0             10
# 25                             NaN  2019.0     222.0      1149-1160
#
#                                                 Title  \
# 0                                                 NaN
# 1   Metatranscriptomic Sequencing of a Cyanobacter...
# 2        Microsoft Word - microorganisms-1106083.docx
# 3                                                 NaN
# 4   Influence of the polar light cycle on seasonal...
# 5   Reproducible growth of Brachypodium in EcoFAB ...
# 6   Microbial Metagenomes Across a Complete Phytop...
# 7   Genomic and functional analyses of fungal and ...
# 8   Mediterranean grassland soil C–N compound turn...
# 9                                                 NaN
# 10  Exploration of the Biosynthetic Potential of t...
# 11  Microbial metagenomes and metatranscriptomes d...
# 12  Time‐series metatranscriptomes reveal conserve...
# 13  Distinct temporal diversity profiles for nitro...
# 14  Soil Bacterial Diversity Is Positively Correla...
# 15  Environmental predictors of electroactive bact...
# 16  Soil pore network response to freeze-thaw cycl...
# 17  Diversity, distribution, and expression of ops...
# 18  The Impact of Freeze‐Thaw History on Soil Carb...
# 19  Standardized multi-omics of Earth’s microbiome...
# 20  Seasonal activities of the phyllosphere microb...
# 21  Metatranscriptomes of two biological soil crus...
# 22                                           12861919
# 23  An integrated metagenomic, metabolomic and tra...
# 24  Complementary Metagenomic Approaches Improve R...
# 25  Multilab EcoFAB study shows highly reproducibl...
#
#                                                Author  \
# 0                                                 NaN
# 1   Terrence H. Bell, Ryan V. Trexler, Xin Peng, M...
# 2                                               Admin
# 3                                                 NaN
# 4                                     Pratibha Panwar
# 5                                                 NaN
# 6                                       Brook L. Nunn
# 7                                        Xuefeng Peng
# 8                                     Spencer Diamond
# 9                                                 NaN
# 10  Patricia M. Blair, Miriam L. Land, Marek J. Pi...
# 11                                     Brent Nowinski
# 12                                                NaN
# 13  William C. Nelson, Emily B. Graham, Alex R. Cr...
# 14  Akane Chiba, Yoshitaka Uchida, Susanne Kublik,...
# 15                                                NaN
# 16                                     Erin C. Rooney
# 17                                                NaN
# 18                                                NaN
# 19                                  Justin P. Shaffer
# 20                                         Adina Howe
# 21  Thuy M. Nguyen, Nuttapon Pombubpa, Marcel Hunt...
# 22                                    Mans, Douglas M
# 23                                 Christopher Schadt
# 24  L. V. Alteio, F. Schulz, R. Seshadri, N. Vargh...
# 25                                                NaN
#
#                                               Subject  \
# 0                                                 NaN
# 1   Microbiol Resour Announc 2020.9:10.1128/mra.01...
# 2                                                 NaN
# 3                                         description
# 4    Microbiome, 2020, doi:10.1186/s40168-020-00889-8
# 5                          Sci. Adv. 2024.10:eadg7888
# 6     Scientific Data, doi:10.1038/s41597-024-04013-5
# 7   Nature Microbiology, doi:10.1038/s41564-020-00...
# 8   Nature Microbiology, doi:10.1038/s41564-019-04...
# 9                                                 NaN
# 10          mSystems 2018.3:10.1128/msystems.00045-18
# 11     Scientific Data, doi:10.1038/s41597-019-0132-4
# 12         Limnology & Oceanography 2020.65:S101-S112
# 13                                                NaN
# 14  This study aimed to investigate the effects of...
# 15         Environmental Microbiology 2023.25:705-720
# 16  Geoderma, 411 (2022) 115674. doi:10.1016/j.geo...
# 17                Molecular Ecology 2023.32:2798-2817
# 18          JGR Biogeosciences 2022.127:e2022JG006889
# 19  Nature Microbiology, doi:10.1038/s41564-022-01...
# 20  Nature Communications, doi:10.1038/s41467-023-...
# 21         Microbiol Resour Announc 2024.13:e01080-23
# 22                                                NaN
# 23    Scientific Data, doi:10.1038/s41597-024-03069-7
# 24          mSystems 2020.5:10.1128/msystems.00768-19
# 25                 New Phytologist 2019.222:1149-1160
#
#                                              Keywords Creation Date  \
# 0                                                 NaN    2023-12-22
# 1                                                 NaN    2019-12-10
# 2                                                 NaN    2021-02-11
# 3                                            keywords           NaN
# 4   Antarctic microbiology,Polar light cycle,Metag...    2020-11-14
# 5                                                 NaN    2023-12-29
# 6                                                 NaN    2025-01-15
# 7                                                 NaN    2021-03-24
# 8                                                 NaN    2019-07-17
# 9                                                 NaN    2021-12-27
# 10  biosynthetic gene clusters, natural product bi...    2018-09-24
# 11                                                NaN    2019-07-12
# 12                                                NaN    2020-01-20
# 13                                                NaN    2020-01-21
# 14  soil bacterial diversity; maize litter decompo...    2021-02-24
# 15                                                NaN    2023-02-23
# 16  Pore morphology,Pore connectivity,Freeze thaw,...    2022-01-20
# 17                                                NaN    2023-05-18
# 18                                                NaN    2022-05-19
# 19                                                NaN    2022-11-30
# 20                                                NaN    2023-02-23
# 21  biocrust, RNA, transcriptome, wetting, desert,...    2024-02-09
# 22                                                NaN    2023-03-14
# 23                                                NaN    2024-04-05
# 24  flow cytometry, metagenomics, microbial ecolog...    2020-03-05
# 25                                                NaN    2019-03-08
#
#    Modification Date                                           Producer  \
# 0         2023-12-22                                     pdfTeX-1.40.19
# 1         2025-02-10  Adobe LiveCycle PDF Generator; modified using ...
# 2         2021-02-11                   Acrobat Distiller 21.0 (Windows)
# 3                NaN           WeasyPrint 0.31 (http://weasyprint.org/)
# 4         2020-11-15  Acrobat Distiller 10.0.0 (Windows); modified u...
# 5         2024-08-22  Adobe PDF Library 15.0; modified using iText 4...
# 6         2025-01-21  iText® 5.3.5 ©2000-2012 1T3XT BVBA (SPRINGER S...
# 7         2021-03-24                                                NaN
# 8         2019-07-17                                                NaN
# 9         2024-08-21  Acrobat Distiller 21.0 (Windows); modified usi...
# 10        2025-02-10  Adobe LiveCycle PDF Generator; modified using ...
# 11        2019-07-15  iText® 5.3.5 ©2000-2012 1T3XT BVBA (AGPL-version)
# 12        2025-02-10  Acrobat Distiller 8.1.0 (Windows); modified us...
# 13        2020-01-21                       PDFlib+PDI 9.0.6 (C++/Win64)
# 14        2021-02-24                                     pdfTeX-1.40.18
# 15        2025-02-10  Acrobat Distiller 11.0 (Windows); modified usi...
# 16        2022-01-20                  Acrobat Distiller 8.1.0 (Windows)
# 17        2025-02-10  Adobe PDF Library 15.0; modified using iText 4...
# 18        2025-02-10  Adobe PDF Library 15.0; modified using iText 4...
# 19        2022-11-30                                                NaN
# 20        2023-02-23  iText® 5.3.5 ©2000-2012 1T3XT BVBA (SPRINGER S...
# 21        2025-02-10  Antenna House PDF Output Library 7.3.1866; mod...
# 22        2025-02-10                  Microsoft® Word for Microsoft 365
# 23        2024-04-05  iText® 5.3.5 ©2000-2012 1T3XT BVBA (SPRINGER S...
# 24        2025-02-10  Adobe LiveCycle PDF Generator; modified using ...
# 25        2024-07-25  Acrobat Distiller 10.0.0 (Windows); modified u...
#
#                                               Creator  \
# 0   copernicus.cls Version 2023/11/02 10.1.11 Cope...
# 1                                                 XPP
# 2                          PScript5.dll Version 5.2.2
# 3                                                 NaN
# 4   Arbortext Advanced Print Publisher 9.1.440/W U...
# 5                       Adobe InDesign 16.2 (Windows)
# 6                                            Springer
# 7                                            Springer
# 8                                            Springer
# 9    XMLPublish v.3.0 Copyright 1991-2017 Aptara Inc.
# 10                                                XPP
# 11                                           Springer
# 12  Arbortext Advanced Print Publisher 9.1.520/W U...
# 13  Arbortext Advanced Print Publisher 11.0.3521/W...
# 14                        LaTeX with hyperref package
# 15  Arbortext Advanced Print Publisher 9.1.520/W U...
# 16                                           Elsevier
# 17                      Adobe InDesign 15.1 (Windows)
# 18                      Adobe InDesign 15.1 (Windows)
# 19                                           Springer
# 20                                           Springer
# 21  Antenna XSL House Formatter V7.3 MR2 Linux : 7...
# 22                        Appligent AppendPDF Pro 5.5
# 23                                           Springer
# 24                                                XPP
# 25  Arbortext Advanced Print Publisher 9.1.531/W U...
#
#                                          title_author  \
# 0                                                 NaN
# 1   Metatranscriptomic Sequencing of a Cyanobacter...
# 2   Microsoft Word - microorganisms-1106083.docx A...
# 3                                                 NaN
# 4   Influence of the polar light cycle on seasonal...
# 5                                                 NaN
# 6   Microbial Metagenomes Across a Complete Phytop...
# 7   Genomic and functional analyses of fungal and ...
# 8   Mediterranean grassland soil C–N compound turn...
# 9                                                 NaN
# 10  Exploration of the Biosynthetic Potential of t...
# 11  Microbial metagenomes and metatranscriptomes d...
# 12                                                NaN
# 13  Distinct temporal diversity profiles for nitro...
# 14  Soil Bacterial Diversity Is Positively Correla...
# 15                                                NaN
# 16  Soil pore network response to freeze-thaw cycl...
# 17                                                NaN
# 18                                                NaN
# 19  Standardized multi-omics of Earth’s microbiome...
# 20  Seasonal activities of the phyllosphere microb...
# 21  Metatranscriptomes of two biological soil crus...
# 22                           12861919 Mans, Douglas M
# 23  An integrated metagenomic, metabolomic and tra...
# 24  Complementary Metagenomic Approaches Improve R...
# 25                                                NaN
#
#                                   title_author_tokens
# 0
# 1   [metatranscriptomic, sequencing, of, a, cyanob...
# 2   [microsoft, word, microorganisms1106083docx, a...
# 3
# 4   [influence, of, the, polar, light, cycle, on, ...
# 5
# 6   [microbial, metagenomes, across, a, complete, ...
# 7   [genomic, and, functional, analyses, of, funga...
# 8   [mediterranean, grassland, soil, c–n, compound...
# 9
# 10  [exploration, of, the, biosynthetic, potential...
# 11  [microbial, metagenomes, and, metatranscriptom...
# 12
# 13  [distinct, temporal, diversity, profiles, for,...
# 14  [soil, bacterial, diversity, is, positively, c...
# 15
# 16  [soil, pore, network, response, to, freezethaw...
# 17
# 18
# 19  [standardized, multiomics, of, earth’s, microb...
# 20  [seasonal, activities, of, the, phyllosphere, ...
# 21  [metatranscriptomes, of, two, biological, soil...
# 22                       [12861919, mans, douglas, m]
# 23  [an, integrated, metagenomic, metabolomic, and...
# 24  [complementary, metagenomic, approaches, impro...
# 25

# %%
# Create a TF-IDF vectorizer to convert the tokenized text into numerical vectors
vectorizer = TfidfVectorizer()

# %%
# Fit the vectorizer on the combined title_author_tokens from both DataFrames
vectorizer.fit(df_citations['title_author_tokens'].apply(lambda x: ' '.join(x)).tolist() +
              df_metadata['title_author_tokens'].apply(lambda x: ' '.join(x)).tolist())
# Out:
# TfidfVectorizer()

# %%
# Transform the title_author_tokens into numerical vectors
citations_vectors = vectorizer.transform(df_citations['title_author_tokens'].apply(lambda x: ' '.join(x)))
metadata_vectors = vectorizer.transform(df_metadata['title_author_tokens'].apply(lambda x: ' '.join(x)))

# %%
# Calculate the cosine similarity matrix
cosine_sim_matrix = cosine_similarity(citations_vectors, metadata_vectors)

# %%
# Find the maximum cosine similarity score for each entry in doi_metadata.tsv
max_sim_scores = cosine_sim_matrix.max(axis=1)

# %%
# Find the maximum cosine similarity score and its index for each entry in doi_metadata.tsv
max_sim_scores = cosine_sim_matrix.max(axis=1)
max_sim_indices = cosine_sim_matrix.argmax(axis=1)

# %%
# Create a list of dictionaries to store the results
results = []
for i, (score, idx) in enumerate(zip(max_sim_scores, max_sim_indices)):
    results.append({
        'Entry': i + 1,
        'DOI': df_citations.loc[i, 'DOI'],
        'Filename': df_metadata.loc[idx, 'Filename'],
        'Similarity Score': score
    })

# %%
df = pd.DataFrame(results)

# %%
df
# Out:
#     Entry                              DOI  \
# 0       1        10.1128/mSystems.00045-18
# 1       2        10.1101/2022.12.12.520098
# 2       3       10.1038/s41564-022-01266-x
# 3       4          10.1111/1462-2920.16314
# 4       5                10.1111/mec.16891
# 5       6      10.1021/acs.estlett.0c00748
# 6       7        10.1128/msystems.00768-19
# 7       8     10.1371/journal.pone.0228165
# 8       9   10.1016/j.geoderma.2021.115674
# 9      10             10.1029/2022JG006889
# 10     11                 10.1002/ppp.2200
# 11     12       10.1038/s41467-023-36515-y
# 12     13                10.1002/lno.11306
# 13     14       10.1038/s41597-024-03069-7
# 14     15       10.1038/s41564-020-00861-0
# 15     16             10.1128/MRA.01361-19
# 16     17             10.1128/mra.01080-23
# 17     18        10.1038/s41597-019-0132-4
# 18     19       10.1038/s41597-024-04013-5
# 19     20       10.1186/s40168-020-00889-8
# 20     21              10.1093/nar/gkab990
# 21     22           10.1126/sciadv.adg7888
# 22     23     10.1371/journal.pone.0228165
# 23     24    10.3390/microorganisms9020357
# 24     25  10.3897/tdwgproceedings.1.20637
# 25     26        10.5194/acp-23-15783-2023
#
#                                              Filename  Similarity Score
# 0   blair-et-al-2018-exploration-of-the-biosynthet...          0.948377
# 1                        2022.12.12.520098v2.full.pdf          0.161309
# 2                              s41564-022-01266-x.pdf          0.187543
# 3   blair-et-al-2018-exploration-of-the-biosynthet...          0.083410
# 4                                            file.pdf          0.098154
# 5   alteio-et-al-2020-complementary-metagenomic-ap...          0.067630
# 6   alteio-et-al-2020-complementary-metagenomic-ap...          1.000000
# 7                                            file.pdf          1.000000
# 8                   1-s2.0-S0016706121007540-main.pdf          0.511187
# 9                   1-s2.0-S0016706121007540-main.pdf          0.232726
# 10                  1-s2.0-S0016706121007540-main.pdf          0.187375
# 11                             s41467-023-36515-y.pdf          0.649401
# 12                              s41597-019-0132-4.pdf          0.074472
# 13                             s41597-024-03069-7.pdf          0.435847
# 14                             s41564-020-00861-0.pdf          0.603828
# 15  bell-et-al-2020-metatranscriptomic-sequencing-...          1.000000
# 16  nguyen-et-al-2024-metatranscriptomes-of-two-bi...          1.000000
# 17  bell-et-al-2020-metatranscriptomic-sequencing-...          0.453781
# 18                             s41597-024-04013-5.pdf          0.515896
# 19                             s40168-020-00889-8.pdf          0.548277
# 20                              acp-23-15783-2023.pdf          0.000000
# 21                             s41564-022-01266-x.pdf          0.058870
# 22                                           file.pdf          1.000000
# 23                     microorganisms-09-00357-v2.pdf          0.994664
# 24                             s41597-024-03069-7.pdf          0.087636
# 25                       2022.12.12.520098v2.full.pdf          0.094915

# %%
df.to_csv("citations_to_metadata_mapping.tsv", sep="\t", index=False)
