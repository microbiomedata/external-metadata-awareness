# %%
import pprint
import re
import string
import urllib.parse
from collections import Counter, defaultdict

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import requests_cache
import yaml
from curies import Converter
from dotenv import dotenv_values
from prefixmaps.io.parser import load_multi_context
from pymongo import MongoClient
from tqdm.notebook import tqdm

# %%
def normalize_string(s):
    """
    Normalizes a string by lowercasing, trimming, and removing duplicate whitespace.
    """
    if not isinstance(s, str):
        return ""  # handle non string input.
    s = s.lower()
    s = s.strip()
    s = re.sub(r'\s+', ' ', s)  # Replace multiple whitespace with single space
    return s

# %%
def repair_curie(raw_curie: str) -> str:
    """
    Attempt to normalize or 'repair' the CURIE-like string:
      1. Normalize namespace to uppercase if it looks like 'ENVO'.
      2. Replace underscores or periods with a colon (':') between prefix & ID.
      3. Strip extra whitespace around the ID.
    """
    curie = raw_curie.strip()

    # Attempt to split at the first occurrence of [.:_]
    match = re.match(r'^([A-Za-z0-9]+)([\.:_])\s*(.*)$', curie) # todo not sensitive enough to the length and letter/number composition of prefix and local portion
    if not match:
        # If it doesn't match, just return the stripped version
        return curie

    prefix, sep, rest = match.groups()

    # Rebuild as prefix:rest with no extra spaces
    # todo repair should include normalizing the case of the prefix
    repaired = f"{prefix}:{rest.strip()}" # todo excessive replacement of underscores with colons in insensitive curies above
    return repaired

# %%
def split_annotations(raw_content: str):
    """
    Split a single raw line into sub-annotations, returning a list of dicts:
      [
         {
           'raw_chunk': "...",         # substring after splitting
           'raw_curie': "...",         # curie as found in text (if any)
           'repaired_curie': "...",    # normalized curie (if any)
           'raw_label': "...",         # substring minus the matched curie portion
           'cleaned_label': "..."      # lowercased + extra whitespace removed
         },
         ...
      ]
    """
    # Split on major delimiters (pipe, semicolon, slash, comma)
    components = re.split(DELIMITERS, raw_content)

    results = []
    for component in components:
        component = component.strip()
        if not component:
            continue

        match = CURIE_PATTERN.search(component) # todo pattern is over-eager in detecting CURIes
        if match:
            raw_curie = match.group(1)
            repaired = repair_curie(raw_curie)

            # Remove the matched substring from the chunk to guess the label
            label_guess = component[:match.start()] + component[match.end():]
            # Also remove leftover brackets or parentheses
            label_guess = re.sub(r'[\(\)\[\]]+', ' ', label_guess).strip()

            cleaned_label = re.sub(f"[{re.escape(string.punctuation)}]", " ", label_guess.lower())
            cleaned_label = re.sub(f"\d+", " ", cleaned_label)
            cleaned_label = re.sub(r'\s+', ' ', cleaned_label.strip())

        else:
            # No curie found; treat entire chunk as label
            raw_curie = ''
            repaired = ''
            cleaned_label = re.sub(f"[{re.escape(string.punctuation)}]", " ", component.lower())
            cleaned_label = re.sub(f"\d+", " ", cleaned_label)
            cleaned_label = re.sub(r'\s+', ' ', cleaned_label.strip())
            label_guess = component

        results.append({
            'raw_component': component,
            'raw_curie': raw_curie,
            'repaired_curie': repaired,
            'repaired_prefix': repaired.split(":")[0],
            'raw_label': label_guess,
            'cleaned_label': cleaned_label,
            'cleaned_label_len': len(cleaned_label),
        })

    return results

# %%
def analyze_ontology_importance(ontology_matches):
    # Step 1: Compute term frequencies across all ontologies
    term_counts = Counter()
    for terms in ontology_matches.values():
        term_counts.update(terms)

    # Step 2: Identify unique terms and count them per ontology
    unique_terms_per_ontology = defaultdict(set)
    unique_counts_per_ontology = {}

    for ontology, terms in ontology_matches.items():
        unique_terms = {term for term in terms if term_counts[term] == 1}
        unique_terms_per_ontology[ontology] = unique_terms
        unique_counts_per_ontology[ontology] = len(unique_terms)

    # Step 3: Sort ontologies by unique term count in descending order
    ranked_ontologies = sorted(unique_counts_per_ontology.items(), key=lambda x: x[1], reverse=True)

    return ranked_ontologies, dict(unique_terms_per_ontology)  # Ensure it returns a dictionary, not defaultdict

# %% [markdown]
# ----

# %% [markdown]
# ## For determining which ontologies to include in the OAK annotation process
# or just trust `prefix_count_frame`?
#
# enhance that by checking `id` in https://raw.githubusercontent.com/OBOFoundry/OBOFoundry.github.io/refs/heads/master/registry/ontologies.yml
#
# will have to normalize cases

# %%
# Specify the path to your .env file
env_path = "../../../local/.env"
# Load variables into a dictionary
env_vars = dotenv_values(env_path)
BIOPORTAL_API_KEY = env_vars['BIOPORTAL_API_KEY']

# %%
# BIOPORTAL_SEARCH_URL = "https://data.bioontology.org/search"

# %%
# BIOPORTAL_PAGE_SIZE = 100

# %%
# # Counter to store occurrences of each ontology
# ontology_counter = Counter()
#
# # Iterate over each query
# for query in queries:
#     print(f"\nSearching for: {query}")
#     page = 1  # Start from page 1
#
#     while True:  # Keep iterating until there are no more pages
#         params = {
#             "q": query,
#             "apikey": BIOPORTAL_API_KEY,
#             "page": page,
#             "pagesize": BIOPORTAL_PAGE_SIZE,
#             "require_exact_match": True
#         }
#
#         # Build the full URL
#         request = requests.Request('GET', BIOPORTAL_SEARCH_URL, params=params)
#         prepared = request.prepare()
#
#         # Print the full URL
#         print(prepared.url)
#
#         # Now make the actual request
#         response = requests.get(BIOPORTAL_SEARCH_URL, params=params)
#
#         if response.status_code == 200:
#             data = response.json()
#             if "collection" not in data or not data["collection"]:
#                 break  # No more results
#
#             for result in data["collection"]:
#                 ontology = result["links"]["ontology"]
#                 ontology_counter[ontology] += 1  # Increment count for this ontology
#
#             # Check if there is a next page
#             if "nextPage" in data["links"]:
#                 page += 1  # Move to the next page
#                 print(f"{page = }")
#             else:
#                 break  # No more pages
#         else:
#             print(f"Error for query '{query}', page {page}: {response.status_code} {response.text}")
#             break  # Exit loop on error
#

# %%
# ontology_hit_counts = {k:len(v) for k,v in ontology_matches.items()}

# %%
# ontology_hit_counts = dict(sorted(ontology_hit_counts.items(), key=lambda item: item[1], reverse=True))

# %%
# # Invert the mapping
# query_matches = defaultdict(set)
# for ontology, classes in ontology_matches.items():
#     for cls in classes:
#         query_matches[cls].add(ontology)

# %%
def analyze_ontology_importance_from_mongo(db_name, collection_name, mongo_uri="mongodb://localhost:27017/"):
    # Connect to MongoDB
    client = MongoClient(mongo_uri)
    db = client[db_name]
    collection = db[collection_name]

    ontology_matches = defaultdict(set)

    for doc in collection.find():
        component_label = doc["component_label"]
        ols_hits = doc.get("ols_hits", [])

        for hit in ols_hits:
            ontology = hit["ontology"]
            ontology_matches[ontology].add(component_label)

    return dict(ontology_matches)

# %%
hits_by_ontology = analyze_ontology_importance_from_mongo(
    db_name="ncbi_metadata",
    collection_name="triad_components_labels"
)

# %%
hits_by_ontology
# Out:
# {'envo': {'ditch',
#   'pharmacy',
#   'administrative region',
#   'agricultural facility',
#   'sheepfold',
#   'metallic material',
#   'mediterranean shrubland biome',
#   'saline spring',
#   'salt lake',
#   'mouth',
#   'ice mass',
#   'material primarily composed of biogenic carbonates',
#   'lake water',
#   'waterbody',
#   'island',
#   'culturing environment',
#   'biosphere',
#   'chicken manure',
#   'terrestrial environmental zone',
#   'alluvial soil',
#   'shrimp pond',
#   'horse manure',
#   'mesoplastic particle',
#   'pancake ice',
#   'microcosm',
#   'hydrothermal vent',
#   'town hall',
#   'dense settlement biome',
#   'tropical woodland biome',
#   'sink',
#   'brine channel',
#   'biomass',
#   'cryopeg',
#   'stony soil',
#   'glacier',
#   'container of an intermittent lake',
#   'precipitation process',
#   'lakeshore',
#   'flood fringe',
#   'contaminated soil',
#   'salt marsh',
#   'university campus',
#   'infralittoral zone',
#   'polar biome',
#   'wetness of soil',
#   'mountain forest soil',
#   'umbrisol',
#   'hallway',
#   'glacial process',
#   'gravel',
#   'acid rock drainage',
#   'cleanroom',
#   'terrestrial ecosystem',
#   'shale',
#   'slush ice',
#   'marine coral reef fore reef',
#   'lake shore',
#   'marine biome',
#   'steel',
#   'halite',
#   'masonry cement',
#   'intermittent wetland',
#   'temperate mountain',
#   'rural area',
#   'montane',
#   'sea sand',
#   'oceanic subsurface zone',
#   'deciduous forest',
#   'lake coast',
#   'limestone',
#   'fen',
#   'intertidal ecosystem',
#   'intermittent pond',
#   'sandy desert',
#   'anthropogenic contamination feature',
#   'settlement',
#   'lahar',
#   'coastal shrimp pond',
#   'tea plantation',
#   'freshwater wetland ecosystem',
#   'montane shrubland biome',
#   'spring',
#   'saline marsh',
#   'phaeozem',
#   'animal habitation',
#   'pump',
#   'saprolite',
#   'nest of bird',
#   'cement',
#   'room',
#   'subalpine biome',
#   'strict nature reserve',
#   'uranium ore',
#   'plantation field',
#   'tube well',
#   'grain',
#   'acidity of water',
#   'human house',
#   'streams',
#   'river valley',
#   'seagrass meadow',
#   'stainless steel',
#   'underground',
#   'glacial ice',
#   'road',
#   'salt pan',
#   'strait',
#   'bovine dairy liquid manure',
#   'metropolitana',
#   'vegetated hill',
#   'saline sediment environment',
#   'coal mine',
#   'vineyard',
#   'tropical',
#   'hotspring',
#   'fly ash',
#   'bench',
#   'peat soil',
#   'heath',
#   'fracture water',
#   'wetland',
#   'muskeg',
#   'biosolids',
#   'grove',
#   'mycetome',
#   'blanket bog',
#   'agronomic process',
#   'coastal zone',
#   'aquatic ecosystem',
#   'rice field',
#   'oil contaminated soil',
#   'dry lake',
#   'freshwater',
#   'nitisol',
#   'suspended sediment',
#   'epilithon',
#   'boulder sediment',
#   'ballast water',
#   'estuarine mud',
#   'coffee plantation',
#   'tropical savanna biome',
#   'hydrothermal seep',
#   'ecosystem process',
#   'algal material',
#   'silage',
#   'oceanic abyssopelagic zone biome',
#   'tropical broadleaf forest biome',
#   'marine hydrothermal plume',
#   'area of scrub',
#   'respirable suspended particulate matter',
#   'ground water',
#   'water ice',
#   'agricultural land conversion',
#   'flood plain',
#   'wwtp',
#   'cold season',
#   'seafloor',
#   'aeolian lake',
#   'mucus material',
#   'alluvial paddy field soil',
#   'marine tidal flow zone',
#   'ocean',
#   'area of woody wetland',
#   'tropical marine upwelling biome',
#   'tropical broadleaf forest',
#   'alkaline environment',
#   'manure storage space',
#   'closed animal house',
#   'saline lake',
#   'talus',
#   'sea ice floe',
#   'constructed pavement',
#   'fluid',
#   'lime mudstone',
#   'sea floor',
#   'plain',
#   'abattoir',
#   'salt',
#   'estuary',
#   'human construction',
#   'gorge',
#   'terrace',
#   'sandstone',
#   'sake brewery',
#   'track',
#   'flat',
#   'oil seep',
#   'village biome',
#   'solar panel array',
#   'sea',
#   'xeric basin biome',
#   'liquid environmental material',
#   'marine snow',
#   'kelp forest',
#   'tissue',
#   'metal contaminated soil',
#   'wetland area',
#   'supratidal zone',
#   'pinyon juniper woodland',
#   'boundary layer',
#   'maar',
#   'tidal watercourse',
#   'potable water',
#   'sugar plantation',
#   'tar pit',
#   'solutional cave',
#   'paved parking lot',
#   'marine ecosystem',
#   'processing plant',
#   'brackish water environment',
#   'phone',
#   'marine bathyal zone biome',
#   'bathymodiolus gill tissue material',
#   'patio',
#   'highway',
#   'glacier surface',
#   'branch',
#   'peat extraction',
#   'deep marine sediment',
#   'desert sand',
#   'salt water',
#   'area of rocky shore',
#   'wet',
#   'forest fire',
#   'wadi',
#   'lock',
#   'intertidal zone',
#   'riverbank',
#   'chemically contaminated sediment',
#   'canyon',
#   'airplane',
#   'moraine',
#   'oxic water',
#   'ocean biome',
#   'marine coral reef crest',
#   'archipelago',
#   'research laboratory',
#   'aquaculture of animals',
#   'marine supralittoral zone',
#   'swamp ecosystem',
#   'gall',
#   'sea beach',
#   'neritic sea surface microlayer biome',
#   'cryosphere',
#   'creosote contaminated soil',
#   'humid air',
#   'ocean strait',
#   'subglacial',
#   'active permafrost layer',
#   'aquarium',
#   'active layer',
#   'hay',
#   'chaparral area',
#   'plane',
#   'building part',
#   'fermentation starter',
#   'vegetable garden soil',
#   'wetland ecosystem',
#   'food processing building',
#   'soil surface layer',
#   'petroleum',
#   'petting zoo',
#   'paper',
#   'stream water',
#   'digestive tract environment',
#   'ocean current',
#   'warehouse',
#   'manufactured plastic',
#   'mere',
#   'waste treatment plant',
#   'biomaterial containment unit',
#   'litter',
#   'wood',
#   'pyritic acid mine drainage',
#   'zoological garden',
#   'basin',
#   'forage material',
#   'vomit material',
#   'neonatal intensive care unit',
#   'rural stormwater',
#   'gas',
#   'emulsion',
#   'rainforest',
#   'retail store',
#   'dense settlement',
#   'drinking water treatment plant',
#   'small freshwater lake biome',
#   'temperate woodland biome',
#   'hypoxic water',
#   'sweat material',
#   'foamed plastic',
#   'flat glass',
#   'silty sediment',
#   'marine water mass',
#   'alkaline hot spring',
#   'freshwater stream biome',
#   'environmental material',
#   'artificial harbor',
#   'fecal environment',
#   'inlet',
#   'bog',
#   'undersea canyon',
#   'aquatic natural environment',
#   'moon',
#   'straw',
#   'soda lake sediment',
#   'thermal pollution',
#   'sugarcane bagasse',
#   'subtropical grassland biome',
#   'cow shed',
#   'aquaculture farm',
#   'lava field',
#   'alpine soil',
#   'interface layer',
#   'volcanic cone',
#   'bottle',
#   'temperate',
#   'microbial mat material',
#   'thermophilic sediment',
#   'feed storage space',
#   'forest canopy',
#   'meltwater',
#   'temperate savanna biome',
#   'tephra',
#   'marine reef',
#   'leptosol',
#   'pool',
#   'wet soil',
#   'bottom',
#   'hydrocarbon seep',
#   'paraffin',
#   'brownish colored sea ice',
#   'whale fall',
#   'dcm',
#   'deep',
#   'municipal landfill',
#   'mediterranean woodland biome',
#   'anthrosol',
#   'rocky sand',
#   'subtropical rainforest',
#   'activated sludge',
#   'quarry',
#   'snowfield',
#   'marine coral reef deep fore reef',
#   'crude oil',
#   'sand',
#   'rainforest biome',
#   'organic material',
#   'tidal flat',
#   'organic matter fall',
#   'water trough',
#   'oil refinery',
#   'neritic pelagic zone biome',
#   'piece of rock',
#   'headwater',
#   'fresh water aquarium',
#   'anthropogenic geographic feature',
#   'garbage dump',
#   'swamp area',
#   'pasture soil',
#   'reservoir',
#   'dust',
#   'marine coral reef back reef',
#   'thatch',
#   'intermittent reservoir',
#   'granular sediment',
#   'broad',
#   'continental temperate',
#   'atmospheric aerosolisation of dust',
#   'atoll',
#   'urban area',
#   'ice sheet',
#   'microplastic particle',
#   'desert area',
#   'drainage ditch',
#   'pumice',
#   'histosol',
#   'drought',
#   'area of deciduous forest',
#   'estuarine water',
#   'hotel',
#   'agricultural wastewater treatment plant',
#   'polar',
#   'manufacturing process',
#   'bodily fluid material',
#   'kettle',
#   'wet market',
#   'sewage',
#   'wooded area',
#   'estuarine open water upper water column',
#   'healthcare environment',
#   'cryosol',
#   'plumbing drain',
#   'boreal',
#   'military training area',
#   'fan',
#   'mud flat',
#   'river bed',
#   'volcanic soil',
#   'submarine canyon',
#   'sea cliff',
#   'chernozem',
#   'oceanic sea surface microlayer biome',
#   'marine environment',
#   'subtropical broadleaf forest',
#   'beehive',
#   'layer',
#   'urban pollution',
#   'area of open water',
#   'lithosphere',
#   'temperate evergreen needleleaf forest',
#   'marine oligotrophic desert',
#   'market',
#   'pockmark field',
#   'gold mine',
#   'plastisphere',
#   'factory',
#   'stalagmite',
#   'wind',
#   'air',
#   'river mouth',
#   'temperate grassland',
#   'peninsula',
#   'space',
#   'carcass',
#   'beach',
#   'desert pavement',
#   'lake bed',
#   'wood fall',
#   'biodegradation of plastic',
#   'durisol',
#   'community garden',
#   'regolith',
#   'coal',
#   'cerebrospinal fluid material',
#   'cropland ecosystem',
#   'cloud',
#   'stalactite',
#   'enriched soil',
#   'concentration of ammonium in liquid water',
#   'nest of termite',
#   'gypsum',
#   'enrichment culturing unit',
#   'coastal cliff',
#   'subtropical desert biome',
#   'gravel pit',
#   'metro',
#   'scum',
#   'red soil',
#   'microbial feature',
#   'biological waste material',
#   'marine littoral zone',
#   'contaminated sludge',
#   'thickness of topsoil',
#   'marine basaltic hydrothermal vent biome',
#   'depression',
#   'desert',
#   'moor',
#   'thermokarst',
#   'ravine',
#   'coastal inlet',
#   'frost',
#   'poultry litter',
#   'forest clearing',
#   'sea shore',
#   'boat',
#   'snowpack',
#   'moderately saline water',
#   'environment determined by a biofilm on an animal surface',
#   'glacial surface layer',
#   'tropical rainforest biome',
#   'plant environment',
#   'airport',
#   'anthracite',
#   'mangrove swamp',
#   'public park',
#   'mining',
#   'area of dwarf scrub',
#   'anoxic lake',
#   'agricultural soil',
#   'swimming pool',
#   'faeces material',
#   'breast milk material',
#   'runoff',
#   'grassland',
#   'fresh animal manure',
#   'area of gramanoid or herbaceous vegetation',
#   'mountain spur',
#   'saline water environment',
#   'sedimentary rock',
#   'alpine biome',
#   'wet meadow ecosystem',
#   'water tap',
#   'tar',
#   'environment determined by a metazoan secretion',
#   'mesoscale marine eddy',
#   'permafrost thawing process',
#   'epiphyton',
#   'watercraft',
#   'vegetation layer',
#   'active chimney',
#   'national forest',
#   'coastal scrubland',
#   'face skin environment',
#   'ecosystem',
#   'mine tailing',
#   'fine sand',
#   'wildfire',
#   'arable',
#   'environmental system determined by a material',
#   'oligotrophic lake',
#   'particulate matter',
#   'clay loam',
#   'intermittent estuary',
#   'tundra ecosystem',
#   'estuarine coastal upper water column',
#   'run',
#   'biofilter',
#   'fermentation pit',
#   'marine coral reef buttress zone',
#   'oceanic mesopelagic zone biome',
#   'bank',
#   'metal',
#   'river channel',
#   'root nodule',
#   'stream',
#   'medical instrument',
#   'vent',
#   'subpolar coniferous forest biome',
#   'calcareous ooze',
#   'lava flow',
#   'rural settlement',
#   'forested wetland',
#   'mountains',
#   'brackish lake',
#   'periphyton',
#   'pier',
#   'church',
#   'muddy soil',
#   'field',
#   'soil texture',
#   'roof',
#   'area of barren land',
#   'zoo',
#   'crustal fluid',
#   'desert ecosystem',
#   'environment determined by a biofilm on a plant surface',
#   'marginal sea biome',
#   'algal bloom',
#   'building wall',
#   'glasshouse',
#   'woodland biome',
#   'roadside soil',
#   'marine abyssal zone biome',
#   'animal aquaculture process',
#   'brackish pond',
#   'sewage treatment plant',
#   'indoor kitchen',
#   'excreta material',
#   'coal mining',
#   'mine',
#   'harbor',
#   'atmospheric aerosol',
#   'monomictic lake',
#   'area of sea ice',
#   'surface sediment',
#   'shallow marine sediment',
#   'urine material',
#   'coastal water body',
#   'rhizoplane',
#   'rangeland biome',
#   'silt',
#   'marine environmental zone',
#   'arable or pasturable land',
#   'coastal ocean water',
#   'marine hydrothermal vent biome',
#   'waterfall',
#   'fertilized soil',
#   'seashore',
#   'alas',
#   'fresh water body',
#   'erosionally enriched glacial ice',
#   'river plume',
#   'animal waste material',
#   'tidal mudflat',
#   'botanical garden',
#   'mangrove island',
#   'agricultural research station',
#   'anthropogenic environmental material',
#   'upland soil',
#   'environmental system process',
#   'temperate mixed needleleaf forest',
#   'aqueduct',
#   'soil',
#   'inshore',
#   'pine grove',
#   'active anaerobic enrichment culturing unit',
#   'mountain pass',
#   'estuarine open water lower water column',
#   'cliff',
#   'puddle',
#   'irrigated field',
#   'pit',
#   'topsoil',
#   'nature reserve',
#   'urban stormwater',
#   'stromatolite mat',
#   'pasture',
#   'refrigerator',
#   'boulder',
#   'mineral material',
#   'bioreactor',
#   'temperate desert biome',
#   'hydroelectric reservoir',
#   'swamp forest',
#   'greenhouse soil',
#   'mangrove sediment',
#   'flood',
#   'microplastic',
#   'trophosome',
#   'lotic water body',
#   'neritic epipelagic zone biome',
#   'muddy water',
#   'cobble',
#   'wash',
#   'coastal area',
#   'biological product',
#   'water filter',
#   'sea state',
#   'mesotrophic water',
#   'vineyards',
#   'volcanic feature',
#   'forest ecosystem',
#   'loam',
#   'shop',
#   'test reactor',
#   'nest of ant',
#   'first year ice',
#   'domestic garden',
#   'mediterranean grassland biome',
#   'landlocked sea',
#   'concrete wall',
#   'street',
#   'mountain',
#   'mangrove biome soil',
#   'hide',
#   'rubber plantation',
#   'marine sponge reef biome',
#   'bone element environment',
#   'finfish farming process',
#   'mountain summit',
#   'freshwater stream',
#   'agricultural environmental material',
#   'sandy loam',
#   'thermocline',
#   'planktonic material',
#   'dilution basin mediterranean sea biome',
#   'crust',
#   'sea grass bed',
#   'concrete road',
#   'soil layer',
#   'nursery',
#   'grassland soil',
#   'root matter',
#   'gypsisol',
#   'window',
#   'sediment environment',
#   'woodland ecosystem',
#   'plaster',
#   'alluvial sediment',
#   'farmyard manure',
#   'marine biota',
#   'soil environment',
#   'acid rain',
#   'soil ph',
#   'upper montane',
#   'alkaline water',
#   'hospital',
#   'fish hatchery',
#   'current',
#   'aquifer',
#   'mudstone',
#   'speleothem',
#   'pond water',
#   'shelf',
#   'environment determined by a plant substance',
#   'podzol',
#   'agriculture',
#   'atmosphere',
#   'composting toilet',
#   'contaminated air',
#   'area of developed open space',
#   'lava',
#   'catchment',
#   'ice piedmont',
#   'temperate deciduous broadleaf forest',
#   'tropical mountain',
#   'sandy soil',
#   'palsa mire',
#   'methane clathrate',
#   'open sea',
#   'understory',
#   'peat bog',
#   'temperate marginal sea biome',
#   'tropical marginal sea biome',
#   'oil reservoir',
#   'compost soil',
#   'tropical forest',
#   'cloud water',
#   'salt spring',
#   'poultry hatchery',
#   'continental shelf',
#   'underground water body',
#   'oasis',
#   'scrub',
#   'upland',
#   'pond soil',
#   'calf shed',
#   'marine sediment',
#   'transportation',
#   'termite nest',
#   'oil palm plantation',
#   'brewery',
#   'lake with an anoxic hypolimnion',
#   'ramsar site',
#   'saline lake sediment',
#   'water',
#   'paint',
#   'temperate shrubland biome',
#   'frozen soil',
#   'pebble',
#   'sludge',
#   'abyssal plain',
#   'meadow soil',
#   'littoral zone',
#   'air vent',
#   'water well',
#   'cambisol',
#   'alluvial plain',
#   'pulp and paper wastewater',
#   'waterborne particulate matter',
#   'blood material',
#   'marine neritic benthic zone biome',
#   'ground',
#   'swamp',
#   'bile material',
#   'brine pool',
#   'watershed',
#   'environmental system determined by an organism',
#   'artificial reef',
#   'sea loch',
#   'stream sediment',
#   'drinking water',
#   'solfatara',
#   'fjord',
#   'gas well',
#   'residential building',
#   'montane desert biome',
#   'temperate mixed forest biome',
#   'planted forest',
#   'anthropised ecosystem',
#   'biome',
#   'ice',
#   'temperate rainforest',
#   'food shop',
#   'canopy',
#   'grassland biome',
#   'landfill',
#   'glacial feature',
#   'saline pan',
#   'sandbar',
#   'tropical shrubland biome',
#   'ocean basin',
#   'open lake',
#   'aircraft',
#   'gas hydrate',
#   'lava cave',
#   'epilimnion',
#   'sea surface layer',
#   'freshwater river biome',
#   'lake bottom mud',
#   'temperature of water',
#   'plant matter fall',
#   'nest',
#   'monument',
#   'mountain range',
#   'organic farm',
#   'prairie',
#   'loamy sand',
#   'eutrophic water',
#   'permafrost',
#   'exterior wall',
#   'biocrust',
#   'biofilm',
#   'marine faunal bed',
#   'plant pot',
#   'biochar',
#   'litter layer',
#   'geyser',
#   'animal house',
#   'habitat',
#   'indoor toilet',
#   'animal litter',
#   'metamorphic rock',
#   'volcanic ash',
#   'fecal material',
#   'roadway',
#   'industrial waste',
#   'oil field production water',
#   'grassland ecosystem',
#   'urban biome',
#   'ultisol',
#   'water pollution',
#   'pipeline network',
#   'mediterranean sea biome',
#   'cooling water',
#   'anaerobic mud',
#   'anoxic water',
#   'environment',
#   'thermokarst depression',
#   'biofouling',
#   'tectonic lake',
#   'mixed forest biome',
#   'aquaculture process',
#   'estuarine tidal riverine open water upper water column',
#   'stagnosol',
#   'mediterranean forest',
#   'slurry',
#   'well',
#   'barrier reef',
#   'switch',
#   'sclerophyllous forest',
#   'fast ice',
#   'dairy',
#   'hydrothermal fluid',
#   'carr',
#   'marine subtidal rocky reef',
#   'anatomical entity environment',
#   'dry valley',
#   'hummock',
#   'alpine tundra biome',
#   'ant hill',
#   'waterhole',
#   'coastal plain',
#   'rock shelter',
#   'tropical lowland evergreen broadleaf rain forest',
#   'organic waste material',
#   'ria',
#   'nitrogen cycling',
#   'undersea feature',
#   'brackish water',
#   'atmospheric boundary layer',
#   'trail',
#   'red clay soil',
#   'sea cucumber gut',
#   'mushroom compost',
#   'mangrove biome sediment',
#   'textile',
#   'daqu',
#   'geothermally active field',
#   'palsa',
#   'subtropical savanna biome',
#   'ornithogenic soil',
#   'sandy sediment',
#   'public road',
#   'temperature of soil',
#   'stormwater',
#   'lake inlet',
#   'forest biome',
#   'season',
#   'mixed forest',
#   'hydrosphere',
#   'oil',
#   'open water',
#   'parking lot',
#   'nature conservation',
#   'tropical biome',
#   'savanna biome',
#   'aerosolisation of dust',
#   'interstitial fluid material',
#   'mediterranean biome',
#   'mesotrophic lake',
#   'campus',
#   'conifer woodland',
#   'drift ice',
#   'agricultural waste material',
#   'anaerobic sludge',
#   'tropical moist broadleaf forest biome',
#   'saline wetland',
#   'neritic mesopelagic zone biome',
#   'old plant',
#   'industrial building',
#   'large freshwater lake biome',
#   'floodplain',
#   'savannah',
#   'mangrove biome',
#   'clay sediment',
#   'area of tundra',
#   'sediment permeated by saline water',
#   'air pressure',
#   'divergent plate boundary',
#   'iron mine',
#   'honeycomb',
#   'tropical dry broadleaf forest biome',
#   'plant litter',
#   'borehole',
#   'anaerobic sediment',
#   'anaerobic sludge blanket reactor',
#   'marine hydrothermal vent',
#   'lignite',
#   'usage of an environment for transportation',
#   'temperate broadleaf evergreen forest',
#   'volcanic island',
#   'rain forest',
#   'solonetz',
#   'dry river',
#   'environmental system',
#   'manufactory',
#   'mineral horizon',
#   'mediterranean forest biome',
#   'sterile water',
#   'cloud forest',
#   'ephemeral spring',
#   'anaerobic bioreactor',
#   'bar',
#   'holothurian digestive tract contents',
#   'marine cold seep biome',
#   'mineral spring',
#   'amenity lake',
#   'temperate biome',
#   'lava tube',
#   'tropical dry broadleaf forest',
#   'artificial lake',
#   'oceanic island',
#   'large river biome',
#   'marine sublittoral zone',
#   'terrigenous sediment',
#   'fumarole',
#   'natural wax',
#   'natural harbor',
#   'door',
#   'concentration basin mediterranean sea biome',
#   'forest floor',
#   'pus material',
#   'continental margin',
#   'coastal sea water',
#   'bird nest',
#   'phreatic zone',
#   'autoclaved sand',
#   'reef',
#   'freshwater marsh',
#   'sterile water environment',
#   'drinking water reservoir',
#   'paddy field',
#   'animal waste',
#   'seagrass bed',
#   'concrete',
#   'poultry manure',
#   'trench',
#   'rocky slope',
#   'marine mud',
#   'marine reef biome',
#   'bedrock',
#   'polar tundra ecosystem',
#   'aldabra island xeric scrub ecoregion',
#   'desert scrubland',
#   'shingle beach',
#   'marine aphotic zone',
#   'organic object formed through microbial activity',
#   'petroleum reservoir',
#   'saline water aquarium',
#   'railway',
#   'coarse beach sand',
#   'pellet',
#   'snow',
#   'cove',
#   'sound',
#   'table',
#   'land use process',
#   'environment associated with a fungal tissue',
#   'temperate broadleaf forest',
#   'burnt soil',
#   'groundwater flow',
#   'ridge',
#   'limestone cave',
#   'steppe',
#   'cave system',
#   'cave',
#   'temperate grassland biome',
#   'hadalpelagic zone',
#   'brush fire',
#   'temperate mixed broadleaf forest',
#   'temperate ecosystem',
#   'fall',
#   'lagoon',
#   'secondary sludge',
#   'underground stream',
#   'environmental monitoring',
#   'circalittoral zone',
#   'area of cropland',
#   ...},
#  'ncit': {'sinus',
#   'pharmacy',
#   'endometrial',
#   'fraxinus excelsior',
#   'petal',
#   'mouth',
#   'stem',
#   'amd',
#   'plants',
#   'cod',
#   'human cornea',
#   'cardiac valve',
#   'epithelium',
#   'outside',
#   'island',
#   'organs',
#   'airway',
#   'transposon',
#   'stent',
#   'arthropoda',
#   'brm',
#   'exocarp',
#   'intermediate',
#   'zebrafish',
#   'pharmaceutical',
#   'cabbage',
#   'embryo',
#   'mussel',
#   'mouse feces',
#   'ceca',
#   'sponge',
#   'white',
#   'kefir',
#   'no information',
#   'vagina',
#   'lui',
#   'whole blood',
#   'mia',
#   'dried blood spot',
#   'peripheral',
#   'aqua',
#   'fruit juice',
#   'alnus glutinosa',
#   'infected',
#   'pinus strobus',
#   'genome',
#   'middle ear',
#   'uti',
#   'duodenal mucosa',
#   'periodontitis',
#   'microbial solid culture',
#   'box',
#   'peripheral blood',
#   'toe',
#   'mat',
#   'sap',
#   'crab',
#   'degradation',
#   'rural area',
#   'calculus',
#   'expectorate',
#   'ppb',
#   'reagent',
#   'april',
#   'wrapper',
#   'opened',
#   'gastric fluid',
#   'bee pollen',
#   'formula',
#   'microbial culture',
#   'intestinal epithelium',
#   'intestinal',
#   'castanea sativa',
#   'spring',
#   'object',
#   'radius',
#   'liver abscess',
#   'pump',
#   'negative control',
#   'cement',
#   'cuticle',
#   'spinal',
#   'hand',
#   'room',
#   'kombucha',
#   'july',
#   'whole animal',
#   'periodontium',
#   'grain',
#   'forehead',
#   'no treatment',
#   'beef',
#   'growth medium',
#   'common cold',
#   'enterocytes',
#   'sbr',
#   'exocrine gland',
#   'epithelial',
#   'chicken',
#   'sterile',
#   'nunavut',
#   'body fluid or substance',
#   'laboratory',
#   'skin ulcer',
#   'svalbard',
#   'eastern oyster',
#   'neighborhood',
#   'swab',
#   'skin lesion',
#   'chamber',
#   'brown rice',
#   'bakers yeast',
#   'arthropod',
#   'microbial dna',
#   'nodule',
#   'cancer',
#   'vessel',
#   'lpa',
#   'zeolite',
#   'keratitis',
#   'tonsil',
#   'untreated control',
#   'upper airway',
#   'domestic animal',
#   'pubis',
#   'lingual',
#   'australia',
#   'aggregates',
#   'dzn',
#   'blood agar',
#   'other',
#   'preterm',
#   'water ice',
#   'june',
#   'artificial',
#   'stella',
#   'buffalo',
#   'equus caballus',
#   'bile duct',
#   'distant',
#   'vascular plant',
#   'culture medium',
#   'pressure',
#   'medicinal leech',
#   'cae',
#   'in patient',
#   'hypodermis',
#   'whole',
#   'not determined',
#   'contaminated',
#   'venezuela',
#   'input',
#   'radish',
#   'cheek mucosa',
#   'powder',
#   'storage',
#   'broiler chicken',
#   'fava bean',
#   'edna',
#   'arsenic',
#   'cucumber',
#   'mozambique',
#   'buffer',
#   'singapore',
#   'sebum',
#   'seminal plasma',
#   'usa',
#   'nasal wash',
#   'animals',
#   'cat',
#   'classroom',
#   'vulva',
#   'duodenal biopsy',
#   'plate',
#   'lower gastrointestinal tract',
#   'female genital tract',
#   'talus',
#   'healthy subject',
#   'juglans regia',
#   'thyroid',
#   'tea plant',
#   'bronchoalveolar lavage fluid',
#   'fluid',
#   'abalone',
#   'endocarditis',
#   'bell pepper',
#   'nacl',
#   'in vitro',
#   'dropping',
#   'liver tissue',
#   'pcr',
#   'rte',
#   'salt',
#   'nano',
#   'ventral',
#   'minas gerais',
#   'bacterium',
#   'hong kong',
#   'mouse cerebellum',
#   'upper',
#   'new mexico',
#   'pancreatic fluid',
#   'sacrum',
#   'ileum',
#   'pear',
#   'watermelon flavor',
#   'sea',
#   'cardia',
#   'tissue',
#   'new zealand',
#   'male genitalia',
#   'exudate',
#   'obesity',
#   'muridae',
#   'sole',
#   'nose swab',
#   'equine',
#   'swine',
#   'diet',
#   'vaginal epithelium',
#   'breast',
#   'mus musculus',
#   'collected',
#   'stomach',
#   'new york',
#   'crp',
#   'butcher',
#   'banana',
#   'pretreatment',
#   'rna',
#   'developmental process',
#   'initial',
#   'throat swab',
#   'rye',
#   'microbial',
#   'netherlands',
#   'phone',
#   'citrus fruit',
#   'midgut',
#   'nasopharyngeal swab',
#   'biopsy',
#   'chest',
#   'female',
#   'sanfilippo syndrome',
#   'attached',
#   'mucus',
#   'taiwan',
#   'bos taurus',
#   'empty',
#   'branch',
#   'viscera',
#   'not identified',
#   'natural',
#   'alaska',
#   'corpus',
#   'contact lens',
#   'epi',
#   'saline',
#   'infant botulism',
#   'fagus sylvatica',
#   'liquid',
#   'ascites',
#   'lock',
#   'nasal mucus',
#   'gram',
#   'rectal swab',
#   'bacterial disease',
#   'cdna',
#   'south',
#   'kidney',
#   'tissue bank',
#   'residue',
#   'carbon',
#   'recipient',
#   'medical',
#   'bladder',
#   'patch',
#   'california',
#   'domestic pig',
#   'gall',
#   'university',
#   'blank sample',
#   'digestive system',
#   'face',
#   'community',
#   'ballast',
#   'clavicle',
#   'spinach',
#   'plane',
#   'stool',
#   't cell lymphoma',
#   'ron',
#   'oncology department',
#   'digestive',
#   'cnr',
#   'bile fluid',
#   'unspecified',
#   'background',
#   'probiotic',
#   'intestinal microbiome',
#   'intrahepatic cholangiocarcinoma',
#   'normal skin',
#   'cervical intraepithelial neoplasia',
#   'rabbit',
#   'paper',
#   'integrated',
#   'device',
#   'bariatric surgery',
#   'refuse',
#   'ocimum basilicum',
#   'birds',
#   'feces',
#   'bal',
#   'drc',
#   'wood',
#   'gallus gallus',
#   'basin',
#   'not assigned',
#   'antarctica',
#   'oscc',
#   'gas',
#   'emulsion',
#   'falkland islands',
#   'quartz',
#   'nigeria',
#   'dermatosis',
#   'bronchial lavage',
#   'research facilities',
#   'liver',
#   'corn',
#   'systemic',
#   'nasal polyp',
#   'terminal ileum',
#   'sham',
#   'denmark',
#   'bog',
#   'kombucha tea',
#   'chile',
#   'smoker',
#   'straw',
#   'reproductive tissue',
#   'eucalyptus',
#   'csf',
#   'bladder tumor',
#   'diabetes',
#   'cultured cell line',
#   'inside',
#   'bottle',
#   'urinary tract',
#   'mammary gland',
#   'molar',
#   'pool',
#   'eyelid',
#   'indirect',
#   'miscellaneous',
#   'phosphate',
#   'high density polyethylene',
#   'bottom',
#   'system',
#   'sto',
#   'healthcare organization',
#   'paraffin',
#   'exercise',
#   'dcm',
#   'fish',
#   'tbi',
#   'deep',
#   'food product',
#   'titanium',
#   'negative',
#   'month',
#   'elbow',
#   'nitric oxide',
#   'dental calculus',
#   'erc',
#   'gbm',
#   'cyst',
#   'ischium',
#   'cold',
#   'interface',
#   'czech republic',
#   'agricultural workers',
#   'http',
#   'petri dish',
#   'dental',
#   'vic',
#   'argentina',
#   'amniotic fluid',
#   'terminal',
#   'hip',
#   'uncertain',
#   'computer',
#   'hypoxia',
#   'mar',
#   'pork',
#   'reservoir',
#   'dust',
#   'cjd',
#   'organic',
#   'broad',
#   'urinary',
#   'wound',
#   'construct',
#   'colon',
#   'solid',
#   'colony',
#   'juice',
#   'fourth',
#   'dmem',
#   'any',
#   'string',
#   'conventional',
#   'government hospital',
#   'oral',
#   'msi',
#   'potting',
#   'russia',
#   'phleum pratense',
#   'preterm infant',
#   'bone tumor',
#   'peanut',
#   'gos',
#   'spinosad',
#   'lung biopsy',
#   'naris',
#   'caffeine',
#   'forestomach',
#   'analysis',
#   'fan',
#   'days',
#   'colon tumor',
#   'treatment plan',
#   'oral mucosa',
#   'peritoneal cavity',
#   'citrate',
#   'municipality',
#   'layer',
#   'unknown',
#   'inguinal lymph node',
#   'gastrointestinal tract',
#   'galactose',
#   'fabric',
#   'europe',
#   'lung fluid',
#   'fmt',
#   'prokaryote',
#   'indonesia',
#   'dessert',
#   'mixture',
#   'air',
#   'glutamine',
#   'male reproductive system',
#   'perianal',
#   'year',
#   'bait',
#   'biological',
#   'don',
#   'space',
#   'sugar',
#   'avian',
#   'rape',
#   'lysozyme',
#   'barley',
#   'cylinder',
#   'epidermis',
#   'testis',
#   'nasal mucosa',
#   'blade',
#   'alimentary canal',
#   'cheek',
#   'ant',
#   'fetal kidney',
#   'ectocervix',
#   'escherichia coli',
#   'hdpe',
#   'pylorus',
#   'blue',
#   'time',
#   'cloud',
#   'pet',
#   'in the field',
#   'secondary',
#   'external acoustic meatus',
#   'total rna',
#   'invasion',
#   'azerbaijan',
#   'hscr',
#   'cont',
#   'intestinal content',
#   'phi',
#   'eye',
#   'hydrocarbon',
#   'mastitis',
#   'kimchi',
#   'spleen',
#   'cornea',
#   'skin tissue',
#   'undetermined',
#   'bread',
#   'canine',
#   'inferior turbinate',
#   'depression',
#   'thawed',
#   'site',
#   'moor',
#   'end stage renal failure',
#   'illinois',
#   'slow',
#   'anaerobic',
#   'ambient',
#   'adjacent',
#   'syringe',
#   'gallus gallus domesticus',
#   'urbanized area',
#   'gastric',
#   'madagascar',
#   'beet',
#   'tibia',
#   'alcoholic beverage',
#   'scrape',
#   'wrist',
#   'arm skin',
#   'meat',
#   'null',
#   'sawdust',
#   'pharynx',
#   'cervical',
#   'olea europaea',
#   'slit lamp',
#   'amphibian',
#   'antecubital fossa',
#   'otorrhea',
#   'scraping',
#   'sites',
#   'filler',
#   'riboflavin',
#   'oral microbiota',
#   'stage',
#   'stool sample',
#   'colon mucosa',
#   'pleural fluid',
#   'oropharyngeal',
#   'not obtained',
#   'protective agent',
#   'nematoda',
#   'green',
#   'tar',
#   'dental caries',
#   'respiratory system',
#   'duodenal fluid',
#   'tch',
#   'protoplast',
#   'soc',
#   'intestinal contents',
#   'organoid',
#   'veal',
#   'cub',
#   'dental exam',
#   'gelatin',
#   'bird',
#   'jejunum',
#   'lung lavage',
#   'tear',
#   'food industry',
#   'menyanthes trifoliata',
#   'needle',
#   'blood vessel',
#   'hydrophilic',
#   'mucosal biopsy',
#   'genitourinary system',
#   'west',
#   'slit lamp examination',
#   'israel',
#   'cow milk',
#   'late',
#   'run',
#   'serum',
#   'pacemaker',
#   'parietal',
#   'sweden',
#   'activated carbon',
#   'frozen',
#   'winter',
#   'cervical tumor',
#   'hours',
#   'anal sac',
#   'bank',
#   'metal',
#   'unit',
#   'root nodule',
#   'sibling',
#   'organism part',
#   'oral gavage',
#   'saliva',
#   'neutral',
#   'church',
#   'field',
#   'specimen',
#   'duckweed',
#   'human bone',
#   'jelly',
#   'light',
#   'eye discharge',
#   'abdominal cavity',
#   'november',
#   'uruguay',
#   'salar',
#   'intestinal microflora',
#   'stomach mucosa',
#   'ssr',
#   'fresh frozen',
#   'insecta',
#   'white oak',
#   'post',
#   'diverticulitis',
#   'buttock',
#   'ini',
#   'crypt',
#   'sycamore',
#   'pdf',
#   'fin',
#   'fingertip',
#   'coal mining',
#   'scallop',
#   'mine',
#   'india',
#   'common bile duct',
#   'pineapple',
#   'south america',
#   'ear',
#   'sfa',
#   'not recorded',
#   'carpinus betulus',
#   'uninfected',
#   'gro',
#   'bronchial brushing',
#   'nhc',
#   'nuclear',
#   'molecular',
#   'cerebrospinal fluid',
#   'garbage',
#   'mint flavor',
#   'abdominal fluid',
#   'pea',
#   'high ph',
#   'disease',
#   'ghana',
#   'alas',
#   'canada',
#   'ct a',
#   'teat',
#   'raspberry',
#   'spb',
#   'bead',
#   'psu',
#   'lung tissue',
#   'spores',
#   'bud',
#   'alabama',
#   'pit',
#   'sputum',
#   'arctic',
#   'paranasal sinuses',
#   'no data',
#   'menthol',
#   'bsl',
#   'uterine cervix',
#   'refrigerator',
#   'march',
#   'fetal',
#   'control',
#   'emergency',
#   'strain',
#   'walnut',
#   'positive control',
#   'gastric mucosa',
#   'acidic',
#   'duck',
#   'wine',
#   'mdf',
#   'bacon',
#   'celsius degree',
#   'wash',
#   'bht',
#   'biological product',
#   'salivary glands',
#   'lavage fluid',
#   'perineum',
#   'hard palate',
#   'beer',
#   'colostrum',
#   'pots',
#   'non malignant',
#   'yes',
#   'macaca mulatta',
#   'meriones unguiculatus',
#   'ilium',
#   'rdna',
#   'bat',
#   'shop',
#   'grape',
#   'pathogen',
#   'engineering',
#   'street',
#   'northeast',
#   'venous',
#   'before treatment',
#   'acetic acid',
#   'in situ',
#   'sputum sample',
#   'digestive tube',
#   'reproductive tract',
#   'unfiltered',
#   'crust',
#   'alveolus',
#   'nursery',
#   'vaginal discharge',
#   'biosample',
#   'compact',
#   'fresh',
#   'taxus baccata',
#   'polyp',
#   'pdb',
#   'stationary phase',
#   'aqueous humour',
#   'window',
#   'gingival sulcus',
#   'nasopharynx',
#   'culture',
#   'gingival',
#   'laboratory test',
#   'plaster',
#   'humerus',
#   'excretion',
#   'lower respiratory system',
#   'nostril',
#   'nature',
#   'high',
#   'thoracic vertebra',
#   'vitamin b',
#   'ocular',
#   'alkaline water',
#   'hospital',
#   'mouse colon',
#   'exhibit',
#   'ingredient',
#   'current',
#   'cell line',
#   'and',
#   'dlbcl',
#   'cardiovascular',
#   'pcl',
#   'healthy',
#   'tonsillar crypt',
#   'eva',
#   'tooth abscess',
#   'abdominal',
#   'tissue sample',
#   'ulcerative colitis',
#   'eczema',
#   'agriculture',
#   'atmosphere',
#   'reference',
#   'frontal',
#   'rcd',
#   'gut epithelium',
#   'ireland',
#   'mutant',
#   'fusarium',
#   'squash',
#   'pla',
#   'rodent',
#   'biological sample',
#   'health',
#   'lung infection',
#   'porcine',
#   'copd',
#   'reunion',
#   'aerobic',
#   'beaver',
#   'blackberry',
#   'rss',
#   'cover',
#   'oasis',
#   'faces',
#   'western european',
#   'food',
#   'belgium',
#   'alberta',
#   'leu',
#   'cavities',
#   'bed',
#   'usd',
#   'company',
#   'transportation',
#   'controlled',
#   'sigmoid colon',
#   'sep',
#   'rvd',
#   'inf',
#   'water',
#   'paint',
#   'sucrose',
#   'cane',
#   'evening',
#   'fiji',
#   'sludge',
#   'gill',
#   'mayotte',
#   'fractionation',
#   'xpc',
#   'ulna',
#   'bulk',
#   'paranasal sinus',
#   'degraded',
#   'animal',
#   'thailand',
#   'hau',
#   'dock',
#   'azoxymethane',
#   'granules',
#   'fvb',
#   'contamination',
#   'tape',
#   'mix',
#   'olive',
#   'neem',
#   'urinary bladder',
#   'electrode',
#   'rep',
#   'buccal swab',
#   'drinking water',
#   'heart',
#   'apple juice',
#   'sweat',
#   'bronchoalveolar lavage',
#   'drinker',
#   'ice',
#   'ovary',
#   'bronchoscope',
#   'saccharin',
#   'gen',
#   'treated',
#   'tissues',
#   'msm',
#   'location',
#   'seminal fluid',
#   'anal canal',
#   'epithelial cells',
#   'gastric juice',
#   'block',
#   'tbc',
#   'fallopian tube',
#   'posttreatment',
#   'sant',
#   'bones',
#   'hormone',
#   'rhesus macaque',
#   'iron',
#   'cream',
#   'cord blood',
#   'rerun',
#   'oab',
#   'oral microbiome',
#   'dentin',
#   'third',
#   'barrel',
#   'trap',
#   'ammonia',
#   'environmental',
#   'axillary lymph node',
#   'liquor',
#   'sda',
#   'protozoa',
#   'vegetable',
#   'lumen',
#   'back',
#   'fur',
#   'dioxane',
#   'rose',
#   'reproductive',
#   'oxide',
#   'evisceration',
#   'parent',
#   'environmental dna',
#   'nhs',
#   'subglottis',
#   'transition zone',
#   'tissue core',
#   'surface',
#   'org',
#   'twig',
#   'necrotic lesion',
#   'prepuce',
#   'lysis',
#   'industrial waste',
#   'rectal',
#   'caenorhabditis elegans',
#   'nob',
#   'transfer',
#   'tail',
#   'mandible',
#   'colorectal',
#   'bac',
#   'environment',
#   'nasal cavity',
#   'buccal cells',
#   'sao paulo',
#   'slurry',
#   'well',
#   'maxillary sinus',
#   'provided',
#   'mature',
#   'sii',
#   'switch',
#   'shrimp',
#   'yeast',
#   'sequence',
#   'fecal',
#   'fast',
#   'non',
#   'homo sapiens',
#   'breath',
#   'pei',
#   'vancomycin',
#   'segment',
#   'scalp',
#   'reproduction',
#   'maternal',
#   'millet',
#   'outpatient',
#   'cassette',
#   'groin',
#   'carrot',
#   'med',
#   'glucose',
#   'calf',
#   'ria',
#   'plant',
#   'collodion',
#   'antibiotic',
#   'mouse ileum',
#   'mammal',
#   'trail',
#   'microorganism',
#   'blood',
#   'senegal',
#   'lymphoid tissue',
#   'surgical',
#   'tsa',
#   'membranous',
#   'abdomen',
#   'chinese',
#   'pollen',
#   'guadeloupe',
#   'foam',
#   'drosophila',
#   'dorsum of tongue',
#   'glass fiber',
#   'physiology',
#   'mouse gastrointestinal tract',
#   'season',
#   'week',
#   'rinse',
#   'soy',
#   'oil',
#   'ctrl',
#   'not available',
#   'probe',
#   'pda',
#   'abscess',
#   'mammary',
#   'olfactory mucosa',
#   'dcb',
#   'grade',
#   'rat cecum',
#   'amaranth',
#   'synthetic',
#   'glp',
#   'intestinal flora',
#   'host',
#   'kidney stone',
#   'diaper',
#   'poland',
#   'palpebral fissure',
#   'intestine',
#   'panama',
#   'single cell',
#   'inulin',
#   'mouse intestine',
#   'mother',
#   'pleural effusion',
#   'cotton',
#   'air pressure',
#   'identifiable',
#   'chlorhexidine',
#   'airborne particulate matter',
#   'native',
#   'defecation',
#   'acetate',
#   ...},
#  'agro': {'agricultural experimental plot',
#   'agricultural process',
#   'agroforestry',
#   'alley cropping',
#   'animal feeding equipment',
#   'animal manure',
#   'augmentation',
#   'biochar',
#   'biofertilizer',
#   'biological control',
#   'block',
#   'buffer',
#   'chicken litter',
#   'column',
#   'conventional tillage',
#   'crop',
#   'crop residue',
#   'crop rotation',
#   'cropping system',
#   'experiment',
#   'farmyard manure',
#   'fertilization',
#   'fertilization process',
#   'field area',
#   'field margin',
#   'glasshouse',
#   'greenhouse',
#   'guano',
#   'harvesting',
#   'husk',
#   'mineral fertilizer',
#   'moist',
#   'nitrogen fertilizer',
#   'organic fertilizer',
#   'parcel',
#   'plot',
#   'pot',
#   'poultry litter',
#   'poultry manure',
#   'rainfed',
#   'relative humidity',
#   'research station field',
#   'ridge',
#   'rotation',
#   'seedling',
#   'sequence',
#   'shelterbelt',
#   'soil sample',
#   'ssti',
#   'tillage',
#   'treatment',
#   'trial',
#   'vermicompost',
#   'water tank'},
#  'snomed': {'sinus',
#   'pharmacy',
#   'metallic material',
#   'cod',
#   'lake water',
#   'epithelium',
#   'aedes albopictus',
#   'island',
#   'cold water',
#   'stent',
#   'diabetic foot ulcer',
#   'chrysanthemum',
#   'breast normal',
#   'intermediate',
#   'cabbage',
#   'mussel',
#   'exposure to environmental pollution',
#   'meters',
#   'sponge',
#   'wool',
#   'whole blood',
#   'nasopharyngeal aspirate',
#   'peripheral',
#   'butterfly',
#   'hospital acquired',
#   'fruit juice',
#   'alnus glutinosa',
#   'genome',
#   'hallway',
#   'gravel',
#   'periodontitis',
#   'shale',
#   'peripheral blood',
#   'wild',
#   'crab',
#   'cytology brush',
#   'calculus',
#   'ppb',
#   'perianal swab',
#   'garage',
#   'apis cerana',
#   'yaan',
#   'bee pollen',
#   'microbial culture',
#   'linum usitatissimum',
#   'ventilator associated pneumonia',
#   'intestinal',
#   'high altitude',
#   'cervical swab',
#   'object',
#   'radius',
#   'pump',
#   'cement',
#   'cervus elaphus',
#   'grain',
#   'beef',
#   'common cold',
#   'aedes aegypti',
#   'dark',
#   'road',
#   'agrochemical',
#   'controlled temperature',
#   'coal mine',
#   'sterile',
#   'nunavut',
#   'laboratory',
#   'skin ulcer',
#   'anal swab',
#   'swab',
#   'skin lesion',
#   'brown rice',
#   'zantedeschia aethiopica',
#   'nodule',
#   'vessel',
#   'prosopis juliflora',
#   'cichorium intybus',
#   'plant material',
#   'keratitis',
#   'lingual',
#   'australia',
#   'other',
#   'artificial',
#   'stella',
#   'equus caballus',
#   'distant',
#   'culture medium',
#   'avulsion',
#   'pressure',
#   'whole',
#   'contaminated',
#   'venezuela',
#   'radish',
#   'powder',
#   'storage',
#   'hawaii island',
#   'surgical intensive care unit',
#   'arsenic',
#   'cucumber',
#   'mozambique',
#   'singapore',
#   'sebum',
#   'seminal plasma',
#   'material anatomical entity',
#   'urinary catheter',
#   'juglans regia',
#   'fluid',
#   'abalone',
#   'endocarditis',
#   'anchovy',
#   'liver tissue',
#   'bacterium',
#   'gorge',
#   'hong kong',
#   'upper',
#   'new mexico',
#   'pancreatic fluid',
#   'track',
#   'plant residue',
#   'flat',
#   'pear',
#   'sea',
#   'blood plasma',
#   'new zealand',
#   'exudate',
#   'obesity',
#   'muridae',
#   'floor swab',
#   'mus musculus',
#   'new york',
#   'banana',
#   'prawns',
#   'mucous',
#   'initial',
#   'throat swab',
#   'rye',
#   'netherlands',
#   'citrus fruit',
#   'institutionalized',
#   'starvation',
#   'nasopharyngeal swab',
#   'biopsy',
#   'female',
#   'sanfilippo syndrome',
#   'mucus',
#   'taiwan',
#   'bos taurus',
#   'natural',
#   'salt water',
#   'alaska',
#   'wet',
#   'puncture',
#   'middle ear fluid',
#   'liquid',
#   'ascites',
#   'nasal mucus',
#   'rectal swab',
#   'antrodia',
#   'food additive',
#   'vinegar',
#   'baker',
#   'carbon',
#   'medical',
#   'patch',
#   'eutrophication',
#   'california',
#   'university',
#   'hyacinthus orientalis',
#   'community',
#   'vaginal swab',
#   'fetal membranes',
#   'citrus sinensis',
#   'spinach',
#   'plane',
#   'stool',
#   'pika',
#   'quercus suber',
#   'petroleum',
#   'cervical intraepithelial neoplasia',
#   'rabbit',
#   'paper',
#   'device',
#   'warehouse',
#   'mineral water',
#   'ocimum basilicum',
#   'feces',
#   'litter',
#   'wood',
#   'gallus gallus',
#   'basin',
#   'antarctica',
#   'neonatal intensive care unit',
#   'gas',
#   'emulsion',
#   'falkland islands',
#   'quartz',
#   'nigeria',
#   'zea mays',
#   'trematode',
#   'kalanchoe',
#   'corn',
#   'systemic',
#   'denmark',
#   'chile',
#   'smoker',
#   'straw',
#   'eucalyptus',
#   'physa',
#   'bottle',
#   'pool',
#   'indirect',
#   'miscellaneous',
#   'phosphate',
#   'bottom',
#   'system',
#   'paraffin',
#   'pinus',
#   'exercise',
#   'apis mellifera',
#   'fish',
#   'deep',
#   'titanium',
#   'negative',
#   'month',
#   'nitric oxide',
#   'dental calculus',
#   'bamboo',
#   'cyst',
#   'catheter tip',
#   'sand',
#   'leaves',
#   'tears',
#   'cold',
#   'czech republic',
#   'petri dish',
#   'dental',
#   'argentina',
#   'amniotic fluid',
#   'uncertain',
#   'computer',
#   'hypoxia',
#   'pork',
#   'reservoir',
#   'dust',
#   'trachypithecus francoisi',
#   'wound',
#   'solid',
#   'juice',
#   'fourth',
#   'brassica oleracea',
#   'drainage ditch',
#   'pumice',
#   'string',
#   'conventional',
#   'solitary bee',
#   'rubber',
#   'government hospital',
#   'oral',
#   'nil',
#   'hotel',
#   'phleum pratense',
#   'bone tumor',
#   'peanut',
#   'high temperature',
#   'sewage',
#   'wooded area',
#   'spinosad',
#   'caffeine',
#   'analysis',
#   'fan',
#   'periapical abscess',
#   'citrate',
#   'chimney',
#   'unknown',
#   'lounge',
#   'galactose',
#   'europe',
#   'normal diet',
#   'market',
#   'concha bullosa',
#   'indonesia',
#   'dessert',
#   'factory',
#   'whale',
#   'mixture',
#   'wind',
#   'air',
#   'glutamine',
#   'perianal',
#   'year',
#   'vicia faba',
#   'lysozyme',
#   'beach',
#   'barley',
#   'cylinder',
#   'urban residential',
#   'coal',
#   'tidal river',
#   'escherichia coli',
#   'rangifer tarandus',
#   'time',
#   'wound swab',
#   'secondary',
#   'lycopersicon esculentum',
#   'azerbaijan',
#   'gravel pit',
#   'phi',
#   'hydrocarbon',
#   'skin tissue',
#   'complicated appendicitis',
#   'undetermined',
#   'bread',
#   'desert',
#   'body fluid',
#   'site',
#   'agarose',
#   'quercus rubra',
#   'illinois',
#   'slow',
#   'humid environment',
#   'syringe',
#   'gastric',
#   'madagascar',
#   'boat',
#   'alcoholic beverage',
#   'airport',
#   'meat',
#   'null',
#   'public park',
#   'biliary sludge',
#   'cervical',
#   'swimming pool',
#   'otorrhea',
#   'scraping',
#   'filler',
#   'riboflavin',
#   'stage',
#   'pleural fluid',
#   'oropharyngeal',
#   'protective agent',
#   'tar',
#   'dental caries',
#   'watercraft',
#   'intestinal contents',
#   'veal',
#   'gelatin',
#   'pyrus communis',
#   'needle',
#   'hydrophilic',
#   'landfill site',
#   'israel',
#   'late',
#   'serum',
#   'rural environment',
#   'parietal',
#   'sweden',
#   'mudflats',
#   'frozen',
#   'lotus tuber',
#   'bank',
#   'metal',
#   'unit',
#   'sibling',
#   'stream',
#   'saliva',
#   'wheat bran',
#   'church',
#   'jelly',
#   'specimen',
#   'pony',
#   'light',
#   'roof',
#   'laboratory incubator',
#   'uruguay',
#   'corned beef',
#   'diverticulitis',
#   'oxygen concentration',
#   'scallop',
#   'india',
#   'pineapple',
#   'harbor',
#   'south america',
#   'duodenal juice',
#   'nicotiana tabacum',
#   'anas penelope',
#   'soft cheese',
#   'cerebrospinal fluid',
#   'waterfall',
#   'relative humidity',
#   'disease',
#   'ghana',
#   'canada',
#   'soil',
#   'cliff',
#   'alabama',
#   'gastrointestinal contents',
#   'faeces',
#   'sputum',
#   'mill',
#   'menthol',
#   'refrigerator',
#   'control',
#   'emergency',
#   'flood',
#   'supragingival dental plaque',
#   'wine',
#   'bacon',
#   'wash',
#   'beer',
#   'colostrum',
#   'yes',
#   'macaca mulatta',
#   'meriones unguiculatus',
#   'shop',
#   'domestic garden',
#   'propolis',
#   'street',
#   'mountain',
#   'venous',
#   'acetic acid',
#   'lichen',
#   'in situ',
#   'matrix stone',
#   'crust',
#   'coriaria thymifolia',
#   'chlorella',
#   'nursery',
#   'vaginal discharge',
#   'fresh',
#   'grapes',
#   'taxus baccata',
#   'polyp',
#   'aqueous humour',
#   'window',
#   'sunlight',
#   'culture',
#   'polyethylene terephthalate',
#   'gingival',
#   'laboratory test',
#   'plaster',
#   'nature',
#   'high',
#   'ocular',
#   'hospital',
#   'current',
#   'and',
#   'pond water',
#   'malus domestica',
#   'abdominal',
#   'ulcerative colitis',
#   'eczema',
#   'atmosphere',
#   'wild bird',
#   'caenorhabditis',
#   'fusarium',
#   'salad',
#   'squash',
#   'railway station',
#   'open sea',
#   'health',
#   'wheat product',
#   'reunion',
#   'cover',
#   'food',
#   'belgium',
#   'alberta',
#   'bed',
#   'ventricular assist device',
#   'controlled',
#   'fertilizer',
#   'dining room',
#   'water',
#   'bacterial genome',
#   'paint',
#   'sucrose',
#   'cane',
#   'human cells',
#   'evening',
#   'fiji',
#   'sludge',
#   'entrance',
#   'mayotte',
#   'allium porrum',
#   'stethoscope',
#   'thailand',
#   'roquefort cheese',
#   'sauce',
#   'blood material',
#   'granules',
#   'swamp',
#   'tape',
#   'mix',
#   'amoeba culture',
#   'electrode',
#   'colonic contents',
#   'apple juice',
#   'sweat',
#   'bronchoalveolar lavage',
#   'ice',
#   'bronchoscope',
#   'saccharin',
#   'food shop',
#   'location',
#   'seminal fluid',
#   'aircraft',
#   'gastric juice',
#   'block',
#   'rape leaf',
#   'hormone',
#   'iron',
#   'cream',
#   'cord blood',
#   'prairie',
#   'third',
#   'barrel',
#   'ammonia',
#   'vegetable',
#   'lumen',
#   'dioxane',
#   'pinus radiata',
#   'parent',
#   'evisceration',
#   'sewer',
#   'plant seeds',
#   'meat products',
#   'surface',
#   'dermatophyte',
#   'sand dunes',
#   'bedroom',
#   'town environment',
#   'lysis',
#   'rectal',
#   'pinch biopsy',
#   'water pollution',
#   'western australia',
#   'caenorhabditis elegans',
#   'plant structure',
#   'colorectal',
#   'environment',
#   'mussels',
#   'mature',
#   'shrimp',
#   'yeast',
#   'low altitude',
#   'fast',
#   'brass',
#   'homo sapiens',
#   'rye bread',
#   'breath',
#   'vancomycin',
#   'segment',
#   'outpatient',
#   'cassette',
#   'carrot',
#   'glucose',
#   'collodion',
#   'brackish water',
#   'antibiotic',
#   'blood',
#   'senegal',
#   'surgical',
#   'agar medium',
#   'membranous',
#   'mouth swab',
#   'industrial plant',
#   'abdomen',
#   'chinese',
#   'pollen',
#   'foam',
#   'week',
#   'rinse',
#   'oil',
#   'probe',
#   'abscess',
#   'urban environment',
#   'grade',
#   'amaranth',
#   'countryside',
#   'kidney stone',
#   'diaper',
#   'poland',
#   'panama',
#   'inulin',
#   'mother',
#   'farming environment',
#   'pleural effusion',
#   'air pressure',
#   'chlorhexidine',
#   'ageing',
#   'honeycomb',
#   'native',
#   'defecation',
#   'salmonella infection',
#   'acetate',
#   'solanum tuberosum',
#   'egg yolk',
#   'grape juice',
#   'contents',
#   'superficial',
#   'remote',
#   'depth',
#   'polyester',
#   'herbicide',
#   'polystyrene',
#   'polynucleobacter',
#   'bar',
#   'pseudomonas aeruginosa',
#   'lymphatic tissue',
#   'temperature',
#   'surgical wound',
#   'door',
#   'tuber',
#   'sudan',
#   'zip',
#   'whole milk',
#   'first',
#   'anatomical structure',
#   'vaccine',
#   'concrete',
#   'brain tissue',
#   'breast milk',
#   'tomato',
#   'punch biopsy',
#   'inguinal',
#   'giardiasis',
#   'nerium indicum',
#   'salmo salar',
#   'cavity',
#   'phosphorus',
#   'glycine max',
#   'alnus incana',
#   'root caries',
#   'potato',
#   'snow',
#   'sound',
#   'pellet',
#   'table',
#   'adenoma',
#   'cervical mucus',
#   'knife',
#   'linitis plastica',
#   'clinical',
#   'laos',
#   'all',
#   'abies balsamea',
#   'cave',
#   'vial',
#   'propionate',
#   'plasmid',
#   'extraction',
#   'blood culture',
#   'algae',
#   'fall',
#   'fungal product',
#   'curette',
#   'gastroenterology',
#   'pharyngitis',
#   'acne',
#   'rail',
#   'wheat flour',
#   'germany',
#   'tunnel',
#   'oil well',
#   'mining waste',
#   'microbiology',
#   'indiana',
#   'kitikmeot',
#   'appendicitis',
#   'vaginal secretion',
#   'ulcer',
#   'periodontal pocket',
#   'chinese cabbage',
#   'cellulose',
#   'form',
#   'aluminium',
#   'transplant',
#   'morphine',
#   'patchy',
#   'elevator',
#   'bicuspid',
#   'brachiaria brizantha',
#   'coastal sea',
#   'woods',
#   'cystitis',
#   'paraffin wax',
#   'leek',
#   'ascitic fluid',
#   'nothing',
#   'bile',
#   'fertilization',
#   'coastal environment',
#   'office',
#   'nitrogen',
#   'anaerobic chamber',
#   'agar',
#   'insecticide',
#   'indian',
#   'polymer',
#   'combined',
#   'overweight',
#   'north carolina',
#   'fermented food',
#   'urethral',
#   'none',
#   'tinea pedis',
#   'postoperative infection',
#   'malaysia',
#   'flowers',
#   'nasopharyngeal',
#   'second',
#   'role',
#   'multiple',
#   'chili powder',
#   'intensive care unit',
#   'mollusk',
#   'ozone',
#   'fracture',
#   'drain',
#   'mixed',
#   'leather',
#   'stigma',
#   'exhaled breath condensate',
#   'oyster',
#   'urine specimen',
#   'morning',
#   'water intake',
#   'periodontal disease',
#   'library',
#   'bulb',
#   'pregnant',
#   'gruyere cheese',
#   'pickle',
#   'internal',
#   'coffea arabica',
#   'neurosurgery',
#   'fungal genome',
#   'cerumen',
#   'gingivitis',
#   'fertiliser',
#   'beta vulgaris',
#   'ferry',
#   'hydrogen sulfide',
#   'wound discharge',
#   'apple',
#   'house dust',
#   'tooth surface',
#   'core',
#   'pneumonia',
#   'ovis aries',
#   'traumatic',
#   'cold environment',
#   'surface swab',
#   'altitude',
#   'interdental',
#   'temperate environment',
#   'whey',
#   'hill',
#   'tofu',
#   'camellia',
#   'natural gas',
#   'environmental pollution',
#   'biopsy sample',
#   'plastic',
#   'equipment',
#   'aluminum',
#   'matrix',
#   'distal',
#   'jordan',
#   'norway',
#   'asia',
#   'external',
#   'top',
#   'whole body',
#   'shellfish',
#   'seafood',
#   'plastic tube',
#   'normal',
#   'small',
#   'peptide',
#   'sheep milk',
#   'suppressive',
#   'capsicum annuum',
#   'motor vehicle',
#   'mexico',
#   'tinea capitis',
#   'not applied',
#   'young',
#   'fungi',
#   'wheat',
#   'white rice',
#   'endodontic paper point',
#   'seedling',
#   'dilution',
#   'oil spill',
#   'source',
# ...
#   'corn',
#   'cornus',
#   'cornus stolonifera',
#   'corylus avellana',
#   'cotton',
#   'cotyledon',
#   'cow',
#   'crayfish',
#   'cryptobranchus alleganiensis alleganiensis',
#   'cryptocarya angulata',
#   'cryptomeria fortunei',
#   'cucumber',
#   'cucumis sativus',
#   'cucurbita pepo',
#   'culex quinquefasciatus',
#   'cultivated sugarcanes',
#   'cundinamarca',
#   'cyanobacteria',
#   'cylinder',
#   'cyperus papyrus',
#   'cyprinus carpio',
#   'dairy cow',
#   'daphnia dentifera',
#   'daphnia magna',
#   'daphnia obtusa',
#   'date palm',
#   'datisca glomerata',
#   'delta',
#   'deyeuxia arundinacea',
#   'dianthus caryophyllus',
#   'diatoms',
#   'dictyota',
#   'dima',
#   'dog',
#   'domestic cow',
#   'domestic pig',
#   'dreissena',
#   'drosophila',
#   'drosophila melanogaster',
#   'duck',
#   'duckweed',
#   'earthworm',
#   'earthworms',
#   'eastern oyster',
#   'elaeagnus pungens',
#   'eleocharis dulcis',
#   'encarsia formosa',
#   'encephalartos ferox',
#   'endiandra wolfei',
#   'enrichment culture',
#   'enrichment cultures',
#   'enterobacteriaceae',
#   'environmental sequence',
#   'eothenomys miletus',
#   'epipedobates anthonyi',
#   'equine',
#   'equus caballus',
#   'eremophila serrulata',
#   'eriobotrya japonica',
#   'eriocheir',
#   'escherichia coli',
#   'estuary metagenome',
#   'eucalyptus',
#   'eukarya',
#   'eukaryota',
#   'eukaryotes',
#   'euonymus japonicus',
#   'european beech',
#   'fagales',
#   'fagus sylvatica',
#   'fava bean',
#   'fecal metagenome',
#   'feces metagenome',
#   'festuca rubra',
#   'ficus',
#   'fir trees',
#   'fish',
#   'fish metagenome',
#   'food fermentation metagenome',
#   'food metagenome',
#   'forsythia viridissima',
#   'fragaria ananassa',
#   'franciscodendron laurifolium',
#   'fraxinus excelsior',
#   'freshwater metagenome',
#   'freshwater sediment metagenome',
#   'fungi',
#   'fusarium',
#   'fusarium graminearum',
#   'fusarium oxysporum',
#   'fusobacterium nucleatum',
#   'galleria mellonella',
#   'gallus gallus',
#   'gallus gallus domesticus',
#   'garcinia',
#   'gazella subgutturosa',
#   'giant panda',
#   'glabella',
#   'glycine max',
#   'goat',
#   'goji berry',
#   'gracilaria',
#   'gracilaria lemaneiformis',
#   'green algae',
#   'green sea turtle',
#   'greta',
#   'guava',
#   'gut metagenome',
#   'gut microbiome',
#   'halichondria panicea',
#   'halictus scabiosae',
#   'haloxylon',
#   'haloxylon ammodendron',
#   'harbor seal',
#   'hedera helix',
#   'hemiptera',
#   'hemp',
#   'hevea brasiliensis',
#   'hexapoda',
#   'hieracium lepidulum',
#   'hirundo rustica',
#   'hiv',
#   'homalodisca vitripennis',
#   'homo sapiens',
#   'honey bee',
#   'honey bees',
#   'honeybee',
#   'honeycomb',
#   'horse',
#   'human',
#   'human bile metagenome',
#   'human feces metagenome',
#   'human gut metagenome',
#   'human gut microbiota',
#   'human metagenome',
#   'human microbiome',
#   'human milk metagenome',
#   'human oral metagenome',
#   'human oral microbiome',
#   'human saliva metagenome',
#   'human sinus metagenome',
#   'human skin metagenome',
#   'human vaginal metagenome',
#   'human virome',
#   'hyacinthus orientalis',
#   'hydra vulgaris',
#   'hypericum hircinum',
#   'hypersaline lake metagenome',
#   'hypholoma',
#   'hypothenemus hampei',
#   'impala',
#   'insect gut metagenome',
#   'insecta',
#   'insects',
#   'ipomoea hederacea',
#   'isatis violascens',
#   'isolate',
#   'isopoda',
#   'ixodes',
#   'jellyfish metagenome',
#   'joshua tree',
#   'juglans regia',
#   'juncus roemerianus',
#   'kalanchoe',
#   'kiwifruit',
#   'kobresia',
#   'kobresia humilis',
#   'kobresia pygmaea',
#   'lagerstroemia',
#   'lambs',
#   'larix kaempferi',
#   'larix laricina',
#   'larus schistisagus',
#   'leaf litter metagenome',
#   'leek',
#   'lens culinaris',
#   'lepidoptera',
#   'ligustrum lucidum',
#   'linum usitatissimum',
#   'lipaphis erysimi pseudobrassicae',
#   'liriope',
#   'lithobates catesbeianus',
#   'lithobates clamitans',
#   'lithobates sylvaticus',
#   'litopenaeus vannamei',
#   'liverwort',
#   'longleaf pine',
#   'lonicera maackii',
#   'lucinoma aequizonata',
#   'lucinoma borealis',
#   'lucinoma capensis',
#   'lucinoma kastoroae',
#   'lucinoma myriamae',
#   'lumbricus terrestris',
#   'lupinus polyphyllus',
#   'lycopersicon esculentum',
#   'lysiloma',
#   'macaca mulatta',
#   'macrocystis pyrifera',
#   'maize',
#   'malcolmia scorpioides',
#   'malus domestica',
#   'malus pumila',
#   'mammals',
#   'mammuthus primigenius',
#   'manta',
#   'marine metagenome',
#   'marine sediment metagenome',
#   'medicago sativa',
#   'medicinal leech',
#   'megachile sculpturalis',
#   'menyanthes trifoliata',
#   'meriones unguiculatus',
#   'mers',
#   'metagenome',
#   'metagenomes',
#   'methanogenic enrichment culture',
#   'mexico',
#   'mice',
#   'microbiota',
#   'microcystis',
#   'microtus agrestis',
#   'microtus arvalis',
#   'microtus oeconomus',
#   'millepora alcicornis',
#   'mimosa pigra',
#   'miscanthus',
#   'mixed culture',
#   'mixed culture metagenome',
#   'mixed sample',
#   'mnemiopsis leidyi',
#   'mock community',
#   'mollusca',
#   'monitilora ramsayi',
#   'mosquito',
#   'mosses',
#   'mouse',
#   'mouse gut metagenome',
#   'mouse metagenome',
#   'muridae',
#   'mus',
#   'mus musculus',
#   'mus musculus domesticus',
#   'mus musculus musculus',
#   'myodes glareolus',
#   'myriophyllum',
#   'myrmicocrypta ednaella',
#   'napier grass',
#   'nassella trichotoma',
#   'neem',
#   'nematoda',
#   'nematodes',
#   'neoromicia',
#   'nerium indicum',
#   'nicotiana tabacum',
#   'niemeyera',
#   'nile tilapia',
#   'noccaea caerulescens',
#   'noctuidae',
#   'none',
#   'norway spruce',
#   'not specified',
#   'oat',
#   'ocimum basilicum',
#   'oil field metagenome',
#   'olea europaea',
#   'oncorhynchus kisutch',
#   'oncorhynchus nerka',
#   'onion',
#   'ophiopogon japonicus',
#   'oral metagenome',
#   'oryza sativa',
#   'other',
#   'ovis aries',
#   'oxalis corniculata',
#   'oysters',
#   'palisade grass',
#   'pampa',
#   'pan',
#   'panama',
#   'panda',
#   'panicum repens',
#   'paratrachymyrmex diversus',
#   'partamona helleri',
#   'parthenium argentatum',
#   'passiflora edulis',
#   'patella',
#   'pea',
#   'peach',
#   'peanut',
#   'pear',
#   'peas',
#   'peltigera',
#   'penaeus vannamei',
#   'perch',
#   'phaseolus coccineus',
#   'phaseolus vulgaris',
#   'philaenus spumarius',
#   'phleum pratense',
#   'phoenix canariensis',
#   'phragmites communis',
#   'phyllosphere metagenome',
#   'phyllostachys edulis',
#   'physa',
#   'picea abies',
#   'picea glauca',
#   'picea mariana',
#   'picea omorika',
#   'picea rubens',
#   'pig',
#   'pig gut metagenome',
#   'pigs',
#   'pilbara',
#   'pilosella officinarum',
#   'pineapple',
#   'pinus',
#   'pinus densiflora',
#   'pinus massoniana',
#   'pinus nigra',
#   'pinus pinaster',
#   'pinus pinea',
#   'pinus radiata',
#   'pinus strobus',
#   'pinus sylvestris',
#   'pisum sativum',
#   'pittosporum angustifolium',
#   'plants',
#   'plasmid',
#   'poa trivialis',
#   'pocillopora',
#   'polynucleobacter',
#   'pomegranate',
#   'poplar',
#   'populus',
#   'porifera',
#   'porites',
#   'potamogeton',
#   'potato',
#   'potatoes',
#   'procapra picticaudata',
#   'procapra przewalskii',
#   'prokaryote',
#   'prokaryotes',
#   'prokaryotic metagenome',
#   'propolis',
#   'prorocentrum lima',
#   'prosopis juliflora',
#   'prunus avium',
#   'prunus persica',
#   'pseudomonas aeruginosa',
#   'pseudotsuga menziesii',
#   'punica granatum',
#   'pygathrix nigripes',
#   'pyropia',
#   'pyrus communis',
#   'pyrus pyrifolia',
#   'quercus',
#   'quercus acutissima',
#   'quercus agrifolia',
#   'quercus coccifera',
#   'quercus ilex',
#   'quercus petraea',
#   'quercus robur',
#   'quercus rotundifolia',
#   'quercus rubra',
#   'quercus suber',
#   'rabbit',
#   'raccoon',
#   'rachis',
#   'racomitrium lanuginosum',
#   'radish',
#   'rainbow trout',
#   'rana italica',
#   'rangifer tarandus',
#   'rape',
#   'raphanus sativus',
#   'rat',
#   'rat gut metagenome',
#   'red algae',
#   'red pepper',
#   'redbanded seabream',
#   'redwood',
#   'rhamnus cathartica',
#   'rhesus macaque',
#   'rhizosphere metagenome',
#   'rhododendron catawbiense',
#   'rhododendron simsii',
#   'rhodomela confervoides',
#   'rhopalosiphum maidis',
#   'rhopalosiphum padi',
#   'rice',
#   'rockinghamia angustifolia',
#   'rodent',
#   'root',
#   'root metagenome',
#   'rubus idaeus',
#   'ruditapes philippinarum',
#   'rye',
#   'sagebrush',
#   'salix caprea',
#   'salix lapponum',
#   'salmo salar',
#   'sargassum',
#   'sargassum thunbergii',
#   'scallop',
#   'schizaphis graminum',
#   'schlumbergera truncata',
#   'scolytinae',
#   'sea',
#   'sea squirts',
#   'sea urchin',
#   'seashore paspalum',
#   'seawater metagenome',
#   'sediment metagenome',
#   'sepsis',
#   'sericopelma',
#   'sheep',
#   'siderastrea stellata',
#   'sika deer',
#   'silo',
#   'siniperca chuatsi',
#   'sinonovacula constricta',
#   'siphamia tubifer',
#   'siphonaptera',
#   'sitobion avenae',
#   'sludge metagenome',
#   'snakes',
#   'soil metagenome',
#   'soil microbiome',
#   'solanum lycopersicum',
#   'solanum melongena',
#   'solanum nigrum',
#   'solanum tuberosum',
#   'solidago canadensis',
#   'solidago decurrens',
#   'sorghum',
#   'sorghum bicolor',
#   'soybean',
#   'spartina maritima',
#   'spatoglossum',
#   'species',
#   'sphagnum',
#   'sphagnum palustre',
#   'spiders',
#   'spinach',
#   'spirogloea muscicola',
#   'spodoptera',
#   'spodoptera frugiperda',
#   'sponge metagenome',
#   'sponges',
#   'squash bug',
#   'stella',
#   'stomach metagenome',
#   'strain',
#   'strawberry',
#   'striga hermonthica',
#   'suaeda salsa',
#   'subsurface metagenome',
#   'sugar beet',
#   'sugarcane',
#   'summer flounder',
#   'sus scrofa domesticus',
#   'sweet cherry',
#   'swine',
#   'switchgrass',
#   'symbiodiniaceae',
#   'synthetic',
#   'synthetic construct',
#   'synthetic metagenome',
#   'synthetic microbial community',
#   'syzygium endophloium',
#   'tara',
#   'taxus baccata',
#   'tepary bean',
#   'tetracme contorta',
#   'tetracme recurvata',
#   'theobroma cacao',
#   'thymus',
#   'thysanolaena maxima',
#   'tibia',
#   'tilapia',
#   'tobacco',
#   'tobacco root',
#   'tomato',
#   'trachea',
#   'trachurus japonicus',
#   'trachypithecus francoisi',
#   'trachypithecus germaini',
#   'trachypithecus leucocephalus',
#   'transposon',
#   'trifolium alexandrinum',
#   'trifolium repens',
#   'triticum aestivum',
#   'tuber',
#   'turkey',
#   'tusk',
#   'typha orientalis',
#   'ulva linza',
#   'umbilicus',
#   'unclassified',
#   'uncultured bacterium',
#   'unknown',
#   'unspecified',
#   'urine metagenome',
#   'vachellia abyssinica',
#   'vaginal metagenome',
#   'valencia',
#   'veronica persica',
#   'vespa velutina',
#   'vicia faba',
#   'vicia sativa',
#   'vigna unguiculata',
#   'vitis vinifera',
#   'water chestnut',
#   'water hyacinth',
#   'water lettuce',
#   'watermelon',
#   'weevils',
#   'whale',
#   'wheat',
#   'white oak',
#   'wild barley',
#   'wild boar',
#   'wild rice',
#   'wren',
#   'zantedeschia aethiopica',
#   'zea mays',
#   'zebrafish',
#   'zingiber officinale',
#   'zostera japonica',
#   'zostera marina',
#   'zuma'},
#  'exo': {'acid rain',
#   'age',
#   'aged',
#   'agricultural process',
#   'asian',
#   'biosphere',
#   'black',
#   'blood',
#   'built environment',
#   'cell',
#   'child',
#   'children',
#   'chinese',
#   'climate change',
#   'country',
#   'diet',
#   'disease',
#   'drug',
#   'female',
#   'indian',
#   'indoor',
#   'location',
#   'male',
#   'maternal',
#   'mother',
#   'muscle',
#   'organ',
#   'other',
#   'outdoor',
#   'province',
#   'smoker',
#   'source',
#   'time',
#   'tissue',
#   'unit',
#   'white',
#   'woman'},
#  'obi': {'animal cage',
#   'apron',
#   'atmosphere',
#   'biopsy',
#   'bioreactor',
#   'cancer',
#   'catheter',
#   'cell culture',
#   'cell culture supernatant',
#   'cell specimen',
#   'computer',
#   'concentrate',
#   'container',
#   'cotton swab',
#   'culture medium',
#   'cultured cell population',
#   'device',
#   'dna extract',
#   'dna extraction',
#   'extraction',
#   'filter paper',
#   'flow cytometer',
#   'illumina miseq',
#   'incubator',
#   'laboratory animal care',
#   'lavage',
#   'lower respiratory tract specimen',
#   'nasopharyngeal swab specimen',
#   'needle',
#   'nucleic acid extract',
#   'organism',
#   'ovitrap',
#   'plasmid',
#   'pool of specimens',
#   'population',
#   'precipitate',
#   'precipitation',
#   'primary cell culture',
#   'processed material',
#   'reagent',
#   'single cell specimen',
#   'specimen',
#   'specimen collection process',
#   'specimen from organism',
#   'storage',
#   'syringe',
#   'tar',
#   'test tube',
#   'urine specimen',
#   'vagina swab specimen',
#   'vial',
#   'washing',
#   'zip'},
#  'po': {'anther',
#   'bark',
#   'branch',
#   'bud',
#   'bulb',
#   'cambium',
#   'canal',
#   'corm',
#   'cotyledon',
#   'drupe fruit',
#   'epicuticular wax',
#   'exocarp',
#   'flag leaf',
#   'flower',
#   'flower bud',
#   'fruit',
#   'hypodermis',
#   'inflorescence',
#   'leaf',
#   'leaf lamina',
#   'leaf sheath',
#   'life of whole plant stage',
#   'peristome',
#   'petal',
#   'petiole',
#   'petiole epidermis',
#   'phloem',
#   'phyllome',
#   'placenta',
#   'plant axis',
#   'plant organ',
#   'plant structure',
#   'plant structure development stage',
#   'pneumatophore',
#   'pollen',
#   'portion of plant tissue',
#   'prop root',
#   'pseudostem',
#   'rhizome',
#   'root',
#   'root nodule',
#   'root system',
#   'root tip',
#   'sapwood',
#   'seed',
#   'seedling',
#   'shoot system',
#   'shoot system meristem',
#   'spikelet',
#   'stem',
#   'stem base',
#   'stigma',
#   'style',
#   'transition zone',
#   'tuber',
#   'vascular leaf',
#   'vascular system',
#   'vegetative shoot system',
#   'whole plant',
#   'xylem',
#   'xylem sap'},
#  'pato': {'acidic',
#   'acidophilic',
#   'aerobic',
#   'age',
#   'alkaline',
#   'anaerobic',
#   'arboreal',
#   'area',
#   'associated',
#   'attached',
#   'back',
#   'benign',
#   'bicuspid',
#   'black',
#   'blue',
#   'broad',
#   'cold',
#   'compact',
#   'contaminated',
#   'contamination',
#   'content',
#   'cuboid',
#   'cut',
#   'dark',
#   'decayed',
#   'deep',
#   'deltoid',
#   'depth',
#   'distal',
#   'dry',
#   'east',
#   'exposed',
#   'female',
#   'flat',
#   'frozen',
#   'gas',
#   'green',
#   'hemispheroid',
#   'high elevation',
#   'high fertility',
#   'high flow',
#   'high temperature',
#   'hot',
#   'humid',
#   'hydrophilic',
#   'hydrophobic',
#   'larval',
#   'late',
#   'lateral',
#   'light',
#   'liquid',
#   'location',
#   'low fertility',
#   'low flow',
#   'low intensity',
#   'low temperature',
#   'male',
#   'mature',
#   'mixed',
#   'mucoid',
#   'mucous',
#   'multiple',
#   'normal',
#   'open',
#   'patchy',
#   'peripheral',
#   'phase',
#   'pooled',
#   'position',
#   'pressure',
#   'purple',
#   'purulent',
#   'radius',
#   'red',
#   'rotation',
#   'salinity',
#   'secondary',
#   'shallow',
#   'sigmoid',
#   'slow',
#   'small',
#   'solid',
#   'south',
#   'split',
#   'squamous',
#   'sterile',
#   'strain',
#   'subcutaneous',
#   'superficial',
#   'tall',
#   'temperature',
#   'temporal',
#   'terminal',
#   'time',
#   'uncontaminated',
#   'undeveloped',
#   'variable',
#   'west',
#   'wet',
#   'white',
#   'whole',
#   'wholeness',
#   'young'},
#  'micro': {'acetate',
#   'acetic acid',
#   'acidic',
#   'aerobic',
#   'anaerobe',
#   'anaerobic',
#   'artificial seawater',
#   'bakers yeast',
#   'brain heart infusion',
#   'brain heart infusion broth',
#   'butanediol',
#   'butyric acid',
#   'casein',
#   'cell cluster',
#   'citrate',
#   'crude oil',
#   'culture media',
#   'dark fermentation',
#   'dry',
#   'endophytic',
#   'epilithic',
#   'epiphytic',
#   'epiphytic environment',
#   'fermentation',
#   'fermenter',
#   'filaments',
#   'filter paper',
#   'filtered seawater',
#   'fried egg',
#   'galactose',
#   'gelatin',
#   'gelatine',
#   'growth medium',
#   'halotolerant',
#   'indole',
#   'inulin',
#   'lb medium',
#   'macconkey agar',
#   'malate',
#   'malt extract',
#   'marine salinity',
#   'media',
#   'medium',
#   'mesophilic',
#   'microaerophilic',
#   'microbiological culture medium',
#   'moist',
#   'mucoid',
#   'mucous',
#   'mulberry',
#   'nutrient medium',
#   'olive fruit',
#   'peptone water',
#   'petri dish',
#   'planktonic',
#   'propionate',
#   'sea salt',
#   'sheath',
#   'sheep blood',
#   'soil extract',
#   'starch',
#   'sucrose',
#   'sunlight',
#   'thermophile',
#   'thermophilic',
#   'tryptic soy broth',
#   'vancomycin',
#   'water filter',
#   'wet',
#   'whole blood',
#   'whole milk',
#   'yeast extract',
#   'ypd agar'},
#  'ohmi': {'bacterial microbiome',
#   'host',
#   'human gut microbiome',
#   'human microbiome',
#   'microbe',
#   'microbial genome',
#   'microbiome',
#   'microbiome in human oral',
#   'microbiota',
#   'mouse microbiome'},
#  'pco': {'alga',
#   'algae',
#   'collection of organisms',
#   'ecological community',
#   'household',
#   'microbe',
#   'microbial community',
#   'microbiota',
#   'organismal entity',
#   'population of organisms',
#   'seaweed'},
#  'mco': {'artificial medium',
#   'experimental process',
#   'human urine',
#   'lb broth',
#   'luria broth',
#   'rich medium',
#   'stationary phase',
#   'treatment'}}

# %%
def invert_hits_by_ontology(hits_by_ontology):
    labels_to_ontologies = defaultdict(set)

    for ontology, labels in hits_by_ontology.items():
        for label in labels:
            labels_to_ontologies[label].add(ontology)

    return dict(labels_to_ontologies)

# %%
hits_by_component_label = invert_hits_by_ontology(hits_by_ontology)

# %%
hits_by_component_label
# Out:
# {'ditch': {'envo'},
#  'pharmacy': {'envo', 'ncit', 'snomed'},
#  'administrative region': {'envo'},
#  'agricultural facility': {'envo'},
#  'sheepfold': {'envo'},
#  'metallic material': {'envo', 'snomed'},
#  'mediterranean shrubland biome': {'envo'},
#  'saline spring': {'envo'},
#  'salt lake': {'envo'},
#  'mouth': {'envo', 'ncit', 'uberon'},
#  'ice mass': {'envo'},
#  'material primarily composed of biogenic carbonates': {'envo'},
#  'lake water': {'envo', 'snomed'},
#  'waterbody': {'envo'},
#  'island': {'envo', 'ncit', 'snomed'},
#  'culturing environment': {'envo'},
#  'biosphere': {'envo', 'exo'},
#  'chicken manure': {'envo'},
#  'terrestrial environmental zone': {'envo'},
#  'alluvial soil': {'envo'},
#  'shrimp pond': {'envo'},
#  'horse manure': {'envo'},
#  'mesoplastic particle': {'envo'},
#  'pancake ice': {'envo'},
#  'microcosm': {'envo'},
#  'hydrothermal vent': {'envo'},
#  'town hall': {'envo'},
#  'dense settlement biome': {'envo'},
#  'tropical woodland biome': {'envo'},
#  'sink': {'envo'},
#  'brine channel': {'envo'},
#  'biomass': {'envo'},
#  'cryopeg': {'envo'},
#  'stony soil': {'envo'},
#  'glacier': {'envo'},
#  'container of an intermittent lake': {'envo'},
#  'precipitation process': {'envo'},
#  'lakeshore': {'envo'},
#  'flood fringe': {'envo'},
#  'contaminated soil': {'envo'},
#  'salt marsh': {'envo'},
#  'university campus': {'envo'},
#  'infralittoral zone': {'envo'},
#  'polar biome': {'envo'},
#  'wetness of soil': {'envo'},
#  'mountain forest soil': {'envo'},
#  'umbrisol': {'envo'},
#  'hallway': {'envo', 'snomed'},
#  'glacial process': {'envo'},
#  'gravel': {'envo', 'snomed'},
#  'acid rock drainage': {'envo'},
#  'cleanroom': {'envo'},
#  'terrestrial ecosystem': {'envo'},
#  'shale': {'envo', 'snomed'},
#  'slush ice': {'envo'},
#  'marine coral reef fore reef': {'envo'},
#  'lake shore': {'envo'},
#  'marine biome': {'envo'},
#  'steel': {'envo'},
#  'halite': {'envo'},
#  'masonry cement': {'envo'},
#  'intermittent wetland': {'envo'},
#  'temperate mountain': {'envo'},
#  'rural area': {'envo', 'ncit'},
#  'montane': {'envo'},
#  'sea sand': {'envo'},
#  'oceanic subsurface zone': {'envo'},
#  'deciduous forest': {'envo'},
#  'lake coast': {'envo'},
#  'limestone': {'envo'},
#  'fen': {'envo'},
#  'intertidal ecosystem': {'envo'},
#  'intermittent pond': {'envo'},
#  'sandy desert': {'envo'},
#  'anthropogenic contamination feature': {'envo'},
#  'settlement': {'envo'},
#  'lahar': {'envo'},
#  'coastal shrimp pond': {'envo'},
#  'tea plantation': {'envo'},
#  'freshwater wetland ecosystem': {'envo'},
#  'montane shrubland biome': {'envo'},
#  'spring': {'envo', 'ncit'},
#  'saline marsh': {'envo'},
#  'phaeozem': {'envo'},
#  'animal habitation': {'envo'},
#  'pump': {'envo', 'ncit', 'snomed'},
#  'saprolite': {'envo'},
#  'nest of bird': {'envo'},
#  'cement': {'envo', 'ncit', 'snomed', 'uberon'},
#  'room': {'envo', 'ncit'},
#  'subalpine biome': {'envo'},
#  'strict nature reserve': {'envo'},
#  'uranium ore': {'envo'},
#  'plantation field': {'envo'},
#  'tube well': {'envo'},
#  'grain': {'envo', 'ncit', 'snomed'},
#  'acidity of water': {'envo'},
#  'human house': {'envo'},
#  'streams': {'envo'},
#  'river valley': {'envo'},
#  'seagrass meadow': {'envo'},
#  'stainless steel': {'envo'},
#  'underground': {'envo'},
#  'glacial ice': {'envo'},
#  'road': {'envo', 'snomed'},
#  'salt pan': {'envo'},
#  'strait': {'envo'},
#  'bovine dairy liquid manure': {'envo'},
#  'metropolitana': {'envo'},
#  'vegetated hill': {'envo'},
#  'saline sediment environment': {'envo'},
#  'coal mine': {'envo', 'snomed'},
#  'vineyard': {'envo'},
#  'tropical': {'envo'},
#  'hotspring': {'envo'},
#  'fly ash': {'envo'},
#  'bench': {'envo'},
#  'peat soil': {'envo'},
#  'heath': {'envo'},
#  'fracture water': {'envo'},
#  'wetland': {'envo'},
#  'muskeg': {'envo'},
#  'biosolids': {'envo'},
#  'grove': {'envo'},
#  'mycetome': {'envo', 'uberon'},
#  'blanket bog': {'envo'},
#  'agronomic process': {'envo'},
#  'coastal zone': {'envo'},
#  'aquatic ecosystem': {'envo'},
#  'rice field': {'envo'},
#  'oil contaminated soil': {'envo'},
#  'dry lake': {'envo'},
#  'freshwater': {'envo'},
#  'nitisol': {'envo'},
#  'suspended sediment': {'envo'},
#  'epilithon': {'envo'},
#  'boulder sediment': {'envo'},
#  'ballast water': {'envo'},
#  'estuarine mud': {'envo'},
#  'coffee plantation': {'envo'},
#  'tropical savanna biome': {'envo'},
#  'hydrothermal seep': {'envo'},
#  'ecosystem process': {'envo'},
#  'algal material': {'envo'},
#  'silage': {'envo'},
#  'oceanic abyssopelagic zone biome': {'envo'},
#  'tropical broadleaf forest biome': {'envo'},
#  'marine hydrothermal plume': {'envo'},
#  'area of scrub': {'envo'},
#  'respirable suspended particulate matter': {'envo'},
#  'ground water': {'envo'},
#  'water ice': {'envo', 'ncit'},
#  'agricultural land conversion': {'envo'},
#  'flood plain': {'envo'},
#  'wwtp': {'envo'},
#  'cold season': {'envo'},
#  'seafloor': {'envo'},
#  'aeolian lake': {'envo'},
#  'mucus material': {'envo'},
#  'alluvial paddy field soil': {'envo'},
#  'marine tidal flow zone': {'envo'},
#  'ocean': {'envo'},
#  'area of woody wetland': {'envo'},
#  'tropical marine upwelling biome': {'envo'},
#  'tropical broadleaf forest': {'envo'},
#  'alkaline environment': {'envo'},
#  'manure storage space': {'envo'},
#  'closed animal house': {'envo'},
#  'saline lake': {'envo'},
#  'talus': {'envo', 'ncit', 'uberon'},
#  'sea ice floe': {'envo'},
#  'constructed pavement': {'envo'},
#  'fluid': {'envo', 'foodon', 'ncit', 'snomed', 'uberon'},
#  'lime mudstone': {'envo'},
#  'sea floor': {'envo'},
#  'plain': {'envo'},
#  'abattoir': {'envo'},
#  'salt': {'envo', 'ncit'},
#  'estuary': {'envo'},
#  'human construction': {'envo'},
#  'gorge': {'envo', 'snomed'},
#  'terrace': {'envo'},
#  'sandstone': {'envo'},
#  'sake brewery': {'envo'},
#  'track': {'envo', 'snomed'},
#  'flat': {'envo', 'pato', 'snomed'},
#  'oil seep': {'envo'},
#  'village biome': {'envo'},
#  'solar panel array': {'envo'},
#  'sea': {'envo', 'ncbitaxon', 'ncit', 'snomed'},
#  'xeric basin biome': {'envo'},
#  'liquid environmental material': {'envo'},
#  'marine snow': {'envo'},
#  'kelp forest': {'envo'},
#  'tissue': {'envo', 'exo', 'ncit', 'uberon'},
#  'metal contaminated soil': {'envo'},
#  'wetland area': {'envo'},
#  'supratidal zone': {'envo'},
#  'pinyon juniper woodland': {'envo'},
#  'boundary layer': {'envo'},
#  'maar': {'envo'},
#  'tidal watercourse': {'envo'},
#  'potable water': {'envo'},
#  'sugar plantation': {'envo'},
#  'tar pit': {'envo'},
#  'solutional cave': {'envo'},
#  'paved parking lot': {'envo'},
#  'marine ecosystem': {'envo'},
#  'processing plant': {'envo'},
#  'brackish water environment': {'envo'},
#  'phone': {'envo', 'ncit'},
#  'marine bathyal zone biome': {'envo'},
#  'bathymodiolus gill tissue material': {'envo'},
#  'patio': {'envo'},
#  'highway': {'envo'},
#  'glacier surface': {'envo'},
#  'branch': {'envo', 'ncit', 'po'},
#  'peat extraction': {'envo'},
#  'deep marine sediment': {'envo'},
#  'desert sand': {'envo'},
#  'salt water': {'envo', 'snomed'},
#  'area of rocky shore': {'envo'},
#  'wet': {'envo', 'micro', 'pato', 'snomed'},
#  'forest fire': {'envo'},
#  'wadi': {'envo'},
#  'lock': {'envo', 'ncit'},
#  'intertidal zone': {'envo'},
#  'riverbank': {'envo'},
#  'chemically contaminated sediment': {'envo'},
#  'canyon': {'envo'},
#  'airplane': {'envo'},
#  'moraine': {'envo'},
#  'oxic water': {'envo'},
#  'ocean biome': {'envo'},
#  'marine coral reef crest': {'envo'},
#  'archipelago': {'envo'},
#  'research laboratory': {'envo'},
#  'aquaculture of animals': {'envo'},
#  'marine supralittoral zone': {'envo'},
#  'swamp ecosystem': {'envo'},
#  'gall': {'envo', 'ncit', 'uberon'},
#  'sea beach': {'envo'},
#  'neritic sea surface microlayer biome': {'envo'},
#  'cryosphere': {'envo'},
#  'creosote contaminated soil': {'envo'},
#  'humid air': {'envo'},
#  'ocean strait': {'envo'},
#  'subglacial': {'envo'},
#  'active permafrost layer': {'envo'},
#  'aquarium': {'envo'},
#  'active layer': {'envo'},
#  'hay': {'envo'},
#  'chaparral area': {'envo'},
#  'plane': {'envo', 'genepio', 'ncit', 'snomed'},
#  'building part': {'envo'},
#  'fermentation starter': {'envo'},
#  'vegetable garden soil': {'envo'},
#  'wetland ecosystem': {'envo'},
#  'food processing building': {'envo'},
#  'soil surface layer': {'envo'},
#  'petroleum': {'envo', 'snomed'},
#  'petting zoo': {'envo'},
#  'paper': {'envo', 'foodon', 'ncit', 'snomed'},
#  'stream water': {'envo'},
#  'digestive tract environment': {'envo'},
#  'ocean current': {'envo'},
#  'warehouse': {'envo', 'snomed'},
#  'manufactured plastic': {'envo'},
#  'mere': {'envo'},
#  'waste treatment plant': {'envo'},
#  'biomaterial containment unit': {'envo'},
#  'litter': {'envo', 'snomed'},
#  'wood': {'envo', 'ncit', 'snomed'},
#  'pyritic acid mine drainage': {'envo'},
#  'zoological garden': {'envo'},
#  'basin': {'envo', 'ncit', 'snomed'},
#  'forage material': {'envo'},
#  'vomit material': {'envo'},
#  'neonatal intensive care unit': {'envo', 'snomed'},
#  'rural stormwater': {'envo'},
#  'gas': {'envo', 'ncit', 'pato', 'snomed'},
#  'emulsion': {'envo', 'ncit', 'snomed'},
#  'rainforest': {'envo'},
#  'retail store': {'envo'},
#  'dense settlement': {'envo'},
#  'drinking water treatment plant': {'envo'},
#  'small freshwater lake biome': {'envo'},
#  'temperate woodland biome': {'envo'},
#  'hypoxic water': {'envo'},
#  'sweat material': {'envo'},
#  'foamed plastic': {'envo'},
#  'flat glass': {'envo'},
#  'silty sediment': {'envo'},
#  'marine water mass': {'envo'},
#  'alkaline hot spring': {'envo'},
#  'freshwater stream biome': {'envo'},
#  'environmental material': {'envo'},
#  'artificial harbor': {'envo'},
#  'fecal environment': {'envo'},
#  'inlet': {'envo'},
#  'bog': {'envo', 'ncit'},
#  'undersea canyon': {'envo'},
#  'aquatic natural environment': {'envo'},
#  'moon': {'envo'},
#  'straw': {'envo', 'foodon', 'ncit', 'snomed'},
#  'soda lake sediment': {'envo'},
#  'thermal pollution': {'envo'},
#  'sugarcane bagasse': {'envo'},
#  'subtropical grassland biome': {'envo'},
#  'cow shed': {'envo'},
#  'aquaculture farm': {'envo'},
#  'lava field': {'envo'},
#  'alpine soil': {'envo'},
#  'interface layer': {'envo'},
#  'volcanic cone': {'envo'},
#  'bottle': {'envo', 'foodon', 'ncit', 'snomed'},
#  'temperate': {'envo'},
#  'microbial mat material': {'envo'},
#  'thermophilic sediment': {'envo'},
#  'feed storage space': {'envo'},
#  'forest canopy': {'envo'},
#  'meltwater': {'envo'},
#  'temperate savanna biome': {'envo'},
#  'tephra': {'envo'},
#  'marine reef': {'envo'},
#  'leptosol': {'envo'},
#  'pool': {'envo', 'ncit', 'snomed'},
#  'wet soil': {'envo'},
#  'bottom': {'envo', 'ncit', 'snomed'},
#  'hydrocarbon seep': {'envo'},
#  'paraffin': {'envo', 'ncit', 'snomed'},
#  'brownish colored sea ice': {'envo'},
#  'whale fall': {'envo'},
#  'dcm': {'envo', 'ncit'},
#  'deep': {'envo', 'ncit', 'pato', 'snomed'},
#  'municipal landfill': {'envo'},
#  'mediterranean woodland biome': {'envo'},
#  'anthrosol': {'envo'},
#  'rocky sand': {'envo'},
#  'subtropical rainforest': {'envo'},
#  'activated sludge': {'envo', 'ncbitaxon'},
#  'quarry': {'envo'},
#  'snowfield': {'envo'},
#  'marine coral reef deep fore reef': {'envo'},
#  'crude oil': {'envo', 'micro'},
#  'sand': {'envo', 'snomed'},
#  'rainforest biome': {'envo'},
#  'organic material': {'envo'},
#  'tidal flat': {'envo'},
#  'organic matter fall': {'envo'},
#  'water trough': {'envo'},
#  'oil refinery': {'envo'},
#  'neritic pelagic zone biome': {'envo'},
#  'piece of rock': {'envo'},
#  'headwater': {'envo'},
#  'fresh water aquarium': {'envo'},
#  'anthropogenic geographic feature': {'envo'},
#  'garbage dump': {'envo'},
#  'swamp area': {'envo'},
#  'pasture soil': {'envo'},
#  'reservoir': {'envo', 'ncit', 'snomed'},
#  'dust': {'envo', 'ncit', 'snomed'},
#  'marine coral reef back reef': {'envo'},
#  'thatch': {'envo'},
#  'intermittent reservoir': {'envo'},
#  'granular sediment': {'envo'},
#  'broad': {'envo', 'ncit', 'pato'},
#  'continental temperate': {'envo'},
#  'atmospheric aerosolisation of dust': {'envo'},
#  'atoll': {'envo'},
#  'urban area': {'envo'},
#  'ice sheet': {'envo'},
#  'microplastic particle': {'envo'},
#  'desert area': {'envo'},
#  'drainage ditch': {'envo', 'snomed'},
#  'pumice': {'envo', 'snomed'},
#  'histosol': {'envo'},
#  'drought': {'envo'},
#  'area of deciduous forest': {'envo'},
#  'estuarine water': {'envo'},
#  'hotel': {'envo', 'snomed'},
#  'agricultural wastewater treatment plant': {'envo'},
#  'polar': {'envo'},
#  'manufacturing process': {'envo'},
#  'bodily fluid material': {'envo'},
#  'kettle': {'envo'},
#  'wet market': {'envo'},
#  'sewage': {'envo', 'snomed'},
#  'wooded area': {'envo', 'snomed'},
#  'estuarine open water upper water column': {'envo'},
#  'healthcare environment': {'envo'},
#  'cryosol': {'envo'},
#  'plumbing drain': {'envo'},
#  'boreal': {'envo'},
#  'military training area': {'envo'},
#  'fan': {'envo', 'ncit', 'snomed'},
#  'mud flat': {'envo'},
#  'river bed': {'envo'},
#  'volcanic soil': {'envo'},
#  'submarine canyon': {'envo'},
#  'sea cliff': {'envo'},
#  'chernozem': {'envo'},
#  'oceanic sea surface microlayer biome': {'envo'},
#  'marine environment': {'envo'},
#  'subtropical broadleaf forest': {'envo'},
#  'beehive': {'envo'},
#  'layer': {'envo', 'ncit', 'uberon'},
#  'urban pollution': {'envo'},
#  'area of open water': {'envo'},
#  'lithosphere': {'envo'},
#  'temperate evergreen needleleaf forest': {'envo'},
#  'marine oligotrophic desert': {'envo'},
#  'market': {'envo', 'snomed'},
#  'pockmark field': {'envo'},
#  'gold mine': {'envo'},
#  'plastisphere': {'envo'},
#  'factory': {'envo', 'snomed'},
#  'stalagmite': {'envo'},
#  'wind': {'envo', 'snomed'},
#  'air': {'envo', 'ncit', 'snomed'},
#  'river mouth': {'envo'},
#  'temperate grassland': {'envo'},
#  'peninsula': {'envo'},
#  'space': {'envo', 'ncit', 'uberon'},
#  'carcass': {'envo', 'uberon'},
#  'beach': {'envo', 'snomed'},
#  'desert pavement': {'envo'},
#  'lake bed': {'envo'},
#  'wood fall': {'envo'},
#  'biodegradation of plastic': {'envo'},
#  'durisol': {'envo'},
#  'community garden': {'envo'},
#  'regolith': {'envo'},
#  'coal': {'envo', 'snomed'},
#  'cerebrospinal fluid material': {'envo'},
#  'cropland ecosystem': {'envo'},
#  'cloud': {'envo', 'ncit'},
#  'stalactite': {'envo'},
#  'enriched soil': {'envo'},
#  'concentration of ammonium in liquid water': {'envo'},
#  'nest of termite': {'envo'},
#  'gypsum': {'envo'},
#  'enrichment culturing unit': {'envo'},
#  'coastal cliff': {'envo'},
#  'subtropical desert biome': {'envo'},
#  'gravel pit': {'envo', 'snomed'},
#  'metro': {'envo'},
#  'scum': {'envo'},
#  'red soil': {'envo'},
#  'microbial feature': {'envo'},
#  'biological waste material': {'envo'},
#  'marine littoral zone': {'envo'},
#  'contaminated sludge': {'envo'},
#  'thickness of topsoil': {'envo'},
#  'marine basaltic hydrothermal vent biome': {'envo'},
#  'depression': {'envo', 'ncit', 'uberon'},
#  'desert': {'envo', 'snomed'},
#  'moor': {'envo', 'ncit'},
#  'thermokarst': {'envo'},
#  'ravine': {'envo'},
#  'coastal inlet': {'envo'},
#  'frost': {'envo'},
#  'poultry litter': {'agro', 'envo'},
#  'forest clearing': {'envo'},
#  'sea shore': {'envo'},
#  'boat': {'envo', 'snomed'},
#  'snowpack': {'envo'},
#  'moderately saline water': {'envo'},
#  'environment determined by a biofilm on an animal surface': {'envo'},
#  'glacial surface layer': {'envo'},
#  'tropical rainforest biome': {'envo'},
#  'plant environment': {'envo'},
#  'airport': {'envo', 'snomed'},
#  'anthracite': {'envo'},
#  'mangrove swamp': {'envo'},
#  'public park': {'envo', 'snomed'},
#  'mining': {'envo'},
#  'area of dwarf scrub': {'envo'},
#  'anoxic lake': {'envo'},
#  'agricultural soil': {'envo'},
#  'swimming pool': {'envo', 'snomed'},
#  'faeces material': {'envo'},
#  'breast milk material': {'envo'},
#  'runoff': {'envo'},
#  'grassland': {'envo'},
#  'fresh animal manure': {'envo'},
#  'area of gramanoid or herbaceous vegetation': {'envo'},
#  'mountain spur': {'envo'},
#  'saline water environment': {'envo'},
#  'sedimentary rock': {'envo'},
#  'alpine biome': {'envo'},
#  'wet meadow ecosystem': {'envo'},
#  'water tap': {'envo'},
#  'tar': {'envo', 'ncit', 'obi', 'snomed'},
#  'environment determined by a metazoan secretion': {'envo'},
#  'mesoscale marine eddy': {'envo'},
#  'permafrost thawing process': {'envo'},
#  'epiphyton': {'envo'},
#  'watercraft': {'envo', 'snomed'},
#  'vegetation layer': {'envo'},
#  'active chimney': {'envo'},
#  'national forest': {'envo'},
#  'coastal scrubland': {'envo'},
#  'face skin environment': {'envo'},
#  'ecosystem': {'envo'},
#  'mine tailing': {'envo'},
#  'fine sand': {'envo'},
#  'wildfire': {'envo'},
#  'arable': {'envo'},
#  'environmental system determined by a material': {'envo'},
#  'oligotrophic lake': {'envo'},
#  'particulate matter': {'envo'},
#  'clay loam': {'envo'},
#  'intermittent estuary': {'envo'},
#  'tundra ecosystem': {'envo'},
#  'estuarine coastal upper water column': {'envo'},
#  'run': {'envo', 'ncit'},
#  'biofilter': {'envo'},
#  'fermentation pit': {'envo'},
#  'marine coral reef buttress zone': {'envo'},
#  'oceanic mesopelagic zone biome': {'envo'},
#  'bank': {'envo', 'ncit', 'snomed'},
#  'metal': {'envo', 'ncit', 'snomed'},
#  'river channel': {'envo'},
#  'root nodule': {'envo', 'ncit', 'po'},
#  'stream': {'envo', 'snomed'},
#  'medical instrument': {'envo'},
#  'vent': {'envo', 'uberon'},
#  'subpolar coniferous forest biome': {'envo'},
#  'calcareous ooze': {'envo'},
#  'lava flow': {'envo'},
#  'rural settlement': {'envo'},
#  'forested wetland': {'envo'},
#  'mountains': {'envo'},
#  'brackish lake': {'envo'},
#  'periphyton': {'envo'},
#  'pier': {'envo'},
#  'church': {'envo', 'ncit', 'snomed'},
#  'muddy soil': {'envo'},
#  'field': {'envo', 'ncit', 'uberon'},
#  'soil texture': {'envo'},
#  'roof': {'envo', 'snomed'},
#  'area of barren land': {'envo'},
#  'zoo': {'envo'},
#  'crustal fluid': {'envo'},
#  'desert ecosystem': {'envo'},
#  'environment determined by a biofilm on a plant surface': {'envo'},
#  'marginal sea biome': {'envo'},
#  'algal bloom': {'envo'},
#  'building wall': {'envo'},
#  'glasshouse': {'agro', 'envo'},
#  'woodland biome': {'envo'},
#  'roadside soil': {'envo'},
#  'marine abyssal zone biome': {'envo'},
#  'animal aquaculture process': {'envo'},
#  'brackish pond': {'envo'},
#  'sewage treatment plant': {'envo'},
#  'indoor kitchen': {'envo'},
#  'excreta material': {'envo'},
#  'coal mining': {'envo', 'ncit'},
#  'mine': {'envo', 'ncit'},
#  'harbor': {'envo', 'snomed'},
#  'atmospheric aerosol': {'envo'},
#  'monomictic lake': {'envo'},
#  'area of sea ice': {'envo'},
#  'surface sediment': {'envo'},
#  'shallow marine sediment': {'envo'},
#  'urine material': {'envo'},
#  'coastal water body': {'envo'},
#  'rhizoplane': {'envo'},
#  'rangeland biome': {'envo'},
#  'silt': {'envo'},
#  'marine environmental zone': {'envo'},
#  'arable or pasturable land': {'envo'},
#  'coastal ocean water': {'envo'},
#  'marine hydrothermal vent biome': {'envo'},
#  'waterfall': {'envo', 'snomed'},
#  'fertilized soil': {'envo'},
#  'seashore': {'envo'},
#  'alas': {'envo', 'ncit'},
#  'fresh water body': {'envo'},
#  'erosionally enriched glacial ice': {'envo'},
#  'river plume': {'envo'},
#  'animal waste material': {'envo'},
#  'tidal mudflat': {'envo'},
#  'botanical garden': {'envo'},
#  'mangrove island': {'envo'},
#  'agricultural research station': {'envo'},
#  'anthropogenic environmental material': {'envo'},
#  'upland soil': {'envo'},
#  'environmental system process': {'envo'},
#  'temperate mixed needleleaf forest': {'envo'},
#  'aqueduct': {'envo', 'uberon'},
#  'soil': {'envo', 'snomed'},
#  'inshore': {'envo'},
#  'pine grove': {'envo'},
#  'active anaerobic enrichment culturing unit': {'envo'},
#  'mountain pass': {'envo'},
#  'estuarine open water lower water column': {'envo'},
#  'cliff': {'envo', 'snomed'},
#  'puddle': {'envo'},
#  'irrigated field': {'envo'},
#  'pit': {'envo', 'ncit', 'uberon'},
#  'topsoil': {'envo'},
#  'nature reserve': {'envo'},
#  'urban stormwater': {'envo'},
#  'stromatolite mat': {'envo'},
#  'pasture': {'envo'},
#  'refrigerator': {'envo', 'ncit', 'snomed'},
#  'boulder': {'envo'},
#  'mineral material': {'envo'},
#  'bioreactor': {'envo', 'obi'},
#  'temperate desert biome': {'envo'},
#  'hydroelectric reservoir': {'envo'},
#  'swamp forest': {'envo'},
#  'greenhouse soil': {'envo'},
#  'mangrove sediment': {'envo'},
#  'flood': {'envo', 'snomed'},
#  'microplastic': {'envo'},
#  'trophosome': {'envo', 'uberon'},
#  'lotic water body': {'envo'},
#  'neritic epipelagic zone biome': {'envo'},
#  'muddy water': {'envo'},
#  'cobble': {'envo'},
#  'wash': {'envo', 'ncit', 'snomed'},
#  'coastal area': {'envo'},
#  'biological product': {'envo', 'ncit'},
#  'water filter': {'envo', 'micro'},
#  'sea state': {'envo'},
#  'mesotrophic water': {'envo'},
#  'vineyards': {'envo'},
#  'volcanic feature': {'envo'},
#  'forest ecosystem': {'envo'},
#  'loam': {'envo'},
#  'shop': {'envo', 'ncit', 'snomed'},
#  'test reactor': {'envo'},
#  'nest of ant': {'envo'},
#  'first year ice': {'envo'},
#  'domestic garden': {'envo', 'snomed'},
#  'mediterranean grassland biome': {'envo'},
#  'landlocked sea': {'envo'},
#  'concrete wall': {'envo'},
#  'street': {'envo', 'ncit', 'snomed'},
#  'mountain': {'envo', 'snomed'},
#  'mangrove biome soil': {'envo'},
#  'hide': {'envo'},
#  'rubber plantation': {'envo'},
#  'marine sponge reef biome': {'envo'},
#  'bone element environment': {'envo'},
#  'finfish farming process': {'envo'},
#  'mountain summit': {'envo'},
#  'freshwater stream': {'envo'},
#  'agricultural environmental material': {'envo'},
#  'sandy loam': {'envo'},
#  'thermocline': {'envo'},
#  'planktonic material': {'envo'},
#  'dilution basin mediterranean sea biome': {'envo'},
#  'crust': {'envo', 'ncit', 'snomed'},
#  'sea grass bed': {'envo'},
#  'concrete road': {'envo'},
#  'soil layer': {'envo'},
#  'nursery': {'envo', 'ncit', 'snomed'},
#  'grassland soil': {'envo'},
#  'root matter': {'envo'},
#  'gypsisol': {'envo'},
#  'window': {'envo', 'ncit', 'snomed'},
#  'sediment environment': {'envo'},
#  'woodland ecosystem': {'envo'},
#  'plaster': {'envo', 'ncit', 'snomed'},
#  'alluvial sediment': {'envo'},
#  'farmyard manure': {'agro', 'envo'},
#  'marine biota': {'envo'},
#  'soil environment': {'envo'},
#  'acid rain': {'envo', 'exo'},
#  'soil ph': {'envo'},
#  'upper montane': {'envo'},
#  'alkaline water': {'envo', 'ncit'},
#  'hospital': {'envo', 'ncit', 'snomed'},
#  'fish hatchery': {'envo'},
#  'current': {'envo', 'ncit', 'snomed'},
#  'aquifer': {'envo'},
#  'mudstone': {'envo'},
#  'speleothem': {'envo'},
#  'pond water': {'envo', 'snomed'},
#  'shelf': {'envo', 'uberon'},
#  'environment determined by a plant substance': {'envo'},
#  'podzol': {'envo'},
#  'agriculture': {'envo', 'ncit'},
#  'atmosphere': {'envo', 'ncit', 'obi', 'snomed'},
#  'composting toilet': {'envo'},
#  'contaminated air': {'envo'},
#  'area of developed open space': {'envo'},
#  'lava': {'envo'},
#  'catchment': {'envo'},
#  'ice piedmont': {'envo'},
#  'temperate deciduous broadleaf forest': {'envo'},
#  'tropical mountain': {'envo'},
#  'sandy soil': {'envo'},
#  'palsa mire': {'envo'},
#  'methane clathrate': {'envo'},
#  'open sea': {'envo', 'snomed'},
#  'understory': {'envo'},
#  'peat bog': {'envo'},
#  'temperate marginal sea biome': {'envo'},
#  'tropical marginal sea biome': {'envo'},
#  'oil reservoir': {'envo'},
#  'compost soil': {'envo'},
#  'tropical forest': {'envo'},
#  'cloud water': {'envo'},
#  'salt spring': {'envo'},
#  'poultry hatchery': {'envo'},
#  'continental shelf': {'envo'},
#  'underground water body': {'envo'},
#  'oasis': {'envo', 'ncit'},
#  'scrub': {'envo'},
#  'upland': {'envo'},
#  'pond soil': {'envo'},
#  'calf shed': {'envo'},
#  'marine sediment': {'envo'},
#  'transportation': {'envo', 'ncit'},
#  'termite nest': {'envo'},
#  'oil palm plantation': {'envo'},
#  'brewery': {'envo'},
#  'lake with an anoxic hypolimnion': {'envo'},
#  'ramsar site': {'envo'},
#  'saline lake sediment': {'envo'},
#  'water': {'envo', 'foodon', 'ncit', 'snomed'},
#  'paint': {'envo', 'ncit', 'snomed'},
#  'temperate shrubland biome': {'envo'},
#  'frozen soil': {'envo'},
#  'pebble': {'envo'},
#  'sludge': {'envo', 'ncit', 'snomed'},
#  'abyssal plain': {'envo'},
#  'meadow soil': {'envo'},
#  'littoral zone': {'envo'},
#  'air vent': {'envo'},
#  'water well': {'envo'},
#  'cambisol': {'envo'},
#  'alluvial plain': {'envo'},
#  'pulp and paper wastewater': {'envo'},
#  'waterborne particulate matter': {'envo'},
#  'blood material': {'envo', 'snomed'},
#  'marine neritic benthic zone biome': {'envo'},
#  'ground': {'envo', 'foodon'},
#  'swamp': {'envo', 'snomed'},
#  'bile material': {'envo'},
#  'brine pool': {'envo'},
#  'watershed': {'envo'},
#  'environmental system determined by an organism': {'envo'},
#  'artificial reef': {'envo'},
#  'sea loch': {'envo'},
#  'stream sediment': {'envo'},
#  'drinking water': {'envo', 'ncit'},
#  'solfatara': {'envo'},
#  'fjord': {'envo'},
#  'gas well': {'envo'},
#  'residential building': {'envo'},
#  'montane desert biome': {'envo'},
#  'temperate mixed forest biome': {'envo'},
#  'planted forest': {'envo'},
#  'anthropised ecosystem': {'envo'},
#  'biome': {'envo'},
#  'ice': {'envo', 'foodon', 'ncit', 'snomed'},
#  'temperate rainforest': {'envo'},
#  'food shop': {'envo', 'snomed'},
#  'canopy': {'envo'},
#  'grassland biome': {'envo'},
#  'landfill': {'envo'},
#  'glacial feature': {'envo'},
#  'saline pan': {'envo'},
#  'sandbar': {'envo'},
#  'tropical shrubland biome': {'envo'},
#  'ocean basin': {'envo'},
#  'open lake': {'envo'},
#  'aircraft': {'envo', 'snomed'},
#  'gas hydrate': {'envo'},
#  'lava cave': {'envo'},
#  'epilimnion': {'envo'},
#  'sea surface layer': {'envo'},
#  'freshwater river biome': {'envo'},
#  'lake bottom mud': {'envo'},
#  'temperature of water': {'envo'},
#  'plant matter fall': {'envo'},
#  'nest': {'envo'},
#  'monument': {'envo'},
#  'mountain range': {'envo'},
#  'organic farm': {'envo'},
#  'prairie': {'envo', 'snomed'},
#  'loamy sand': {'envo'},
#  'eutrophic water': {'envo'},
#  'permafrost': {'envo'},
#  'exterior wall': {'envo'},
#  'biocrust': {'envo'},
#  'biofilm': {'envo'},
#  'marine faunal bed': {'envo'},
#  'plant pot': {'envo'},
#  'biochar': {'agro', 'envo'},
#  'litter layer': {'envo'},
#  'geyser': {'envo'},
#  'animal house': {'envo'},
#  'habitat': {'envo'},
#  'indoor toilet': {'envo'},
#  'animal litter': {'envo'},
#  'metamorphic rock': {'envo'},
#  'volcanic ash': {'envo'},
#  'fecal material': {'envo', 'uberon'},
#  'roadway': {'envo'},
#  'industrial waste': {'envo', 'ncit'},
#  'oil field production water': {'envo'},
#  'grassland ecosystem': {'envo'},
#  'urban biome': {'envo'},
#  'ultisol': {'envo'},
#  'water pollution': {'envo', 'snomed'},
#  'pipeline network': {'envo'},
#  'mediterranean sea biome': {'envo'},
#  'cooling water': {'envo'},
#  'anaerobic mud': {'envo'},
#  'anoxic water': {'envo'},
#  'environment': {'envo', 'ncit', 'snomed'},
#  'thermokarst depression': {'envo'},
#  'biofouling': {'envo'},
#  'tectonic lake': {'envo'},
#  'mixed forest biome': {'envo'},
#  'aquaculture process': {'envo'},
#  'estuarine tidal riverine open water upper water column': {'envo'},
#  'stagnosol': {'envo'},
#  'mediterranean forest': {'envo'},
#  'slurry': {'envo', 'ncit'},
#  'well': {'envo', 'ncit'},
#  'barrier reef': {'envo'},
#  'switch': {'envo', 'ncit'},
#  'sclerophyllous forest': {'envo'},
#  'fast ice': {'envo'},
#  'dairy': {'envo'},
#  'hydrothermal fluid': {'envo'},
#  'carr': {'envo'},
#  'marine subtidal rocky reef': {'envo'},
#  'anatomical entity environment': {'envo'},
#  'dry valley': {'envo'},
#  'hummock': {'envo'},
#  'alpine tundra biome': {'envo'},
#  'ant hill': {'envo'},
#  'waterhole': {'envo'},
#  'coastal plain': {'envo'},
#  'rock shelter': {'envo'},
#  'tropical lowland evergreen broadleaf rain forest': {'envo'},
#  'organic waste material': {'envo'},
#  'ria': {'envo', 'ncit'},
#  'nitrogen cycling': {'envo'},
#  'undersea feature': {'envo'},
#  'brackish water': {'envo', 'snomed'},
#  'atmospheric boundary layer': {'envo'},
#  'trail': {'envo', 'ncit'},
#  'red clay soil': {'envo'},
#  'sea cucumber gut': {'envo'},
#  'mushroom compost': {'envo'},
#  'mangrove biome sediment': {'envo'},
#  'textile': {'envo'},
#  'daqu': {'envo'},
#  'geothermally active field': {'envo'},
#  'palsa': {'envo'},
#  'subtropical savanna biome': {'envo'},
#  'ornithogenic soil': {'envo'},
#  'sandy sediment': {'envo'},
#  'public road': {'envo'},
#  'temperature of soil': {'envo'},
#  'stormwater': {'envo'},
#  'lake inlet': {'envo'},
#  'forest biome': {'envo'},
#  'season': {'envo', 'ncit'},
#  'mixed forest': {'envo'},
#  'hydrosphere': {'envo'},
#  'oil': {'envo', 'foodon', 'ncit', 'snomed'},
#  'open water': {'envo'},
#  'parking lot': {'envo'},
#  'nature conservation': {'envo'},
#  'tropical biome': {'envo'},
#  'savanna biome': {'envo'},
#  'aerosolisation of dust': {'envo'},
#  'interstitial fluid material': {'envo'},
#  'mediterranean biome': {'envo'},
#  'mesotrophic lake': {'envo'},
#  'campus': {'envo'},
#  'conifer woodland': {'envo'},
#  'drift ice': {'envo'},
#  'agricultural waste material': {'envo'},
#  'anaerobic sludge': {'envo'},
#  'tropical moist broadleaf forest biome': {'envo'},
#  'saline wetland': {'envo'},
#  'neritic mesopelagic zone biome': {'envo'},
#  'old plant': {'envo'},
#  'industrial building': {'envo'},
#  'large freshwater lake biome': {'envo'},
#  'floodplain': {'envo'},
#  'savannah': {'envo'},
#  'mangrove biome': {'envo'},
#  'clay sediment': {'envo'},
#  'area of tundra': {'envo'},
#  'sediment permeated by saline water': {'envo'},
#  'air pressure': {'envo', 'ncit', 'snomed'},
#  'divergent plate boundary': {'envo'},
#  'iron mine': {'envo'},
#  'honeycomb': {'envo', 'ncbitaxon', 'snomed'},
#  'tropical dry broadleaf forest biome': {'envo'},
#  'plant litter': {'envo'},
#  'borehole': {'envo'},
#  'anaerobic sediment': {'envo'},
#  'anaerobic sludge blanket reactor': {'envo'},
#  'marine hydrothermal vent': {'envo'},
#  'lignite': {'envo'},
#  'usage of an environment for transportation': {'envo'},
#  'temperate broadleaf evergreen forest': {'envo'},
#  'volcanic island': {'envo'},
#  'rain forest': {'envo'},
#  'solonetz': {'envo'},
#  'dry river': {'envo'},
#  'environmental system': {'envo'},
#  'manufactory': {'envo'},
#  'mineral horizon': {'envo'},
#  'mediterranean forest biome': {'envo'},
#  'sterile water': {'envo'},
#  'cloud forest': {'envo'},
#  'ephemeral spring': {'envo'},
#  'anaerobic bioreactor': {'envo'},
#  'bar': {'envo', 'ncit', 'snomed', 'uberon'},
#  'holothurian digestive tract contents': {'envo'},
#  'marine cold seep biome': {'envo'},
#  'mineral spring': {'envo'},
#  'amenity lake': {'envo'},
#  'temperate biome': {'envo'},
#  'lava tube': {'envo'},
#  'tropical dry broadleaf forest': {'envo'},
#  'artificial lake': {'envo'},
#  'oceanic island': {'envo'},
#  'large river biome': {'envo'},
#  'marine sublittoral zone': {'envo'},
#  'terrigenous sediment': {'envo'},
#  'fumarole': {'envo'},
#  'natural wax': {'envo'},
#  'natural harbor': {'envo'},
#  'door': {'envo', 'ncit', 'snomed'},
#  'concentration basin mediterranean sea biome': {'envo'},
#  'forest floor': {'envo'},
#  'pus material': {'envo'},
#  'continental margin': {'envo'},
#  'coastal sea water': {'envo'},
#  'bird nest': {'envo'},
#  'phreatic zone': {'envo'},
#  'autoclaved sand': {'envo'},
#  'reef': {'envo'},
#  'freshwater marsh': {'envo'},
#  'sterile water environment': {'envo'},
#  'drinking water reservoir': {'envo'},
#  'paddy field': {'envo'},
#  'animal waste': {'envo'},
#  'seagrass bed': {'envo'},
#  'concrete': {'envo', 'snomed'},
#  'poultry manure': {'agro', 'envo'},
#  'trench': {'envo'},
#  'rocky slope': {'envo'},
#  'marine mud': {'envo'},
#  'marine reef biome': {'envo'},
#  'bedrock': {'envo'},
#  'polar tundra ecosystem': {'envo'},
#  'aldabra island xeric scrub ecoregion': {'envo'},
#  'desert scrubland': {'envo'},
#  'shingle beach': {'envo'},
#  'marine aphotic zone': {'envo'},
#  'organic object formed through microbial activity': {'envo'},
#  'petroleum reservoir': {'envo'},
#  'saline water aquarium': {'envo'},
#  'railway': {'envo'},
#  'coarse beach sand': {'envo'},
#  'pellet': {'envo', 'ncit', 'snomed', 'uberon'},
#  'snow': {'envo', 'snomed'},
#  'cove': {'envo'},
#  'sound': {'envo', 'ncit', 'snomed'},
#  'table': {'envo', 'ncit', 'snomed'},
#  'land use process': {'envo'},
#  'environment associated with a fungal tissue': {'envo'},
#  'temperate broadleaf forest': {'envo'},
#  'burnt soil': {'envo'},
#  'groundwater flow': {'envo'},
#  'ridge': {'agro', 'envo', 'ncit', 'uberon'},
#  'limestone cave': {'envo'},
#  'steppe': {'envo'},
#  'cave system': {'envo'},
#  'cave': {'envo', 'ncit', 'snomed'},
#  'temperate grassland biome': {'envo'},
#  'hadalpelagic zone': {'envo'},
#  'brush fire': {'envo'},
#  'temperate mixed broadleaf forest': {'envo'},
#  'temperate ecosystem': {'envo'},
#  'fall': {'envo', 'ncit', 'snomed'},
#  'lagoon': {'envo'},
#  'secondary sludge': {'envo'},
#  'underground stream': {'envo'},
#  'environmental monitoring': {'envo'},
#  'circalittoral zone': {'envo'},
#  'area of cropland': {'envo'},
#  ...}

# %%
def find_exclusive_hits(hits_by_component_label):
    exclusive_hits = defaultdict(set)

    for component_label, ontologies in hits_by_component_label.items():
        if len(ontologies) == 1:  # If the label is found in only one ontology
            ontology = next(iter(ontologies))  # Get the single ontology
            exclusive_hits[ontology].add(component_label)

    return dict(exclusive_hits)

# %%
exclusive_hits_by_ontology = find_exclusive_hits(hits_by_component_label)

# %%
exclusive_hits_by_ontology
# Out:
# {'envo': {'ditch',
#   'administrative region',
#   'agricultural facility',
#   'sheepfold',
#   'mediterranean shrubland biome',
#   'saline spring',
#   'salt lake',
#   'ice mass',
#   'material primarily composed of biogenic carbonates',
#   'waterbody',
#   'culturing environment',
#   'chicken manure',
#   'terrestrial environmental zone',
#   'alluvial soil',
#   'shrimp pond',
#   'horse manure',
#   'mesoplastic particle',
#   'pancake ice',
#   'microcosm',
#   'hydrothermal vent',
#   'town hall',
#   'dense settlement biome',
#   'sink',
#   'tropical woodland biome',
#   'brine channel',
#   'biomass',
#   'cryopeg',
#   'stony soil',
#   'glacier',
#   'container of an intermittent lake',
#   'precipitation process',
#   'lakeshore',
#   'flood fringe',
#   'contaminated soil',
#   'salt marsh',
#   'university campus',
#   'infralittoral zone',
#   'polar biome',
#   'wetness of soil',
#   'mountain forest soil',
#   'umbrisol',
#   'glacial process',
#   'acid rock drainage',
#   'cleanroom',
#   'terrestrial ecosystem',
#   'slush ice',
#   'marine coral reef fore reef',
#   'lake shore',
#   'marine biome',
#   'steel',
#   'halite',
#   'masonry cement',
#   'intermittent wetland',
#   'temperate mountain',
#   'montane',
#   'sea sand',
#   'oceanic subsurface zone',
#   'deciduous forest',
#   'lake coast',
#   'limestone',
#   'fen',
#   'intertidal ecosystem',
#   'intermittent pond',
#   'sandy desert',
#   'anthropogenic contamination feature',
#   'settlement',
#   'lahar',
#   'coastal shrimp pond',
#   'tea plantation',
#   'freshwater wetland ecosystem',
#   'montane shrubland biome',
#   'saline marsh',
#   'phaeozem',
#   'animal habitation',
#   'saprolite',
#   'nest of bird',
#   'subalpine biome',
#   'strict nature reserve',
#   'uranium ore',
#   'plantation field',
#   'tube well',
#   'acidity of water',
#   'human house',
#   'streams',
#   'river valley',
#   'seagrass meadow',
#   'stainless steel',
#   'underground',
#   'glacial ice',
#   'salt pan',
#   'strait',
#   'bovine dairy liquid manure',
#   'metropolitana',
#   'vegetated hill',
#   'saline sediment environment',
#   'vineyard',
#   'tropical',
#   'hotspring',
#   'fly ash',
#   'bench',
#   'peat soil',
#   'heath',
#   'fracture water',
#   'wetland',
#   'muskeg',
#   'biosolids',
#   'grove',
#   'blanket bog',
#   'agronomic process',
#   'coastal zone',
#   'aquatic ecosystem',
#   'rice field',
#   'oil contaminated soil',
#   'dry lake',
#   'freshwater',
#   'nitisol',
#   'suspended sediment',
#   'epilithon',
#   'boulder sediment',
#   'ballast water',
#   'estuarine mud',
#   'coffee plantation',
#   'tropical savanna biome',
#   'hydrothermal seep',
#   'ecosystem process',
#   'algal material',
#   'silage',
#   'oceanic abyssopelagic zone biome',
#   'tropical broadleaf forest biome',
#   'marine hydrothermal plume',
#   'area of scrub',
#   'respirable suspended particulate matter',
#   'ground water',
#   'agricultural land conversion',
#   'flood plain',
#   'wwtp',
#   'cold season',
#   'seafloor',
#   'aeolian lake',
#   'mucus material',
#   'alluvial paddy field soil',
#   'marine tidal flow zone',
#   'ocean',
#   'area of woody wetland',
#   'tropical marine upwelling biome',
#   'tropical broadleaf forest',
#   'alkaline environment',
#   'manure storage space',
#   'closed animal house',
#   'saline lake',
#   'sea ice floe',
#   'constructed pavement',
#   'lime mudstone',
#   'sea floor',
#   'plain',
#   'abattoir',
#   'estuary',
#   'human construction',
#   'terrace',
#   'sandstone',
#   'sake brewery',
#   'oil seep',
#   'village biome',
#   'solar panel array',
#   'xeric basin biome',
#   'liquid environmental material',
#   'marine snow',
#   'kelp forest',
#   'metal contaminated soil',
#   'wetland area',
#   'supratidal zone',
#   'pinyon juniper woodland',
#   'boundary layer',
#   'maar',
#   'tidal watercourse',
#   'potable water',
#   'sugar plantation',
#   'tar pit',
#   'solutional cave',
#   'paved parking lot',
#   'marine ecosystem',
#   'processing plant',
#   'brackish water environment',
#   'marine bathyal zone biome',
#   'bathymodiolus gill tissue material',
#   'patio',
#   'highway',
#   'glacier surface',
#   'peat extraction',
#   'deep marine sediment',
#   'desert sand',
#   'area of rocky shore',
#   'forest fire',
#   'wadi',
#   'intertidal zone',
#   'riverbank',
#   'chemically contaminated sediment',
#   'canyon',
#   'airplane',
#   'moraine',
#   'oxic water',
#   'ocean biome',
#   'marine coral reef crest',
#   'archipelago',
#   'research laboratory',
#   'aquaculture of animals',
#   'marine supralittoral zone',
#   'swamp ecosystem',
#   'sea beach',
#   'neritic sea surface microlayer biome',
#   'cryosphere',
#   'creosote contaminated soil',
#   'humid air',
#   'ocean strait',
#   'subglacial',
#   'active permafrost layer',
#   'aquarium',
#   'active layer',
#   'hay',
#   'chaparral area',
#   'building part',
#   'fermentation starter',
#   'vegetable garden soil',
#   'wetland ecosystem',
#   'food processing building',
#   'soil surface layer',
#   'petting zoo',
#   'stream water',
#   'digestive tract environment',
#   'ocean current',
#   'manufactured plastic',
#   'mere',
#   'waste treatment plant',
#   'biomaterial containment unit',
#   'pyritic acid mine drainage',
#   'zoological garden',
#   'forage material',
#   'vomit material',
#   'rural stormwater',
#   'rainforest',
#   'retail store',
#   'dense settlement',
#   'drinking water treatment plant',
#   'small freshwater lake biome',
#   'temperate woodland biome',
#   'hypoxic water',
#   'sweat material',
#   'foamed plastic',
#   'flat glass',
#   'silty sediment',
#   'marine water mass',
#   'alkaline hot spring',
#   'freshwater stream biome',
#   'environmental material',
#   'artificial harbor',
#   'fecal environment',
#   'inlet',
#   'undersea canyon',
#   'aquatic natural environment',
#   'moon',
#   'soda lake sediment',
#   'thermal pollution',
#   'sugarcane bagasse',
#   'subtropical grassland biome',
#   'cow shed',
#   'aquaculture farm',
#   'lava field',
#   'alpine soil',
#   'interface layer',
#   'volcanic cone',
#   'temperate',
#   'microbial mat material',
#   'thermophilic sediment',
#   'feed storage space',
#   'forest canopy',
#   'meltwater',
#   'temperate savanna biome',
#   'tephra',
#   'marine reef',
#   'leptosol',
#   'wet soil',
#   'hydrocarbon seep',
#   'brownish colored sea ice',
#   'whale fall',
#   'municipal landfill',
#   'mediterranean woodland biome',
#   'anthrosol',
#   'rocky sand',
#   'subtropical rainforest',
#   'quarry',
#   'snowfield',
#   'marine coral reef deep fore reef',
#   'rainforest biome',
#   'organic material',
#   'tidal flat',
#   'organic matter fall',
#   'water trough',
#   'oil refinery',
#   'neritic pelagic zone biome',
#   'piece of rock',
#   'headwater',
#   'fresh water aquarium',
#   'anthropogenic geographic feature',
#   'garbage dump',
#   'swamp area',
#   'pasture soil',
#   'marine coral reef back reef',
#   'thatch',
#   'intermittent reservoir',
#   'granular sediment',
#   'continental temperate',
#   'atmospheric aerosolisation of dust',
#   'atoll',
#   'urban area',
#   'ice sheet',
#   'microplastic particle',
#   'desert area',
#   'histosol',
#   'drought',
#   'area of deciduous forest',
#   'estuarine water',
#   'agricultural wastewater treatment plant',
#   'polar',
#   'manufacturing process',
#   'bodily fluid material',
#   'kettle',
#   'wet market',
#   'estuarine open water upper water column',
#   'healthcare environment',
#   'cryosol',
#   'plumbing drain',
#   'boreal',
#   'military training area',
#   'mud flat',
#   'river bed',
#   'volcanic soil',
#   'submarine canyon',
#   'sea cliff',
#   'chernozem',
#   'oceanic sea surface microlayer biome',
#   'marine environment',
#   'subtropical broadleaf forest',
#   'beehive',
#   'urban pollution',
#   'area of open water',
#   'lithosphere',
#   'temperate evergreen needleleaf forest',
#   'marine oligotrophic desert',
#   'pockmark field',
#   'gold mine',
#   'plastisphere',
#   'stalagmite',
#   'river mouth',
#   'temperate grassland',
#   'peninsula',
#   'desert pavement',
#   'lake bed',
#   'wood fall',
#   'biodegradation of plastic',
#   'durisol',
#   'community garden',
#   'regolith',
#   'cerebrospinal fluid material',
#   'cropland ecosystem',
#   'stalactite',
#   'enriched soil',
#   'concentration of ammonium in liquid water',
#   'nest of termite',
#   'gypsum',
#   'enrichment culturing unit',
#   'coastal cliff',
#   'subtropical desert biome',
#   'metro',
#   'scum',
#   'red soil',
#   'microbial feature',
#   'biological waste material',
#   'marine littoral zone',
#   'contaminated sludge',
#   'thickness of topsoil',
#   'marine basaltic hydrothermal vent biome',
#   'thermokarst',
#   'ravine',
#   'coastal inlet',
#   'frost',
#   'forest clearing',
#   'sea shore',
#   'glacial surface layer',
#   'snowpack',
#   'moderately saline water',
#   'environment determined by a biofilm on an animal surface',
#   'tropical rainforest biome',
#   'plant environment',
#   'anthracite',
#   'mangrove swamp',
#   'mining',
#   'area of dwarf scrub',
#   'anoxic lake',
#   'agricultural soil',
#   'faeces material',
#   'breast milk material',
#   'runoff',
#   'grassland',
#   'fresh animal manure',
#   'area of gramanoid or herbaceous vegetation',
#   'mountain spur',
#   'saline water environment',
#   'sedimentary rock',
#   'alpine biome',
#   'wet meadow ecosystem',
#   'water tap',
#   'environment determined by a metazoan secretion',
#   'mesoscale marine eddy',
#   'permafrost thawing process',
#   'epiphyton',
#   'vegetation layer',
#   'active chimney',
#   'national forest',
#   'coastal scrubland',
#   'face skin environment',
#   'ecosystem',
#   'mine tailing',
#   'fine sand',
#   'wildfire',
#   'arable',
#   'environmental system determined by a material',
#   'oligotrophic lake',
#   'particulate matter',
#   'clay loam',
#   'intermittent estuary',
#   'tundra ecosystem',
#   'estuarine coastal upper water column',
#   'biofilter',
#   'fermentation pit',
#   'marine coral reef buttress zone',
#   'oceanic mesopelagic zone biome',
#   'river channel',
#   'medical instrument',
#   'subpolar coniferous forest biome',
#   'calcareous ooze',
#   'lava flow',
#   'rural settlement',
#   'forested wetland',
#   'mountains',
#   'brackish lake',
#   'periphyton',
#   'pier',
#   'muddy soil',
#   'soil texture',
#   'area of barren land',
#   'zoo',
#   'crustal fluid',
#   'desert ecosystem',
#   'environment determined by a biofilm on a plant surface',
#   'marginal sea biome',
#   'algal bloom',
#   'building wall',
#   'woodland biome',
#   'roadside soil',
#   'marine abyssal zone biome',
#   'animal aquaculture process',
#   'brackish pond',
#   'sewage treatment plant',
#   'indoor kitchen',
#   'excreta material',
#   'atmospheric aerosol',
#   'monomictic lake',
#   'area of sea ice',
#   'surface sediment',
#   'shallow marine sediment',
#   'urine material',
#   'coastal water body',
#   'rhizoplane',
#   'rangeland biome',
#   'silt',
#   'marine environmental zone',
#   'arable or pasturable land',
#   'coastal ocean water',
#   'marine hydrothermal vent biome',
#   'fertilized soil',
#   'seashore',
#   'fresh water body',
#   'erosionally enriched glacial ice',
#   'river plume',
#   'animal waste material',
#   'tidal mudflat',
#   'botanical garden',
#   'mangrove island',
#   'agricultural research station',
#   'anthropogenic environmental material',
#   'upland soil',
#   'environmental system process',
#   'temperate mixed needleleaf forest',
#   'inshore',
#   'pine grove',
#   'active anaerobic enrichment culturing unit',
#   'mountain pass',
#   'estuarine open water lower water column',
#   'puddle',
#   'irrigated field',
#   'topsoil',
#   'nature reserve',
#   'urban stormwater',
#   'stromatolite mat',
#   'pasture',
#   'boulder',
#   'mineral material',
#   'temperate desert biome',
#   'hydroelectric reservoir',
#   'swamp forest',
#   'greenhouse soil',
#   'mangrove sediment',
#   'microplastic',
#   'lotic water body',
#   'neritic epipelagic zone biome',
#   'muddy water',
#   'cobble',
#   'coastal area',
#   'sea state',
#   'mesotrophic water',
#   'vineyards',
#   'volcanic feature',
#   'forest ecosystem',
#   'loam',
#   'test reactor',
#   'nest of ant',
#   'first year ice',
#   'mediterranean grassland biome',
#   'landlocked sea',
#   'concrete wall',
#   'mangrove biome soil',
#   'hide',
#   'rubber plantation',
#   'marine sponge reef biome',
#   'bone element environment',
#   'finfish farming process',
#   'mountain summit',
#   'freshwater stream',
#   'agricultural environmental material',
#   'sandy loam',
#   'thermocline',
#   'planktonic material',
#   'dilution basin mediterranean sea biome',
#   'sea grass bed',
#   'concrete road',
#   'soil layer',
#   'grassland soil',
#   'root matter',
#   'gypsisol',
#   'sediment environment',
#   'woodland ecosystem',
#   'alluvial sediment',
#   'marine biota',
#   'soil environment',
#   'soil ph',
#   'upper montane',
#   'fish hatchery',
#   'aquifer',
#   'mudstone',
#   'speleothem',
#   'environment determined by a plant substance',
#   'podzol',
#   'composting toilet',
#   'contaminated air',
#   'area of developed open space',
#   'lava',
#   'catchment',
#   'ice piedmont',
#   'temperate deciduous broadleaf forest',
#   'tropical mountain',
#   'sandy soil',
#   'palsa mire',
#   'methane clathrate',
#   'understory',
#   'peat bog',
#   'temperate marginal sea biome',
#   'tropical marginal sea biome',
#   'oil reservoir',
#   'compost soil',
#   'tropical forest',
#   'cloud water',
#   'salt spring',
#   'poultry hatchery',
#   'continental shelf',
#   'underground water body',
#   'scrub',
#   'upland',
#   'pond soil',
#   'calf shed',
#   'marine sediment',
#   'termite nest',
#   'oil palm plantation',
#   'brewery',
#   'lake with an anoxic hypolimnion',
#   'ramsar site',
#   'saline lake sediment',
#   'temperate shrubland biome',
#   'frozen soil',
#   'pebble',
#   'abyssal plain',
#   'meadow soil',
#   'littoral zone',
#   'air vent',
#   'water well',
#   'cambisol',
#   'alluvial plain',
#   'pulp and paper wastewater',
#   'waterborne particulate matter',
#   'marine neritic benthic zone biome',
#   'bile material',
#   'brine pool',
#   'watershed',
#   'environmental system determined by an organism',
#   'artificial reef',
#   'sea loch',
#   'stream sediment',
#   'solfatara',
#   'fjord',
#   'gas well',
#   'residential building',
#   'montane desert biome',
#   'temperate mixed forest biome',
#   'planted forest',
#   'anthropised ecosystem',
#   'biome',
#   'temperate rainforest',
#   'canopy',
#   'grassland biome',
#   'landfill',
#   'glacial feature',
#   'saline pan',
#   'sandbar',
#   'tropical shrubland biome',
#   'ocean basin',
#   'open lake',
#   'gas hydrate',
#   'lava cave',
#   'epilimnion',
#   'sea surface layer',
#   'freshwater river biome',
#   'lake bottom mud',
#   'temperature of water',
#   'plant matter fall',
#   'nest',
#   'monument',
#   'mountain range',
#   'organic farm',
#   'loamy sand',
#   'eutrophic water',
#   'permafrost',
#   'exterior wall',
#   'biocrust',
#   'biofilm',
#   'marine faunal bed',
#   'plant pot',
#   'litter layer',
#   'geyser',
#   'animal house',
#   'habitat',
#   'indoor toilet',
#   'animal litter',
#   'metamorphic rock',
#   'volcanic ash',
#   'roadway',
#   'oil field production water',
#   'grassland ecosystem',
#   'urban biome',
#   'ultisol',
#   'pipeline network',
#   'mediterranean sea biome',
#   'cooling water',
#   'anaerobic mud',
#   'anoxic water',
#   'thermokarst depression',
#   'biofouling',
#   'tectonic lake',
#   'mixed forest biome',
#   'aquaculture process',
#   'estuarine tidal riverine open water upper water column',
#   'stagnosol',
#   'mediterranean forest',
#   'barrier reef',
#   'sclerophyllous forest',
#   'fast ice',
#   'dairy',
#   'hydrothermal fluid',
#   'carr',
#   'marine subtidal rocky reef',
#   'anatomical entity environment',
#   'dry valley',
#   'hummock',
#   'alpine tundra biome',
#   'ant hill',
#   'waterhole',
#   'coastal plain',
#   'rock shelter',
#   'tropical lowland evergreen broadleaf rain forest',
#   'organic waste material',
#   'nitrogen cycling',
#   'undersea feature',
#   'atmospheric boundary layer',
#   'red clay soil',
#   'sea cucumber gut',
#   'mushroom compost',
#   'mangrove biome sediment',
#   'textile',
#   'daqu',
#   'geothermally active field',
#   'palsa',
#   'subtropical savanna biome',
#   'ornithogenic soil',
#   'sandy sediment',
#   'public road',
#   'temperature of soil',
#   'stormwater',
#   'lake inlet',
#   'forest biome',
#   'mixed forest',
#   'hydrosphere',
#   'open water',
#   'parking lot',
#   'nature conservation',
#   'tropical biome',
#   'savanna biome',
#   'aerosolisation of dust',
#   'interstitial fluid material',
#   'mediterranean biome',
#   'mesotrophic lake',
#   'campus',
#   'conifer woodland',
#   'drift ice',
#   'agricultural waste material',
#   'anaerobic sludge',
#   'tropical moist broadleaf forest biome',
#   'saline wetland',
#   'neritic mesopelagic zone biome',
#   'old plant',
#   'industrial building',
#   'large freshwater lake biome',
#   'floodplain',
#   'savannah',
#   'mangrove biome',
#   'clay sediment',
#   'area of tundra',
#   'sediment permeated by saline water',
#   'divergent plate boundary',
#   'iron mine',
#   'tropical dry broadleaf forest biome',
#   'plant litter',
#   'borehole',
#   'anaerobic sediment',
#   'anaerobic sludge blanket reactor',
#   'marine hydrothermal vent',
#   'lignite',
#   'usage of an environment for transportation',
#   'temperate broadleaf evergreen forest',
#   'volcanic island',
#   'rain forest',
#   'solonetz',
#   'dry river',
#   'environmental system',
#   'manufactory',
#   'mineral horizon',
#   'mediterranean forest biome',
#   'sterile water',
#   'cloud forest',
#   'ephemeral spring',
#   'anaerobic bioreactor',
#   'holothurian digestive tract contents',
#   'marine cold seep biome',
#   'mineral spring',
#   'amenity lake',
#   'temperate biome',
#   'lava tube',
#   'tropical dry broadleaf forest',
#   'artificial lake',
#   'oceanic island',
#   'large river biome',
#   'marine sublittoral zone',
#   'terrigenous sediment',
#   'fumarole',
#   'natural wax',
#   'natural harbor',
#   'concentration basin mediterranean sea biome',
#   'forest floor',
#   'pus material',
#   'continental margin',
#   'coastal sea water',
#   'bird nest',
#   'phreatic zone',
#   'autoclaved sand',
#   'reef',
#   'freshwater marsh',
#   'sterile water environment',
#   'drinking water reservoir',
#   'paddy field',
#   'animal waste',
#   'seagrass bed',
#   'trench',
#   'rocky slope',
#   'marine mud',
#   'marine reef biome',
#   'bedrock',
#   'polar tundra ecosystem',
#   'aldabra island xeric scrub ecoregion',
#   'desert scrubland',
#   'shingle beach',
#   'marine aphotic zone',
#   'organic object formed through microbial activity',
#   'petroleum reservoir',
#   'saline water aquarium',
#   'railway',
#   'coarse beach sand',
#   'cove',
#   'land use process',
#   'environment associated with a fungal tissue',
#   'temperate broadleaf forest',
#   'burnt soil',
#   'groundwater flow',
#   'limestone cave',
#   'steppe',
#   'cave system',
#   'temperate grassland biome',
#   'hadalpelagic zone',
#   'brush fire',
#   'temperate mixed broadleaf forest',
#   'temperate ecosystem',
#   'lagoon',
#   'secondary sludge',
#   'underground stream',
#   'environmental monitoring',
#   'circalittoral zone',
#   'area of cropland',
#   'acidic soil',
#   'gravel field',
#   'chyme material',
#   'marine mesopelagic zone',
#   'turf',
#   'dry woodland',
#   'polar desert biome',
#   'agricultural waste',
#   'chemocline',
#   'cell culturing',
#   'montane conifer woodland',
#   'continental slope',
#   'hypereutrophic water',
#   'sphagnum bog',
#   'andosol',
#   'laboratory environment',
#   'particulate environmental material',
#   'salt pond',
#   'area of polar tundra',
#   'desert scrub',
#   'farms',
#   'chicken coop',
#   'salt contaminated soil',
#   'continental rise',
#   'processing line',
#   'ice field',
#   'saline water',
#   'aerobic bioreactor',
#   'humic lake',
#   'pond bottom',
#   'uranium mine',
#   'methane seep',
#   'woodland clearing',
#   'cenote',
#   'hydrothermal field',
#   'rice straw',
#   'lichen woodland',
#   'marine abyssalpelagic zone',
#   'ecotone',
#   'arid subtropical',
#   'surface soil',
#   'sewage plant',
#   'sinkhole',
#   'biodegradation',
#   'hypersaline lake',
#   'desert oasis',
#   'understorey',
#   'marine brine pool',
#   'intensive care unit facility',
#   'burned soil',
#   'feces material',
#   'metalimnion',
#   'forestry',
#   'alkaline flat',
#   'tended pasturable land',
#   'shoreline',
#   'epeiric sea biome',
#   'terrestrial natural environment',
#   'rangeland',
#   'subtropical forest',
#   'fouling',
#   'marine pelagic biome',
#   'farm soil',
#   'bacteria enriched soil',
#   'subtropical shrubland biome',
#   'seabed',
#   'oxbow lake',
#   'large river headwater biome',
#   'igneous rock',
#   'rock',
#   'warm monomictic lake',
#   'steppe soil',
#   'mine drainage',
#   'marine bed',
#   'cultivated environment',
#   'glacier retreat',
#   'glacial retreat',
#   'botanic garden',
#   'area of developed space with high usage intensity',
#   'brackish estuary',
#   'broadleaf forest biome',
#   'acidic hot spring',
#   'irrigation reservoir',
#   'sediment surface',
#   'alkaline spring',
#   'volcanic rock',
#   'freshwater littoral zone',
#   'area of developed space',
#   'ecological corridor',
#   'seamount',
#   'estuarine coastal surface layer',
#   'bayou',
#   'island arc',
#   'underground river',
#   'luvisol',
#   'drainage basin',
#   'subpolar environment',
#   'asphalt lake',
#   'tropical marine coral reef biome',
#   'freshwater algal bloom',
#   'paper product',
#   'polar environment',
#   'snowmelt',
#   'shore',
#   'tailing',
#   'organic dairy farm',
#   'brook',
#   'marine algal bloom',
#   'fluid environmental material',
#   'irrigation ditch',
#   'freshwater spring',
#   'salty soil',
#   'estuarine biome',
#   'subtropical biome',
#   'subalpine',
#   'area of developed space with low usage intensity',
#   'clay soil',
#   'axilla skin environment',
#   'dry lake bed',
#   'peat cut',
#   'oceanic hadal pelagic zone biome',
#   'sand dune',
#   'sea cave',
#   'barrier island',
#   'soda lake',
#   'allotment garden',
#   'mound',
#   'silty loam',
#   'stream bed',
#   'manure',
#   'snow field',
#   'environment associated with an animal part or small animal',
#   'caldera lake',
#   'algal production',
#   'mussel bed',
#   'marine pelagic zone',
#   'photobioreactor',
#   'gleysol',
#   'rivulet',
#   'area of emergent herbaceous wetland',
#   'refinery',
#   'iucn national park',
#   'slough',
#   'sea water',
#   'temperature of environmental material',
#   'stagnant water',
#   'thermokarst lake',
#   'nesting material',
#   'woodland area',
#   'banana plantation',
#   'sedimentary stratum',
#   'sodium chloride salt',
#   'saliva material',
#   'industrial wastewate treatment plant',
#   'estuarine coastal lower water column',
#   'freshwater lake biome',
#   'tile',
#   'fish farm',
#   'agricultural ecosystem',
#   'microcontinental island',
#   'rapids',
#   'rocky desert',
#   'leaf litter',
#   'taiga',
#   'culvert',
#   'water current',
#   'ice shelf',
#   ...},
#  'ncit': {'abdominal fluid',
#   'acne vulgaris',
#   'activated',
#   'activated carbon',
#   'adjacent',
#   'after treatment',
#   'aggregates',
#   'agricultural workers',
#   'aif',
#   'air control',
#   'airborne particulate matter',
#   'alp',
#   'alps',
#   'ambient',
#   'ambient air',
#   'amc',
#   'amd',
#   'american',
#   'amf',
#   'amplification',
#   'ann arbor',
#   'ant',
#   'antecubital fossa',
#   'antibiotics',
#   'any',
#   'aom',
#   'apa',
#   'app',
#   'april',
#   'aqua',
#   'aqueous',
#   'arctic',
#   'ari',
#   'arthropod',
#   'aso',
#   'aspirate',
#   'ast',
#   'aus',
#   'autumn',
#   'azoxymethane',
#   'bac',
#   'background',
#   'bacterial disease',
#   'bait',
#   'ballast',
#   'balloon',
#   'barcode',
#   'bariatric surgery',
#   'base',
#   'baseline',
#   'batch',
#   'bck',
#   'bead',
#   'before treatment',
#   'ben',
#   'bht',
#   'bile fluid',
#   'bile juice',
#   'biliary',
#   'biological',
#   'biological sample',
#   'biom',
#   'biosample',
#   'birth canal',
#   'bladder tumor',
#   'blade',
#   'blood agar',
#   'blood collection tube',
#   'blood draw',
#   'blood sample',
#   'bob',
#   'boxwood',
#   'brain metastases',
#   'brain metastasis',
#   'brain tumor',
#   'breast tissue',
#   'breast tumor',
#   'breed',
#   'breeding',
#   'brewers yeast',
#   'brm',
#   'bronchial brushing',
#   'bronchial lavage',
#   'bronchial lavage fluid',
#   'bronchial secretion',
#   'bronchoalveolar lavage fluid',
#   'bryophyte',
#   'bsc',
#   'bsl',
#   'buccal cells',
#   'buccal surface',
#   'buccal swab',
#   'buckwheat',
#   'bulk',
#   'butcher',
#   'cae',
#   'can',
#   'carbohydrates',
#   'cardia',
#   'cardiovascular',
#   'care',
#   'cavities',
#   'cbfb',
#   'cca',
#   'cdna',
#   'cecal',
#   'cell line',
#   'cells',
#   'celsius degree',
#   'center',
#   'cervical tumor',
#   'cervicovaginal secretion',
#   'chamber',
#   'che',
#   'cheek mucosa',
#   'cip',
#   'cjd',
#   'classroom',
#   'clinical study',
#   'clo',
#   'close',
#   'clover',
#   'cnr',
#   'collar',
#   'collected',
#   'cologne',
#   'colon tumor',
#   'colon wall',
#   'colony',
#   'colorado river',
#   'colorectal adenocarcinoma',
#   'colorectal cancer',
#   'colorectal polyp',
#   'commercial',
#   'common milkweed',
#   'company',
#   'con',
#   'cond',
#   'consortium',
#   'construct',
#   'cont',
#   'contact lens',
#   'cool',
#   'copd',
#   'cows',
#   'crc',
#   'crp',
#   'crypt',
#   'ct a',
#   'ctd',
#   'ctrl',
#   'cub',
#   'cultured cell line',
#   'currency',
#   'cyc',
#   'cytosol',
#   'dairy products',
#   'damp',
#   'days',
#   'dcb',
#   'dcf',
#   'dcs',
#   'degradation',
#   'degraded',
#   'dental exam',
#   'dental implant',
#   'deposits',
#   'dermatosis',
#   'developmental process',
#   'diabetes',
#   'dialysate',
#   'dic',
#   'digestive',
#   'discovery',
#   'diseased',
#   'dlbcl',
#   'dmem',
#   'dms',
#   'dna',
#   'domestic animal',
#   'don',
#   'donor',
#   'drainage',
#   'dried blood spot',
#   'drinker',
#   'dropping',
#   'dss',
#   'duodenal biopsy',
#   'duodenal fluid',
#   'dys',
#   'dzn',
#   'ecm',
#   'ecto',
#   'edna',
#   'edta',
#   'empty',
#   'enclosure',
#   'end stage renal failure',
#   'endometrial',
#   'engineering',
#   'enrichment',
#   'enterocytes',
#   'entity',
#   'env',
#   'environmental dna',
#   'epi',
#   'epithelial',
#   'epithelial cells',
#   'erc',
#   'esophageal',
#   'eswatini',
#   'eukaryote',
#   'eva',
#   'evolution',
#   'exacerbation',
#   'exhibit',
#   'expectorate',
#   'experimental',
#   'exposure',
#   'external surface',
#   'extremely preterm infant',
#   'eye discharge',
#   'faces',
#   'fca',
#   'feature',
#   'fecal',
#   'fermented dairy product',
#   'fetal',
#   'fetal kidney',
#   'fetal liver',
#   'ffpe',
#   'filed',
#   'flask',
#   'floor',
#   'fmt',
#   'food industry',
#   'formation',
#   'formula',
#   'fos',
#   'fractionation',
#   'frozen tissue',
#   'fruit or vegetable',
#   'fvb',
#   'gac',
#   'galician',
#   'garbage',
#   'gastric biopsy',
#   'gastric fluid',
#   'gastric tissue',
#   'gastrointestinal',
#   'gastrointestinal fluid or secretion',
#   'gcf',
#   'gdna',
#   'gen',
#   'general population',
#   'generation',
#   'genomic dna',
#   'gingival margin',
#   'glass fiber',
#   'glp',
#   'gos',
#   'gram negative bacteria',
#   'granule',
#   'graphite',
#   'greenland',
#   'gro',
#   'gsm',
#   'guadeloupe',
#   'gut flora',
#   'gut microbiota',
#   'hamster',
#   'han chinese',
#   'hau',
#   'hdpe',
#   'health care',
#   'healthcare',
#   'healthcare organization',
#   'healthy',
#   'healthy control',
#   'healthy subject',
#   'hek',
#   'high density polyethylene',
#   'high ph',
#   'hive',
#   'hollow fiber',
#   'homogenate',
#   'hours',
#   'hrs',
#   'hrt',
#   'hscr',
#   'http',
#   'hubei',
#   'human adipose tissue',
#   'human amniotic fluid',
#   'human bone',
#   'human colostrum',
#   'human cornea',
#   'human placenta',
#   'human skin',
#   'hun',
#   'hypoxic',
#   'ibd',
#   'identifiable',
#   'ile',
#   'ileostomy',
#   'ileum wall',
#   'imo',
#   'in patient',
#   'in the field',
#   'in vitro',
#   'in vitro model',
#   'industrial',
#   'industry',
#   'inf',
#   'infant botulism',
#   'infected',
#   'infection',
#   'ini',
#   'inner',
#   'input',
#   'inside',
#   'integrated',
#   'interface',
#   'intestinal flora',
#   'intestinal microbiome',
#   'intestinal microbiota',
#   'intestinal microflora',
#   'intestines',
#   'intrahepatic cholangiocarcinoma',
#   'invasion',
#   'ireland',
#   'july',
#   'june',
#   'kernel',
#   'keyboard',
#   'kit',
#   'lab',
#   'lake superior',
#   'lam',
#   'lavage fluid',
#   'ldl',
#   'leu',
#   'liquid based cytology',
#   'liver abscess',
#   'load',
#   'log',
#   'low ph',
#   'lpa',
#   'lui',
#   'luminal',
#   'lung biopsy',
#   'lung fluid',
#   'lung infection',
#   'lung lavage',
#   'lung tissue',
#   'lung tumor',
#   'lymph node biopsy',
#   'lymphoid',
#   'lysate',
#   'mammalian',
#   'mammary',
#   'managed',
#   'mar',
#   'march',
#   'marker',
#   'mastitis',
#   'mat',
#   'mbo',
#   'mbr',
#   'mce',
#   'mda',
#   'mdf',
#   'med',
#   'mef',
#   'mesenteric lymph nodes',
#   'metagenomic',
#   'metallic',
#   'mia',
#   'microbial',
#   'microbial dna',
#   'microbial solid culture',
#   'microneedle array',
#   'microorganism',
#   'microorganisms',
#   'middle',
#   'minas gerais',
#   'minerals',
#   'mint flavor',
#   'mirasol',
#   'miss',
#   'missing data',
#   'missing information',
#   'mnase',
#   'molecular',
#   'months',
#   'mouse blood',
#   'mouse cecum',
#   'mouse cerebellum',
#   'mouse colon',
#   'mouse digestive system',
#   'mouse digestive tract',
#   'mouse feces',
#   'mouse gastrointestinal tract',
#   'mouse ileum',
#   'mouse intestine',
#   'mouse lung',
#   'mouse oral cavity',
#   'mouse skin',
#   'mouse spleen',
#   'mouse stomach',
#   'mouse stool',
#   'mouthwash',
#   'mrs',
#   'msi',
#   'msm',
#   'mucosal biopsy',
#   'mucosal lavage',
#   'municipality',
#   'murine',
#   'mutant',
#   'mycelium',
#   'mycobiome',
#   'nacl',
#   'naive',
#   'nano',
#   'nasal lavage',
#   'nasal polyp',
#   'nasal swab',
#   'nasal wash',
#   'nat',
#   'near',
#   'necrotic lesion',
#   'neg',
#   'negative control',
#   'neighborhood',
#   'neutral',
#   'nhc',
#   'nhs',
#   'night',
#   'nih clinical center',
#   'no data',
#   'no information',
#   'no treatment',
#   'nob',
#   'nod',
#   'nom',
#   'non',
#   'non malignant',
#   'normal skin',
#   'northeast',
#   'northern',
#   'northwestern',
#   'nose swab',
#   'not',
#   'not assigned',
#   'not available',
#   'not determined',
#   'not given',
#   'not identified',
#   'not known',
#   'not obtained',
#   'not recorded',
#   'nov',
#   'november',
#   'npk',
#   'nuclear',
#   'oab',
#   'occipital',
#   'oct',
#   'omb',
#   'oncology department',
#   'opened',
#   'operating room',
#   'opt',
#   'oral cancer',
#   'oral gavage',
#   'oral microbiome',
#   'oral microbiota',
#   'oral rinse',
#   'org',
#   'organic',
#   'organism part',
#   'organisms',
#   'organoid',
#   'organs',
#   'oropharyngeal swab',
#   'orthodontic treatment',
#   'orthopedics',
#   'oscc',
#   'others',
#   'outside',
#   'oxide',
#   'pacemaker',
#   'pair',
#   'pancreas tumor',
#   'paranasal sinuses',
#   'pathogen',
#   'pbmc',
#   'pbr',
#   'pbs',
#   'pcl',
#   'pcos',
#   'pcr',
#   'pda',
#   'pdac',
#   'pdb',
#   'pdf',
#   'pei',
#   'pha',
#   'pharmaceutical',
#   'pharyngeal',
#   'phosphate buffer',
#   'physiology',
#   'pipe',
#   'pji',
#   'placebo',
#   'plant',
#   'plasma sample',
#   'pmr',
#   'pnd',
#   'polymers',
#   'positive control',
#   'posttreatment',
#   'pots',
#   'potting',
#   'preterm',
#   'preterm birth',
#   'preterm infant',
#   'pretreatment',
#   'primary',
#   'prm',
#   'probiotic',
#   'processing',
#   'product',
#   'protist',
#   'protoplast',
#   'protozoa',
#   'provided',
#   'psu',
#   'pvc',
#   'quality control',
#   'rabbit breed',
#   'ras',
#   'rat cecum',
#   'rcd',
#   'rda',
#   'rdna',
#   'reactor',
#   'rec',
#   'recipient',
#   'recover',
#   'recovery',
#   'reference',
#   'refuse',
#   'remission',
#   'renal failure',
#   'rep',
#   'replicate',
#   'reproduction',
#   'reproductive',
#   'rerun',
#   'research facilities',
#   'residue',
#   'respiratory',
#   'respiratory flora',
#   'rio grande do sul',
#   'rna',
#   'rnalater',
#   'ron',
#   'room temperature',
#   'rose',
#   'rpmi',
#   'rrna',
#   'rss',
#   'rte',
#   'rural',
#   'russia',
#   'rvd',
#   'salar',
#   'saline',
#   'saliva sample',
#   'salivary glands',
#   'sam',
#   'sample',
#   'sampling',
#   'sant',
#   'sao paulo',
#   'sap',
#   'saw',
#   'sawdust',
#   'sbr',
#   'scrape',
#   'sda',
#   'sds',
#   'sed',
#   'seeds',
#   'seg',
#   'senior',
#   'sep',
#   'september',
#   'sfa',
#   'sham',
#   'shelf life',
#   'shelter',
#   'sii',
#   'sites',
#   'skin abscess',
#   'skin biopsy',
#   'slit lamp',
#   'slit lamp examination',
#   'small intestinal biopsy',
#   'sml',
#   'smoking',
#   'social',
#   'south korea',
#   'southeast',
#   'southeastern',
#   'spb',
#   'spf',
#   'spinal',
#   'spm',
#   'spore',
#   'spores',
#   'sputum sample',
#   'srb',
#   'ssr',
#   'standard',
#   'station',
#   'stimulated',
#   'sto',
#   'stomach contents',
#   'stone',
#   'stool sample',
#   'storage media',
#   'subcutaneous abscess',
#   'subgingival',
#   'subject',
#   'submaxillary',
#   'substrate',
#   'sufu',
#   'summer',
#   'sup',
#   'supernatant',
#   'svalbard',
#   'swds',
#   'sycamore',
#   'syk',
#   't cell lymphoma',
#   'tad',
#   'tap',
#   'tbc',
#   'tbi',
#   'tch',
#   'tcs',
#   'tea plant',
#   'terminal ileum',
#   'test',
#   'thr',
#   'tibetan',
#   'time point',
#   'tissue bank',
#   'tissue core',
#   'tissue sample',
#   'tissue type',
#   'tissues',
#   'tma',
#   'tobacco leaf',
#   'tonsils',
#   'tooth abscess',
#   'topography',
#   'total rna',
#   'tracheal aspirate',
#   'transcriptome',
#   'transfer',
#   'transformed',
#   'transition',
#   'trap',
#   'treated',
#   'treatment plan',
#   'tree root',
#   'tris buffer',
#   'tsa',
#   'tumor',
#   'tumor sample',
#   'tumor tissue',
#   'twig',
#   'uberon',
#   'ucd',
#   'unclear',
#   'unfiltered',
#   'uninfected',
#   'united states',
#   'untreated control',
#   'upper airway',
#   'urbanized area',
#   'urethane',
#   'urinary',
#   'urinary tract infection',
#   'urine sample',
#   'usa',
#   'usd',
#   'uterine',
#   'uti',
#   'variety',
#   'vascular plant',
#   'vat',
#   'vcap',
#   'ventral',
#   'vertebrate',
#   'vic',
#   'viral particles',
#   'vitamin b',
#   'watermelon flavor',
#   'western european',
#   'wgs',
#   'whole animal',
#   'wild type',
#   'winter',
#   'world',
#   'wound infection',
#   'wrapper',
#   'wuhan',
#   'xpc',
#   'zeolite'},
#  'agro': {'agricultural experimental plot',
#   'agroforestry',
#   'alley cropping',
#   'animal feeding equipment',
#   'augmentation',
#   'biofertilizer',
#   'biological control',
#   'chicken litter',
#   'conventional tillage',
#   'crop residue',
#   'crop rotation',
#   'cropping system',
#   'fertilization process',
#   'field area',
#   'field margin',
#   'harvesting',
#   'mineral fertilizer',
#   'nitrogen fertilizer',
#   'parcel',
#   'plot',
#   'rainfed',
#   'research station field',
#   'shelterbelt',
#   'soil sample',
#   'ssti',
#   'tillage',
#   'vermicompost'},
#  'snomed': {'acute pulpitis',
#   'agar',
#   'agar medium',
#   'agarose',
#   'ageing',
#   'agrochemical',
#   'altitude',
#   'aluminium',
#   'amoeba culture',
#   'anaerobic chamber',
#   'anaerobic culture',
#   'anal swab',
#   'animal hide',
#   'avulsion',
#   'bacterial culture',
#   'bacterial genome',
#   'baker',
#   'bedroom',
#   'biliary sludge',
#   'blood culture',
#   'brain tissue',
#   'bran',
#   'brass',
#   'breast normal',
#   'bronchial fluid',
#   'burial',
#   'canalisation',
#   'caries active',
#   'catarrhal gingivitis',
#   'catheter tip',
#   'cereal',
#   'cervical swab',
#   'chimney',
#   'city environment',
#   'coagulant',
#   'coastal environment',
#   'coastal sea',
#   'cockroach',
#   'cold water',
#   'colonic contents',
#   'complicated appendicitis',
#   'concha bullosa',
#   'controlled temperature',
#   'coriaria thymifolia',
#   'countryside',
#   'cyst fluid',
#   'cytology brush',
#   'dermatophyte',
#   'diabetic foot ulcer',
#   'diarrhoea',
#   'dining room',
#   'douglas fir',
#   'downstream',
#   'duodenal',
#   'duodenal biopsy sample',
#   'duodenal juice',
#   'ear discharge',
#   'elevator',
#   'endodontic paper point',
#   'endometrial biopsy curette',
#   'endotracheal tube',
#   'england',
#   'entrance',
#   'eutrophication',
#   'exposure to environmental pollution',
#   'eye fluid',
#   'farm house',
#   'farm land',
#   'farming environment',
#   'fermented food',
#   'fertiliser',
#   'fertilizer',
#   'fetal membranes',
#   'floor swab',
#   'flowers',
#   'forceps',
#   'frontal recess',
#   'fungal genome',
#   'fungal product',
#   'garage',
#   'gastrointestinal contents',
#   'giardiasis',
#   'golf course',
#   'grapes',
#   'group c',
#   'group d',
#   'gymnasium',
#   'hawaii island',
#   'heavy metal',
#   'high altitude',
#   'high fat diet',
#   'hospital acquired',
#   'hospital environment',
#   'hospital patient',
#   'hot environment',
#   'hot water',
#   'house dust',
#   'housed',
#   'human cells',
#   'human tissue',
#   'humid environment',
#   'industrial environment',
#   'industrial plant',
#   'industrial site',
#   'insecticide',
#   'institutionalized',
#   'interdental',
#   'interdigital',
#   'kitikmeot',
#   'knife',
#   'laboratory incubator',
#   'landfill site',
#   'leather',
#   'leaves',
#   'ligature',
#   'lotus tuber',
#   'lounge',
#   'low altitude',
#   'matrix stone',
#   'meat products',
#   'medical intensive care unit',
#   'medical student',
#   'meters',
#   'microbial agent',
#   'middle ear fluid',
#   'mill',
#   'mining waste',
#   'moorland',
#   'mouth swab',
#   'mudflats',
#   'museum',
#   'mussels',
#   'nasopharyngeal',
#   'nasopharyngeal aspirate',
#   'nil',
#   'normal diet',
#   'not applied',
#   'nothing',
#   'open wound',
#   'oral swab',
#   'oxygen concentration',
#   'perianal swab',
#   'periapical abscess',
#   'pika',
#   'pinch biopsy',
#   'plant residue',
#   'plant roots',
#   'plant seeds',
#   'plastic tube',
#   'polluted environment',
#   'polycarbonate',
#   'polyester',
#   'polyethylene terephthalate',
#   'polypropylene',
#   'polystyrene',
#   'pony',
#   'prawns',
#   'pregnant woman',
#   'puncture',
#   'pustular',
#   'railway station',
#   'rape leaf',
#   'raspberries',
#   'respiratory sample',
#   'root caries',
#   'rubber',
#   'rural environment',
#   'rye bread',
#   'salmonella infection',
#   'sand dunes',
#   'seafood',
#   'separation',
#   'sewer',
#   'skin swab',
#   'small intestine contents',
#   'smoked salmon',
#   'snorkel',
#   'soap dispenser',
#   'solitary bee',
#   'south australia',
#   'south georgia',
#   'soya milk',
#   'spruce',
#   'stamina',
#   'starvation',
#   'stethoscope',
#   'stool specimen',
#   'streptococcal toxic shock syndrome',
#   'sulfide',
#   'suppressive',
#   'surface swab',
#   'surgical intensive care unit',
#   'surgical wound',
#   'sylvatic',
#   't shirt',
#   'tidal river',
#   'tinea capitis',
#   'tinea corporis',
#   'tinea pedis',
#   'toilet seat',
#   'tooth surface',
#   'town environment',
#   'tracheal',
#   'traumatic',
#   'tree bark',
#   'trematode',
#   'tunis',
#   'tweezer',
#   'upstream',
#   'urban environment',
#   'urban residential',
#   'urethral catheter',
#   'urinary catheter',
#   'vaginal swab',
#   'vegetation',
#   'ventilator associated pneumonia',
#   'ventricular assist device',
#   'western australia',
#   'wheat flour',
#   'wheat product',
#   'wild',
#   'woods',
#   'wound slough',
#   'wound swab',
#   'yaan'},
#  'uberon': {'adult stage',
#   'adults',
#   'airways',
#   'albumen',
#   'alimentary part of gastrointestinal system',
#   'alimentary tract',
#   'alveolus of lung',
#   'ammocoete',
#   'anatomical cavity',
#   'anatomical conduit',
#   'anatomical entity',
#   'anterior nares',
#   'anterior naris',
#   'arteria femoralis',
#   'axilla skin',
#   'back skin',
#   'blood vasculature',
#   'blood vessels',
#   'bodily fluid',
#   'bodily secretion',
#   'body external integument structure',
#   'body wall',
#   'bone element',
#   'buttocks',
#   'caeca',
#   'caecum mucosa',
#   'caterpillar',
#   'cecal mucosa',
#   'cecum mucosa',
#   'cervical os',
#   'chyme',
#   'cloacal mucosa',
#   'colorectum',
#   'conjunctival fornix',
#   'cow dung',
#   'cud',
#   'dentine',
#   'digestive fluid',
#   'digestive gland',
#   'digestive system element',
#   'digestive tract contents',
#   'digestive tract epithelium',
#   'digit skin',
#   'distal intestine',
#   'dorsal tongue',
#   'dung',
#   'ear wax',
#   'egg shell',
#   'eggshell',
#   'endodermal part of digestive tract',
#   'endometrium epithelium',
#   'epithelium of esophagus',
#   'epithelium of external nose',
#   'epithelium of ileum',
#   'epithelium of rectum',
#   'epithelium of trachea',
#   'epithelium of vagina',
#   'excrement',
#   'excreta',
#   'excretory tube',
#   'external naris',
#   'extraembryonic tissue',
#   'eyes',
#   'facial skin',
#   'feather',
#   'fecal matter',
#   'female anatomical structure',
#   'fetal placenta',
#   'follicular fluid',
#   'forehead skin',
#   'fornix',
#   'gastrointestinal system mucosa',
#   'gi tract',
#   'gill filaments',
#   'gut mucosa',
#   'gut wall',
#   'haemolymphatic fluid',
#   'hallux',
#   'heart valve',
#   'heel',
#   'hemolymph',
#   'hemolymphoid system',
#   'hepatopancreas',
#   'holdfast',
#   'hoof',
#   'hyponychium',
#   'ileal mucosa',
#   'ileum mucosa',
#   'inc',
#   'interdigit',
#   'intermediate cuneiform',
#   'intestinal juice',
#   'intestinal lumen',
#   'intestinal tract',
#   'jejunal lumen',
#   'jejunal mucosa',
#   'jejunum mucosa',
#   'kidney pelvis',
#   'larva',
#   'lateral cuneiform',
#   'lateral vaginal canal',
#   'left medial canthus',
#   'lower back',
#   'lower digestive tract',
#   'lower gi tract',
#   'lower intestine',
#   'lower jaw region',
#   'lower respiratory tract',
#   'lower third of vagina',
#   'lower urinary tract',
#   'lumen of digestive tract',
#   'lumen of duodenum',
#   'lumen of intestine',
#   'lumen of vagina',
#   'lung epithelium',
#   'mammary gland fluid',
#   'mantle tissue',
#   'mao',
#   'material entity in digestive tract',
#   'medial cuneiform',
#   'mhb',
#   'middle meatus',
#   'mouth cavity',
#   'mucosa of nasopharynx',
#   'mucosa of oral region',
#   'mucosa of rectum',
#   'mucosa of vagina',
#   'multicellular organism',
#   'nares',
#   'nasal cavity mucosa',
#   'navicular',
#   'nose skin',
#   'ocular adnexa',
#   'ocular surface',
#   'ocular surface region',
#   'oral epithelium',
#   'oral opening',
#   'oral vestibule',
#   'organ subunit',
#   'organism substance',
#   'oronasal secretion',
#   'oropharyngeal cavity',
#   'papillae',
#   'parenchyma of central nervous system',
#   'penile skin',
#   'perianal skin',
#   'pharyngeal mucosa',
#   'pinna surface epithelium',
#   'placentome',
#   'planta',
#   'posterior fornix',
#   'posterior fornix of vagina',
#   'posterior intestine',
#   'presumptive gut',
#   'pyloric caeca',
#   'pyloric cecum',
#   'pyloric gastric gland',
#   'rectum mucosa',
#   'renal system',
#   'reproductive organ',
#   'reproductive structure',
#   'reproductive system mucosa',
#   'respiratory airway',
#   'respiratory system epithelium',
#   'respiratory system mucosa',
#   'right lobe of liver',
#   'right medial canthus',
#   'rumen epithelium',
#   'rumen papillae',
#   'ruminal fluid',
#   'ruminant stomach',
#   'salivary gland secretion',
#   'secretion of exocrine gland',
#   'serosa of intestine',
#   'siphon',
#   'skin epidermis',
#   'skin epithelium',
#   'skin mucous',
#   'skin mucus',
#   'skin of abdomen',
#   'skin of anterior chest',
#   'skin of back',
#   'skin of chest',
#   'skin of elbow',
#   'skin of external ear',
#   'skin of face',
#   'skin of forearm',
#   'skin of forehead',
#   'skin of knee',
#   'skin of leg',
#   'skin of manus',
#   'skin of pes',
#   'skin secretion',
#   'space surrounding organism',
#   'spinal fluid',
#   'squama',
#   'stomach antrum',
#   'stomach epithelium',
#   'stomach muscularis externa',
#   'subdivision of digestive tract',
#   'subgingival dental plaque',
#   'superior surface of tongue',
#   'supragingival plaque',
#   'surface of tongue',
#   'tadpole',
#   'tongue dorsum',
#   'tongue squamous epithelium',
#   'tooth row',
#   'tracheal mucosa',
#   'tract',
#   'tube foot',
#   'udder',
#   'upper back',
#   'upper back skin',
#   'upper gi tract',
#   'upper respiratory tract',
#   'uropygial gland',
#   'uterine cavity',
#   'uterine epithelium',
#   'uterine lumen',
#   'vagina orifice',
#   'vagina squamous epithelium',
#   'vaginal fluid',
#   'vaginal lumen',
#   'vaginal mucosa',
#   'vaginal orifice',
#   'vasculature',
#   'venom gland',
#   'vocal fold',
#   'wall of stomach',
#   'zone of skin',
#   'zone of stomach'},
#  'genepio': {'caecal content',
#   'isolation medium',
#   'not collected',
#   'not provided',
#   'pool water',
#   'restricted access',
#   'stomach content'},
#  'foodon': {'acid whey',
#   'agave plant',
#   'alfalfa plant',
#   'almond tree',
#   'animal food product',
#   'animal milk',
#   'aquaculture area',
#   'ascidian',
#   'batter',
#   'bee food product',
#   'beef cattle',
#   'beef mince',
#   'beef trim',
#   'beer beverage',
#   'beetle',
#   'berry plant',
#   'bers',
#   'beverage food product',
#   'biltong',
#   'bone or shell',
#   'bottled beer food product',
#   'broth',
#   'buckwheat seed',
#   'capsicum annum',
#   'cat food',
#   'cellulose film',
#   'cereal grain',
#   'cheese core',
#   'cheese food product',
#   'cheese rind',
#   'chicken breast',
#   'chicken carcass',
#   'chicken egg',
#   'chicken feed',
#   'chicken meat',
#   'chicken meat food product',
#   'chicken thigh',
#   'chipotle',
#   'chopped',
#   'citrus fruit food product',
#   'cocoa mass',
#   'cod fillet',
#   'commercial yogurt',
#   'common bean',
#   'companion animal',
#   'cooking pot',
#   'corn cob',
#   'corn flour',
#   'corn stover',
#   'cottonseed',
#   'cow milk based food product',
#   'cow milk cheese',
#   'cow teat skin',
#   'cultured',
#   'curd',
#   'dog food',
#   'dough',
#   'eucalyptus plant',
#   'fermented beverage',
#   'fermented dairy food product',
#   'fermented fish or seafood food product',
#   'fermented grape beverage',
#   'fermented product',
#   'fermented rice beverage',
#   'fermented soybean food product',
#   'fermented vegetable food product',
#   'finisher',
#   'fish food',
#   'fish food product',
#   'fish sauce',
#   'fish skin',
#   'food fermentation',
#   'food material',
#   'food packaging',
#   'food product for animal',
#   'food production',
#   'food transformation process',
#   'food treatment process',
#   'free range',
#   'fruit pulp',
#   'gastropod',
#   'grape leaf',
#   'grape marc',
#   'grape must',
#   'grape pomace',
#   'ground beef',
#   'hydroponic cultivation',
#   'iceberg lettuce plant',
#   'in brine',
#   'insect food product',
#   'jarlsburg cheese',
#   'jellyfish',
#   'jeotgal',
#   'koji',
#   'lactose free food',
#   'leafy greens',
#   'lettuce leaf',
#   'lunch meat',
#   'macroalgae',
#   'maize plant',
#   'mandarin orange food product',
#   'marine fish',
#   'marine mammal',
#   'medicinal plant',
#   'microbial food product',
#   'millet plant',
#   'must',
#   'oak',
#   'oak tree',
#   'oat straw',
#   'onion plant',
#   'organ meat',
#   'organic farming',
#   'peel',
#   'pepper tree',
#   'pet food',
#   'pig brain',
#   'pig lung',
#   'pig stomach',
#   'piglet',
#   'plant derived beverage',
#   'plant derived fermented beverage',
#   'plant food product',
#   'plant root food product',
#   'plant stem food product',
#   'plastic container',
#   'poblano',
#   'polyethylene surface',
#   'pomegranate wine',
#   'potato plant',
#   'poultry food product',
#   'poultry meat',
#   'poultry meat product',
#   'poultry sausage',
#   'processed food product',
#   'rapeseed',
#   'raw milk',
#   'restored',
#   'rice beer',
#   'rice husk',
#   'rice plant',
#   'rice wine',
#   'roe deer',
#   'ryegrass',
#   'sake mash',
#   'sea cucumber',
#   'semihard cheese product',
#   'sheep milk cheese',
#   'sheep stomach',
#   'shiraz',
#   'signalgrass plant',
#   'slush',
#   'snake',
#   'sorghum flour',
#   'sourdough',
#   'sourdough starter',
#   'sow',
#   'soybean paste',
#   'strawberry plant',
#   'sugar cane',
#   'sugar solution',
#   'sunflower meal',
#   'swine liver',
#   'tomato food product',
#   'tomato plant',
#   'traditional food claim',
#   'tunicate',
#   'turkey meat',
#   'vanilla ice cream',
#   'wheat plant',
#   'wild animal',
#   'yoghurt'},
#  'ncbitaxon': {'aai',
#   'abies alba',
#   'abutilon theophrasti',
#   'acer pseudoplatanus',
#   'agapanthus praecox',
#   'agricola',
#   'albizia julibrissin',
#   'alexandrium tamarense',
#   'aloe x spinosissima',
#   'amaranthus macrocarpus',
#   'amaranthus powellii',
#   'amaranthus rudis',
#   'amazonia',
#   'ammonia oxidizing bacteria',
#   'anaerobic digester metagenome',
#   'andes',
#   'andringitra',
#   'anoplura',
#   'anthidium florentinum',
#   'aplysina aerophoba',
#   'apodemus agrarius',
#   'apodemus flavicollis',
#   'apterostigma urichii',
#   'aquatic metagenome',
#   'arabidopsis',
#   'arabidopsis thaliana',
#   'areca palm',
#   'arrhenatherum elatius',
#   'artemia',
#   'astragalus variabilis',
#   'atacama',
#   'atta mexicana',
#   'aulacomnium androgynum',
#   'aurelia aurita',
#   'avena strigosa',
#   'bathyaustriella thionipta',
#   'bed bug',
#   'bees',
#   'betula nana',
#   'biocrust metagenome',
#   'biofilm metagenome',
#   'bioreactor metagenome',
#   'bioreactor sludge metagenome',
#   'bischofia polycarpa',
#   'blood metagenome',
#   'bovine gut metagenome',
#   'brachiaria ruziziensis',
#   'brackenridgea australiana',
#   'brassica carinata',
#   'bromus',
#   'bromus carinatus',
#   'brook trout',
#   'bryophyta',
#   'canga',
#   'carex rostrata',
#   'cecropia',
#   'ceratopetalum succirubrum',
#   'cercis chinensis',
#   'cereus hexagonus',
#   'chicken gut metagenome',
#   'chionochloa macra',
#   'chionochloa pallens',
#   'chlamydomonas reinhardtii',
#   'choisya ternata',
#   'citrullus lanatus',
#   'clinical samples',
#   'cnidaria',
#   'colonia',
#   'conifers',
#   'copepods',
#   'coral reef metagenome',
#   'corallina officinalis',
#   'coreopsis lanceolata',
#   'coriaria arborea',
#   'coriaria myrtifolia',
#   'coriaria nepalensis',
#   'cornus',
#   'cryptobranchus alleganiensis alleganiensis',
#   'cryptocarya angulata',
#   'cryptomeria fortunei',
#   'culex quinquefasciatus',
#   'cultivated sugarcanes',
#   'cundinamarca',
#   'cyperus papyrus',
#   'daphnia dentifera',
#   'daphnia magna',
#   'daphnia obtusa',
#   'deyeuxia arundinacea',
#   'dianthus caryophyllus',
#   'diatoms',
#   'dictyota',
#   'dima',
#   'domestic cow',
#   'dreissena',
#   'drosophila melanogaster',
#   'earthworms',
#   'elaeagnus pungens',
#   'encarsia formosa',
#   'encephalartos ferox',
#   'endiandra wolfei',
#   'enrichment culture',
#   'enrichment cultures',
#   'environmental sequence',
#   'eothenomys miletus',
#   'epipedobates anthonyi',
#   'eremophila serrulata',
#   'eriocheir',
#   'estuary metagenome',
#   'eukarya',
#   'eukaryotes',
#   'euonymus japonicus',
#   'fagales',
#   'fecal metagenome',
#   'feces metagenome',
#   'festuca rubra',
#   'ficus',
#   'fir trees',
#   'fish metagenome',
#   'food fermentation metagenome',
#   'food metagenome',
#   'forsythia viridissima',
#   'fragaria ananassa',
#   'franciscodendron laurifolium',
#   'freshwater metagenome',
#   'freshwater sediment metagenome',
#   'galleria mellonella',
#   'garcinia',
#   'giant panda',
#   'gracilaria lemaneiformis',
#   'greta',
#   'gut metagenome',
#   'halichondria panicea',
#   'halictus scabiosae',
#   'haloxylon',
#   'haloxylon ammodendron',
#   'harbor seal',
#   'hevea brasiliensis',
#   'hexapoda',
#   'hieracium lepidulum',
#   'hirundo rustica',
#   'homalodisca vitripennis',
#   'honey bee',
#   'honey bees',
#   'honeybee',
#   'human bile metagenome',
#   'human feces metagenome',
#   'human gut metagenome',
#   'human gut microbiota',
#   'human metagenome',
#   'human milk metagenome',
#   'human oral metagenome',
#   'human oral microbiome',
#   'human saliva metagenome',
#   'human sinus metagenome',
#   'human skin metagenome',
#   'human vaginal metagenome',
#   'human virome',
#   'hydra vulgaris',
#   'hypericum hircinum',
#   'hypersaline lake metagenome',
#   'hypholoma',
#   'hypothenemus hampei',
#   'impala',
#   'insect gut metagenome',
#   'insects',
#   'ipomoea hederacea',
#   'isatis violascens',
#   'isopoda',
#   'jellyfish metagenome',
#   'joshua tree',
#   'juncus roemerianus',
#   'kobresia',
#   'kobresia humilis',
#   'kobresia pygmaea',
#   'lagerstroemia',
#   'lambs',
#   'larix kaempferi',
#   'larix laricina',
#   'larus schistisagus',
#   'leaf litter metagenome',
#   'lepidoptera',
#   'ligustrum lucidum',
#   'lipaphis erysimi pseudobrassicae',
#   'liriope',
#   'lithobates catesbeianus',
#   'lithobates clamitans',
#   'lithobates sylvaticus',
#   'litopenaeus vannamei',
#   'longleaf pine',
#   'lonicera maackii',
#   'lucinoma aequizonata',
#   'lucinoma borealis',
#   'lucinoma capensis',
#   'lucinoma kastoroae',
#   'lucinoma myriamae',
#   'lumbricus terrestris',
#   'lupinus polyphyllus',
#   'lysiloma',
#   'macrocystis pyrifera',
#   'malcolmia scorpioides',
#   'malus pumila',
#   'mammals',
#   'mammuthus primigenius',
#   'manta',
#   'marine metagenome',
#   'marine sediment metagenome',
#   'megachile sculpturalis',
#   'metagenomes',
#   'methanogenic enrichment culture',
#   'microtus agrestis',
#   'microtus arvalis',
#   'microtus oeconomus',
#   'millepora alcicornis',
#   'mimosa pigra',
#   'miscanthus',
#   'mixed culture',
#   'mixed culture metagenome',
#   'mixed sample',
#   'mnemiopsis leidyi',
#   'mock community',
#   'monitilora ramsayi',
#   'mosquito',
#   'mosses',
#   'mouse gut metagenome',
#   'mouse metagenome',
#   'mus musculus domesticus',
#   'mus musculus musculus',
#   'myodes glareolus',
#   'myriophyllum',
#   'myrmicocrypta ednaella',
#   'napier grass',
#   'nassella trichotoma',
#   'nematodes',
#   'neoromicia',
#   'niemeyera',
#   'noccaea caerulescens',
#   'noctuidae',
#   'norway spruce',
#   'oil field metagenome',
#   'ophiopogon japonicus',
#   'oral metagenome',
#   'oysters',
#   'palisade grass',
#   'panda',
#   'panicum repens',
#   'paratrachymyrmex diversus',
#   'partamona helleri',
#   'parthenium argentatum',
#   'peltigera',
#   'philaenus spumarius',
#   'phragmites communis',
#   'phyllosphere metagenome',
#   'picea abies',
#   'picea glauca',
#   'picea mariana',
#   'picea omorika',
#   'picea rubens',
#   'pig gut metagenome',
#   'pigs',
#   'pilbara',
#   'pilosella officinarum',
#   'pinus densiflora',
#   'pinus massoniana',
#   'pinus nigra',
#   'pinus pinaster',
#   'pittosporum angustifolium',
#   'poa trivialis',
#   'pocillopora',
#   'poplar',
#   'porifera',
#   'porites',
#   'potamogeton',
#   'potatoes',
#   'procapra picticaudata',
#   'procapra przewalskii',
#   'prokaryotic metagenome',
#   'prorocentrum lima',
#   'pseudotsuga menziesii',
#   'pygathrix nigripes',
#   'pyropia',
#   'quercus',
#   'quercus acutissima',
#   'quercus agrifolia',
#   'quercus coccifera',
#   'quercus ilex',
#   'quercus petraea',
#   'quercus rotundifolia',
#   'racomitrium lanuginosum',
#   'rainbow trout',
#   'rana italica',
#   'rat gut metagenome',
#   'redbanded seabream',
#   'redwood',
#   'rhizosphere metagenome',
#   'rhododendron catawbiense',
#   'rhododendron simsii',
#   'rhodomela confervoides',
#   'rhopalosiphum maidis',
#   'rhopalosiphum padi',
#   'rockinghamia angustifolia',
#   'root metagenome',
#   'ruditapes philippinarum',
#   'salix caprea',
#   'salix lapponum',
#   'sargassum',
#   'sargassum thunbergii',
#   'schizaphis graminum',
#   'schlumbergera truncata',
#   'scolytinae',
#   'sea urchin',
#   'seashore paspalum',
#   'seawater metagenome',
#   'sediment metagenome',
#   'sericopelma',
#   'siderastrea stellata',
#   'sika deer',
#   'sinonovacula constricta',
#   'siphamia tubifer',
#   'siphonaptera',
#   'sitobion avenae',
#   'sludge metagenome',
#   'snakes',
#   'soil metagenome',
#   'soil microbiome',
#   'solidago decurrens',
#   'spartina maritima',
#   'spatoglossum',
#   'sphagnum',
#   'sphagnum palustre',
#   'spiders',
#   'spirogloea muscicola',
#   'spodoptera',
#   'spodoptera frugiperda',
#   'sponge metagenome',
#   'sponges',
#   'squash bug',
#   'stomach metagenome',
#   'striga hermonthica',
#   'suaeda salsa',
#   'subsurface metagenome',
#   'sugarcane',
#   'summer flounder',
#   'switchgrass',
#   'symbiodiniaceae',
#   'synthetic construct',
#   'synthetic metagenome',
#   'synthetic microbial community',
#   'syzygium endophloium',
#   'tara',
#   'tetracme contorta',
#   'tetracme recurvata',
#   'thysanolaena maxima',
#   'tobacco root',
#   'trachurus japonicus',
#   'trachypithecus germaini',
#   'trachypithecus leucocephalus',
#   'trifolium alexandrinum',
#   'typha orientalis',
#   'ulva linza',
#   'uncultured bacterium',
#   'urine metagenome',
#   'vachellia abyssinica',
#   'vaginal metagenome',
#   'valencia',
#   'veronica persica',
#   'vespa velutina',
#   'water hyacinth',
#   'water lettuce',
#   'weevils',
#   'wild barley',
#   'wild rice',
#   'wren',
#   'zostera japonica',
#   'zostera marina',
#   'zuma'},
#  'exo': {'built environment', 'indoor', 'outdoor'},
#  'obi': {'cell culture supernatant',
#   'cotton swab',
#   'cultured cell population',
#   'dna extract',
#   'illumina miseq',
#   'incubator',
#   'laboratory animal care',
#   'lower respiratory tract specimen',
#   'nucleic acid extract',
#   'ovitrap',
#   'pool of specimens',
#   'processed material',
#   'specimen collection process',
#   'specimen from organism',
#   'vagina swab specimen',
#   'washing'},
#  'po': {'drupe fruit',
#   'epicuticular wax',
#   'flag leaf',
#   'leaf lamina',
#   'leaf sheath',
#   'life of whole plant stage',
#   'peristome',
#   'petiole epidermis',
#   'phloem',
#   'phyllome',
#   'plant axis',
#   'plant organ',
#   'plant structure development stage',
#   'pneumatophore',
#   'portion of plant tissue',
#   'prop root',
#   'pseudostem',
#   'root system',
#   'root tip',
#   'sapwood',
#   'shoot system',
#   'shoot system meristem',
#   'spikelet',
#   'stem base',
#   'vascular leaf',
#   'vegetative shoot system',
#   'whole plant',
#   'xylem',
#   'xylem sap'},
#  'pato': {'acidophilic',
#   'alkaline',
#   'arboreal',
#   'decayed',
#   'exposed',
#   'hemispheroid',
#   'high elevation',
#   'high fertility',
#   'high flow',
#   'larval',
#   'low fertility',
#   'low flow',
#   'low intensity',
#   'salinity',
#   'shallow',
#   'sigmoid',
#   'squamous',
#   'tall',
#   'uncontaminated',
#   'undeveloped',
#   'wholeness'},
#  'micro': {'artificial seawater',
#   'brain heart infusion',
#   'brain heart infusion broth',
#   'butanediol',
#   'culture media',
#   'dark fermentation',
#   'endophytic',
#   'epilithic',
#   'epiphytic',
#   'epiphytic environment',
#   'fermenter',
#   'filaments',
#   'filtered seawater',
#   'gelatine',
#   'halotolerant',
#   'lb medium',
#   'malate',
#   'marine salinity',
#   'mesophilic',
#   'microaerophilic',
#   'microbiological culture medium',
#   'nutrient medium',
#   'olive fruit',
#   'peptone water',
#   'planktonic',
#   'sheath',
#   'sheep blood',
#   'soil extract',
#   'thermophile',
#   'thermophilic',
#   'tryptic soy broth',
#   'ypd agar'},
#  'ohmi': {'bacterial microbiome',
#   'human gut microbiome',
#   'microbial genome',
#   'microbiome in human oral',
#   'mouse microbiome'},
#  'pco': {'alga',
#   'collection of organisms',
#   'ecological community',
#   'microbial community',
#   'organismal entity',
#   'population of organisms'},
#  'mco': {'artificial medium',
#   'experimental process',
#   'human urine',
#   'lb broth',
#   'luria broth',
#   'rich medium'}}

# %%
def count_exclusive_hits(exclusive_hits_by_ontology):
    exclusive_hit_counts = {ontology: len(labels) for ontology, labels in exclusive_hits_by_ontology.items()}
    sorted_exclusive_hit_counts = dict(sorted(exclusive_hit_counts.items(), key=lambda x: x[1], reverse=True))
    return sorted_exclusive_hit_counts

# %%
exclusive_hit_counts = count_exclusive_hits(exclusive_hits_by_ontology)

# %% [markdown]
# display the number of unique hits per target ontology

# %%
exclusive_hit_counts
# Out:
# {'envo': 1578,
#  'ncit': 724,
#  'ncbitaxon': 375,
#  'uberon': 232,
#  'snomed': 225,
#  'foodon': 172,
#  'micro': 32,
#  'po': 29,
#  'agro': 27,
#  'pato': 21,
#  'obi': 16,
#  'genepio': 7,
#  'pco': 6,
#  'mco': 6,
#  'ohmi': 5,
#  'exo': 3}

# %%
COMPONENT_COUNT_THRESHOLD
# Out:
# 2

# %%
exclusive_hits_by_ontology['snomed']
# Out:
# {'acute pulpitis',
#  'agar',
#  'agar medium',
#  'agarose',
#  'ageing',
#  'agrochemical',
#  'altitude',
#  'aluminium',
#  'amoeba culture',
#  'anaerobic chamber',
#  'anaerobic culture',
#  'anal swab',
#  'animal hide',
#  'avulsion',
#  'bacterial culture',
#  'bacterial genome',
#  'baker',
#  'bedroom',
#  'biliary sludge',
#  'blood culture',
#  'brain tissue',
#  'bran',
#  'brass',
#  'breast normal',
#  'bronchial fluid',
#  'burial',
#  'canalisation',
#  'caries active',
#  'catarrhal gingivitis',
#  'catheter tip',
#  'cereal',
#  'cervical swab',
#  'chimney',
#  'city environment',
#  'coagulant',
#  'coastal environment',
#  'coastal sea',
#  'cockroach',
#  'cold water',
#  'colonic contents',
#  'complicated appendicitis',
#  'concha bullosa',
#  'controlled temperature',
#  'coriaria thymifolia',
#  'countryside',
#  'cyst fluid',
#  'cytology brush',
#  'dermatophyte',
#  'diabetic foot ulcer',
#  'diarrhoea',
#  'dining room',
#  'douglas fir',
#  'downstream',
#  'duodenal',
#  'duodenal biopsy sample',
#  'duodenal juice',
#  'ear discharge',
#  'elevator',
#  'endodontic paper point',
#  'endometrial biopsy curette',
#  'endotracheal tube',
#  'england',
#  'entrance',
#  'eutrophication',
#  'exposure to environmental pollution',
#  'eye fluid',
#  'farm house',
#  'farm land',
#  'farming environment',
#  'fermented food',
#  'fertiliser',
#  'fertilizer',
#  'fetal membranes',
#  'floor swab',
#  'flowers',
#  'forceps',
#  'frontal recess',
#  'fungal genome',
#  'fungal product',
#  'garage',
#  'gastrointestinal contents',
#  'giardiasis',
#  'golf course',
#  'grapes',
#  'group c',
#  'group d',
#  'gymnasium',
#  'hawaii island',
#  'heavy metal',
#  'high altitude',
#  'high fat diet',
#  'hospital acquired',
#  'hospital environment',
#  'hospital patient',
#  'hot environment',
#  'hot water',
#  'house dust',
#  'housed',
#  'human cells',
#  'human tissue',
#  'humid environment',
#  'industrial environment',
#  'industrial plant',
#  'industrial site',
#  'insecticide',
#  'institutionalized',
#  'interdental',
#  'interdigital',
#  'kitikmeot',
#  'knife',
#  'laboratory incubator',
#  'landfill site',
#  'leather',
#  'leaves',
#  'ligature',
#  'lotus tuber',
#  'lounge',
#  'low altitude',
#  'matrix stone',
#  'meat products',
#  'medical intensive care unit',
#  'medical student',
#  'meters',
#  'microbial agent',
#  'middle ear fluid',
#  'mill',
#  'mining waste',
#  'moorland',
#  'mouth swab',
#  'mudflats',
#  'museum',
#  'mussels',
#  'nasopharyngeal',
#  'nasopharyngeal aspirate',
#  'nil',
#  'normal diet',
#  'not applied',
#  'nothing',
#  'open wound',
#  'oral swab',
#  'oxygen concentration',
#  'perianal swab',
#  'periapical abscess',
#  'pika',
#  'pinch biopsy',
#  'plant residue',
#  'plant roots',
#  'plant seeds',
#  'plastic tube',
#  'polluted environment',
#  'polycarbonate',
#  'polyester',
#  'polyethylene terephthalate',
#  'polypropylene',
#  'polystyrene',
#  'pony',
#  'prawns',
#  'pregnant woman',
#  'puncture',
#  'pustular',
#  'railway station',
#  'rape leaf',
#  'raspberries',
#  'respiratory sample',
#  'root caries',
#  'rubber',
#  'rural environment',
#  'rye bread',
#  'salmonella infection',
#  'sand dunes',
#  'seafood',
#  'separation',
#  'sewer',
#  'skin swab',
#  'small intestine contents',
#  'smoked salmon',
#  'snorkel',
#  'soap dispenser',
#  'solitary bee',
#  'south australia',
#  'south georgia',
#  'soya milk',
#  'spruce',
#  'stamina',
#  'starvation',
#  'stethoscope',
#  'stool specimen',
#  'streptococcal toxic shock syndrome',
#  'sulfide',
#  'suppressive',
#  'surface swab',
#  'surgical intensive care unit',
#  'surgical wound',
#  'sylvatic',
#  't shirt',
#  'tidal river',
#  'tinea capitis',
#  'tinea corporis',
#  'tinea pedis',
#  'toilet seat',
#  'tooth surface',
#  'town environment',
#  'tracheal',
#  'traumatic',
#  'tree bark',
#  'trematode',
#  'tunis',
#  'tweezer',
#  'upstream',
#  'urban environment',
#  'urban residential',
#  'urethral catheter',
#  'urinary catheter',
#  'vaginal swab',
#  'vegetation',
#  'ventilator associated pneumonia',
#  'ventricular assist device',
#  'western australia',
#  'wheat flour',
#  'wheat product',
#  'wild',
#  'woods',
#  'wound slough',
#  'wound swab',
#  'yaan'}

# %%
triad_components_labels_collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ncbi_metadata'), 'triad_components_labels')

# %%
# Aggregation query
pipeline = [
    {
        "$project": {
            "_id": 0,
            "component_label": 1,
            "count": 1,
            "exact_something_match_count": {
                "$size": {
                    "$filter": {
                        "input": { "$ifNull": ["$ols_hits", []] },  # Ensure ols_hits is always an array
                        "as": "hit",
                        "cond": {"$eq": ["$$hit.exact_something_match", True]}
                    }
                }
            },
            "exact_label_match_count": {
                "$size": {
                    "$filter": {
                        "input": { "$ifNull": ["$ols_hits", []] },  # Ensure ols_hits is always an array
                        "as": "hit",
                        "cond": {"$eq": ["$$hit.exact_label_match", True]}
                    }
                }
            }
        }
    }
]

# %%
# Run the aggregation query
results = list(triad_components_labels_collection.aggregate(pipeline))

# %%
# Convert results to a Pandas DataFrame
df = pd.DataFrame(results)

# %%
df
# Out:
#                        component_label   count  exact_something_match_count  \
# 0                    terrestrial biome  185397                            1
# 1             human associated habitat  471324                            0
# 2                   biological product    1950                            2
# 3      homo sapiens associated habitat     246                            0
# 4                              aquatic   43759                            0
# ...                                ...     ...                          ...
# 45152                         illinois       2                            2
# 45153                salar de pajonale      14                            0
# 45154           human esophagus tissue      68                            0
# 45155                  intretidal zone     229                            0
# 45156                     bee cuticula       2                            0
#
#        exact_label_match_count
# 0                            1
# 1                            0
# 2                            1
# 3                            0
# 4                            0
# ...                        ...
# 45152                        2
# 45153                        0
# 45154                        0
# 45155                        0
# 45156                        0
#
# [45157 rows x 4 columns]

# %%
df.shape
# Out:
# (45157, 4)

# %%
followup_df = df.loc[(df['exact_label_match_count'] == 0) & (df['exact_something_match_count'] == 0) & (df['count'] > 1), ['component_label']]

# %%
followup_df
# Out:
#                                component_label
# 1                     human associated habitat
# 3              homo sapiens associated habitat
# 4                                      aquatic
# 5                                pacific ocean
# 8                          rainforest division
# ...                                        ...
# 45150  dna isolation from enriched medium http
# 45153                        salar de pajonale
# 45154                   human esophagus tissue
# 45155                          intretidal zone
# 45156                             bee cuticula
#
# [27224 rows x 1 columns]

# %%
followup_df.to_csv("common_components_with_no_exact_label_match.tsv", sep="\t", index=False)

# %%
df[df["count"] >= COMPONENT_COUNT_THRESHOLD].shape[0]
# Out:
# 32402

# %%
# low return on investment in absolute terms but does give a good sense of which ontologioes to use
df[(df["count"] >= COMPONENT_COUNT_THRESHOLD) & (df["exact_label_match_count"] > 0)].shape[0]
# Out:
# 4109

# %%
df[(df["count"] < COMPONENT_COUNT_THRESHOLD) & (df["exact_label_match_count"] > 0)].shape[0]
# Out:
# 0

# %%
df[(df["count"] >= COMPONENT_COUNT_THRESHOLD) & (df["exact_label_match_count"] == 0)].shape[0]
# Out:
# 28293

# %%
df[df["count"] == 1].shape[0]
# Out:
# 12755

# %%
df[df["count"] == 2].shape[0]
# Out:
# 4489

# %%
df[df["count"] == 3].shape[0]
# Out:
# 2817

# %%
# # Aggregate to count unique occurrences
# pipeline = [
#     {"$unwind": "$parsed_annotations"},
#     {"$group": {"_id": "$parsed_annotations.repaired_prefix", "count": {"$sum": 1}}}
# ]

# %%
# results = list(triad_values_collection.aggregate(pipeline))

# %%
# # Convert to dictionary (optional)
# count_dict = {doc["_id"]: doc["count"] for doc in results if doc["_id"] is not None}

# %%
# # Convert to DataFrame
# count_frame = pd.DataFrame(list(count_dict.items()), columns=["Key", "Value"])

# %%
# count_frame

# %%
# see also prefix_count_frame ?
#count_frame only adds an explicit row for no prefix

# %%
# add mondo and or doid?

# %%
# isolate species names like human, mouse

# %%
# what happened to strings like envo:soil?

# %%
# look up CURIes

# %%
# Aggregate to count unique occurrences
pipeline = [
    {"$unwind": "$parsed_annotations"},
    {"$group": {"_id": "$parsed_annotations.repaired_curie", "count": {"$sum": 1}}}
]

# %%
results = list(triad_values_collection.aggregate(pipeline))

# %%
count_dict = {doc["_id"]: doc["count"] for doc in results if doc["_id"] is not None}

# %%
curie_count_frame = pd.DataFrame(list(count_dict.items()), columns=["CURIe", "count"])

# %%
curie_count_frame[["prefix", "local_id"]] = curie_count_frame["CURIe"].str.split(":", expand=True)

# %%
curie_count_frame["obo_or_bioportal"] = curie_count_frame["prefix"].str.lower().isin(legit_prefixes_lc)

# %%
context = load_multi_context(["merged"])

# %%
extended_prefix_map = context.as_extended_prefix_map()

# %%
converter = Converter.from_extended_prefix_map(extended_prefix_map)
# 20 seconds

# %%
# Function to safely expand CURIEs, ignoring invalid ones
def safe_expand(curie):
    if isinstance(curie, str) and ":" in curie:  # Ensure it's a CURIE
        return converter.expand(curie.upper())
    return None  # Return None for invalid CURIEs

# %%
# Apply the function to expand CURIEs
curie_count_frame["inferred_uri"] = curie_count_frame["CURIe"].apply(safe_expand)

# %%
curie_count_frame
# Out:
#                 CURIe  count       prefix  local_id  obo_or_bioportal  \
# 0       ENVO:00002632      2         ENVO  00002632              True
# 1         seqMAT57:40      1     seqMAT57        40             False
# 2               946:C      1          946         C             False
# 3          mouse:0310      1        mouse      0310             False
# 4       ENVO:00002316      5         ENVO  00002316              True
# ...               ...    ...          ...       ...               ...
# 38310       Horse:4N1      1        Horse       4N1             False
# 38311      sample:620      1       sample       620             False
# 38312  Rhizosphere:27      1  Rhizosphere        27             False
# 38313      sample:606      1       sample       606             False
# 38314    seqMAT57:127      1     seqMAT57       127             False
#
#                                        inferred_uri
# 0      http://purl.obolibrary.org/obo/ENVO_00002632
# 1                                              None
# 2                                              None
# 3                                              None
# 4      http://purl.obolibrary.org/obo/ENVO_00002316
# ...                                             ...
# 38310                                          None
# 38311                                          None
# 38312                                          None
# 38313                                          None
# 38314                                          None
#
# [38315 rows x 6 columns]

# %% [markdown]
# Those counts may not be really useful because they're not multiplied out my the number of Biosample annotations that were split into a component from whihc that CURIe could be extracted

# %%
# Function to get the label from BioPortal safely
def get_bioportal_info(uri, prefix, BIOPORTAL_API_KEY):
    if not isinstance(uri, str) or not uri.startswith(("http://", "https://")):
        return None, None  # Ignore invalid URIs

    if not isinstance(prefix, str):
        return None, None

    # print(uri)

    # Upper-case the ontology prefix
    ontology = prefix.upper()

    # URL-encode the inferred URI
    encoded_uri = urllib.parse.quote(uri, safe="")

    # Correct API request URL format
    url = f"https://data.bioontology.org/ontologies/{ontology}/classes/{encoded_uri}?apikey={BIOPORTAL_API_KEY}"

    # # Print the URL before making the request
    # print(f"Querying BioPortal: {url}")

    try:
        response = requests.get(url, headers={"Authorization": f"apikey {BIOPORTAL_API_KEY}"})

        if response.status_code == 200:
            data = response.json()
            pref_label = data.get("prefLabel", "")
            # print(pref_label)
            obsolete = data.get("obsolete", False)  # Default to False if missing
            # print(obsolete)
            return pref_label, obsolete
        else:
            return f"Error: {response.status_code}"
    except Exception as e:
        return None, None  # todo better handling/reporting

# %%
# Filter rows where count > 1 and obo_or_bioportal is True
promising_uri_frame = curie_count_frame[
    (curie_count_frame["count"] > 1) & (curie_count_frame["obo_or_bioportal"] == True)
].copy()

# %%
promising_uri_frame
# Out:
#                 CURIe  count  prefix  local_id  obo_or_bioportal  \
# 0       ENVO:00002632      2    ENVO  00002632              True
# 4       ENVO:00002316      5    ENVO  00002316              True
# 10      ENVO:02000076      4    ENVO  02000076              True
# 22     UBERON:0003347      3  UBERON   0003347              True
# 28      ENVO:00000168      2    ENVO  00000168              True
# ...               ...    ...     ...       ...               ...
# 38291   ENVO:00002394      3    ENVO  00002394              True
# 38292   ENVO:00000571      5    ENVO  00000571              True
# 38294   ENVO:00001013      2    ENVO  00001013              True
# 38306   ENVO:03501290      2    ENVO  03501290              True
# 38307   ENVO:01000752      4    ENVO  01000752              True
#
#                                         inferred_uri  \
# 0       http://purl.obolibrary.org/obo/ENVO_00002632
# 4       http://purl.obolibrary.org/obo/ENVO_00002316
# 10      http://purl.obolibrary.org/obo/ENVO_02000076
# 22     http://purl.obolibrary.org/obo/UBERON_0003347
# 28      http://purl.obolibrary.org/obo/ENVO_00000168
# ...                                              ...
# 38291   http://purl.obolibrary.org/obo/ENVO_00002394
# 38292   http://purl.obolibrary.org/obo/ENVO_00000571
# 38294   http://purl.obolibrary.org/obo/ENVO_00001013
# 38306   http://purl.obolibrary.org/obo/ENVO_03501290
# 38307   http://purl.obolibrary.org/obo/ENVO_01000752
#
#                  bioportal_label is_obsolete
# 0                     Error: 404         NaN
# 4                     Error: 404         NaN
# 10         obsolete potato salad        True
# 22                UBERON_0003347        True
# 28                      blowhole       False
# ...                          ...         ...
# 38291                 Error: 404         NaN
# 38292  obsolete arboreal habitat        True
# 38294                 Error: 404         NaN
# 38306                supermarket       False
# 38307        area of barren land       False
#
# [4545 rows x 8 columns]

# %%
# Enable tqdm for Pandas in Jupyter Notebook
tqdm.pandas()

# %%
# Apply function to get BioPortal labels and obsolescence status
promising_uri_frame[["bioportal_label", "is_obsolete"]] = promising_uri_frame.progress_apply(
    lambda row: pd.Series(get_bioportal_info(row["inferred_uri"], row["prefix"], BIOPORTAL_API_KEY)),
    axis=1  # Apply function row-wise
)
# Out:
#   0%|          | 0/4545 [00:00<?, ?it/s]

# %% [markdown]
# ----

# %%
# bioportal ncbi taxon URIs look like
# http://purl.bioontology.org/ontology/NCBITAXON/9606

# note most of the taxon code appear to be run-ons from 9606 human

# not
# http://purl.obolibrary.org/obo/NCBITaxon_7460

# i just dealt with that and NCIT CURIes in the curation below

# %%
promising_uri_frame.to_csv("non_singleton_prefiltered_bioportal_label_lookup.tsv", sep="\t", index=False)

# %%
# see CURIe	count	prefix	local_id	obo_or_bioportal	inferred_uri	bioportal_label	is_obsolete	manual_lookup	assuming_curie_drag	manual_lookup_curie

# in non_singleton_prefiltered_bioportal_label_lookup_curated.csv

# %%
# look for these in "parsed_annotations.repaired_curie" and return content

malformed_curies = [
    'ENVO:agricultural',
    'ENVO:alcohol',
    'ENVO:anaerobic',
    'ENVO:anthropogenic',
    'ENVO:coastal',
    'ENVO:cropland',
    'ENVO:desert',
    'ENVO:dry',
    'ENVO:ENVO',
    'ENVO:farm',
    'ENVO:food',
    'ENVO:forest',
    'ENVO:freshwater',
    'ENVO:grassland',
    'ENVO:human',
    'ENVO:marine',
    'ENVO:microbial',
    'ENVO:Montane',
    'ENVO:montane',
    'ENVO:ocean',
    'ENVO:PO',
    'ENVO:research',
    'ENVO:shrubland',
    'ENVO:small',
    'ENVO:surface',
    'ENVO:temperate',
    'ENVO:Temperate',
    'ENVO:tropical',
    'ENVO:Tropical',
    'ENVO:tundra',
    'ENVO:UBERON',
    'ENVO:urban',
    'ENVO:vinegar',
    'ENVO:wastewater',
    'ENVO:water',
]

# %%
# Query to find documents where 'parsed_annotations.repaired_curie' is in our list
query = {"parsed_annotations.repaired_curie": {"$in": malformed_curies}}

# Project to only return the 'content' field
projection = {"content": 1, "_id": 0}

# Fetch results
results = triad_values_collection.find(query, projection)

# %%
# Extract and print content
content_list = {doc["content"] for doc in results}

# %%
# Write to a text file
output_file = "contents_of_local_text_curies.tsv"
with open(output_file, "w", encoding="utf-8") as f:
    for content in content_list:
        f.write(content + "\n")

print(f"Content list written to {output_file}")
# Out:
# Content list written to contents_of_local_text_curies.tsv

# %% [markdown]
# ----

# %%
curie_curations = dict()

# %% [markdown]
# split out the curie knowledge form automated searches and from curation

# %%
non_singleton_prefiltered_bioportal_label_lookup_curated_tsv = "non_singleton_prefiltered_bioportal_label_lookup_curated.tsv"

# %%
non_singleton_prefiltered_bioportal_label_lookup_curated_frame = pd.read_csv(non_singleton_prefiltered_bioportal_label_lookup_curated_tsv, sep="\t")

# %%
non_singleton_prefiltered_bioportal_label_lookup_curated_lod = non_singleton_prefiltered_bioportal_label_lookup_curated_frame.to_dict("records")

# %%
# Define the keys to extract
keys_to_include = [
    'bioportal_label', 'is_obsolete', 'manual_lookup_label',
    'manual_lookup_curie', 'curie_drag_label', 'curie_drag_curie'
]

# Iterate through the list of dictionaries and construct the curation dictionary
for record in non_singleton_prefiltered_bioportal_label_lookup_curated_lod:
    curie_key = record.get("curie")  # Extract the curie field

    if curie_key:  # Ensure curie is not None or missing
        curie_curations[curie_key] = {
            key: value
            for key, value in record.items()
            if key in keys_to_include
            and not pd.isna(value)  # Exclude NaN values
            and value not in (None, "")  # Exclude None and empty strings
            and not str(value).startswith("Error:")  # Exclude "Error:" values
        }

# %%
len(curie_curations)
# Out:
# 4545

# %%
contents_of_local_text_curies_curated_tsv = "contents_of_local_text_curies_curated.tsv"

# %%
contents_of_local_text_curies_curated_frame = pd.read_csv(contents_of_local_text_curies_curated_tsv, sep="\t")

# %%
contents_of_local_text_curies_curated_lod = contents_of_local_text_curies_curated_frame.to_dict("records")

# %%
text_curations = dict()

# %%
# Define the keys to extract
keys_to_include = [
    'manual_lookup_curie', 'manual_lookup_label',
    'curie_drag_curie', 'curie_drag_label'
]

# Iterate through the list of dictionaries
for index, record in enumerate(contents_of_local_text_curies_curated_lod):
    if not isinstance(record, dict):  # Ensure it's a dictionary
        print(f"Skipping non-dictionary record at index {index}: {record}")
        continue

    triad_key = record.get("triad_component_label")  # Extract the new key

    if not triad_key:  # Check for missing or empty triad_component_label
        print(f"Skipping record at index {index}: Missing 'triad_component_label' field")
        continue

    # Extract only the necessary fields, filtering out None, empty strings, "Error:", and NaN values
    filtered_fields = {
        key: value
        for key, value in record.items()
        if key in keys_to_include
        and not pd.isna(value)  # Exclude NaN values
        and value not in (None, "")  # Exclude None and empty strings
        and not str(value).startswith("Error:")  # Exclude "Error:" values
    }

    if filtered_fields:  # Only add if there's valid data left
        text_curations[triad_key] = filtered_fields

# %%
len(text_curations)
# Out:
# 79

# %%
# Get the 'curations' collection from the existing db object
curie_curations_collection = db["curie_curations"]

# %%
# dump scuration to JSON or YAML

# %%
# Prepare data for insertion by transforming curations dict into a list of documents
temp_documents = [
    {"curie": key, **curation_data}  # Expand inner dict into MongoDB document format
    for key, curation_data in curie_curations.items()
]

# %%
# Insert documents into MongoDB
if temp_documents:  # Ensure there's data to insert
    curie_curations_collection.insert_many(temp_documents)
    print(f"Inserted {len(temp_documents)} records.")
else:
    print("No records to insert.")
# Out:
# Inserted 4545 records.

# %%
text_curations_collection = db["text_curations"]

# %%
# Prepare data for insertion by transforming curations dict into a list of documents
temp_documents = [
    {"text": key, **curation_data}  # Expand inner dict into MongoDB document format
    for key, curation_data in text_curations.items()
]

# %%
# Insert documents into MongoDB
if temp_documents:  # Ensure there's data to insert
    text_curations_collection.insert_many(temp_documents)
    print(f"Inserted {len(temp_documents)} records .")
else:
    print("No records to insert.")
# Out:
# Inserted 79 records .

# %%
# Ensure indexes exist for efficient querying
# curations_collection.create_index([("text", 1)])

# %%
unmapped_component_labels = list(followup_df['component_label'])

# %%
len(unmapped_component_labels)
# Out:
# 27224

# %%
# Load YAML into a dictionary
def load_yaml_to_dict(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        data = yaml.safe_load(file)
    return data

# %%
organisms_anatomy_terms_yaml = "organisms_anatomy_terms.yaml"

# %%
organisms_anatomy_terms = load_yaml_to_dict(organisms_anatomy_terms_yaml)

# %%
def extract_leaf_values(data):
    leaf_values = []

    if isinstance(data, dict):
        for value in data.values():
            leaf_values.extend(extract_leaf_values(value))
    elif isinstance(data, list):
        for item in data:
            leaf_values.extend(extract_leaf_values(item))
    else:
        leaf_values.append(data)  # It's a scalar value

    return leaf_values

# %%
organisms_anatomy_terms = extract_leaf_values(organisms_anatomy_terms)

# %%
len(organisms_anatomy_terms)
# Out:
# 267

# %%
def extract_longest_terms(unmapped_component_labels, organisms_anatomy_terms):
    # Sort terms by length (longest first) to maximize coverage with the fewest terms
    organisms_anatomy_terms = sorted(organisms_anatomy_terms, key=len, reverse=True)

    result = {}

    for label in unmapped_component_labels:
        label_lower = label.lower()
        extracted_terms = []
        remaining_text = label_lower

        for term in organisms_anatomy_terms:
            term_lower = term.lower()
            # Search for term in the label
            if term_lower in remaining_text:
                extracted_terms.append(term)
                # Remove the matched portion
                remaining_text = re.sub(r'\b' + re.escape(term_lower) + r'\b', '', remaining_text, count=1).strip()

        if len(extracted_terms) > 0:
            result[label] = {
                "extracted_terms": extracted_terms,
                "remaining": remaining_text if remaining_text and remaining_text != label_lower else None
            }

    return result

# %%
# # Example Usage
# unmapped_component_labels = ["Human liver tissue", "Bacterial cell wall", "Mouse brain sample"]
# organisms_anatomy_terms = ["liver", "human", "tissue", "cell wall", "bacterial", "brain", "mouse"]

# %%
organisms_anatomy_components_extracted = extract_longest_terms(unmapped_component_labels, organisms_anatomy_terms)

# %%
def dump_dict_to_yaml(data, file_path):
    """Dump a dictionary to a YAML file."""
    with open(file_path, "w") as file:
        yaml.dump(data, file, default_flow_style=False, allow_unicode=True)

# %%
dump_dict_to_yaml(organisms_anatomy_components_extracted, "organisms_anatomy_components_extracted.yaml")

# %%
organisms_anatomy_components_extracted
# Out:
# {'human associated habitat': {'extracted_terms': ['human'],
#   'remaining': 'associated habitat'},
#  'homo sapiens associated habitat': {'extracted_terms': ['homo sapiens'],
#   'remaining': 'associated habitat'},
#  'temperate grasslands': {'extracted_terms': ['rat'], 'remaining': None},
#  'mammalia associated habitat': {'extracted_terms': ['mammalia'],
#   'remaining': 'associated habitat'},
#  'root soil interface of potato': {'extracted_terms': ['potato', 'root'],
#   'remaining': 'soil interface of'},
#  'temperate broadleaf and mixed forest biome': {'extracted_terms': ['leaf',
#    'rat'],
#   'remaining': None},
#  'phyllosphere': {'extracted_terms': ['phyllosphere'], 'remaining': None},
#  'mammillaria carnea rhizosphere': {'extracted_terms': ['rhizosphere'],
#   'remaining': 'mammillaria carnea'},
#  'human gut': {'extracted_terms': ['human', 'gut'], 'remaining': None},
#  'mice gut': {'extracted_terms': ['mice', 'gut'], 'remaining': None},
#  'near water': {'extracted_terms': ['ear'], 'remaining': None},
#  'termite gut': {'extracted_terms': ['gut'], 'remaining': 'termite'},
#  'gut contents': {'extracted_terms': ['gut'], 'remaining': 'contents'},
#  'human subgingiva': {'extracted_terms': ['human'], 'remaining': 'subgingiva'},
#  'soybean crop': {'extracted_terms': ['soybean'], 'remaining': 'crop'},
#  'swab sample of the gingival sulcus': {'extracted_terms': ['gingival sulcus'],
#   'remaining': 'swab sample of the'},
#  'larval rearing tank': {'extracted_terms': ['ear'], 'remaining': None},
#  'whole fish': {'extracted_terms': ['fish'], 'remaining': 'whole'},
#  'treatment shipping bag water with fish': {'extracted_terms': ['fish'],
#   'remaining': 'treatment shipping bag water with'},
#  'control shipping bag water without fish': {'extracted_terms': ['fish'],
#   'remaining': 'control shipping bag water without'},
#  'leaves without infection': {'extracted_terms': ['leaves'],
#   'remaining': 'without infection'},
#  'leaf samples': {'extracted_terms': ['leaf'], 'remaining': 'samples'},
#  'lettuce field': {'extracted_terms': ['lettuce'], 'remaining': 'field'},
#  'plant material phyllosphere': {'extracted_terms': ['phyllosphere'],
#   'remaining': 'plant material'},
#  'rumen content': {'extracted_terms': ['rumen'], 'remaining': 'content'},
#  'coral': {'extracted_terms': ['coral'], 'remaining': None},
#  'laboratory animal center': {'extracted_terms': ['rat'], 'remaining': None},
#  'human milk microbiome': {'extracted_terms': ['human', 'milk'],
#   'remaining': 'microbiome'},
#  'human milk': {'extracted_terms': ['human', 'milk'], 'remaining': None},
#  'soil and root': {'extracted_terms': ['root'], 'remaining': 'soil and'},
#  'mangrove ecosystem': {'extracted_terms': ['stem'], 'remaining': None},
#  'midgut content': {'extracted_terms': ['midgut'], 'remaining': 'content'},
#  'chlorpyrifos resistant strain reared underg': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'fipronil resistant strain reared undermg': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'rhizosphere sediment': {'extracted_terms': ['rhizosphere'],
#   'remaining': 'sediment'},
#  'lower airways': {'extracted_terms': ['airways'], 'remaining': 'lower'},
#  'temperate domain': {'extracted_terms': ['rat'], 'remaining': None},
#  'alpine meadow and alpine scrub': {'extracted_terms': ['pine'],
#   'remaining': None},
#  'alpine meadow': {'extracted_terms': ['pine'], 'remaining': None},
#  'lung microbiome': {'extracted_terms': ['lung'], 'remaining': 'microbiome'},
#  'insect gut': {'extracted_terms': ['insect', 'gut'], 'remaining': None},
#  'pine forest soil pinus muricata': {'extracted_terms': ['pine', 'cat'],
#   'remaining': 'forest soil pinus muricata'},
#  'high temperature habitat': {'extracted_terms': ['rat'], 'remaining': None},
#  'seedling days post germination': {'extracted_terms': ['seed'],
#   'remaining': None},
#  'macrotermes michaelseni gut homogenate': {'extracted_terms': ['gut'],
#   'remaining': 'macrotermes michaelseni  homogenate'},
#  'temperate shrubland': {'extracted_terms': ['rat'], 'remaining': None},
#  'alpine region': {'extracted_terms': ['pine'], 'remaining': None},
#  'human lung microbiome': {'extracted_terms': ['human', 'lung'],
#   'remaining': 'microbiome'},
#  'human lung': {'extracted_terms': ['human', 'lung'], 'remaining': None},
#  'cdna libraries generated from cells filtered from seawater': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'sinus middle meatus': {'extracted_terms': ['middle meatus'],
#   'remaining': 'sinus'},
#  'alpine tundra': {'extracted_terms': ['pine'], 'remaining': None},
#  'foregut contents': {'extracted_terms': ['gut'], 'remaining': None},
#  'large intestine contents': {'extracted_terms': ['intestine'],
#   'remaining': 'large  contents'},
#  'canine oral cavity': {'extracted_terms': ['oral cavity', 'canine'],
#   'remaining': None},
#  'broadleaf and mixed forest biome': {'extracted_terms': ['leaf'],
#   'remaining': None},
#  'sub boreal spruce biogeoclimatic zone': {'extracted_terms': ['spruce'],
#   'remaining': 'sub boreal  biogeoclimatic zone'},
#  'fermentation humic sustrate': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'gut content': {'extracted_terms': ['gut'], 'remaining': 'content'},
#  'human associated biome': {'extracted_terms': ['human'],
#   'remaining': 'associated biome'},
#  'moose rumen': {'extracted_terms': ['rumen'], 'remaining': 'moose'},
#  'whole rumen digesta': {'extracted_terms': ['rumen'],
#   'remaining': 'whole  digesta'},
#  'whole rumen contents': {'extracted_terms': ['rumen'],
#   'remaining': 'whole  contents'},
#  'sheep rumen': {'extracted_terms': ['sheep', 'rumen'], 'remaining': None},
#  'laboratory microcosm': {'extracted_terms': ['rat'], 'remaining': None},
#  'rice paddy field': {'extracted_terms': ['rice'], 'remaining': 'paddy field'},
#  'tongue plaque': {'extracted_terms': ['tongue'], 'remaining': 'plaque'},
#  'perchlorate': {'extracted_terms': ['rat'], 'remaining': None},
#  'faecal': {'extracted_terms': ['faecal'], 'remaining': None},
#  'human gut microbiome of anorexic': {'extracted_terms': ['human', 'gut'],
#   'remaining': 'microbiome of anorexic'},
#  'early exponential growth': {'extracted_terms': ['ear'], 'remaining': None},
#  'human body': {'extracted_terms': ['human'], 'remaining': 'body'},
#  'shrimp culture water': {'extracted_terms': ['shrimp'],
#   'remaining': 'culture water'},
#  'shrimp culture pond': {'extracted_terms': ['shrimp'],
#   'remaining': 'culture pond'},
#  'cat faecal microbiota': {'extracted_terms': ['faecal', 'cat'],
#   'remaining': 'microbiota'},
#  'cold temperature habitat': {'extracted_terms': ['rat'], 'remaining': None},
#  'rhizosphere soil and endosphere': {'extracted_terms': ['rhizosphere',
#    'endosphere'],
#   'remaining': 'soil and'},
#  'honeybee midgut': {'extracted_terms': ['midgut', 'bee'],
#   'remaining': 'honeybee'},
#  'swine intestinal tract': {'extracted_terms': ['intestinal tract', 'swine'],
#   'remaining': None},
#  'contents of the cecum': {'extracted_terms': ['cecum'],
#   'remaining': 'contents of the'},
#  'contents of the midcolon near the spiral bend': {'extracted_terms': ['colon',
#    'ear'],
#   'remaining': None},
#  'feces collected at necropsy': {'extracted_terms': ['feces'],
#   'remaining': 'collected at necropsy'},
#  'contents of the distal ileum': {'extracted_terms': ['ileum'],
#   'remaining': 'contents of the distal'},
#  'mucosal scrapings of the cecum': {'extracted_terms': ['mucosal', 'cecum'],
#   'remaining': 'scrapings of the'},
#  'mucosal scrapings of the midcolon near the spiral bend': {'extracted_terms': ['mucosal',
#    'colon',
#    'ear'],
#   'remaining': 'scrapings of the midcolon near the spiral bend'},
#  'mucosal scrapings of the distal ileum': {'extracted_terms': ['mucosal',
#    'ileum'],
#   'remaining': 'scrapings of the distal'},
#  'soybean field': {'extracted_terms': ['soybean'], 'remaining': 'field'},
#  'laboratory inbred mouse strain': {'extracted_terms': ['mouse', 'rat'],
#   'remaining': 'laboratory inbred  strain'},
#  'free range chicken farm': {'extracted_terms': ['chicken'],
#   'remaining': 'free range  farm'},
#  'temperate broadleaf and mixed forests': {'extracted_terms': ['leaf', 'rat'],
#   'remaining': None},
#  'temperate coniferous forests': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'insect guts': {'extracted_terms': ['insect', 'gut'], 'remaining': 'guts'},
#  'liquid fraction of rumen sample': {'extracted_terms': ['rumen'],
#   'remaining': 'liquid fraction of  sample'},
#  'solid fraction of rumen sample': {'extracted_terms': ['rumen'],
#   'remaining': 'solid fraction of  sample'},
#  'mouse metatranscriptome': {'extracted_terms': ['mouse'],
#   'remaining': 'metatranscriptome'},
#  'forestomach content': {'extracted_terms': ['stomach'], 'remaining': None},
#  'forestomach contents': {'extracted_terms': ['stomach'], 'remaining': None},
#  'non rhizosphere': {'extracted_terms': ['rhizosphere'], 'remaining': 'non'},
#  'cdna from liquid fraction of rumen sample': {'extracted_terms': ['rumen'],
#   'remaining': 'cdna from liquid fraction of  sample'},
#  'cdna from solid fraction of rumen sample': {'extracted_terms': ['rumen'],
#   'remaining': 'cdna from solid fraction of  sample'},
#  'rumen liquids': {'extracted_terms': ['rumen'], 'remaining': 'liquids'},
#  'rumen solids': {'extracted_terms': ['rumen'], 'remaining': 'solids'},
#  'rumen solids and liquids': {'extracted_terms': ['rumen'],
#   'remaining': 'solids and liquids'},
#  'rice paddy soils': {'extracted_terms': ['rice'], 'remaining': 'paddy soils'},
#  'temperate zone usa': {'extracted_terms': ['rat'], 'remaining': None},
#  'saliva sample from atqasuk': {'extracted_terms': ['saliva'],
#   'remaining': 'sample from atqasuk'},
#  'saliva sample from human': {'extracted_terms': ['saliva', 'human'],
#   'remaining': 'sample from'},
#  'saliva sample from barrow': {'extracted_terms': ['saliva'],
#   'remaining': 'sample from barrow'},
#  'saliva sample from nuiqsut': {'extracted_terms': ['saliva'],
#   'remaining': 'sample from nuiqsut'},
#  'saliva sample from wainwright': {'extracted_terms': ['saliva'],
#   'remaining': 'sample from wainwright'},
#  'saliva sample from german': {'extracted_terms': ['saliva'],
#   'remaining': 'sample from german'},
#  'saliva sample from': {'extracted_terms': ['saliva'],
#   'remaining': 'sample from'},
#  'saliva sample from drc': {'extracted_terms': ['saliva'],
#   'remaining': 'sample from drc'},
#  'saliva sample from sl': {'extracted_terms': ['saliva'],
#   'remaining': 'sample from sl'},
#  'human scalp': {'extracted_terms': ['human', 'scalp'], 'remaining': None},
#  'temperate broadleaf and mixed forest': {'extracted_terms': ['leaf', 'rat'],
#   'remaining': None},
#  'pig farm adult pig': {'extracted_terms': ['pig'],
#   'remaining': 'farm adult pig'},
#  'pig farm juvenile pig': {'extracted_terms': ['pig'],
#   'remaining': 'farm juvenile pig'},
#  'temperate urban': {'extracted_terms': ['rat'], 'remaining': None},
#  'pine rhizosphere': {'extracted_terms': ['rhizosphere', 'pine'],
#   'remaining': None},
#  'rumen fluid': {'extracted_terms': ['rumen fluid'], 'remaining': None},
#  'temperate shelf and sea biome': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'dna template was not subjected to whole genome amplification was subjected only to pcr': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'dna template was generated by mda multiple displacement amplification': {'extracted_terms': ['rat',
#    'cat'],
#   'remaining': None},
#  'dna template was generated by pwga primase based whole genome amplification': {'extracted_terms': ['rat',
#    'cat'],
#   'remaining': None},
#  'gut of honey bee': {'extracted_terms': ['honey bee', 'gut'],
#   'remaining': 'of'},
#  'leafs': {'extracted_terms': ['leaf'], 'remaining': None},
#  'humangut': {'extracted_terms': ['human', 'gut'], 'remaining': None},
#  'humanfecal': {'extracted_terms': ['human', 'fecal'], 'remaining': None},
#  'fecal content': {'extracted_terms': ['fecal'], 'remaining': 'content'},
#  'deep water coral reef': {'extracted_terms': ['coral'],
#   'remaining': 'deep water  reef'},
#  'flooded rice paddy': {'extracted_terms': ['rice'],
#   'remaining': 'flooded  paddy'},
#  'corn field': {'extracted_terms': ['corn'], 'remaining': 'field'},
#  'rhizosphere soil': {'extracted_terms': ['rhizosphere'], 'remaining': 'soil'},
#  'treated by mc lr in higher concentration': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'treated by mc lr in lower concentration': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'united states food and drug administration as a prescription medical device': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'leaf surface': {'extracted_terms': ['leaf'], 'remaining': 'surface'},
#  'sequencing replicate': {'extracted_terms': ['cat'], 'remaining': None},
#  'temperate woodland': {'extracted_terms': ['rat'], 'remaining': None},
#  'coral island': {'extracted_terms': ['coral'], 'remaining': 'island'},
#  'temperate coniferous forest': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'alpine vegetation': {'extracted_terms': ['pine'], 'remaining': None},
#  'cow rumen': {'extracted_terms': ['rumen', 'cow'], 'remaining': None},
#  'laboratory digester': {'extracted_terms': ['rat'], 'remaining': None},
#  'continuous permafrost near bitumen': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'pig gut': {'extracted_terms': ['pig', 'gut'], 'remaining': None},
#  'luminal contents from cecum': {'extracted_terms': ['cecum'],
#   'remaining': 'luminal contents from'},
#  'feces of bats': {'extracted_terms': ['feces'], 'remaining': 'of bats'},
#  'hydrate bearing region': {'extracted_terms': ['rat', 'ear'],
#   'remaining': None},
#  'copper control biofilm year months old': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'copperspiked biofilm year months old': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'copperand a polyphaga spiked biofilm year months old': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'upvc control biofilm year months old': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'upvcspiked biofilm year months old': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'upvcand a polyphaga spiked biofilm year months old': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'contents of guts': {'extracted_terms': ['gut'], 'remaining': None},
#  'human airway': {'extracted_terms': ['airway', 'human'], 'remaining': None},
#  'human cadaver': {'extracted_terms': ['human'], 'remaining': 'cadaver'},
#  'fecal dna': {'extracted_terms': ['fecal'], 'remaining': 'dna'},
#  'fecal samples': {'extracted_terms': ['fecal'], 'remaining': 'samples'},
#  'and subtropical moist broadleaf forest biome': {'extracted_terms': ['leaf'],
#   'remaining': None},
#  'insect cell line': {'extracted_terms': ['insect'], 'remaining': 'cell line'},
#  'gut microbiota of large yellow croaker': {'extracted_terms': ['oak', 'gut'],
#   'remaining': 'microbiota of large yellow croaker'},
#  'laboratory evolution': {'extracted_terms': ['rat'], 'remaining': None},
#  'seed lot': {'extracted_terms': ['seed'], 'remaining': 'lot'},
#  'questing tick from herbaceous layer': {'extracted_terms': ['tick'],
#   'remaining': 'questing  from herbaceous layer'},
#  'tick': {'extracted_terms': ['tick'], 'remaining': None},
#  'mid gut': {'extracted_terms': ['gut'], 'remaining': 'mid'},
#  'root associated': {'extracted_terms': ['root'], 'remaining': 'associated'},
#  'mucosa tissue and swabs': {'extracted_terms': ['mucosa'],
#   'remaining': 'tissue and swabs'},
#  'ear biopsy': {'extracted_terms': ['ear'], 'remaining': 'biopsy'},
#  'potato field': {'extracted_terms': ['potato'], 'remaining': 'field'},
#  'mucosa tissue and swabs from vocal cord polyps patients': {'extracted_terms': ['mucosa'],
#   'remaining': 'tissue and swabs from vocal cord polyps patients'},
#  'insect tissue': {'extracted_terms': ['insect'], 'remaining': 'tissue'},
#  'fecal sample': {'extracted_terms': ['fecal'], 'remaining': 'sample'},
#  'year burning': {'extracted_terms': ['ear'], 'remaining': None},
#  'culture of escherichia coli population isolated from mice fecal contents': {'extracted_terms': ['fecal',
#    'mice'],
#   'remaining': 'culture of escherichia coli population isolated from   contents'},
#  'human gut sample': {'extracted_terms': ['human', 'gut'],
#   'remaining': 'sample'},
#  'eucalyptus plantation located at a region originally with brazilian atlantic florest': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'mixed plantation located at a region originally with brazilian atlantic florest': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'acacia mangium plantation located at a region originally with brazilian atlantic florest': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'sponge symbiont': {'extracted_terms': ['sponge'], 'remaining': 'symbiont'},
#  'fish gut': {'extracted_terms': ['fish', 'gut'], 'remaining': None},
#  'gujarat': {'extracted_terms': ['rat'], 'remaining': None},
#  'pig feces': {'extracted_terms': ['feces', 'pig'], 'remaining': None},
#  'swine manure': {'extracted_terms': ['swine'], 'remaining': 'manure'},
#  'l continuous fermentation of carbohydrates': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'soils used to inoculate seedlings': {'extracted_terms': ['seed'],
#   'remaining': None},
#  'rooted cuttings': {'extracted_terms': ['root'], 'remaining': None},
#  'seedlings': {'extracted_terms': ['seed'], 'remaining': None},
#  'rabbit caecum': {'extracted_terms': ['caecum'], 'remaining': 'rabbit'},
#  'coral mucus': {'extracted_terms': ['coral', 'mucus'], 'remaining': None},
#  'mucosa washing': {'extracted_terms': ['mucosa'], 'remaining': 'washing'},
#  'grapevine': {'extracted_terms': ['grapevine'], 'remaining': None},
#  'mosquito midgut': {'extracted_terms': ['mosquito', 'midgut'],
#   'remaining': None},
#  'soybean rhizosphere soil samples after years of continuous cropping': {'extracted_terms': ['rhizosphere',
#    'soybean',
#    'ears',
#    'ear'],
#   'remaining': 'soil samples after years of continuous cropping'},
#  'fresh leaves': {'extracted_terms': ['leaves'], 'remaining': 'fresh'},
#  'oak conifer forest': {'extracted_terms': ['oak'],
#   'remaining': 'conifer forest'},
#  'canine associated': {'extracted_terms': ['canine'],
#   'remaining': 'associated'},
#  'honey bee pollen': {'extracted_terms': ['honey bee'], 'remaining': 'pollen'},
#  'honey bee guts': {'extracted_terms': ['honey bee', 'gut'],
#   'remaining': 'guts'},
#  'chicken farm': {'extracted_terms': ['chicken'], 'remaining': 'farm'},
#  'caecal microbes': {'extracted_terms': ['caeca'], 'remaining': None},
#  'soybean soil': {'extracted_terms': ['soybean'], 'remaining': 'soil'},
#  'crude oil from the oil stratum withбуc': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'oil production water phase from the oil stratum withбуc': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'mediterranean temperate coastal area': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'fecal matter of c mice exposure tomg': {'extracted_terms': ['fecal', 'mice'],
#   'remaining': 'matter of c  exposure tomg'},
#  'swine farm': {'extracted_terms': ['swine'], 'remaining': 'farm'},
#  'plant leaf': {'extracted_terms': ['leaf'], 'remaining': 'plant'},
#  'rhizosphere of tomato': {'extracted_terms': ['rhizosphere', 'tomato'],
#   'remaining': 'of'},
#  'roots and soil': {'extracted_terms': ['roots'], 'remaining': 'and soil'},
#  'plant endosphere': {'extracted_terms': ['endosphere'], 'remaining': 'plant'},
#  'temperate valley': {'extracted_terms': ['rat'], 'remaining': None},
#  'human oral': {'extracted_terms': ['human'], 'remaining': 'oral'},
#  'human saliva': {'extracted_terms': ['saliva', 'human'], 'remaining': None},
#  'temperate deciduous forest': {'extracted_terms': ['rat'], 'remaining': None},
#  'human blood': {'extracted_terms': ['human', 'blood'], 'remaining': None},
#  'years wastewater irrigation': {'extracted_terms': ['ears', 'ear'],
#   'remaining': None},
#  'paratistic on pyrus communis': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'raw ewe s milk': {'extracted_terms': ['milk'], 'remaining': 'raw ewe s'},
#  'curd for canestrato pugliese cheese': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'canestrato cheese after brining': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'canestrato cheese after days ripening': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'alpine meadow soil': {'extracted_terms': ['pine'], 'remaining': None},
#  'activated sludge of wastewater treatment system': {'extracted_terms': ['stem'],
#   'remaining': None},
#  'freshly voided feces': {'extracted_terms': ['feces'],
#   'remaining': 'freshly voided'},
#  'tobacco leaf scraps wastes': {'extracted_terms': ['leaf'],
#   'remaining': 'tobacco  scraps wastes'},
#  'tobacco plant stems wastes': {'extracted_terms': ['stems'],
#   'remaining': 'tobacco plant  wastes'},
#  'and cow dung': {'extracted_terms': ['cow'], 'remaining': 'and  dung'},
#  'human feces': {'extracted_terms': ['human', 'feces'], 'remaining': None},
#  'steer rumen': {'extracted_terms': ['rumen'], 'remaining': 'steer'},
#  'murine gut': {'extracted_terms': ['urine', 'urine', 'gut'],
#   'remaining': 'murine'},
#  'human gastric': {'extracted_terms': ['human'], 'remaining': 'gastric'},
#  'plant leaves': {'extracted_terms': ['leaves'], 'remaining': 'plant'},
#  'uws laboratory line': {'extracted_terms': ['rat'], 'remaining': None},
#  'moist broadleaf forests': {'extracted_terms': ['leaf'], 'remaining': None},
#  'human supragingival plaque': {'extracted_terms': ['supragingival plaque',
#    'human'],
#   'remaining': None},
#  'soil aquifer treatment system': {'extracted_terms': ['stem'],
#   'remaining': None},
#  'diptera intestine': {'extracted_terms': ['intestine'],
#   'remaining': 'diptera'},
#  'human oral mucosa model': {'extracted_terms': ['mucosa', 'human'],
#   'remaining': 'oral  model'},
#  'qdaff laboratory line bn': {'extracted_terms': ['rat'], 'remaining': None},
#  'broadleaf and mixed forests': {'extracted_terms': ['leaf'],
#   'remaining': None},
#  'mouse body': {'extracted_terms': ['mouse'], 'remaining': 'body'},
#  'bombus bimaculatus gut': {'extracted_terms': ['gut'],
#   'remaining': 'bombus bimaculatus'},
#  'bee gut': {'extracted_terms': ['bee', 'gut'], 'remaining': None},
#  'gut tissue': {'extracted_terms': ['gut'], 'remaining': 'tissue'},
#  'bombus vagans gut': {'extracted_terms': ['gut'],
#   'remaining': 'bombus vagans'},
#  'replicate soil from leizhou': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'replicate soil from yingtan': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'replicate soil from jiaxing': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'replicate soil from gushi of taoyuan': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'replicate soil from baodongyu of taoyuan': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'foam substrate': {'extracted_terms': ['rat'], 'remaining': None},
#  'milk vetch': {'extracted_terms': ['milk'], 'remaining': 'vetch'},
#  'fish gut microbiome': {'extracted_terms': ['fish', 'gut'],
#   'remaining': 'microbiome'},
#  'ixodes persulcatus tick': {'extracted_terms': ['tick', 'cat'],
#   'remaining': 'ixodes persulcatus'},
#  'microbiome associated with ixodes persulcatus tick': {'extracted_terms': ['tick',
#    'cat'],
#   'remaining': 'microbiome associated with ixodes persulcatus'},
#  'temperate decidious forest': {'extracted_terms': ['rat'], 'remaining': None},
#  'dna from roots of tree': {'extracted_terms': ['roots'],
#   'remaining': 'dna from  of tree'},
#  'roots': {'extracted_terms': ['roots'], 'remaining': None},
#  'rna from roots of tree': {'extracted_terms': ['roots'],
#   'remaining': 'rna from  of tree'},
#  'temperate flooded field': {'extracted_terms': ['rat'], 'remaining': None},
#  'rice canopy': {'extracted_terms': ['rice'], 'remaining': 'canopy'},
#  'prrd root': {'extracted_terms': ['root'], 'remaining': 'prrd'},
#  'prsd stem': {'extracted_terms': ['stem'], 'remaining': 'prsd'},
#  'r rd root': {'extracted_terms': ['root'], 'remaining': 'r rd'},
#  'r sd stem': {'extracted_terms': ['stem'], 'remaining': 'r sd'},
#  'sard root': {'extracted_terms': ['root'], 'remaining': 'sard'},
#  'sasd stem': {'extracted_terms': ['stem'], 'remaining': 'sasd'},
#  'wastewater treatment system': {'extracted_terms': ['stem'],
#   'remaining': None},
#  'drinking water distribution system': {'extracted_terms': ['stem'],
#   'remaining': None},
#  'cattle feedlot': {'extracted_terms': ['cattle'], 'remaining': 'feedlot'},
#  'fecal grab sample': {'extracted_terms': ['fecal'],
#   'remaining': 'grab sample'},
#  'fecal grab sample from animal c': {'extracted_terms': ['fecal'],
#   'remaining': 'grab sample from animal c'},
#  'fecal grab sample from animal ss': {'extracted_terms': ['fecal'],
#   'remaining': 'grab sample from animal ss'},
#  'rat blood': {'extracted_terms': ['blood', 'rat'], 'remaining': None},
#  'antarctic coastal ecosystem': {'extracted_terms': ['stem'],
#   'remaining': None},
#  'fish pond': {'extracted_terms': ['fish'], 'remaining': 'pond'},
#  'plant stem': {'extracted_terms': ['stem'], 'remaining': 'plant'},
#  'colonic tissue microbiome': {'extracted_terms': ['colon'],
#   'remaining': None},
#  'spruce forest': {'extracted_terms': ['spruce'], 'remaining': 'forest'},
#  'beech forest': {'extracted_terms': ['beech'], 'remaining': 'forest'},
#  'colon biopsy': {'extracted_terms': ['colon'], 'remaining': 'biopsy'},
#  'metagenome from milk used for fontina cheese production': {'extracted_terms': ['milk'],
#   'remaining': 'metagenome from  used for fontina cheese production'},
#  'human oral cavity': {'extracted_terms': ['oral cavity', 'human'],
#   'remaining': None},
#  'beech rhizosphere': {'extracted_terms': ['rhizosphere', 'beech'],
#   'remaining': None},
#  'faecal virome': {'extracted_terms': ['faecal'], 'remaining': 'virome'},
#  'years contiunous cropping': {'extracted_terms': ['ears', 'ear'],
#   'remaining': None},
#  'human stool': {'extracted_terms': ['human'], 'remaining': 'stool'},
#  'bioelectrochemical system': {'extracted_terms': ['stem'], 'remaining': None},
#  'cattle milk associated habitat': {'extracted_terms': ['cattle', 'milk'],
#   'remaining': 'associated habitat'},
#  'swine intestine': {'extracted_terms': ['intestine', 'swine'],
#   'remaining': None},
#  'fecal swab': {'extracted_terms': ['fecal'], 'remaining': 'swab'},
#  'saliva and plaque': {'extracted_terms': ['saliva'],
#   'remaining': 'and plaque'},
#  'birch root': {'extracted_terms': ['birch', 'root'], 'remaining': None},
#  'buffalo milk associated habitat': {'extracted_terms': ['milk'],
#   'remaining': 'buffalo  associated habitat'},
#  'human oral biome': {'extracted_terms': ['human'], 'remaining': 'oral biome'},
#  'cf lung': {'extracted_terms': ['lung'], 'remaining': 'cf'},
#  'cystic fibosis sputum': {'extracted_terms': ['sputum'],
#   'remaining': 'cystic fibosis'},
#  'human oral sample': {'extracted_terms': ['human'],
#   'remaining': 'oral sample'},
#  'human oral cavity swab': {'extracted_terms': ['oral cavity', 'human'],
#   'remaining': 'swab'},
#  'laboratory reagents': {'extracted_terms': ['rat'], 'remaining': None},
#  'deep sea coral community': {'extracted_terms': ['coral'],
#   'remaining': 'deep sea  community'},
#  'rice soil': {'extracted_terms': ['rice'], 'remaining': 'soil'},
#  'apple leaves': {'extracted_terms': ['leaves', 'apple'], 'remaining': None},
#  'apple orchard': {'extracted_terms': ['apple'], 'remaining': 'orchard'},
#  'from feces': {'extracted_terms': ['feces'], 'remaining': 'from'},
#  'bovine rumen': {'extracted_terms': ['rumen'], 'remaining': 'bovine'},
#  'laboratory culture': {'extracted_terms': ['rat'], 'remaining': None},
#  'field sampling of ticks': {'extracted_terms': ['ticks'],
#   'remaining': 'field sampling of'},
#  'dna extraction from ticks': {'extracted_terms': ['ticks'],
#   'remaining': 'dna extraction from'},
#  'coastal ecosystem': {'extracted_terms': ['stem'], 'remaining': None},
#  'cattle manure': {'extracted_terms': ['cattle'], 'remaining': 'manure'},
#  'cattle excrements': {'extracted_terms': ['cattle'],
#   'remaining': 'excrements'},
#  'cat feces cat': {'extracted_terms': ['feces', 'cat'], 'remaining': 'cat'},
#  'swine feces swine': {'extracted_terms': ['swine', 'feces'],
#   'remaining': 'swine'},
#  'dog feces dog': {'extracted_terms': ['feces', 'dog'], 'remaining': 'dog'},
#  'chicken feces chicken': {'extracted_terms': ['chicken', 'feces'],
#   'remaining': 'chicken'},
#  'cow feces cow': {'extracted_terms': ['feces', 'cow'], 'remaining': 'cow'},
#  'mule deer feces deer': {'extracted_terms': ['mule deer', 'feces', 'deer'],
#   'remaining': None},
#  'pig feces pig': {'extracted_terms': ['feces', 'pig'], 'remaining': 'pig'},
#  'dog feces brazil dog': {'extracted_terms': ['feces', 'dog'],
#   'remaining': 'brazil dog'},
#  'horse feces horse': {'extracted_terms': ['horse', 'feces'],
#   'remaining': 'horse'},
#  'cow feces brazil cow': {'extracted_terms': ['feces', 'cow'],
#   'remaining': 'brazil cow'},
#  'mixture of alcohol mash and wheat bran': {'extracted_terms': ['wheat'],
#   'remaining': 'mixture of alcohol mash and  bran'},
#  'mouse fecal': {'extracted_terms': ['mouse', 'fecal'], 'remaining': None},
#  'human stomach': {'extracted_terms': ['stomach', 'human'], 'remaining': None},
#  'the sputum of a cystic fibrosis patient': {'extracted_terms': ['sputum'],
#   'remaining': 'the  of a cystic fibrosis patient'},
#  'spartina alterniflora roots associated': {'extracted_terms': ['roots'],
#   'remaining': 'spartina alterniflora  associated'},
#  'mangrove roots associated': {'extracted_terms': ['roots'],
#   'remaining': 'mangrove  associated'},
#  'oak litter': {'extracted_terms': ['oak'], 'remaining': 'litter'},
#  'human skin surface': {'extracted_terms': ['human', 'skin'],
#   'remaining': 'surface'},
#  'mouse gut': {'extracted_terms': ['mouse', 'gut'], 'remaining': None},
#  'human fecal': {'extracted_terms': ['human', 'fecal'], 'remaining': None},
#  'biological replicate a': {'extracted_terms': ['cat'], 'remaining': None},
#  'biological replicate b': {'extracted_terms': ['cat'], 'remaining': None},
#  'biological replicate c': {'extracted_terms': ['cat'], 'remaining': None},
#  'biological replicate d': {'extracted_terms': ['cat'], 'remaining': None},
#  'induced sputum': {'extracted_terms': ['sputum'], 'remaining': 'induced'},
#  'human associated': {'extracted_terms': ['human'], 'remaining': 'associated'},
#  'nearshore': {'extracted_terms': ['ears', 'ear'], 'remaining': None},
#  'oxygen deficient coastal upwelling ecosystem': {'extracted_terms': ['stem'],
#   'remaining': None},
#  'colon content': {'extracted_terms': ['colon'], 'remaining': 'content'},
#  'agroecosystem': {'extracted_terms': ['stem'], 'remaining': None},
#  'pine forest': {'extracted_terms': ['pine'], 'remaining': 'forest'},
#  'pine forest plot covered by calluna vulgaris': {'extracted_terms': ['pine'],
#   'remaining': 'forest plot covered by calluna vulgaris'},
#  'pine forest plot without ericaceaen understory': {'extracted_terms': ['pine'],
#   'remaining': 'forest plot without ericaceaen understory'},
#  'pine forest plot covered by vaccinium myrtillus': {'extracted_terms': ['pine'],
#   'remaining': 'forest plot covered by vaccinium myrtillus'},
#  'embryonic stem cells derived from inner cell mass': {'extracted_terms': ['stem'],
#   'remaining': 'embryonic  cells derived from inner cell mass'},
#  'microrganisms associated to corals': {'extracted_terms': ['corals'],
#   'remaining': 'microrganisms associated to'},
#  'coral tissue': {'extracted_terms': ['coral'], 'remaining': 'tissue'},
#  'wheat field': {'extracted_terms': ['wheat'], 'remaining': 'field'},
#  'green leafs': {'extracted_terms': ['leaf'], 'remaining': None},
#  'years croping': {'extracted_terms': ['ears', 'ear'], 'remaining': None},
#  'human skin microbiome in pilosebaceous unit': {'extracted_terms': ['human',
#    'skin'],
#   'remaining': 'microbiome in pilosebaceous unit'},
#  'human nose follicule content': {'extracted_terms': ['human', 'nose'],
#   'remaining': 'follicule content'},
#  'a sample from a subject with healthy skin': {'extracted_terms': ['skin'],
#   'remaining': 'a sample from a subject with healthy'},
#  'fermented soybean': {'extracted_terms': ['soybean'],
#   'remaining': 'fermented'},
#  'wheat leaves': {'extracted_terms': ['leaves', 'wheat'], 'remaining': None},
#  'goat milk cake': {'extracted_terms': ['milk'], 'remaining': 'goat  cake'},
#  'human gut stool': {'extracted_terms': ['human', 'gut'],
#   'remaining': 'stool'},
#  'plant root': {'extracted_terms': ['root'], 'remaining': 'plant'},
#  'fermented fish': {'extracted_terms': ['fish'], 'remaining': 'fermented'},
#  'wheat sourdough': {'extracted_terms': ['wheat'], 'remaining': 'sourdough'},
#  'fermented wheat flour': {'extracted_terms': ['wheat'],
#   'remaining': 'fermented  flour'},
#  'human tooth': {'extracted_terms': ['human', 'tooth'], 'remaining': None},
#  'human hair': {'extracted_terms': ['human', 'hair'], 'remaining': None},
#  'fecal contents': {'extracted_terms': ['fecal'], 'remaining': 'contents'},
#  'greater cane rat caecum bacteriome s amplicon': {'extracted_terms': ['caecum',
#    'rat'],
#   'remaining': 'greater cane   bacteriome s amplicon'},
#  'fish cages': {'extracted_terms': ['fish'], 'remaining': 'cages'},
#  'salmon fillet': {'extracted_terms': ['salmon'], 'remaining': 'fillet'},
#  'cooked peeled shrimps': {'extracted_terms': ['shrimp'], 'remaining': None},
#  'human red blood cells': {'extracted_terms': ['human', 'blood'],
#   'remaining': 'red  cells'},
#  'human sputum': {'extracted_terms': ['sputum', 'human'], 'remaining': None},
#  'poplar leaf': {'extracted_terms': ['leaf'], 'remaining': 'poplar'},
#  'temperate region forest': {'extracted_terms': ['rat'], 'remaining': None},
#  'temperature habitat': {'extracted_terms': ['rat'], 'remaining': None},
#  'sponge tissue': {'extracted_terms': ['sponge'], 'remaining': 'tissue'},
#  'ponderosa pine': {'extracted_terms': ['pine'], 'remaining': 'ponderosa'},
#  'gut dissection': {'extracted_terms': ['gut'], 'remaining': 'dissection'},
#  'sewer system': {'extracted_terms': ['stem'], 'remaining': None},
#  'laboratory reactor system simulating a real rising main sewer pipe': {'extracted_terms': ['stem',
#    'rat'],
#   'remaining': None},
#  'stratified estuary': {'extracted_terms': ['rat'], 'remaining': None},
#  'fed with soybean oil': {'extracted_terms': ['soybean'],
#   'remaining': 'fed with  oil'},
#  'fed with beef tallow': {'extracted_terms': ['bee'], 'remaining': None},
#  'fed with linseed oil': {'extracted_terms': ['seed'], 'remaining': None},
#  'fed with fish oil': {'extracted_terms': ['fish'],
#   'remaining': 'fed with  oil'},
#  'rumen contents': {'extracted_terms': ['rumen'], 'remaining': 'contents'},
#  'estuarine ecosystems': {'extracted_terms': ['stems', 'stem'],
#   'remaining': None},
#  'marine invertebrate': {'extracted_terms': ['rat'], 'remaining': None},
#  'cathode biofilm': {'extracted_terms': ['cat'], 'remaining': None},
#  'chicken cecal contents': {'extracted_terms': ['chicken'],
#   'remaining': 'cecal contents'},
#  'abalone seed nursing pond': {'extracted_terms': ['seed'],
#   'remaining': 'abalone  nursing pond'},
#  'potato dextrose agar': {'extracted_terms': ['potato'],
#   'remaining': 'dextrose agar'},
#  'saffron rhizosphere metagenome': {'extracted_terms': ['rhizosphere'],
#   'remaining': 'saffron  metagenome'},
#  'rat gut': {'extracted_terms': ['rat', 'gut'], 'remaining': None},
#  'obtained in laboratory': {'extracted_terms': ['rat'], 'remaining': None},
#  'bio dried substrate': {'extracted_terms': ['rat'], 'remaining': None},
#  'floating pumice': {'extracted_terms': ['mice'], 'remaining': None},
#  'temperate broadleaf': {'extracted_terms': ['leaf', 'rat'],
#   'remaining': None},
#  'rhizosphere of poa annua turf': {'extracted_terms': ['rhizosphere'],
#   'remaining': 'of poa annua turf'},
#  'cathodic biofilm in a membraneless methanogenic microbial electrolysis cell': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'graphite cathode': {'extracted_terms': ['cat'], 'remaining': None},
#  'citrus infected tissue': {'extracted_terms': ['citrus'],
#   'remaining': 'infected tissue'},
#  'pig farm': {'extracted_terms': ['pig'], 'remaining': 'farm'},
#  'pig slurry': {'extracted_terms': ['pig'], 'remaining': 'slurry'},
#  'tomato field': {'extracted_terms': ['tomato'], 'remaining': 'field'},
#  'cattle rumen': {'extracted_terms': ['cattle', 'rumen'], 'remaining': None},
#  'rotten apple fruit': {'extracted_terms': ['apple'],
#   'remaining': 'rotten  fruit'},
#  'tick associated habitat': {'extracted_terms': ['tick'],
#   'remaining': 'associated habitat'},
#  'endosphere': {'extracted_terms': ['endosphere'], 'remaining': None},
#  'biological replicate': {'extracted_terms': ['cat'], 'remaining': None},
#  'pooled data from replicates': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'in vitro fermentation pig feces': {'extracted_terms': ['feces', 'pig'],
#   'remaining': 'in vitro fermentation'},
#  'fecal microbiome': {'extracted_terms': ['fecal'], 'remaining': 'microbiome'},
#  'respiratory care center': {'extracted_terms': ['rat'], 'remaining': None},
#  'methanogenic biocathode': {'extracted_terms': ['cat'], 'remaining': None},
#  'methanogenic biocathode open circuit': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'human peridontal picket': {'extracted_terms': ['human'],
#   'remaining': 'peridontal picket'},
#  'bio dried substrates': {'extracted_terms': ['rat'], 'remaining': None},
#  'pinus sylvestris forest soil': {'extracted_terms': ['pinus sylvestris'],
#   'remaining': 'forest soil'},
#  'sequencing batch airlift reactor for partial nitrification': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'min after substrate feeding': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'partial nitrification aerobic granules': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'fermented rice grains': {'extracted_terms': ['rice'],
#   'remaining': 'fermented  grains'},
#  'ozonated year': {'extracted_terms': ['ear'], 'remaining': None},
#  'agricultural soil growing corn': {'extracted_terms': ['corn'],
#   'remaining': 'agricultural soil growing'},
#  'pine branch or stem': {'extracted_terms': ['pine', 'stem'],
#   'remaining': 'branch or'},
#  'methane hydrate and oil bearing sediments': {'extracted_terms': ['rat',
#    'ear'],
#   'remaining': None},
#  'human intestine': {'extracted_terms': ['intestine', 'human'],
#   'remaining': None},
#  'mixed species mosquitos': {'extracted_terms': ['mosquito'],
#   'remaining': None},
#  'viral fraction from sputum': {'extracted_terms': ['sputum'],
#   'remaining': 'viral fraction from'},
#  'biofilm filtrate': {'extracted_terms': ['rat'], 'remaining': None},
#  'coral specimens': {'extracted_terms': ['coral'], 'remaining': 'specimens'},
#  'honey bee midgut': {'extracted_terms': ['honey bee', 'midgut'],
#   'remaining': None},
#  'coast pinus muricata forest': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'urine microbiome': {'extracted_terms': ['urine'], 'remaining': 'microbiome'},
#  'insectary': {'extracted_terms': ['insect'], 'remaining': None},
#  'lab mosquito colony': {'extracted_terms': ['mosquito', 'colon'],
#   'remaining': 'lab  colony'},
#  'alpine forest': {'extracted_terms': ['pine'], 'remaining': None},
#  'goat rumen': {'extracted_terms': ['rumen'], 'remaining': 'goat'},
#  'cow s milk': {'extracted_terms': ['milk', 'cow'], 'remaining': 's'},
#  'temperature and humidity conditions on an artificial diet made of white bean': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'gurbantunggut desert': {'extracted_terms': ['gut'], 'remaining': None},
#  'root soil': {'extracted_terms': ['root'], 'remaining': 'soil'},
#  'soil rhizosphere': {'extracted_terms': ['rhizosphere'], 'remaining': 'soil'},
#  'buffalo rumen': {'extracted_terms': ['rumen'], 'remaining': 'buffalo'},
#  'proximal jejunum sampleo h negative animal': {'extracted_terms': ['jejunum'],
#   'remaining': 'proximal  sampleo h negative animal'},
#  'mid jejunum sampleo h negative animal': {'extracted_terms': ['jejunum'],
#   'remaining': 'mid  sampleo h negative animal'},
#  'distal jejunum sampleo h negative animal': {'extracted_terms': ['jejunum'],
#   'remaining': 'distal  sampleo h negative animal'},
#  'cecum sampleo h negative animal': {'extracted_terms': ['cecum'],
#   'remaining': 'sampleo h negative animal'},
#  'descending colon sampleo h negative animal': {'extracted_terms': ['colon'],
#   'remaining': 'descending  sampleo h negative animal'},
#  'spiral colon sampleo h negative animal': {'extracted_terms': ['colon'],
#   'remaining': 'spiral  sampleo h negative animal'},
#  'rectum sampleo h negative animal': {'extracted_terms': ['rectum'],
#   'remaining': 'sampleo h negative animal'},
#  'rectum tissue sampleo h negative animal': {'extracted_terms': ['rectum'],
#   'remaining': 'tissue sampleo h negative animal'},
#  'proximal jejunum sample fromo h supershedder animal': {'extracted_terms': ['jejunum'],
#   'remaining': 'proximal  sample fromo h supershedder animal'},
#  'mid jejunum sample fromo h supershedder animal': {'extracted_terms': ['jejunum'],
#   'remaining': 'mid  sample fromo h supershedder animal'},
#  'distal jejunum sample fromo h supershedder animal': {'extracted_terms': ['jejunum'],
#   'remaining': 'distal  sample fromo h supershedder animal'},
#  'cecum sample fromo h supershedder animal': {'extracted_terms': ['cecum'],
#   'remaining': 'sample fromo h supershedder animal'},
#  'descending colon sample fromo h supershedder animal': {'extracted_terms': ['colon'],
#   'remaining': 'descending  sample fromo h supershedder animal'},
#  'spiral colon sample fromo h supershedder animal': {'extracted_terms': ['colon'],
#   'remaining': 'spiral  sample fromo h supershedder animal'},
#  'rectum sample fromo h supershedder animal': {'extracted_terms': ['rectum'],
#   'remaining': 'sample fromo h supershedder animal'},
#  'rectum tissue sample fromo h supershedder animal': {'extracted_terms': ['rectum'],
#   'remaining': 'tissue sample fromo h supershedder animal'},
#  'fish gastrointestinal tract': {'extracted_terms': ['gastrointestinal tract',
#    'fish'],
#   'remaining': None},
#  'potato plot': {'extracted_terms': ['potato'], 'remaining': 'plot'},
#  'early developed biocrusts': {'extracted_terms': ['ear'], 'remaining': None},
#  'laboratory colony': {'extracted_terms': ['colon', 'rat'], 'remaining': None},
#  'rhizospheresoil': {'extracted_terms': ['rhizosphere'], 'remaining': None},
#  'rice roots': {'extracted_terms': ['roots', 'rice'], 'remaining': None},
#  'vaginal sample': {'extracted_terms': ['vaginal'], 'remaining': 'sample'},
#  'influent sewage human': {'extracted_terms': ['human'],
#   'remaining': 'influent sewage'},
#  'control mucosal tissue': {'extracted_terms': ['mucosal'],
#   'remaining': 'control  tissue'},
#  'rhizosphere sediments': {'extracted_terms': ['rhizosphere'],
#   'remaining': 'sediments'},
#  'rabbit caecum bacteriome s amplicon': {'extracted_terms': ['caecum'],
#   'remaining': 'rabbit  bacteriome s amplicon'},
#  'temperate soil': {'extracted_terms': ['rat'], 'remaining': None},
#  'human elbow': {'extracted_terms': ['human'], 'remaining': 'elbow'},
#  'pig colon': {'extracted_terms': ['colon', 'pig'], 'remaining': None},
#  'pig nasal cavity': {'extracted_terms': ['nasal cavity', 'pig'],
#   'remaining': None},
#  'oak trees': {'extracted_terms': ['oak'], 'remaining': 'trees'},
#  'animal gut': {'extracted_terms': ['gut'], 'remaining': 'animal'},
#  'fressh fecal of pigs': {'extracted_terms': ['fecal', 'pigs'],
#   'remaining': 'fressh  of'},
#  'green ecosystem': {'extracted_terms': ['stem'], 'remaining': None},
#  'hive reared': {'extracted_terms': ['ear'], 'remaining': None},
#  'gut samples': {'extracted_terms': ['gut'], 'remaining': 'samples'},
#  'hindgut exposed new': {'extracted_terms': ['hindgut'],
#   'remaining': 'exposed new'},
#  'birch': {'extracted_terms': ['birch'], 'remaining': None},
#  'tomato rhizosphere': {'extracted_terms': ['rhizosphere', 'tomato'],
#   'remaining': None},
#  'tree fine root': {'extracted_terms': ['root'], 'remaining': 'tree fine'},
#  'laboratory strain': {'extracted_terms': ['rat'], 'remaining': None},
#  'tongue scraping': {'extracted_terms': ['tongue'], 'remaining': 'scraping'},
#  'bark buds timber needles leaves': {'extracted_terms': ['leaves', 'bark'],
#   'remaining': 'buds timber needles'},
#  'aeration tank': {'extracted_terms': ['rat'], 'remaining': None},
#  'insecta associated habitat': {'extracted_terms': ['insect'],
#   'remaining': None},
#  'plant phyllosphere': {'extracted_terms': ['phyllosphere'],
#   'remaining': 'plant'},
#  'farm feces': {'extracted_terms': ['feces'], 'remaining': 'farm'},
#  'temperate forest biome': {'extracted_terms': ['rat'], 'remaining': None},
#  'ectomycorrhizal root tips': {'extracted_terms': ['root'],
#   'remaining': 'ectomycorrhizal  tips'},
#  'root tissue after experimental manipulation od assembly': {'extracted_terms': ['root'],
#   'remaining': 'tissue after experimental manipulation od assembly'},
#  'tea leaves': {'extracted_terms': ['leaves'], 'remaining': 'tea'},
#  'aquatic formerly temperate forest': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'chicken gut': {'extracted_terms': ['chicken', 'gut'], 'remaining': None},
#  'ileal mucosal contents': {'extracted_terms': ['mucosal'],
#   'remaining': 'ileal  contents'},
#  'caecal mucosal contents': {'extracted_terms': ['mucosal', 'caeca'],
#   'remaining': 'caecal  contents'},
#  'frozen feces': {'extracted_terms': ['feces'], 'remaining': 'frozen'},
#  'avocado rhizosphere': {'extracted_terms': ['rhizosphere'],
#   'remaining': 'avocado'},
#  'mixture of rumen fluid and undigested fiber': {'extracted_terms': ['rumen fluid'],
#   'remaining': 'mixture of  and undigested fiber'},
#  'fish tanks': {'extracted_terms': ['fish'], 'remaining': 'tanks'},
#  'temperate shelf and sea': {'extracted_terms': ['rat'], 'remaining': None},
#  'mouse associated habitat': {'extracted_terms': ['mouse'],
#   'remaining': 'associated habitat'},
#  'honey bee hive': {'extracted_terms': ['honey bee'], 'remaining': 'hive'},
#  'bee bread': {'extracted_terms': ['bee'], 'remaining': 'bread'},
#  'broad leaf forest': {'extracted_terms': ['leaf'],
#   'remaining': 'broad  forest'},
#  'tomato roots': {'extracted_terms': ['tomato', 'roots'], 'remaining': None},
#  'wheat head': {'extracted_terms': ['wheat'], 'remaining': 'head'},
#  'horse feces': {'extracted_terms': ['horse', 'feces'], 'remaining': None},
#  'drosophila adult guts': {'extracted_terms': ['gut'], 'remaining': None},
#  'extreme high temperature habitat': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'fermented soybean product': {'extracted_terms': ['soybean'],
#   'remaining': 'fermented  product'},
#  'bee gut tissue': {'extracted_terms': ['bee', 'gut'], 'remaining': 'tissue'},
#  'honey bee hindgut': {'extracted_terms': ['honey bee', 'hindgut'],
#   'remaining': None},
#  'ruminant gut': {'extracted_terms': ['gut'], 'remaining': 'ruminant'},
#  'root associated fungal community': {'extracted_terms': ['root'],
#   'remaining': 'associated fungal community'},
#  'root nodules': {'extracted_terms': ['root'], 'remaining': 'nodules'},
#  'in vitro biofilm grown from human saliva': {'extracted_terms': ['saliva',
#    'human'],
#   'remaining': 'in vitro biofilm grown from'},
#  'human saliva form healthy human adults': {'extracted_terms': ['saliva',
#    'human'],
#   'remaining': 'form healthy human adults'},
#  'human cell': {'extracted_terms': ['human'], 'remaining': 'cell'},
#  'enrichment culture with jm incubated at â¡ã¦ replicate': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'enrichment culture with jm replicate': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'lab colony started from wild mosquitoes': {'extracted_terms': ['mosquitoes',
#    'colon'],
#   'remaining': 'lab colony started from wild'},
#  'seeding sludge': {'extracted_terms': ['seed'], 'remaining': None},
#  'fish tissue': {'extracted_terms': ['fish'], 'remaining': 'tissue'},
#  'adult insects': {'extracted_terms': ['insects'], 'remaining': 'adult'},
#  'rcirculating aquaculture system': {'extracted_terms': ['stem'],
#   'remaining': None},
#  'rearing water': {'extracted_terms': ['ear'], 'remaining': None},
#  'human nipple aspirate fluid': {'extracted_terms': ['aspirate fluid',
#    'human'],
#   'remaining': 'nipple'},
#  'oil polluted aspen rhizosphere': {'extracted_terms': ['rhizosphere'],
#   'remaining': 'oil polluted aspen'},
#  'aspen rhizosphere associated oil polluted sandy soil': {'extracted_terms': ['rhizosphere'],
#   'remaining': 'aspen  associated oil polluted sandy soil'},
#  'aspen rhizosphere associated oil polluted sandy soilav': {'extracted_terms': ['rhizosphere'],
#   'remaining': 'aspen  associated oil polluted sandy soilav'},
# ...
#   'remaining': 'maxillary sinus'},
#  'with patent maxillary antrostomies': {'extracted_terms': ['axilla'],
#   'remaining': None},
#  'maxillary sinus swab eluent': {'extracted_terms': ['axilla'],
#   'remaining': None},
#  'human nasal cavity': {'extracted_terms': ['nasal cavity', 'human'],
#   'remaining': None},
#  'leaf and root': {'extracted_terms': ['root', 'leaf'], 'remaining': 'and'},
#  'temparate woodland biome': {'extracted_terms': ['rat'], 'remaining': None},
#  'temperate agricultural land': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'maize leaves': {'extracted_terms': ['leaves', 'maize'], 'remaining': None},
#  'microbial biomass from maize leaves': {'extracted_terms': ['leaves',
#    'maize'],
#   'remaining': 'microbial biomass from'},
#  'mouse gut wt c bl': {'extracted_terms': ['mouse', 'gut'],
#   'remaining': 'wt c bl'},
#  'mouse gut rag c bl': {'extracted_terms': ['mouse', 'gut'],
#   'remaining': 'rag c bl'},
#  'panicum virgatum replicate no nitrogen control': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'panicum virgatum replicate mineral fertilizer': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'panicum virgatum replicate intercrop alfalfa': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'pinus pinaster infected with pine wilt disease': {'extracted_terms': ['pine'],
#   'remaining': 'pinus pinaster infected with  wilt disease'},
#  'anearobic bioreactor': {'extracted_terms': ['ear'], 'remaining': None},
#  'human colorectum': {'extracted_terms': ['rectum', 'human'],
#   'remaining': 'colorectum'},
#  'biofilm of cathode': {'extracted_terms': ['cat'], 'remaining': None},
#  'grapevine leaves': {'extracted_terms': ['grapevine', 'leaves'],
#   'remaining': None},
#  'replicate a': {'extracted_terms': ['cat'], 'remaining': None},
#  'replicate b': {'extracted_terms': ['cat'], 'remaining': None},
#  'replicate c': {'extracted_terms': ['cat'], 'remaining': None},
#  'soybean stem': {'extracted_terms': ['soybean', 'stem'], 'remaining': None},
#  'leaf of rice plant': {'extracted_terms': ['rice', 'leaf'],
#   'remaining': 'of  plant'},
#  'rat gut microbiota': {'extracted_terms': ['rat', 'gut'],
#   'remaining': 'microbiota'},
#  'antibiotics effects on gut microbiota': {'extracted_terms': ['gut'],
#   'remaining': 'antibiotics effects on  microbiota'},
#  'spruce budworm midgut': {'extracted_terms': ['spruce', 'midgut'],
#   'remaining': 'budworm'},
#  'spruce budworm reared on synthetic diet number': {'extracted_terms': ['spruce',
#    'ear'],
#   'remaining': 'budworm reared on synthetic diet number'},
#  'spruce budworm collected on balsam fir number': {'extracted_terms': ['spruce'],
#   'remaining': 'budworm collected on balsam fir number'},
#  'spruce budworm collected on black spruce number': {'extracted_terms': ['spruce'],
#   'remaining': 'budworm collected on black spruce number'},
#  'vaginal swab eluate': {'extracted_terms': ['vaginal'],
#   'remaining': 'swab eluate'},
#  'l laboratory scale continuously stirred tank reactors': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'latrine urine exit': {'extracted_terms': ['urine'],
#   'remaining': 'latrine  exit'},
#  'latrine urine exit rep': {'extracted_terms': ['urine'],
#   'remaining': 'latrine  exit rep'},
#  'composting feces with ash': {'extracted_terms': ['feces'],
#   'remaining': 'composting  with ash'},
#  'sewage system': {'extracted_terms': ['stem'], 'remaining': None},
#  'animal feces': {'extracted_terms': ['feces'], 'remaining': 'animal'},
#  'feces sample': {'extracted_terms': ['feces'], 'remaining': 'sample'},
#  'midgut of the stink bug plautia stali': {'extracted_terms': ['midgut'],
#   'remaining': 'of the stink bug plautia stali'},
#  'secondary cooling water system of nuclear reactor': {'extracted_terms': ['stem',
#    'ear'],
#   'remaining': None},
#  'insect associated': {'extracted_terms': ['insect'],
#   'remaining': 'associated'},
#  'barley field': {'extracted_terms': ['barley'], 'remaining': 'field'},
#  'norgen sputum collection': {'extracted_terms': ['sputum'],
#   'remaining': 'norgen  collection'},
#  'southwest national primate research center': {'extracted_terms': ['ear'],
#   'remaining': None},
#  'dna extratced frompa': {'extracted_terms': ['rat'], 'remaining': None},
#  'human microbiome project mock commnuity': {'extracted_terms': ['human'],
#   'remaining': 'microbiome project mock commnuity'},
#  'human lung tissue': {'extracted_terms': ['human', 'lung'],
#   'remaining': 'tissue'},
#  'lung cancer patients': {'extracted_terms': ['lung'],
#   'remaining': 'cancer patients'},
#  'lung tumor tissue': {'extracted_terms': ['lung'],
#   'remaining': 'tumor tissue'},
#  'lung non malignant tissue': {'extracted_terms': ['lung'],
#   'remaining': 'non malignant tissue'},
#  'mongolian fermented mare milk': {'extracted_terms': ['milk'],
#   'remaining': 'mongolian fermented mare'},
#  'bare mudflat location': {'extracted_terms': ['cat'], 'remaining': None},
#  'mature spartina alterniflora location': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'suaeda salsa location': {'extracted_terms': ['cat'], 'remaining': None},
#  'phragmites australis location': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'fecal bacteriome': {'extracted_terms': ['fecal'], 'remaining': 'bacteriome'},
#  'human plasma': {'extracted_terms': ['plasma', 'human'], 'remaining': None},
#  'octocoral': {'extracted_terms': ['coral'], 'remaining': None},
#  'male fish': {'extracted_terms': ['fish'], 'remaining': 'male'},
#  'female fish': {'extracted_terms': ['fish'], 'remaining': 'female'},
#  'driking water system': {'extracted_terms': ['stem'], 'remaining': None},
#  'beef c': {'extracted_terms': ['bee'], 'remaining': None},
#  'chicken c': {'extracted_terms': ['chicken'], 'remaining': 'c'},
#  'citrus orchards': {'extracted_terms': ['citrus'], 'remaining': 'orchards'},
#  'p hindgut compartment': {'extracted_terms': ['hindgut'],
#   'remaining': 'p  compartment'},
#  'cf patient sputum': {'extracted_terms': ['sputum'],
#   'remaining': 'cf patient'},
#  'explanted lung mucus': {'extracted_terms': ['mucus', 'lung'],
#   'remaining': 'explanted'},
#  'cow stable': {'extracted_terms': ['cow'], 'remaining': 'stable'},
#  'ileum content': {'extracted_terms': ['ileum'], 'remaining': 'content'},
#  'mus musculus gut bacteria': {'extracted_terms': ['mus musculus', 'gut'],
#   'remaining': 'bacteria'},
#  'gastro intestine of yakushima macaques': {'extracted_terms': ['intestine'],
#   'remaining': 'gastro  of yakushima macaques'},
#  'wheat heads': {'extracted_terms': ['wheat'], 'remaining': 'heads'},
#  'bee colony': {'extracted_terms': ['colon', 'bee'], 'remaining': 'colony'},
#  'building fish processing': {'extracted_terms': ['fish'],
#   'remaining': 'building  processing'},
#  'skin sample above panniculus': {'extracted_terms': ['skin'],
#   'remaining': 'sample above panniculus'},
#  'skin sample under panniculus': {'extracted_terms': ['skin'],
#   'remaining': 'sample under panniculus'},
#  'rumen biome': {'extracted_terms': ['rumen'], 'remaining': 'biome'},
#  'fiber associated rumen fraction': {'extracted_terms': ['rumen'],
#   'remaining': 'fiber associated  fraction'},
#  'multi year ice': {'extracted_terms': ['ear'], 'remaining': None},
#  'high alpine': {'extracted_terms': ['pine'], 'remaining': None},
#  'osamx system': {'extracted_terms': ['stem'], 'remaining': None},
#  'spontaneously expectorated sputum': {'extracted_terms': ['sputum', 'rat'],
#   'remaining': 'spontaneously expectorated'},
#  'the midgut of the bordered plant bug physopelta gutta': {'extracted_terms': ['midgut',
#    'gut'],
#   'remaining': 'the  of the bordered plant bug physopelta gutta'},
#  'the midgut of the bordered plant bug physopelta parviceps': {'extracted_terms': ['midgut'],
#   'remaining': 'the  of the bordered plant bug physopelta parviceps'},
#  'faecal sample': {'extracted_terms': ['faecal'], 'remaining': 'sample'},
#  'gut feces': {'extracted_terms': ['feces', 'gut'], 'remaining': None},
#  'sugarbeet': {'extracted_terms': ['bee'], 'remaining': None},
#  'cervicovaginal lavage': {'extracted_terms': ['vaginal', 'vagina'],
#   'remaining': None},
#  'agro ecosystem': {'extracted_terms': ['stem'], 'remaining': None},
#  'cave ecosystem': {'extracted_terms': ['stem'], 'remaining': None},
#  'freshwater river system': {'extracted_terms': ['stem'], 'remaining': None},
#  'pig associated habitat': {'extracted_terms': ['pig'],
#   'remaining': 'associated habitat'},
#  'cathode granule read': {'extracted_terms': ['cat'], 'remaining': None},
#  'first airway': {'extracted_terms': ['airway'], 'remaining': 'first'},
#  'second airway': {'extracted_terms': ['airway'], 'remaining': 'second'},
#  'sludge and cattle dung': {'extracted_terms': ['cattle'],
#   'remaining': 'sludge and  dung'},
#  'rootzonesoil': {'extracted_terms': ['root'], 'remaining': None},
#  'oyster reef': {'extracted_terms': ['oyster'], 'remaining': 'reef'},
#  'moderately saline soil': {'extracted_terms': ['rat'], 'remaining': None},
#  'alpine cryosphere': {'extracted_terms': ['pine'], 'remaining': None},
#  'a respiratory tract': {'extracted_terms': ['respiratory tract'],
#   'remaining': 'a'},
#  'human clinical sample': {'extracted_terms': ['human'],
#   'remaining': 'clinical sample'},
#  'paddy field eco system': {'extracted_terms': ['stem'], 'remaining': None},
#  'mid vaginal swab samples': {'extracted_terms': ['vaginal'],
#   'remaining': 'mid  swab samples'},
#  'vaginal mucus': {'extracted_terms': ['vaginal', 'mucus'], 'remaining': None},
#  'human gastric tissue': {'extracted_terms': ['human'],
#   'remaining': 'gastric tissue'},
#  'jejunumob': {'extracted_terms': ['jejunum'], 'remaining': None},
#  'jejunumle': {'extracted_terms': ['jejunum'], 'remaining': None},
#  'ileumob': {'extracted_terms': ['ileum'], 'remaining': None},
#  'ileumle': {'extracted_terms': ['ileum'], 'remaining': None},
#  'cecumob': {'extracted_terms': ['cecum'], 'remaining': None},
#  'cecumle': {'extracted_terms': ['cecum'], 'remaining': None},
#  'oral human associated habitat': {'extracted_terms': ['human'],
#   'remaining': 'oral  associated habitat'},
#  'coral surface mucus layer': {'extracted_terms': ['coral', 'mucus'],
#   'remaining': 'surface  layer'},
#  'camelid milk': {'extracted_terms': ['milk'], 'remaining': 'camelid'},
#  'pooled morning milk herd level': {'extracted_terms': ['milk'],
#   'remaining': 'pooled morning  herd level'},
#  'bovine milk': {'extracted_terms': ['milk'], 'remaining': 'bovine'},
#  'sour milk fermented': {'extracted_terms': ['milk'],
#   'remaining': 'sour  fermented'},
#  'mice feces': {'extracted_terms': ['feces', 'mice'], 'remaining': None},
#  'temperate deciduous forests': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'spinach and chicken': {'extracted_terms': ['chicken'],
#   'remaining': 'spinach and'},
#  'duck cecum': {'extracted_terms': ['cecum'], 'remaining': 'duck'},
#  'marine sponge': {'extracted_terms': ['sponge'], 'remaining': 'marine'},
#  'temperate conifer forest': {'extracted_terms': ['rat'], 'remaining': None},
#  'earth': {'extracted_terms': ['ear'], 'remaining': None},
#  'rhizofiltration system': {'extracted_terms': ['stem', 'rat'],
#   'remaining': None},
#  'the gut feces in piglets control group': {'extracted_terms': ['feces',
#    'pig',
#    'gut'],
#   'remaining': 'the   in piglets control group'},
#  'the gut feces in piglets treatment group': {'extracted_terms': ['feces',
#    'pig',
#    'gut'],
#   'remaining': 'the   in piglets treatment group'},
#  'human sputum subject': {'extracted_terms': ['sputum', 'human'],
#   'remaining': 'subject'},
#  'sputum subject': {'extracted_terms': ['sputum'], 'remaining': 'subject'},
#  'anaerobic community in v v and sodium nitrate with sodium acetate': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'insect cadaver': {'extracted_terms': ['insect'], 'remaining': 'cadaver'},
#  'human lower gi tract': {'extracted_terms': ['human'],
#   'remaining': 'lower gi tract'},
#  'torso skin': {'extracted_terms': ['skin'], 'remaining': 'torso'},
#  'swine colon': {'extracted_terms': ['swine', 'colon'], 'remaining': None},
#  'picea abies forest': {'extracted_terms': ['picea abies'],
#   'remaining': 'forest'},
#  'photo autotrophic bioreactor operating under feast famine conditions': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'panda gut': {'extracted_terms': ['gut'], 'remaining': 'panda'},
#  'water buffalo feces': {'extracted_terms': ['feces'],
#   'remaining': 'water buffalo'},
#  'anoxic rice field': {'extracted_terms': ['rice'],
#   'remaining': 'anoxic  field'},
#  'temperate region': {'extracted_terms': ['rat'], 'remaining': None},
#  'oak forest': {'extracted_terms': ['oak'], 'remaining': 'forest'},
#  'marine aquaculture system': {'extracted_terms': ['stem'], 'remaining': None},
#  'laboratory based incubation study': {'extracted_terms': ['rat'],
#   'remaining': None},
#  'sponge iron': {'extracted_terms': ['sponge'], 'remaining': 'iron'},
#  'lower airway': {'extracted_terms': ['airway'], 'remaining': 'lower'},
#  'infant gut': {'extracted_terms': ['gut'], 'remaining': 'infant'},
#  'human associated environment': {'extracted_terms': ['human'],
#   'remaining': 'associated environment'},
#  'human oral wash': {'extracted_terms': ['human'], 'remaining': 'oral wash'},
#  'human tongue dorsum swab': {'extracted_terms': ['tongue', 'human'],
#   'remaining': 'dorsum swab'},
#  'human hard palate swab': {'extracted_terms': ['human'],
#   'remaining': 'hard palate swab'},
#  'human buccal mucosa swab': {'extracted_terms': ['mucosa', 'human'],
#   'remaining': 'buccal  swab'},
#  'human keratinized gingiva swab': {'extracted_terms': ['human', 'rat'],
#   'remaining': 'keratinized gingiva swab'},
#  'human palatine tonsils swab': {'extracted_terms': ['tonsil', 'human'],
#   'remaining': 'palatine tonsils swab'},
#  'human supragingival plaque scrape': {'extracted_terms': ['supragingival plaque',
#    'human'],
#   'remaining': 'scrape'},
#  'human anteior nares swab from both sides': {'extracted_terms': ['human',
#    'nares'],
#   'remaining': 'anteior  swab from both sides'},
#  'corn fields': {'extracted_terms': ['corn'], 'remaining': 'fields'},
#  'leaf plant': {'extracted_terms': ['leaf'], 'remaining': 'plant'},
#  'rectum id etec day': {'extracted_terms': ['rectum'],
#   'remaining': 'id etec day'},
#  'rectum id sham day': {'extracted_terms': ['rectum'],
#   'remaining': 'id sham day'},
#  'insect associated bacteria': {'extracted_terms': ['insect'],
#   'remaining': 'associated bacteria'},
#  'insect microbial community': {'extracted_terms': ['insect'],
#   'remaining': 'microbial community'},
#  'endoglacial sediment': {'extracted_terms': ['dog'], 'remaining': None},
#  'alpine shrub': {'extracted_terms': ['pine'], 'remaining': None},
#  'canna indica aeration': {'extracted_terms': ['rat'], 'remaining': None},
#  'insect whole body': {'extracted_terms': ['insect'],
#   'remaining': 'whole body'},
#  'bacteria associated with laboratory reared emerald ash borer': {'extracted_terms': ['rat',
#    'ear'],
#   'remaining': None},
#  'vaginal secretions': {'extracted_terms': ['vaginal'],
#   'remaining': 'secretions'},
#  'lung fluid sheep': {'extracted_terms': ['sheep', 'lung'],
#   'remaining': 'fluid'},
#  'throat swab sheep': {'extracted_terms': ['sheep'],
#   'remaining': 'throat swab'},
#  'enviromental system': {'extracted_terms': ['stem'], 'remaining': None},
#  'mosquito larvae': {'extracted_terms': ['mosquito'], 'remaining': 'larvae'},
#  'cathode': {'extracted_terms': ['cat'], 'remaining': None},
#  'shallow sea hydrothermal system': {'extracted_terms': ['stem'],
#   'remaining': None},
#  'cells grown without treatment replicate biological replicate': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'cell exposed to so treatment replicate biological replicate': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'cells recovered after the removal of so from the medium replicate biological replicate': {'extracted_terms': ['cat'],
#   'remaining': None},
#  'environnemental system': {'extracted_terms': ['stem'], 'remaining': None},
#  'earthworm cocoon': {'extracted_terms': ['earthworm'], 'remaining': 'cocoon'},
#  'agroecosystems': {'extracted_terms': ['stems', 'stem'], 'remaining': None},
#  'tomato root': {'extracted_terms': ['tomato', 'root'], 'remaining': None},
#  ...}

# %%
def accumulate_extracted_terms(extraction_dict):
    accumulated_set = set()

    for key, value in extraction_dict.items():
        accumulated_set.update(value["extracted_terms"])
        remaining = value["remaining"]
        # if remaining and remaining.strip() and remaining.lower() != key.lower():
        #     accumulated_set.add(remaining)

    return accumulated_set

# %%
unique_extractions = accumulate_extracted_terms(organisms_anatomy_components_extracted)

# %%
len(unique_extractions)
# Out:
# 234

# %%
unique_extractions
# Out:
# {'acropora palmata',
#  'agrostis capillaris',
#  'airway',
#  'airways',
#  'amniotic fluid',
#  'antecubital fossa',
#  'anterior nares',
#  'apis cerana',
#  'apis mellifera',
#  'apple',
#  'apples',
#  'arthropod',
#  'ascites',
#  'asian hornet',
#  'aspirate fluid',
#  'aurelia aurita',
#  'axilla',
#  'bark',
#  'barley',
#  'bee',
#  'beech',
#  'bees',
#  'beetle',
#  'betula pendula',
#  'bile',
#  'birch',
#  'bird',
#  'birds',
#  'blood',
#  'blueberry',
#  'bos indicus',
#  'bos taurus',
#  'brachypodium distachyon',
#  'brain',
#  'breastmilk',
#  'bumblebee',
#  'caeca',
#  'caecum',
#  'canine',
#  'cat',
#  'cattle',
#  'cecum',
#  'ceratophyllum demersum',
#  'cerebrospinal fluid',
#  'cervical',
#  'cervicovaginal fluid',
#  'cervicovaginal secretion',
#  'cervicovaginal secretions',
#  'cervix',
#  'cervus canadensis nelsoni',
#  'channel island fox',
#  'cheetah',
#  'chicken',
#  'chickens',
#  'citrus',
#  'colon',
#  'coral',
#  'corals',
#  'corn',
#  'coronal sulcus',
#  'cotton',
#  'cotton rat',
#  'cow',
#  'cows',
#  'daphnia magna',
#  'deer',
#  'digestive tract',
#  'dog',
#  'ear',
#  'ears',
#  'earthworm',
#  'earthworms',
#  'endosphere',
#  'epithelial cells',
#  'equine',
#  'external auditory canal',
#  'eye',
#  'faecal',
#  'faeces',
#  'fagus sylvatica',
#  'fecal',
#  'feces',
#  'feline',
#  'festuca rubra',
#  'fingertips',
#  'fish',
#  'fishes',
#  'gallus gallus domesticus',
#  'gastrointestinal tract',
#  'gingival crevicular fluid',
#  'gingival sulcus',
#  'grapevine',
#  'groin',
#  'gut',
#  'hair',
#  'hindgut',
#  'holcus lanatus',
#  'homo sapiens',
#  'honey bee',
#  'hordeum vulgare',
#  'horse',
#  'horses',
#  'human',
#  'ileum',
#  'inguinal',
#  'insect',
#  'insects',
#  'intestinal lumen',
#  'intestinal tract',
#  'intestine',
#  'intestines',
#  'jejunum',
#  'kiwifruit',
#  'lavage fluid',
#  'leaf',
#  'leaves',
#  'lettuce',
#  'lipoptena cervi',
#  'lorikeet',
#  'lung',
#  'lungs',
#  'maize',
#  'mammalia',
#  'meriones unguiculatus',
#  'mice',
#  'middle meatus',
#  'midgut',
#  'milk',
#  'mosquito',
#  'mosquitoes',
#  'mouse',
#  'mouth',
#  'mucosa',
#  'mucosal',
#  'mucus',
#  'mule deer',
#  'mus musculus',
#  'nare',
#  'nares',
#  'nasal cavity',
#  'nasopharynx',
#  'nose',
#  'oak',
#  'oaks',
#  'oncorhynchus mykiss',
#  'oral cavity',
#  'oropharynx',
#  'oryza sativa',
#  'ovis aries',
#  'oyster',
#  'oysters',
#  'penguin',
#  'peritoneal fluid',
#  'periurethral',
#  'phaeocystis globosa',
#  'phyllosphere',
#  'picea abies',
#  'pig',
#  'pigs',
#  'pika',
#  'pine',
#  'pines',
#  'pinus sylvestris',
#  'placenta',
#  'plantar aspect',
#  'plaque biofilm',
#  'plasma',
#  'posterior fornix',
#  'potato',
#  'potatoes',
#  'prorocentrum lima',
#  'prostate',
#  'pseudotsuga menziesii',
#  'quercus robur',
#  'rat',
#  'rats',
#  'rattus norvegicus',
#  'rectum',
#  'respiratory tract',
#  'retroauricular crease',
#  'rhizoplane',
#  'rhizosphere',
#  'rice',
#  'root',
#  'roots',
#  'rumen',
#  'rumen fluid',
#  'rumen papillae',
#  'saliva',
#  'salmo salar',
#  'salmon',
#  'sargassum hemiphyllum',
#  'scalp',
#  'seed',
#  'seeds',
#  'sheep',
#  'shelfordella lateralis',
#  'shrimp',
#  'skin',
#  'soybean',
#  'soybeans',
#  'sponge',
#  'sponges',
#  'spruce',
#  'sputum',
#  'stem',
#  'stems',
#  'stomach',
#  'subgingival plaque',
#  'supragingival plaque',
#  'sus scrofa',
#  'sweat',
#  'swine',
#  'tear',
#  'teeth',
#  'tick',
#  'ticks',
#  'toe web',
#  'tomato',
#  'tongue',
#  'tonsil',
#  'tooth',
#  'trachea',
#  'trout',
#  'urinary tract',
#  'urine',
#  'vagina',
#  'vaginal',
#  'vaginal fluid',
#  'villi',
#  'vole',
#  'wasp',
#  'wheat',
#  'wound fluid'}

# %% [markdown]
# these labels arent' necessarily the real labels of the terms

# %%
observed_cache = db["observed_cache"]

# %%
# Ensure the index on curie field for fast lookup
observed_cache.create_index("curie", unique=True)
# Out:
# 'curie_1'

# %%
# Iterate through documents in triad_components_labels_collection
for doc in triad_components_labels_collection.find({}, {"ols_hits": 1}):
    if "ols_hits" in doc and isinstance(doc["ols_hits"], list):
        for ols_hit in doc["ols_hits"]:
            obo_id = ols_hit.get("obo_id")
            label = ols_hit.get("label")

            if obo_id and label:
                # Check if the curie already exists in observed_validated
                if not observed_cache.find_one({"curie": obo_id}):
                    # Insert new document
                    observed_cache.insert_one({"curie": obo_id, "label": label})

# %%
# Iterate through documents in triad_components_labels_collection
for doc in curie_curations_collection.find({}):
    if "curie" in doc and "bioportal_label" in doc:
        if not observed_cache.find_one({"curie": doc['curie']}):
            # Insert new document
            observed_cache.insert_one({"curie": doc['curie'], "label": doc['bioportal_label']})
