# %%
import folium
import pandas as pd

# %%
# input_tsv = "stream_bank_riparian/stream_bank_riparian.tsv"
# output_html="stream_bank_riparian/stream_bank_riparian.html"

input_tsv = "emp_500_ng/MacRae-Crerar/macrae_crerar_attributes.tsv"
output_html="emp_500_ng/MacRae-Crerar/macrae_crerar.html"

# %%
# lat_col = "lat"
# lon_col = "lon"
# id_col = "sample name"
# category_col = "category"

lat_col = "latitude_decimal"
lon_col = "longitude_decimal"
id_col = "accession"
category_col = "cluster"

# %%
df = pd.read_csv(input_tsv, sep="\t")

# %%
# Get unique categories from the category column
categories = df[category_col].unique()

# %%
# Define a basic list of colors (extend it if necessary)
color_list = ['red', 'green', 'blue', 'orange', 'purple',  'yellow']

# Map each category to a color by cycling through the color_list
category_colors = {category: color_list[i % len(color_list)] for i, category in enumerate(categories)}

# %% [markdown]
# - 'OpenStreetMap' (default)
# - 'Mapbox Bright'
# - 'Esri WorldImagery'

# %%
# Create a folium map centered around the average latitude and longitude using OpenStreetMap
map_center = [df[lat_col].mean(), df[lon_col].mean()]
mymap = folium.Map(location=map_center, zoom_start=10, tiles='OpenStreetMap')

# %%
# Add markers with color based on the category
for _, row in df.iterrows():
    folium.Marker(
        location=[row[lat_col], row[lon_col]],
        popup=row[id_col],  # Show sample name in popup
        icon=folium.Icon(color=category_colors.get(row[category_col], 'gray'))  # Default to gray if category is not found
    ).add_to(mymap)

# %%
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbff7d29843911d91b181713c6d93a97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbff7d29843911d91b181713c6d93a97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbff7d29843911d91b181713c6d93a97 = L.map(
#                 &quot;map_fbff7d29843911d91b181713c6d93a97&quot;,
#                 {
#                     center: [51.177037037037046, 100.96194444444443],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e48e8fd324e95bc0666bbe0a93ee38d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e48e8fd324e95bc0666bbe0a93ee38d8.addTo(map_fbff7d29843911d91b181713c6d93a97);
#
#
#             var marker_c3fd0f6e1d8b20f0b9e0505d5e03c49d = L.marker(
#                 [51.199444444444445, 100.92861111111112],
#                 {
# }
#             ).addTo(map_fbff7d29843911d91b181713c6d93a97);
#
#
#             var icon_cdedcbe2cc163c39cd3907860f4611c2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_c3fd0f6e1d8b20f0b9e0505d5e03c49d.setIcon(icon_cdedcbe2cc163c39cd3907860f4611c2);
#
#
#         var popup_1f68cd149420217a7dbf7dfdab26fbd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b70245f6b8a97553260bce27472130e = $(`&lt;div id=&quot;html_6b70245f6b8a97553260bce27472130e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SAMEA7724107&lt;/div&gt;`)[0];
#                 popup_1f68cd149420217a7dbf7dfdab26fbd9.setContent(html_6b70245f6b8a97553260bce27472130e);
#
#
#
#         marker_c3fd0f6e1d8b20f0b9e0505d5e03c49d.bindPopup(popup_1f68cd149420217a7dbf7dfdab26fbd9)
#         ;
#
#
#
#
#             var marker_3dfdc6deb2331a15776f0b003ec46fa1 = L.marker(
#                 [51.199444444444445, 100.92861111111112],
#                 {
# }
#             ).addTo(map_fbff7d29843911d91b181713c6d93a97);
#
#
#             var icon_7d5c4c4a617942224194581d41c57c73 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_3dfdc6deb2331a15776f0b003ec46fa1.setIcon(icon_7d5c4c4a617942224194581d41c57c73);
#
#
#         var popup_4b1b346ff2666a511819ef3d7dc51108 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50c307db68be89fff6bf13737b439f7e = $(`&lt;div id=&quot;html_50c307db68be89fff6bf13737b439f7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SAMEA7724108&lt;/div&gt;`)[0];
#                 popup_4b1b346ff2666a511819ef3d7dc51108.setContent(html_50c307db68be89fff6bf13737b439f7e);
#
#
#
#         marker_3dfdc6deb2331a15776f0b003ec46fa1.bindPopup(popup_4b1b346ff2666a511819ef3d7dc51108)
#         ;
#
#
#
#
#             var marker_eeaa988c60de66fcf7de2e2b91b0228b = L.marker(
#                 [51.199444444444445, 100.92861111111112],
#                 {
# }
#             ).addTo(map_fbff7d29843911d91b181713c6d93a97);
#
#
#             var icon_4dc4cd46638cf4210cecb31fe1bf2cb3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_eeaa988c60de66fcf7de2e2b91b0228b.setIcon(icon_4dc4cd46638cf4210cecb31fe1bf2cb3);
#
#
#         var popup_191fa16f2fbf65b4adc33d1d8503b151 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a973a959dc4869160326aa3b2addf874 = $(`&lt;div id=&quot;html_a973a959dc4869160326aa3b2addf874&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SAMEA7724109&lt;/div&gt;`)[0];
#                 popup_191fa16f2fbf65b4adc33d1d8503b151.setContent(html_a973a959dc4869160326aa3b2addf874);
#
#
#
#         marker_eeaa988c60de66fcf7de2e2b91b0228b.bindPopup(popup_191fa16f2fbf65b4adc33d1d8503b151)
#         ;
#
#
#
#
#             var marker_5268af011727bbcf079d69776f4fc1c4 = L.marker(
#                 [51.199444444444445, 100.92861111111112],
#                 {
# }
#             ).addTo(map_fbff7d29843911d91b181713c6d93a97);
#
#
#             var icon_3e1935391a8e51cde3172169a8503e17 = L.

# %%
mymap.save(output_html)
