# %%
from linkml_runtime import SchemaView
import pprint
import pandas as pd
from jsonasobj2 import as_dict

# %%
schema_url = "https://raw.githubusercontent.com/microbiomedata/nmdc-schema/refs/heads/main/nmdc_schema/nmdc_materialized_patterns.yaml"

# %%
schema_view = SchemaView(schema_url)

# %%
class_names = list(schema_view.all_classes().keys())

# %%
class_names.sort()

# %%
report = []

# %%
for c_name in class_names:
    ic = schema_view.induced_class(c_name)
    slot_names = list(ic.attributes.keys())
    slot_names.sort()
    for slot_name in slot_names:
        ica = ic.attributes[slot_name]
        ica_dict = ica.__dict__
        temp_dict = {
            "class": c_name,
            "slot": slot_name,
        }
        for k, v in ica_dict.items():
            if v and k not in [
                'alias',  # done: only interesting if different from key/name
                'annotations', # done
                'any_of',  # done. just __repr__ flatten
                'domain_of',  # done. definitely leave out
                'examples',  # done
                'from_schema',  # done. definitely leave out
                'name',  # done. definitely leave out
                'owner',  # done. definitely leave out
                'structured_pattern',  # done
                'structured_aliases',  # maybe there's a better way to handle this than just a .__repr__
            ]:
                if isinstance(v, list):
                    if all(isinstance(item, str) for item in v):
                        stringified = '|'.join(v)
                    else:
                        stringified = '|'.join(repr(item) for item in v)
                else:
                    stringified = v
                temp_dict[k] = stringified

            if v and k == 'alias' and v != slot_name:
                temp_dict['alias'] = v

            if v and k == 'structured_pattern':
                temp_dict['structured_pattern.syntax'] = v.syntax
                if not v.interpolated:
                    print(f"{c_name}.{slot_name}.structured_pattern is not interpolated")
                if v.partial_match:
                    print(f"{c_name}.{slot_name}.structured_pattern is set as partial match TRUE")
                sp_dict_keys = set(v.__dict__.keys())
                for i in sp_dict_keys:
                    if v[i] and i not in [
                        'syntax',
                        'interpolated',
                        'partial_match',
                    ]:
                        print(f"{c_name}.{slot_name}.structured_pattern has unexpected field {i}")

            if v and k == 'any_of':
                temp_dict['any_of'] = v.__repr__()

            if v and k == 'structured_aliases':
                temp_dict['structured_aliases'] = v.__repr__()

            example_values = []

            if v and k == 'examples':
                for example in v:
                    if example.value:
                        example_values.append(example.value)
                        if example.description:
                            print(
                                f"{c_name}.{slot_name}.examples with value {example.value} has description: {example.description}")
                            pass
                example_values = "|".join(example_values)
                temp_dict['example_values'] = example_values

        anndict = as_dict(ica.annotations)
        for anndictk, anndictv in anndict.items():
            temp_dict[f"annotation_{anndictk}"] = anndictv['value']

        report.append(temp_dict)
# Out:
# Biosample.bulk_elect_conductivity.examples with value JsonObj(has_raw_value='0.017 mS/cm', has_numeric_value=0.017, has_unit='mS/cm') has description: The conductivity measurement was 0.017 millisiemens per centimeter.
# Biosample.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Biosample.insdc_biosample_identifiers.examples with value https://bioregistry.io/biosample:SAMD00212331 has description: I13_N_5-10 sample from Soil fungal diversity along elevational gradients
# CalibrationInformation.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# ChemicalConversionProcess.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# ChemicalEntity.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# ChromatographicSeparationProcess.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# ChromatographicSeparationProcess.id.structured_pattern is not interpolated
# ChromatographyConfiguration.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# CollectingBiosamplesFromSite.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Configuration.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# DataGeneration.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# DataObject.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# DissolvingProcess.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Doi.doi_category.examples with value dataset_doi has description: The corresponding DOI is a dataset resource type.
# Doi.doi_provider.examples with value ess_dive has description: The corresponding DOI is associated with ESS-DIVE.
# Doi.doi_value.examples with value doi:10.46936/10.25585/60000880 has description: The DOI links to an electronic document.
# EnvironmentalMaterialTerm.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Extraction.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# FieldResearchSite.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# FiltrationProcess.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# FunctionalAnnotationTerm.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# GeneProduct.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# InformationObject.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Instrument.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# LibraryPreparation.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MagsAnalysis.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Manifest.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Manifest.id.structured_pattern is not interpolated
# MassSpectrometry.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MassSpectrometryConfiguration.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MaterialEntity.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MaterialProcessing.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MetabolomicsAnalysis.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MetagenomeAnnotation.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MetagenomeAssembly.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MetagenomeSequencing.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MetaproteomicsAnalysis.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MetatranscriptomeAnnotation.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MetatranscriptomeAssembly.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MetatranscriptomeExpressionAnalysis.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MixingProcess.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# MixingProcess.id.structured_pattern is not interpolated
# NamedThing.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# NomAnalysis.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# NucleotideSequencing.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# NucleotideSequencing.insdc_bioproject_identifiers.examples with value https://bioregistry.io/bioproject:PRJNA366857 has description: Avena fatua rhizosphere microbial communities - H1_Rhizo_Litter_2 metatranscriptome
# OntologyClass.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# OrthologyGroup.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Pathway.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# PlannedProcess.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Pooling.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# ProcessedSample.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# ReadBasedTaxonomyAnalysis.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# ReadQcAnalysis.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Sample.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Site.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# StorageProcess.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Study.associated_dois.examples with value [{'doi': 'doi:10.46936/intm.proj.2021.60141/60000423', 'doi_provider': 'emsl', 'doi_category': 'award_doi'}, {'doi': 'doi:10.1101/2022.12.12.520098', 'doi_category': 'publication_doi'}, {'doi': 'doi:10.48321/D1Z60Q', 'doi_category': 'data_management_plan_doi', 'doi_provider': 'gsc'}] has description: Provides a list of two DOIs; specifically, an EMSL award DOI and a publication DOI.
# Study.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# Study.insdc_bioproject_identifiers.examples with value https://bioregistry.io/bioproject:PRJNA366857 has description: Avena fatua rhizosphere microbial communities - H1_Rhizo_Litter_2 metatranscriptome
# SubSamplingProcess.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248
# WorkflowExecution.id.examples with value nmdc:mgmag-00-x012.1_7_c1 has description: https://github.com/microbiomedata/nmdc-schema/pull/499#discussion_r1018499248

# %%
report_frame = pd.DataFrame(report)

# %%
initial_columns = [
    'class',
    'slot',
]

# %%
all_column_names = set(report_frame.columns)

# %%
sorted_column_names = list(all_column_names - set(initial_columns))

# %%
sorted_column_names.sort()

# %%
reunited_column_names = initial_columns + sorted_column_names

# %%
report_frame = report_frame[reunited_column_names]

# %%
report_frame.drop_duplicates(inplace=True)

# %%
report_frame
# Out:
#                   class              slot abstract alias  \
# 0        AttributeValue     has_raw_value      NaN   NaN
# 1        AttributeValue              type      NaN   NaN
# 2             Biosample  abs_air_humidity      NaN   NaN
# 3             Biosample          add_date      NaN   NaN
# 4             Biosample  add_recov_method      NaN   NaN
# ...                 ...               ...      ...   ...
# 1561  WorkflowExecution        start_date      NaN   NaN
# 1562  WorkflowExecution   started_at_time      NaN   NaN
# 1563  WorkflowExecution              type      NaN   NaN
# 1564  WorkflowExecution           version      NaN   NaN
# 1565  WorkflowExecution   was_informed_by      NaN   NaN
#
#                                                 aliases  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                 absolute air humidity
# 3                                                   NaN
# 4     secondary and tertiary recovery methods and st...
# ...                                                 ...
# 1561                                                NaN
# 1562                                                NaN
# 1563                                                NaN
# 1564                                                NaN
# 1565                                                NaN
#
#      annotation_expected_value annotation_occurrence  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# 2            measurement value                     1
# 3                          NaN                   NaN
# 4        enumeration;timestamp                     1
# ...                        ...                   ...
# 1561                       NaN                   NaN
# 1562                       NaN                   NaN
# 1563                       NaN                   NaN
# 1564                       NaN                   NaN
# 1565                       NaN                   NaN
#
#                               annotation_preferred_unit annotation_tooltip  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2     gram per gram, kilogram per kilogram, kilogram...                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN                NaN
# ...                                                 ...                ...
# 1561                                                NaN                NaN
# 1562                                                NaN                NaN
# 1563                                                NaN                NaN
# 1564                                                NaN                NaN
# 1565                                                NaN                NaN
#
#      any_of  ... recommended required  \
# 0       NaN  ...         NaN      NaN
# 1       NaN  ...         NaN     True
# 2       NaN  ...         NaN      NaN
# 3       NaN  ...         NaN      NaN
# 4       NaN  ...         NaN      NaN
# ...     ...  ...         ...      ...
# 1561    NaN  ...         NaN      NaN
# 1562    NaN  ...         NaN     True
# 1563    NaN  ...         NaN     True
# 1564    NaN  ...         NaN      NaN
# 1565    NaN  ...         NaN     True
#
#                                                see_also slot_group  \
# 0                                                   NaN        NaN
# 1     https://github.com/microbiomedata/nmdc-schema/...        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
# ...                                                 ...        ...
# 1561                                                NaN        NaN
# 1562                                                NaN        NaN
# 1563  https://github.com/microbiomedata/nmdc-schema/...        NaN
# 1564                                                NaN        NaN
# 1565                                                NaN        NaN
#
#           slot_uri string_serialization  \
# 0              NaN                  NaN
# 1         rdf:type                  NaN
# 2     MIXS:0000122                  NaN
# 3              NaN                  NaN
# 4     MIXS:0001009                  NaN
# ...            ...                  ...
# 1561           NaN                  NaN
# 1562           NaN                  NaN
# 1563      rdf:type                  NaN
# 1564           NaN                  NaN
# 1565           NaN                  NaN
#
#                                      structured_aliases  \
# 0                                                   NaN
# 1     JsonObj(workflow_execution_class=StructuredAli...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1561                                                NaN
# 1562                                                NaN
# 1563  JsonObj(workflow_execution_class=StructuredAli...
# 1564                                                NaN
# 1565  JsonObj(was_informed_by=StructuredAlias({\n  '...
#
#      structured_pattern.syntax  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 1561                       NaN
# 1562                       NaN
# 1563                       NaN
# 1564                       NaN
# 1565                       NaN
#
#                                                   title  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                 absolute air humidity
# 3                                                   NaN
# 4     secondary and tertiary recovery methods and st...
# ...                                                 ...
# 1561                                                NaN
# 1562                                                NaN
# 1563                                                NaN
# 1564                                                NaN
# 1565                                                NaN
#
#                                    todos
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 1561  add date string validation pattern
# 1562                                 NaN
# 1563                                 NaN
# 1564                                 NaN
# 1565                                 NaN
#
# [1566 rows x 46 columns]

# %%
report_frame.to_csv("nmdc_schema_flattening.tsv")
